# %% [markdown]
# # BHSA and OSM: comparison on part-of-speech
#
# We will investigate how the morphology marked up in the OSM corresponds and differs from the BHSA linguistic features.
#
# In this notebook we investigate the markup of *part-of-speech*.
#
# We use the `osm` and `osm_sf` features compiled by the
# [BHSAbridgeOSM notebook](BHSAbridgeOSM.ipynb).

# %%
import os
import operator
import collections
from functools import reduce

from tf.fabric import Fabric
from utils import show

# %% [markdown]
# # Load data
# We load the BHSA data in the standard way, and we add the OSM data as a module of the features `osm` and `osm_sf`.
# Note that we only need to point TF to the right directories, and then we can load all features
# that are present in those directories.

# %%
BHSA = 'BHSA/tf/2017'
OSM = 'bridging/tf/2017'

TF = Fabric(locations='~/github/etcbc', modules=[BHSA, OSM])
api = TF.load('''
    sp pdp
    lex voc_lex_utf8 freq_lex
    gloss
    osm osm_sf
    g_word_utf8
''')
api.makeAvailableIn(globals())
# Out:
# This is Text-Fabric 3.1.1
# Api reference : https://github.com/Dans-labs/text-fabric/wiki/Api
# Tutorial      : https://github.com/Dans-labs/text-fabric/blob/master/docs/tutorial.ipynb
# Example data  : https://github.com/Dans-labs/text-fabric-data
#
# 117 features found and 0 ignored
#   0.00s loading features ...
#    |     0.21s B g_word_utf8          from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.13s B sp                   from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.14s B pdp                  from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.14s B lex                  from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.01s B voc_lex_utf8         from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.11s B freq_lex             from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.01s B gloss                from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.14s B osm                  from /Users/dirk/github/etcbc/bridging/tf/2017
#    |     0.02s B osm_sf               from /Users/dirk/github/etcbc/bridging/tf/2017
#    |     0.00s Feature overview: 111 for nodes; 5 for edges; 1 configs; 7 computed
#   5.19s All features loaded/computed - for details use loadLog()

# %% [markdown]
# # Part of speech
#
# The BHSA has two features for part-of-speech:
# [sp](https://etcbc.github.io/bhsa/features/hebrew/2017/sp)
# and
# [pdp](https://etcbc.github.io/bhsa/features/hebrew/2017/pdp).
#
# The first one, `sp`, is lexical part of speech, a context-insensitve assignment of part-of-speech labels to
# occurrences of lexemes.
#
# The second one, `pdp`, is *phrase dependent part of speech*. This assignment is sensitive to
# cases where adjectives are used as noun, nouns as prepositions, etc.
#
# A preliminary check has revealed that the OSM part-of-speech is resembles `sp` more than `pdp`, so
# we stick to `sp`.
#
# The OSM has part-of-speech as the second letter of the morph string.
# See [here](http://openscriptures.github.io/morphhb/parsing/HebrewMorphologyCodes.html).
#
# The BHSA makes a few more distinctions in its [sp](https://etcbc.github.io/bhsa/features/hebrew/2017/sp) feature,
# so we map the OSM values to sets of BHSA values.
#
# But the OSM has a subclassification of particles (`T`) that we should use.
#
# One of the OSM values is `S` (suffix).
# The BHSA has no counterpart for this, but we expect that all morph strings in the `osm_sf` features will show
# the `S`.
#
# We'll test that as well.

# %% [markdown]
# Here is the default mapping between OSM part-of-speech and BHSA part-of-speech.
#
# We'll see later that this results in many discrepancies.
#
# We'll analyze the discrepancies, and try to overcome them by making lexeme-dependent exceptions to these rules.
#
# It turns out that we need a few dozen lexeme-based exception rules and we'll have nearly 1000
# left-over cases that merit closer inspection.

# %%
particleTypes = dict(
    a='affirmation',
    d='definite article',
    e='exhortation',
    i='interrogative',
    j='interjection',
    m='demonstrative',
    n='negative',
    o='direct object marker',
    r='relative',
)

# %%
pspBhsFromOsm = {
    'A': {'adjv'}, # adjective
    'C': {'conj'}, # conjunction
    'D': {'advb'}, # adverb
    'N': {'subs', 'nmpr'}, # noun
    'P': {'prps', 'prde'}, # pronoun
    'R': {'prep'}, # preposition 
    'S': {'_suffix_'}, # suffix
    'Ta': {'advb'},
    'Td': {'art'},
    'Te': {'intj'},
    'Ti': {'prin', 'inrg'},
    'Tj': {'intj'},
    'Tm': {'intj', 'advb'},
    'Tn': {'nega'},
    'To': {'prep'}, # object marker
    'Tr': {'conj'}, # relative
    'T': {'intj'},
    'V': {'verb'}, # verb
    '×': set(), # no morphology
}

# %% [markdown]
# Just for ease of processing, we make a mapping from slots to OSM part-of-speech.
#
# We assign `×` slot `w` if there is no valid OSM part-of-speech label available for `w`.

# %%
osmPsp = {}
noPsp = 0
for w in F.otype.s('word'):
    osm = F.osm.v(w)
    if osm == None or osm == '' or osm == '*' or len(osm) < 2:
        psp = '×'
        noPsp += 1
    else:
        psp = osm[1]
        if psp == 'T':
            psp = osm[1:3]
    osmPsp[w] = psp 

allPsp = len(osmPsp)
withPsp = allPsp - noPsp
print('''{} BHSA words:
    having  OSM part of speech: {:>3}% = {:>6}
    without OSM part of speech: {:>3}% = {:>6}
'''.format(
    F.otype.maxSlot,
    round(100 * withPsp / allPsp),
    withPsp,
    round(100 * noPsp / allPsp),
    noPsp,
))
# Out:
# 426584 BHSA words:
#     having  OSM part of speech:  87% = 372636
#     without OSM part of speech:  13% =  53948

# %% [markdown]
# We organize the osm-bhs combinations that show up in the text in several ways.
#
# `psp` is keyed by: osm, bhs, lexeme node.
#
# `pspLex` is keyed by: lexeme node, osm, bhs, and then contains a list of slots where this combination occurs.
#
# Both mappings contains a list of slots where the combinations occur.

# %%
psp = {}
pspLex = {}
for lx in F.otype.s('lex'):
    ws = L.d(lx, otype='word')
    for w in ws:
        osm = osmPsp[w]
        bhs = F.sp.v(w)
        psp.setdefault(osm, {}).setdefault(bhs, {}).setdefault(lx, set()).add(w)
        pspLex.setdefault(lx, {}).setdefault(osm, {}).setdefault(bhs, set()).add(w)

# %% [markdown]
# For each osm-bhs combination, we want to see how many lexemes and how many occurrences have that combination.

# %%
pspCount = {}
for (osm, osmData) in psp.items():
    for (bhs, bhsData) in osmData.items():
        nlex = len(bhsData)
        noccs = reduce(operator.add, (len(x) for x in bhsData.values()), 0)
        pspCount.setdefault(osm, {})[bhs] = (nlex, noccs)

# %% [markdown]
# Now we are going to present an overview of osm-bhs combinations.
#
# We mark a combination with `OK` if the combination is according to the default OSM-BHS mapping.
#
# We use the mark `*` if there is no OSM part-of-speech available.
#
# Otherwise we mark it with a `?`.

# %%
mismatches = []
for osm in pspCount:
    print(osm)
    totalOccs = sum(x[1] for x in pspCount[osm].values())
    for (bhs, (nlex, noccs)) in sorted(pspCount[osm].items(), key=lambda x: (-x[1][1], -x[1][0], x[0])):
        perc = round(100 * noccs / totalOccs)
        status = bhs in pspBhsFromOsm[osm]
        statusLabel = 'OK' if status else '?'
        if not status:
            if osm == '×':
                statusLabel = '*'
            else:
                mismatches.append((osm, bhs, nlex, noccs))
        print('\t=> {:<4} ({:<2}) in {:>4} lexemes and {:>3}% = {:>6} occurrences'.format(
            bhs, statusLabel, nlex, perc, noccs,
        ))
total = 0
for (osm, bhs, nlex, noccs) in mismatches:
    total += noccs
print('\n{:<24} {:>6} occurrences'.format('Total number of mismatches', total))
# Out:
# R
# 	=> prep (OK) in   22 lexemes and  96% =  55591 occurrences
# 	=> subs (? ) in   18 lexemes and   3% =   1658 occurrences
# 	=> advb (? ) in    1 lexemes and   0% =    194 occurrences
# 	=> inrg (? ) in    1 lexemes and   0% =    169 occurrences
# 	=> conj (? ) in    2 lexemes and   0% =      5 occurrences
# 	=> art  (? ) in    1 lexemes and   0% =      2 occurrences
# 	=> nmpr (? ) in    1 lexemes and   0% =      2 occurrences
# 	=> verb (? ) in    1 lexemes and   0% =      1 occurrences
# ×
# 	=> verb (* ) in 1189 lexemes and  25% =  13584 occurrences
# 	=> subs (* ) in 2427 lexemes and  23% =  12637 occurrences
# 	=> art  (* ) in    1 lexemes and  17% =   9384 occurrences
# 	=> conj (* ) in    9 lexemes and  14% =   7821 occurrences
# 	=> prep (* ) in   23 lexemes and  12% =   6495 occurrences
# 	=> adjv (* ) in  468 lexemes and   4% =   2090 occurrences
# 	=> nmpr (* ) in  452 lexemes and   2% =   1279 occurrences
# 	=> inrg (* ) in   12 lexemes and   0% =    246 occurrences
# 	=> intj (* ) in   12 lexemes and   0% =     97 occurrences
# 	=> advb (* ) in   20 lexemes and   0% =     93 occurrences
# 	=> prps (* ) in   15 lexemes and   0% =     93 occurrences
# 	=> prde (* ) in   17 lexemes and   0% =     92 occurrences
# 	=> nega (* ) in    3 lexemes and   0% =     26 occurrences
# 	=> prin (* ) in    3 lexemes and   0% =     11 occurrences
# N
# 	=> subs (OK) in 3226 lexemes and  75% =  98678 occurrences
# 	=> nmpr (OK) in 2305 lexemes and  24% =  31764 occurrences
# 	=> adjv (? ) in   44 lexemes and   1% =    910 occurrences
# 	=> verb (? ) in    7 lexemes and   0% =      8 occurrences
# 	=> advb (? ) in    2 lexemes and   0% =      2 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# V
# 	=> verb (OK) in 1533 lexemes and 100% =  60074 occurrences
# 	=> subs (? ) in    5 lexemes and   0% =      6 occurrences
# 	=> adjv (? ) in    2 lexemes and   0% =      3 occurrences
# 	=> nmpr (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# To
# 	=> prep (OK) in    5 lexemes and 100% =  10912 occurrences
# Td
# 	=> art  (OK) in    1 lexemes and 100% =  20999 occurrences
# 	=> subs (? ) in    2 lexemes and   0% =      2 occurrences
# 	=> inrg (? ) in    1 lexemes and   0% =      2 occurrences
# Ti
# 	=> prin (OK) in    3 lexemes and  54% =    992 occurrences
# 	=> inrg (OK) in   14 lexemes and  46% =    837 occurrences
# 	=> art  (? ) in    1 lexemes and   0% =      1 occurrences
# C
# 	=> conj (OK) in   11 lexemes and 100% =  49250 occurrences
# 	=> subs (? ) in    4 lexemes and   0% =    122 occurrences
# 	=> prep (? ) in    4 lexemes and   0% =     77 occurrences
# 	=> advb (? ) in    3 lexemes and   0% =      8 occurrences
# 	=> prde (? ) in    1 lexemes and   0% =      6 occurrences
# A
# 	=> adjv (OK) in  305 lexemes and  50% =   6449 occurrences
# 	=> subs (? ) in   51 lexemes and  50% =   6438 occurrences
# 	=> verb (? ) in    6 lexemes and   0% =     38 occurrences
# 	=> nmpr (? ) in    5 lexemes and   0% =     30 occurrences
# 	=> advb (? ) in    2 lexemes and   0% =      3 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# Tn
# 	=> nega (OK) in    5 lexemes and  90% =   6026 occurrences
# 	=> subs (? ) in    2 lexemes and  10% =    659 occurrences
# 	=> prep (? ) in    2 lexemes and   0% =     15 occurrences
# 	=> nmpr (? ) in    2 lexemes and   0% =      4 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> inrg (? ) in    1 lexemes and   0% =      1 occurrences
# Tr
# 	=> conj (OK) in    3 lexemes and  97% =   5641 occurrences
# 	=> prep (? ) in    1 lexemes and   3% =    165 occurrences
# 	=> verb (? ) in    1 lexemes and   0% =      1 occurrences
# P
# 	=> prps (OK) in   22 lexemes and  65% =   4910 occurrences
# 	=> prde (OK) in   10 lexemes and  34% =   2562 occurrences
# 	=> prin (? ) in    2 lexemes and   0% =     18 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      5 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> subs (? ) in    1 lexemes and   0% =      1 occurrences
# D
# 	=> advb (OK) in   43 lexemes and  72% =   2767 occurrences
# 	=> subs (? ) in   11 lexemes and  28% =   1066 occurrences
# 	=> inrg (? ) in    1 lexemes and   1% =     29 occurrences
# 	=> intj (? ) in    2 lexemes and   0% =      2 occurrences
# 	=> verb (? ) in    1 lexemes and   0% =      2 occurrences
# 	=> adjv (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# Tm
# 	=> intj (OK) in    4 lexemes and  66% =   1129 occurrences
# 	=> advb (OK) in    1 lexemes and  25% =    422 occurrences
# 	=> subs (? ) in    1 lexemes and   8% =    138 occurrences
# 	=> adjv (? ) in    1 lexemes and   1% =     10 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      1 occurrences
# Tj
# 	=> intj (OK) in   17 lexemes and  97% =    306 occurrences
# 	=> subs (? ) in    1 lexemes and   1% =      3 occurrences
# 	=> verb (? ) in    1 lexemes and   1% =      2 occurrences
# 	=> inrg (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> nega (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> nmpr (? ) in    1 lexemes and   0% =      1 occurrences
# Ta
# 	=> advb (OK) in    5 lexemes and  93% =   1061 occurrences
# 	=> subs (? ) in    2 lexemes and   7% =     75 occurrences
# 	=> prps (? ) in    2 lexemes and   0% =      5 occurrences
# S
# 	=> prps (? ) in    3 lexemes and 100% =      3 occurrences
# Te
# 	=> intj (OK) in    3 lexemes and 100% =    351 occurrences
# 	=> adjv (? ) in    1 lexemes and   0% =      1 occurrences
# T
# 	=> prep (? ) in    1 lexemes and 100% =      9 occurrences
#
# Total number of mismatches  11915 occurrences

# %% [markdown]
# It is not as bad as it seems.
# The number of *lexemes* involved in a mismatch is limited:

# %%
mismatchLexemes = set()
for (osm, bhs, nlex, noccs) in mismatches:
    lexemes = psp[osm][bhs].keys()
    mismatchLexemes |= lexemes
print('Lexemes to be researched: {}'.format(len(mismatchLexemes)))
# Out:
# Lexemes to be researched: 207

# %% [markdown]
# We are going to investigate the lexemes that are involved in a mismatch.
#
# It turns out that:
#
# * for most of the lexemes there is a dominant combination of OSM and BHSA assigned part-of-speech;
# * non-dominant combinations mostly have a very limited number of occurrences.
#
# This is what we are going to do:
#
# * for each lexeme we go along with the dominant combination.
#   If that is different from the default marking, we add a lexeme-bound exception to the rule
#   that maps OSM part-of-speech to BHSA part-of-speech.
# * if even the dominant combination has less than 10 occurrences, we do not add a lexeme-bound rule,
#   but we add the case to the list of exceptional cases.
# * we spell out the exceptional cases, so that readers can manually check the part-of-speeches as assigned by
#   OSM and BHSA.
#
# In order to determine what is dominant: if a combination has 50% or more of occurrences of a lexeme.
# then that combination is dominant.
# So, for each lexeme there is at least one dominant case.
#
# There may not be a dominant case if not all occurrences of a lexeme have been marked up in the OSM.

# %% [markdown]
# The next cell computes the new rules and the exceptions.
# It will show all new rules, and all kinds of exceptions.
# But it only shows at most 10 instances of each kind of exception.
#
# All exceptions are written to a tab-separated file
# [pspCases.tsv](pspCases.tsv).

# %%
closerLook = set()

rules = []
text = []

def getOSMpsp(w):
    return '{} - {}'.format(str(F.osm.v(w)), str(F.osm_sf.v(w)))

fields = '''
    passage
    slot
    occurrence
    lex-node
    lex
    lex-pointed
    gloss
    bhsa-psp
    osm-psp
    #cases-like-this
'''.strip().split()
lineFormat = ('{}\t' * (len(fields) - 1)) + '{}\n'

casesLikeThis = {}

for lx in sorted(mismatchLexemes, key=lambda x: -F.freq_lex.v(x)):
    freqLex = F.freq_lex.v(lx)
    text.append('\n{:<15}        {:>6}x [{}] "{}"'.format(
        F.lex.v(lx), 
        freqLex,
        F.gloss.v(lx),
        F.voc_lex_utf8.v(lx), 
    ))
    nRealCases = freqLex
    if '×' in pspLex[lx]:
        for (bhs, ws) in pspLex[lx]['×'].items():
            nRealCases -= len(ws)

    osmCount = collections.Counter()
    for (osm, osmData) in pspLex[lx].items():
        for ws in osmData.values():
            osmCount[osm] += len(ws)
            
    for osm in sorted(pspLex[lx], key=lambda x: -osmCount[x]):
        if osm == '×': continue
        osmData = pspLex[lx][osm]
        for (bhs, ws) in sorted(osmData.items(), key=lambda x: (-len(x[1]), x[0])):
            showCases = False
            nws = len(ws)
            status = bhs in pspBhsFromOsm[osm]
            statusLabel = 'OK' if status else '?'

            if 2 * nws > freqLex and nws >= 10:
                if status:
                    pass
                else:
                    statusLabel = 'NN'
                    rules.append((lx, osm, bhs, ws))
            else:
                if status:
                    statusLabel = 'OK?'
                else:
                    showCases = True

            text.append('\t{:<2} ~ {:<4} ({:<3}) {:>6}x'.format(
                bhs, osm, statusLabel, nws,
            ))
            
            if showCases:
                for w in sorted(ws)[0:10]:
                    text.append(show(T, F, [w], F.sp.v, getOSMpsp, indent='\t\t\t\t\t', asString=True))
                if nws > 10:
                    text.append('\t\t\t\t\tand {} more occurrences'.format(nws - 10))
                closerLook |= set(ws)
                for w in ws:
                    casesLikeThis[w] = nws

with open('pspCases.tsv', 'w') as fh:
    fh.write(lineFormat.format(*fields))
    for w in sorted(closerLook):
        closerLook.add(w)
        fh.write(lineFormat.format(
            '{} {}:{}'.format(*T.sectionFromNode(w)),
            w,
            F.g_word_utf8.v(w),
            lx, 
            F.lex.v(lx),
            F.voc_lex_utf8.v(lx),
            F.gloss.v(lx),
            F.sp.v(w),
            F.osm.v(w),
            casesLikeThis[w],
        ))
print('Written {} cases to file'.format(len(closerLook)))

if rules:
    print('Lexeme-bound exceptions  : {:>4}'.format(len(rules)))
else:
    print('No lexeme-bound exceptions')

if closerLook or text:
    print('Cases that need attention: {:>4}'.format(len(closerLook)))
else:
    print('All cases clear')

print('\nLEXEME-BOUND EXCEPTIONS\n')
casesSolved = set()
for (lx, osm, bhs, ws) in rules:
    casesSolved |= set(ws)
    print('\t{:<15} {:<4} ~ {:<2} ({:>5}x) [{:<20}] "{}"'.format(
        F.lex.v(lx),
        bhs,
        osm,
        len(ws),
        F.gloss.v(lx),
        F.voc_lex_utf8.v(lx),
))
print('This solves {} cases'.format(len(casesSolved)))
print('Remaining cases: {}'.format(total - len(casesSolved)))

print('\nCASES FOR ATTENTION\n')
for t in text: print(t)
# Out:
# Written 824 cases to file
# Lexeme-bound exceptions  :   54
# Cases that need attention:  824
#
# LEXEME-BOUND EXCEPTIONS
#
# 	>XD/            subs ~ A  (  910x) [one                 ] "אֶחָד"
# 	>JN/            subs ~ Tn (  639x) [<NEG>               ] "אַיִן"
# 	CNJM/           subs ~ A  (  768x) [two                 ] "שְׁנַיִם"
# 	>XR/            subs ~ R  (  586x) [after               ] "אַחַר"
# 	CLC/            subs ~ A  (  600x) [three               ] "שָׁלֹשׁ"
# 	M>H/            subs ~ A  (  565x) [hundred             ] "מֵאָה"
# 	XMC/            subs ~ A  (  506x) [five                ] "חָמֵשׁ"
# 	TXT/            subs ~ R  (  370x) [under part          ] "תַּחַת"
# 	>LP=/           subs ~ A  (  492x) [thousand            ] "אֶלֶף"
# 	CB</            subs ~ A  (  482x) [seven               ] "שֶׁבַע"
# 	<WD/            subs ~ D  (  423x) [duration            ] "עֹוד"
# 	>RB</           subs ~ A  (  453x) [four                ] "אַרְבַּע"
# 	BJN/            subs ~ R  (  355x) [interval            ] "בַּיִן"
# 	SBJB/           subs ~ D  (  207x) [surrounding         ] "סָבִיב"
# 	<FRJM/          subs ~ A  (  315x) [twenty              ] "עֶשְׂרִים"
# 	M>D/            subs ~ D  (  290x) [might               ] "מְאֹד"
# 	LWJ/            adjv ~ N  (  239x) [Levite              ] "לֵוִי"
# 	PLCTJ/          adjv ~ N  (  262x) [Philistine          ] "פְּלִשְׁתִּי"
# 	CC/             subs ~ A  (  274x) [six                 ] "שֵׁשׁ"
# 	<FR/            subs ~ A  (  203x) [-teen               ] "עָשָׂר"
# 	LKN             advb ~ R  (  194x) [therefore           ] "לָכֵן"
# 	LMH             inrg ~ R  (  169x) [why                 ] "לָמָה"
# 	GBWR/           subs ~ A  (  137x) [vigorous            ] "גִּבֹּור"
# 	NGD/            subs ~ R  (  120x) [counterpart         ] "נֶגֶד"
# 	CMNH/           subs ~ A  (  147x) [eight               ] "שְׁמֹנֶה"
# 	JC/             subs ~ Tm (  138x) [existence           ] "יֵשׁ"
# 	<FRH/           subs ~ A  (  134x) [-teen               ] "עֶשְׂרֵה"
# 	<FRH=/          subs ~ A  (  120x) [ten                 ] "עֲשָׂרָה"
# 	BLT/            subs ~ C  (  100x) [failure             ] "בֵּלֶת"
# 	B<D/            subs ~ R  (   67x) [distance            ] "בַּעַד"
# 	>MRJ/           adjv ~ N  (   84x) [Amorite             ] "אֱמֹרִי"
# 	JHWDJ/          adjv ~ N  (   45x) [Jewish              ] "יְהוּדִי"
# 	TC</            subs ~ A  (   78x) [nine                ] "תֵּשַׁע"
# 	KN<NJ/          adjv ~ N  (   62x) [Canaanite           ] "כְּנַעֲנִי"
# 	VWBH/           subs ~ A  (   65x) [what is good        ] "טֹובָה"
# 	>YL/            subs ~ R  (   39x) [side                ] "אֵצֶל"
# 	<FR=/           subs ~ A  (   56x) [ten                 ] "עֶשֶׂר"
# 	VRM/            subs ~ D  (   56x) [beginning           ] "טֶרֶם"
# 	XTJ/            adjv ~ N  (   32x) [Hittite             ] "חִתִּי"
# 	<MD/            subs ~ R  (   41x) [company             ] "עִמָּד"
# 	QDM/            subs ~ R  (   27x) [before              ] "קֳדָם"
# 	JBWSJ/          adjv ~ N  (   34x) [Jebusite            ] "יְבוּסִי"
# 	>N              inrg ~ D  (   29x) [whither             ] "אָן"
# 	CC=/            subs ~ A  (   31x) [linen               ] "שֵׁשׁ"
# 	MWL/            subs ~ R  (   24x) [front               ] "מוּל"
# 	QBL/            subs ~ C  (   17x) [opposite            ] "קֳבֵל"
# 	XWJ/            adjv ~ N  (   18x) [Hivite              ] "חִוִּי"
# 	PRZJ/           adjv ~ N  (   15x) [Perizzite           ] "פְּרִזִּי"
# 	>JTJ/           subs ~ Ta (   14x) [existence           ] "אִיתַי"
# 	QHTJ/           adjv ~ N  (   12x) [Kohathite           ] "קְהָתִי"
# 	XKJM/           adjv ~ N  (   13x) [wise                ] "חַכִּים"
# 	>LP==/          subs ~ A  (   13x) [group of thousand   ] "אֶלֶף"
# 	GRCNJ/          adjv ~ N  (   11x) [Gershonite          ] "גֵּרְשֻׁנִּי"
# 	GL<DJ/          adjv ~ N  (   10x) [Gileadite           ] "גִּלְעָדִי"
# This solves 11091 cases
# Remaining cases: 824
#
# CASES FOR ATTENTION
#
#
# W                       50272x [and] "וְ"
# 	conj ~ C    (OK )  42715x
# 	conj ~ R    (?  )      4x
# 					Isaiah 1:5 w212146 "וְ"
# 						BHS: conj
# 						OSM: HR - None
# 					Jonah 2:4 w298980 "וְ"
# 						BHS: conj
# 						OSM: HR - None
# 					Jonah 3:5 w299157 "וְ"
# 						BHS: conj
# 						OSM: HR - None
# 					Jonah 4:11 w299537 "וּ"
# 						BHS: conj
# 						OSM: HR - None
# 	conj ~ A    (?  )      1x
# 					Ecclesiastes 8:12 w362111 "וּ"
# 						BHS: conj
# 						OSM: HAcbsc - HC
#
# H                       30386x [the] "הַ"
# 	art ~ Td   (OK )  20999x
# 	art ~ R    (?  )      2x
# 					Haggai 2:6 w304606 "הֶ"
# 						BHS: art
# 						OSM: HR - None
# 					Haggai 2:19 w304900 "הַ"
# 						BHS: art
# 						OSM: HRd - None
# 	art ~ Ti   (?  )      1x
# 					Amos 5:25 w296900 "הַ"
# 						BHS: art
# 						OSM: HTi - None
#
# L                       20069x [to] "לְ"
# 	prep ~ R    (OK )  18032x
# 	prep ~ Tn   (?  )     13x
# 					Exodus 21:8 w40141 "לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Leviticus 11:21 w58184 "לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Leviticus 25:30 w67708 "לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					2_Samuel 16:18 w170177 "לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					2_Kings 8:10 w199807 "לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Isaiah 9:2 w215177 "לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Isaiah 49:5 w229221 "לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Isaiah 63:9 w233605 "לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Job 6:21 w337759 "לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Job 13:15 w339385 "לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					and 3 more occurrences
# 	prep ~ V    (?  )      1x
# 					Song_of_songs 2:13 w357957 "לכי"
# 						BHS: prep
# 						OSM: HVqv2fs - None
#
# >L                       5517x [to] "אֶל"
# 	prep ~ R    (OK )   5504x
# 	prep ~ Tn   (?  )      2x
# 					Judges 19:23 w139675 "אַל"
# 						BHS: prep
# 						OSM: HTn - None
# 					Jeremiah 47:6 w260350 "אַל"
# 						BHS: prep
# 						OSM: HTn - None
#
# >CR                      5500x [<relative>] "אֲשֶׁר"
# 	conj ~ Tr   (OK )   5497x
# 	conj ~ P    (?  )      1x
# 					Ruth 2:9 w356432 "אֲשֶׁ֥ר"
# 						BHS: conj
# 						OSM: HPr - None
#
# <FH[                     2629x [make] "עשׂה"
# 	verb ~ V    (OK )   2319x
# 	verb ~ A    (?  )      1x
# 					1_Kings 22:49 w194645 "עשׂר"
# 						BHS: verb
# 						OSM: HAcmsa - None
#
# HW>                      1394x [he] "הוּא"
# 	prps ~ P    (OK )   1388x
# 	prps ~ S    (?  )      1x
# 					Jeremiah 18:3 w243708 "הו"
# 						BHS: prps
# 						OSM: HSp3ms - None
#
# <D                       1263x [unto] "עַד"
# 	prep ~ R    (OK )   1259x
# 	prep ~ D    (?  )      1x
# 					Ruth 1:13 w356038 "עַ֚ד"
# 						BHS: prep
# 						OSM: HD - None
#
# JCB[                     1082x [sit] "ישׁב"
# 	verb ~ V    (OK )    920x
# 	verb ~ N    (?  )      1x
# 					Obadiah 1:3 w298206 "שִׁבְתֹּ֑ו"
# 						BHS: verb
# 						OSM: HNcfsc - HSp3ms
#
# >XD/                      970x [one] "אֶחָד"
# 	subs ~ A    (NN )    910x
#
# CNH/                      876x [year] "שָׁנָה"
# 	subs ~ N    (OK )    824x
# 	subs ~ A    (?  )     31x
# 					Genesis 11:10 w5143 "שָׁנָ֔ה"
# 						BHS: subs
# 						OSM: HAcbsc - HNcfsa
# 					Genesis 21:5 w9687 "שָׁנָ֑ה"
# 						BHS: subs
# 						OSM: HAcbsc - HNcfsa
# 					Genesis 23:1 w10747 "שְׁנֵ֖י"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 25:7 w12523 "שְׁנֵֽי"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 25:7 w12529 "שָׁנָ֛ה"
# 						BHS: subs
# 						OSM: HAcbsc - HNcfsa
# 					Genesis 25:17 w12670 "שְׁנֵי֙"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 25:17 w12674 "שָׁנָ֛ה"
# 						BHS: subs
# 						OSM: HAcbsc - HNcfsa
# 					Genesis 35:28 w19527 "שָׁנָ֖ה"
# 						BHS: subs
# 						OSM: HAcbsc - HNcfsa
# 					Genesis 41:27 w22856 "שְׁנֵ֥י"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 41:30 w22885 "שְׁנֵ֤י"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					and 21 more occurrences
#
# >JN/                      788x [<NEG>] "אַיִן"
# 	subs ~ Tn   (NN )    639x
#
# CNJM/                     768x [two] "שְׁנַיִם"
# 	subs ~ A    (NN )    768x
#
# H=                        743x [<interrogative>] "הֲ"
# 	inrg ~ Ti   (OK )    534x
# 	inrg ~ Td   (?  )      2x
# 					Exodus 10:7 w33968 "הֲ"
# 						BHS: inrg
# 						OSM: HTd - None
# 					Song_of_songs 6:11 w358841 "הֲ"
# 						BHS: inrg
# 						OSM: HTd - None
#
# W                         731x [and] "וְ"
# 	conj ~ C    (OK )    486x
# 	conj ~ N    (?  )      1x
# 					Daniel 2:23 w370982 "וּ"
# 						BHS: conj
# 						OSM: ANcfsd - None
# 	conj ~ R    (?  )      1x
# 					Daniel 6:28 w374522 "וּ"
# 						BHS: conj
# 						OSM: AR - None
#
# >XR/                      715x [after] "אַחַר"
# 	subs ~ R    (NN )    586x
# 	subs ~ N    (OK?)      1x
#
# CLC/                      602x [three] "שָׁלֹשׁ"
# 	subs ~ A    (NN )    600x
#
# M>H/                      579x [hundred] "מֵאָה"
# 	subs ~ A    (NN )    565x
# 	subs ~ R    (?  )     13x
# 					Genesis 11:10 w5142 "מְאַ֣ת"
# 						BHS: subs
# 						OSM: HR - None
# 					Genesis 21:5 w9686 "מְאַ֣ת"
# 						BHS: subs
# 						OSM: HR - None
# 					Genesis 25:7 w12528 "מְאַ֥ת"
# 						BHS: subs
# 						OSM: HR - None
# 					Genesis 25:17 w12673 "מְאַ֥ת"
# 						BHS: subs
# 						OSM: HR - None
# 					Genesis 35:28 w19526 "מְאַ֥ת"
# 						BHS: subs
# 						OSM: HR - None
# 					Exodus 38:25 w50893 "מְאַ֣ת"
# 						BHS: subs
# 						OSM: HR - None
# 					Exodus 38:27 w50947 "מְאַת֙"
# 						BHS: subs
# 						OSM: HR - None
# 					Exodus 38:27 w50962 "מְאַ֧ת"
# 						BHS: subs
# 						OSM: HR - None
# 					Numbers 2:9 w70537 "מְאַ֨ת"
# 						BHS: subs
# 						OSM: HR - None
# 					Numbers 2:16 w70632 "מְאַ֨ת"
# 						BHS: subs
# 						OSM: HR - None
# 					and 3 more occurrences
#
# XMC/                      506x [five] "חָמֵשׁ"
# 	subs ~ A    (NN )    506x
#
# TXT/                      505x [under part] "תַּחַת"
# 	subs ~ R    (NN )    370x
# 	subs ~ N    (OK?)      2x
#
# >LP=/                     492x [thousand] "אֶלֶף"
# 	subs ~ A    (NN )    492x
#
# CB</                      490x [seven] "שֶׁבַע"
# 	subs ~ A    (NN )    482x
# 	subs ~ N    (OK?)      3x
#
# <WD/                      490x [duration] "עֹוד"
# 	subs ~ D    (NN )    423x
#
# VWB/                      469x [good] "טֹוב"
# 	adjv ~ A    (OK )    445x
# 	adjv ~ V    (?  )      2x
# 					1_Samuel 16:16 w150632 "טֹ֥וב"
# 						BHS: adjv
# 						OSM: HVqq3ms - None
# 					1_Samuel 16:23 w150776 "טֹ֣וב"
# 						BHS: adjv
# 						OSM: HVqp3ms - None
#
# >RB</                     454x [four] "אַרְבַּע"
# 	subs ~ A    (NN )    453x
#
# RB/                       429x [much] "רַב"
# 	adjv ~ A    (OK )    405x
# 	adjv ~ N    (?  )      1x
# 					Amos 6:2 w296968 "רַבָּ֑ה"
# 						BHS: adjv
# 						OSM: HNp - None
#
# BJN/                      407x [interval] "בַּיִן"
# 	subs ~ R    (NN )    355x
#
# L                         378x [to] "לְ"
# 	prep ~ R    (OK )    191x
# 	prep ~ To   (OK?)     32x
# 	prep ~ C    (?  )     18x
# 					Daniel 2:8 w370683 "ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:10 w370739 "ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:12 w370782 "ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:24 w370997 "ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:40 w371351 "ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:41 w371393 "ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:45 w371481 "ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:3 w371670 "לַ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:7 w371737 "ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:8 w371772 "ל"
# 						BHS: prep
# 						OSM: AC - None
# 					and 8 more occurrences
#
# DJ                        345x [<relative>] "דִּי"
# 	prep ~ Tr   (?  )    165x
# 					Daniel 2:9 w370691 "דִּ֣י"
# 						BHS: prep
# 						OSM: ATr - None
# 					Daniel 2:9 w370709 "דִּ֥י"
# 						BHS: prep
# 						OSM: ATr - None
# 					Daniel 2:10 w370732 "דִּ֚י"
# 						BHS: prep
# 						OSM: ATr - None
# 					Daniel 2:11 w370761 "דִֽי"
# 						BHS: prep
# 						OSM: ATr - None
# 					Daniel 2:11 w370769 "דִּ֥י"
# 						BHS: prep
# 						OSM: ATr - None
# 					Daniel 2:11 w370775 "דִּ֚י"
# 						BHS: prep
# 						OSM: ATr - None
# 					Daniel 2:14 w370822 "דִּ֣י"
# 						BHS: prep
# 						OSM: ATr - None
# 					Daniel 2:14 w370824 "דִּ֚י"
# 						BHS: prep
# 						OSM: ATr - None
# 					Daniel 2:15 w370837 "דִֽי"
# 						BHS: prep
# 						OSM: ATr - None
# 					Daniel 2:19 w370909 "דִֽי"
# 						BHS: prep
# 						OSM: ATr - None
# 					and 155 more occurrences
# 	prep ~ C    (?  )     39x
# 					Daniel 2:8 w370678 "דִּ֥י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:8 w370685 "דִּ֣י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:8 w370687 "דִּ֥י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:9 w370718 "דִּ֥י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:10 w370741 "דִּ֚י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:16 w370859 "דִּ֚י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:18 w370894 "דִּ֣י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:20 w370933 "דִּ֧י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:23 w370989 "דִּֽי"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:23 w370992 "דִּֽי"
# 						BHS: prep
# 						OSM: AC - None
# 					and 29 more occurrences
# 	prep ~ T    (?  )      9x
# 					Daniel 3:22 w372113 "דִּ֥י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 4:12 w372600 "דִּ֣י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 4:20 w372811 "דִּ֣י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 4:26 w372935 "דִּ֥י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 5:5 w373249 "דִּ֣י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 5:5 w373259 "דִּֽי"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 5:5 w373262 "דִּ֣י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 5:7 w373306 "דִּ֣י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 5:7 w373320 "דִֽי"
# 						BHS: prep
# 						OSM: AT - None
# 	prep ~ P    (?  )      5x
# 					Daniel 3:6 w371723 "דִּי"
# 						BHS: prep
# 						OSM: APf3bs - None
# 					Daniel 3:11 w371824 "דִּי"
# 						BHS: prep
# 						OSM: APf3cs - None
# 					Daniel 4:14 w372650 "דִּ֤י"
# 						BHS: prep
# 						OSM: APfxcs - None
# 					Daniel 4:22 w372881 "דִּ֥י"
# 						BHS: prep
# 						OSM: APrxcs - None
# 					Daniel 4:29 w373010 "דִּ֥י"
# 						BHS: prep
# 						OSM: APrxcs - None
# 	prep ~ To   (OK?)      1x
# 	prep ~ A    (?  )      1x
# 					Daniel 4:23 w372897 "דִּ֣י"
# 						BHS: prep
# 						OSM: AAafsa - None
#
# SBJB/                     336x [surrounding] "סָבִיב"
# 	subs ~ D    (NN )    207x
# 	subs ~ N    (OK?)     47x
#
# <FRJM/                    315x [twenty] "עֶשְׂרִים"
# 	subs ~ A    (NN )    315x
#
# M>D/                      300x [might] "מְאֹד"
# 	subs ~ D    (NN )    290x
#
# LWJ/                      292x [Levite] "לֵוִי"
# 	adjv ~ N    (NN )    239x
#
# ML>[                      292x [be full] "מלא"
# 	verb ~ V    (OK )    196x
# 	verb ~ A    (?  )     32x
# 					Numbers 7:13 w74146 "מְלֵאִ֗ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Numbers 7:14 w74158 "מְלֵאָ֥ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					Numbers 7:19 w74228 "מְלֵאִ֗ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Numbers 7:20 w74240 "מְלֵאָ֥ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					Numbers 7:25 w74309 "מְלֵאִ֗ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Numbers 7:26 w74321 "מְלֵאָ֥ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					Numbers 7:31 w74390 "מְלֵאִ֗ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Numbers 7:32 w74402 "מְלֵאָ֥ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					Numbers 7:37 w74471 "מְלֵאִ֗ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Numbers 7:38 w74483 "מְלֵאָ֥ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					and 22 more occurrences
#
# PLCTJ/                    288x [Philistine] "פְּלִשְׁתִּי"
# 	adjv ~ N    (NN )    262x
#
# QRB[                      281x [approach] "קרב"
# 	verb ~ V    (OK )    254x
# 	verb ~ A    (?  )      1x
# 					Zephaniah 1:14 w303365 "קָרֹ֖וב"
# 						BHS: verb
# 						OSM: HAamsa - None
#
# >P/                       277x [nose] "אַף"
# 	subs ~ N    (OK )    210x
# 	subs ~ Ta   (?  )     61x
# 					Genesis 27:45 w14450 "אַף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Genesis 30:2 w15620 "אַ֥ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Exodus 4:14 w30441 "אַ֨ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Exodus 32:19 w46923 "אַ֣ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Exodus 32:22 w46988 "אַ֖ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Numbers 11:10 w76982 "אַ֤ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Numbers 12:9 w77733 "אַ֧ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Numbers 22:22 w84242 "אַ֣ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Numbers 22:27 w84374 "אַ֣ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Numbers 24:10 w85352 "אַ֤ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					and 51 more occurrences
#
# CC/                       274x [six] "שֵׁשׁ"
# 	subs ~ A    (NN )    274x
#
# HM                        269x [they] "הֵם"
# 	prps ~ P    (OK )    266x
# 	prps ~ S    (?  )      1x
# 					Song_of_songs 6:5 w358742 "הֵ֖ם"
# 						BHS: prps
# 						OSM: HSp3mp - None
#
# XJ/                       239x [alive] "חַי"
# 	adjv ~ A    (OK )    234x
# 	adjv ~ N    (?  )      1x
# 					Ruth 3:13 w357009 "חַי"
# 						BHS: adjv
# 						OSM: HNcmsa - None
#
# B                         226x [in] "בְּ"
# 	prep ~ R    (OK )    141x
# 	prep ~ N    (?  )      1x
# 					Daniel 6:28 w374523 "בְ"
# 						BHS: prep
# 						OSM: ANcmpd - None
#
# <FR/                      203x [-teen] "עָשָׂר"
# 	subs ~ A    (NN )    203x
#
# LKN                       200x [therefore] "לָכֵן"
# 	advb ~ R    (NN )    194x
#
# LMH                       178x [why] "לָמָה"
# 	inrg ~ R    (NN )    169x
# 	inrg ~ Ti   (OK?)      1x
#
# GBWR/                     159x [vigorous] "גִּבֹּור"
# 	subs ~ A    (NN )    137x
#
# NGD/                      151x [counterpart] "נֶגֶד"
# 	subs ~ R    (NN )    120x
#
# CMNH/                     147x [eight] "שְׁמֹנֶה"
# 	subs ~ A    (NN )    147x
#
# M<L/                      140x [top] "מַעַל"
# 	subs ~ D    (?  )     63x
# 					Genesis 6:16 w2900 "מַ֔עְלָה"
# 						BHS: subs
# 						OSM: HD - HSd
# 					Genesis 7:20 w3440 "מַ֔עְלָה"
# 						BHS: subs
# 						OSM: HD - HSd
# 					Exodus 25:20 w42254 "מַ֗עְלָה"
# 						BHS: subs
# 						OSM: HD - HSd
# 					Exodus 37:9 w50072 "מַ֗עְלָה"
# 						BHS: subs
# 						OSM: HD - HSd
# 					Exodus 38:26 w50932 "מַ֔עְלָה"
# 						BHS: subs
# 						OSM: HD - HSd
# 					Leviticus 27:7 w69079 "מַ֨עְלָה֙"
# 						BHS: subs
# 						OSM: HD - HSd
# 					Numbers 1:3 w69665 "מַ֔עְלָה"
# 						BHS: subs
# 						OSM: HD - HSd
# 					Numbers 1:18 w69816 "מַ֖עְלָה"
# 						BHS: subs
# 						OSM: HD - HSd
# 					Numbers 1:20 w69854 "מַ֔עְלָה"
# 						BHS: subs
# 						OSM: HD - HSd
# 					Numbers 1:22 w69891 "מַ֔עְלָה"
# 						BHS: subs
# 						OSM: HD - HSd
# 					and 53 more occurrences
# 	subs ~ R    (?  )      2x
# 					Haggai 2:18 w304862 "מָ֑עְלָה"
# 						BHS: subs
# 						OSM: HR - HSd
# 					Ecclesiastes 3:21 w360509 "מָ֑עְלָה"
# 						BHS: subs
# 						OSM: HR - HSd
#
# JC/                       138x [existence] "יֵשׁ"
# 	subs ~ Tm   (NN )    138x
#
# XKM/                      138x [wise] "חָכָם"
# 	adjv ~ A    (OK )    125x
# 	adjv ~ N    (?  )      1x
# 					Proverbs 1:5 w346968 "חָ֭כָם"
# 						BHS: adjv
# 						OSM: HNcmsa - None
#
# <FRH/                     134x [-teen] "עֶשְׂרֵה"
# 	subs ~ A    (NN )    134x
#
# <FRH=/                    120x [ten] "עֲשָׂרָה"
# 	subs ~ A    (NN )    120x
#
# MN                        119x [from] "מִן"
# 	prep ~ R    (OK )    103x
# 	prep ~ C    (?  )      1x
# 					Daniel 3:22 w372092 "מִן"
# 						BHS: prep
# 						OSM: AC - None
#
# BLT/                      112x [failure] "בֵּלֶת"
# 	subs ~ C    (NN )    100x
# 	subs ~ R    (?  )      1x
# 					Hosea 13:4 w293772 "בִּלְתִּֽי"
# 						BHS: subs
# 						OSM: HR - HSp1cs
#
# KNP/                      109x [wing] "כָּנָף"
# 	subs ~ N    (OK )     59x
# 	subs ~ D    (?  )      8x
# 					Deuteronomy 32:11 w111587 "כְּנָפָיו֙"
# 						BHS: subs
# 						OSM: HD -
# 					1_Kings 6:24 w180572 "כְּנָפָ֖יו"
# 						BHS: subs
# 						OSM: HD -
# 					1_Kings 6:24 w180576 "כְּנָפָֽיו"
# 						BHS: subs
# 						OSM: HD -
# 					Isaiah 8:8 w214878 "כְּנָפָ֔יו"
# 						BHS: subs
# 						OSM: HD -
# 					Jeremiah 48:40 w260991 "כְּנָפָ֖יו"
# 						BHS: subs
# 						OSM: HD -
# 					Jeremiah 49:22 w261544 "כְּנָפָ֖יו"
# 						BHS: subs
# 						OSM: HD -
# 					Psalms 91:4 w326442 "כְּנָפָ֣יו"
# 						BHS: subs
# 						OSM: HD -
# 					Ruth 2:12 w356507 "כְּנָפָֽיו"
# 						BHS: subs
# 						OSM: HD -
#
# B<D/                      105x [distance] "בַּעַד"
# 	subs ~ R    (NN )     67x
#
# M<V/                      101x [little] "מְעַט"
# 	subs ~ N    (OK )     54x
# 	subs ~ A    (?  )      5x
# 					Hosea 1:4 w290992 "מְעַ֗ט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Hosea 8:10 w292726 "מְּעָ֔ט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Haggai 1:6 w304217 "מְעָ֗ט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Haggai 1:9 w304272 "מְעָ֔ט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Ruth 2:7 w356376 "מְעָֽט"
# 						BHS: subs
# 						OSM: HAamsa - None
#
# J<N/                      100x [motive] "יַעַן"
# 	subs ~ C    (?  )      4x
# 					Hosea 8:1 w292616 "יַ֚עַן"
# 						BHS: subs
# 						OSM: HC - None
# 					Amos 5:11 w296673 "יַ֣עַן"
# 						BHS: subs
# 						OSM: HC - None
# 					Haggai 1:9 w304280 "יַ֣עַן"
# 						BHS: subs
# 						OSM: HC - None
# 					Haggai 1:9 w304285 "יַ֗עַן"
# 						BHS: subs
# 						OSM: HC - None
#
# ZNH[                       93x [fornicate] "זנה"
# 	verb ~ V    (OK )     61x
# 	verb ~ N    (?  )      1x
# 					Joel 4:3 w295061 "זֹּונָ֔ה"
# 						BHS: verb
# 						OSM: HNcfsa - None
#
# >MRJ/                      87x [Amorite] "אֱמֹרִי"
# 	adjv ~ N    (NN )     84x
#
# JHWDJ/                     82x [Jewish] "יְהוּדִי"
# 	adjv ~ N    (NN )     45x
# 	adjv ~ A    (OK?)      2x
#
# MHR[                       81x [hasten] "מהר"
# 	verb ~ V    (OK )     55x
# 	verb ~ A    (?  )      1x
# 					Zephaniah 1:14 w303367 "מַהֵ֣ר"
# 						BHS: verb
# 						OSM: HAamsa - None
#
# TC</                       78x [nine] "תֵּשַׁע"
# 	subs ~ A    (NN )     78x
#
# KN<NJ/                     73x [Canaanite] "כְּנַעֲנִי"
# 	adjv ~ N    (NN )     62x
#
# KSJL/                      70x [insolent] "כְּסִיל"
# 	adjv ~ N    (?  )      1x
# 					Proverbs 3:35 w347774 "כְסִילִ֗ים"
# 						BHS: adjv
# 						OSM: HNcmpa - None
#
# KKR/                       68x [disk] "כִּכָּר"
# 	subs ~ N    (OK )     51x
# 	subs ~ A    (?  )      2x
# 					Exodus 38:25 w50894 "כִּכָּ֑ר"
# 						BHS: subs
# 						OSM: HAcbsc - HNcbsa
# 					Exodus 38:27 w50948 "כִּכַּ֣ר"
# 						BHS: subs
# 						OSM: HAcbsc - HNcbsc
#
# VWBH/                      65x [what is good] "טֹובָה"
# 	subs ~ A    (NN )     65x
#
# K                          63x [like] "כְּ"
# 	prep ~ R    (OK?)     30x
# 	prep ~ C    (?  )     19x
# 					Daniel 2:8 w370682 "כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:10 w370738 "כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:12 w370781 "כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:24 w370996 "כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:40 w371350 "כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:41 w371392 "כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:45 w371480 "כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:7 w371736 "כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:8 w371771 "כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:22 w372088 "כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					and 9 more occurrences
#
# >YL/                       61x [side] "אֵצֶל"
# 	subs ~ R    (NN )     39x
#
# DNH                        58x [this] "דְּנָה"
# 	prde ~ P    (OK?)     27x
# 	prde ~ C    (?  )      6x
# 					Daniel 2:12 w370784 "דְּנָ֔ה"
# 						BHS: prde
# 						OSM: AC - None
# 					Daniel 2:24 w370999 "דְּנָ֗ה"
# 						BHS: prde
# 						OSM: AC - None
# 					Daniel 3:7 w371739 "דְּנָ֡ה"
# 						BHS: prde
# 						OSM: AC - None
# 					Daniel 3:8 w371774 "דְּנָה֙"
# 						BHS: prde
# 						OSM: AC - None
# 					Daniel 3:22 w372091 "דְּנָ֗ה"
# 						BHS: prde
# 						OSM: AC - None
# 					Daniel 6:10 w374043 "דְּנָ֑ה"
# 						BHS: prde
# 						OSM: AC - None
#
# BLJ/                       58x [destruction] "בְּלִי"
# 	subs ~ Tn   (?  )     20x
# 					Genesis 31:20 w16737 "בְּלִי֙"
# 						BHS: subs
# 						OSM: HTn - None
# 					2_Samuel 1:21 w160870 "בְּלִ֖י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Isaiah 14:6 w216934 "בְּלִ֥י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Isaiah 28:8 w220950 "בְּלִ֖י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Isaiah 32:10 w222800 "בְּלִ֥י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Isaiah 38:17 w225311 "בְּלִ֔י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Hosea 7:8 w292480 "בְּלִ֥י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Hosea 8:7 w292687 "בְּלִ֣י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Malachi 3:10 w310378 "בְּלִי"
# 						BHS: subs
# 						OSM: HTn - None
# 					Psalms 19:4 w313207 "בְּ֝לִ֗י"
# 						BHS: subs
# 						OSM: HTn - None
# 					and 10 more occurrences
# 	subs ~ N    (OK?)     20x
#
# >DN/                       57x [pedestal] "אֶדֶן"
# 	subs ~ N    (OK )     56x
# 	subs ~ A    (?  )      1x
# 					Exodus 38:27 w50963 "אֲדָנִ֛ים"
# 						BHS: subs
# 						OSM: HAcbsc - HNcmpa
#
# <FR=/                      56x [ten] "עֶשֶׂר"
# 	subs ~ A    (NN )     56x
#
# VRM/                       56x [beginning] "טֶרֶם"
# 	subs ~ D    (NN )     56x
#
# XTJ/                       48x [Hittite] "חִתִּי"
# 	adjv ~ N    (NN )     32x
#
# JXD/                       47x [gathering] "יַחַד"
# 	subs ~ N    (OK?)     14x
# 	subs ~ D    (?  )      3x
# 					Hosea 11:7 w293404 "יַ֖חַד"
# 						BHS: subs
# 						OSM: HD - None
# 					Hosea 11:8 w293422 "יַ֖חַד"
# 						BHS: subs
# 						OSM: HD - None
# 					Psalms 2:2 w310753 "יָ֑חַד"
# 						BHS: subs
# 						OSM: HD - None
#
# <MD/                       45x [company] "עִמָּד"
# 	subs ~ R    (NN )     41x
#
# VWB[                       44x [be good] "טוב"
# 	verb ~ V    (OK?)      8x
# 	verb ~ A    (?  )      2x
# 					Hosea 2:9 w291267 "טֹ֥וב"
# 						BHS: verb
# 						OSM: HAamsa - None
# 					Hosea 10:1 w293076 "טֹ֣וב"
# 						BHS: verb
# 						OSM: HAamsa - None
#
# QDM/                       42x [before] "קֳדָם"
# 	subs ~ R    (NN )     27x
#
# JBWSJ/                     41x [Jebusite] "יְבוּסִי"
# 	adjv ~ N    (NN )     34x
#
# >N                         41x [whither] "אָן"
# 	inrg ~ D    (NN )     29x
# 	inrg ~ Ti   (OK?)      4x
#
# MCJX/                      39x [anointed] "מָשִׁיחַ"
# 	subs ~ N    (OK )     21x
# 	subs ~ A    (?  )      1x
# 					Psalms 2:2 w310758 "מְשִׁיחֹֽו"
# 						BHS: subs
# 						OSM: HAamsc - HSp3ms
#
# CC=/                       38x [linen] "שֵׁשׁ"
# 	subs ~ A    (NN )     31x
# 	subs ~ N    (OK?)      5x
#
# MR/                        37x [bitter] "מַר"
# 	adjv ~ A    (OK )     31x
# 	adjv ~ N    (?  )      1x
# 					Ruth 1:20 w356181 "מָרָ֔א"
# 						BHS: adjv
# 						OSM: HNp - None
#
# >J/                        36x [coast, island] "אִי"
# 	subs ~ N    (OK )     25x
# 	subs ~ Tj   (?  )      3x
# 					Isaiah 23:2 w219430 "אִ֑י"
# 						BHS: subs
# 						OSM: HTj - None
# 					Isaiah 23:6 w219483 "אִֽי"
# 						BHS: subs
# 						OSM: HTj - None
# 					Jeremiah 47:4 w260328 "אִ֥י"
# 						BHS: subs
# 						OSM: HTj - None
#
# MWL/                       36x [front] "מוּל"
# 	subs ~ R    (NN )     24x
#
# CB<==/                     35x [Sheba] "שֶׁבַע"
# 	nmpr ~ N    (OK )     19x
# 	nmpr ~ A    (?  )     16x
# 					Genesis 26:33 w13598 "שֶׁ֔בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					Joshua 15:28 w121878 "שֶׁ֖בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					Joshua 19:2 w123440 "שֶׁ֥בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					Joshua 19:2 w123442 "שֶׁ֖בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					Judges 20:1 w139905 "שֶׁ֔בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					2_Samuel 17:11 w170533 "שֶׁ֔בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					2_Samuel 24:2 w175464 "שֶׁ֔בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					2_Samuel 24:15 w175800 "שֶׁ֔בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					1_Kings 19:3 w191454 "שֶׁ֖בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					Amos 5:5 w296582 "שֶׁ֖בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					and 6 more occurrences
#
# <BRJ/                      34x [Hebrew] "עִבְרִי"
# 	adjv ~ N    (?  )     13x
# 					Genesis 40:15 w22188 "עִבְרִ֑ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					Genesis 43:32 w24786 "עִבְרִים֙"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					Exodus 2:6 w29235 "עִבְרִ֖ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					Exodus 5:3 w30858 "עִבְרִ֖ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					Exodus 7:16 w32063 "עִבְרִים֙"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					Exodus 9:1 w33037 "עִבְרִ֔ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					Exodus 9:13 w33301 "עִבְרִ֔ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					Exodus 10:3 w33847 "עִבְרִ֔ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					1_Samuel 4:6 w143432 "עִבְרִ֑ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					1_Samuel 13:3 w147857 "עִבְרִֽים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					and 3 more occurrences
#
# XTN[                       33x [be father-in-law] "חתן"
# 	verb ~ V    (OK?)      7x
# 	verb ~ N    (?  )      1x
# 					Judges 4:11 w129619 "חֹתֵ֣ן"
# 						BHS: verb
# 						OSM: HNcmsc - None
#
# XZH[                       31x [see] "חזה"
# 	verb ~ V    (OK )     28x
# 	verb ~ Tr   (?  )      1x
# 					Daniel 2:26 w371072 "חֲזֵ֖ית"
# 						BHS: verb
# 						OSM: ATr - None
#
# MWL[                       30x [circumcise] "מול"
# 	verb ~ V    (OK )     28x
# 	verb ~ R    (?  )      1x
# 					Jeremiah 9:24 w239863 "מ֖וּל"
# 						BHS: verb
# 						OSM: HR - None
#
# MYRJ/                      30x [Egyptian] "מִצְרִי"
# 	adjv ~ N    (?  )     10x
# 					Genesis 39:2 w21452 "מִּצְרִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					Genesis 39:5 w21508 "מִּצְרִ֖י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					Exodus 2:12 w29368 "מִּצְרִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					Exodus 2:14 w29415 "מִּצְרִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					2_Samuel 23:21 w175249 "מִּצְרִי֙"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					2_Samuel 23:21 w175265 "מִּצְרִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					Ezra 9:1 w382304 "מִּצְרִ֖י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					1_Chronicles 11:23 w397482 "מִּצְרִ֜י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					1_Chronicles 11:23 w397493 "מִּצְרִ֤י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					1_Chronicles 11:23 w397512 "מִּצְרִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# QBL/                       29x [opposite] "קֳבֵל"
# 	subs ~ C    (NN )     17x
# 	subs ~ R    (?  )      5x
# 					Daniel 2:31 w371183 "קָבְלָ֑ךְ"
# 						BHS: subs
# 						OSM: AR - ASp2ms
# 					Daniel 3:3 w371680 "קֳבֵ֣ל"
# 						BHS: subs
# 						OSM: AR - None
# 					Daniel 5:1 w373173 "קֳבֵ֥ל"
# 						BHS: subs
# 						OSM: AR - None
# 					Daniel 5:5 w373255 "קֳבֵ֣ל"
# 						BHS: subs
# 						OSM: AR - None
# 					Daniel 5:10 w373360 "קֳבֵ֨ל"
# 						BHS: subs
# 						OSM: AR - None
#
# KN/                        26x [correct] "כֵּן"
# 	adjv ~ A    (OK?)     13x
# 	adjv ~ Tm   (?  )     10x
# 					Exodus 10:29 w34441 "כֵּ֣ן"
# 						BHS: adjv
# 						OSM: HTm - None
# 					Numbers 27:7 w87018 "כֵּ֗ן"
# 						BHS: adjv
# 						OSM: HTm - None
# 					Numbers 36:5 w92641 "כֵּ֛ן"
# 						BHS: adjv
# 						OSM: HTm - None
# 					Joshua 2:4 w113450 "כֵּ֗ן"
# 						BHS: adjv
# 						OSM: HTm - None
# 					Judges 12:6 w135537 "כֵּ֔ן"
# 						BHS: adjv
# 						OSM: HTm - None
# 					1_Samuel 23:17 w155703 "כֵּֽן"
# 						BHS: adjv
# 						OSM: HTm - None
# 					Psalms 90:12 w326354 "כֵּ֣ן"
# 						BHS: adjv
# 						OSM: HTm - None
# 					Proverbs 11:19 w349793 "כֵּן"
# 						BHS: adjv
# 						OSM: HTm - None
# 					Proverbs 28:2 w354600 "כֵּ֣ן"
# 						BHS: adjv
# 						OSM: HTm - None
# 					Ecclesiastes 8:10 w362082 "כֵּן"
# 						BHS: adjv
# 						OSM: HTm - None
# 	adjv ~ D    (?  )      1x
# 					Amos 5:14 w296736 "כֵ֞ן"
# 						BHS: adjv
# 						OSM: HD - None
#
# XWJ/                       25x [Hivite] "חִוִּי"
# 	adjv ~ N    (NN )     18x
#
# KCJ/                       25x [Ethiopian] "כֻּשִׁי"
# 	adjv ~ N    (?  )      2x
# 					Amos 9:7 w297962 "כֻשִׁיִּ֨ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					Zephaniah 2:12 w303670 "כּוּשִׁ֔ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
#
# RBB[                       23x [be much] "רבב"
# 	verb ~ V    (OK )     20x
# 	verb ~ A    (?  )      1x
# 					Hosea 9:7 w292903 "רַבָּ֖ה"
# 						BHS: verb
# 						OSM: HAafsa - None
#
# PRZJ/                      23x [Perizzite] "פְּרִזִּי"
# 	adjv ~ N    (NN )     15x
#
# TMWL/                      23x [yesterday] "תְּמֹול"
# 	subs ~ D    (?  )      7x
# 					Exodus 5:8 w30963 "תְּמֹ֤ול"
# 						BHS: subs
# 						OSM: HD - None
# 					Exodus 5:14 w31087 "תְּמֹ֖ול"
# 						BHS: subs
# 						OSM: HD - None
# 					1_Samuel 20:27 w154001 "תְּמֹ֥ול"
# 						BHS: subs
# 						OSM: HD - None
# 					2_Samuel 3:17 w162032 "תְּמֹול֙"
# 						BHS: subs
# 						OSM: HD - None
# 					2_Samuel 15:20 w169320 "תְּמֹ֣ול"
# 						BHS: subs
# 						OSM: HD - None
# 					Ruth 2:11 w356488 "תְּמֹ֥ול"
# 						BHS: subs
# 						OSM: HD - None
# 					1_Chronicles 11:2 w397010 "תְּמֹ֣ול"
# 						BHS: subs
# 						OSM: HD - None
#
# LW                         22x [if only] "לוּ"
# 	conj ~ C    (OK )     21x
# 	conj ~ Tn   (?  )      1x
# 					2_Samuel 19:7 w172095 "לא"
# 						BHS: conj
# 						OSM: HTn - None
#
# >R</                       21x [earth] "אֲרַע"
# 	subs ~ N    (OK )     15x
# 	subs ~ Td   (?  )      1x
# 					Daniel 6:28 w374524 "אַרְעָ֑א"
# 						BHS: subs
# 						OSM: ATd - ATd
#
# XV>=/                      19x [sinful] "חַטָּא"
# 	adjv ~ A    (OK )     17x
# 	adjv ~ N    (?  )      1x
# 					Proverbs 1:10 w347016 "חַ֝טָּאִ֗ים"
# 						BHS: adjv
# 						OSM: HNcmpa - None
#
# CKX[                       18x [find] "שׁכח"
# 	verb ~ V    (OK )     13x
# 	verb ~ N    (?  )      1x
# 					Daniel 6:23 w374385 "הִשְׁתְּכַ֣חַת"
# 						BHS: verb
# 						OSM: ANcfsa - None
#
# >KN                        18x [surely] "אָכֵן"
# 	intj ~ D    (?  )      1x
# 					Zephaniah 3:7 w303852 "אָכֵן֙"
# 						BHS: intj
# 						OSM: HD - None
#
# >JTJ/                      17x [existence] "אִיתַי"
# 	subs ~ Ta   (NN )     14x
#
# HN                         16x [if] "הֵן"
# 	conj ~ C    (OK?)      7x
# 	conj ~ Tm   (?  )      1x
# 					Daniel 2:6 w370639 "הֵ֨ן"
# 						BHS: conj
# 						OSM: ATm - None
#
# CLJC=/                     16x [adjutant] "שָׁלִישׁ"
# 	subs ~ N    (OK?)      6x
# 	subs ~ A    (?  )      2x
# 					1_Chronicles 11:11 w397216 "שׁלושׁים"
# 						BHS: subs
# 						OSM: HAcbpa - None
# 					1_Chronicles 12:19 w398017 "שׁלושׁים"
# 						BHS: subs
# 						OSM: HAcbpa - None
#
# YJH/                       16x [dry country] "צִיָּה"
# 	subs ~ N    (OK )     13x
# 	subs ~ A    (?  )      1x
# 					Joel 2:20 w294738 "צִיָּ֣ה"
# 						BHS: subs
# 						OSM: HAafsa - None
#
# ZWLH/                      16x [except] "זוּלָה"
# 	subs ~ N    (OK?)      2x
# 	subs ~ R    (?  )      1x
# 					Hosea 13:4 w293766 "זֽוּלָתִי֙"
# 						BHS: subs
# 						OSM: HR - HSp1cs
#
# MW>BJ/                     16x [Moabite] "מֹואָבִי"
# 	adjv ~ N    (?  )      7x
# 					Ruth 1:4 w355864 "מֹֽאֲבִיֹּ֔ות"
# 						BHS: adjv
# 						OSM: HNgfpa - None
# 					Ruth 1:22 w356212 "מֹּואֲבִיָּ֤ה"
# 						BHS: adjv
# 						OSM: HNgfsa - None
# 					Ruth 2:2 w356247 "מֹּואֲבִיָּ֜ה"
# 						BHS: adjv
# 						OSM: HNgfsa - None
# 					Ruth 2:6 w356340 "מֹֽואֲבִיָּה֙"
# 						BHS: adjv
# 						OSM: HNgfsa - None
# 					Ruth 2:21 w356710 "מֹּואֲבִיָּ֑ה"
# 						BHS: adjv
# 						OSM: HNgfsa - None
# 					Ruth 4:5 w357236 "מֹּואֲבִיָּ֤ה"
# 						BHS: adjv
# 						OSM: HNgfsa - None
# 					Ruth 4:10 w357349 "מֹּאֲבִיָּה֩"
# 						BHS: adjv
# 						OSM: HNgfsa - None
#
# YJDNJ/                     16x [Sidonian] "צִידֹנִי"
# 	adjv ~ N    (?  )      1x
# 					Judges 3:3 w128760 "צִּ֣ידֹנִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# HW>                        15x [he] "הוּא"
# 	prps ~ P    (OK?)      8x
# 	prps ~ Ta   (?  )      4x
# 					Daniel 2:28 w371120 "הֽוּא"
# 						BHS: prps
# 						OSM: HTa - None
# 					Daniel 2:38 w371321 "ה֔וּא"
# 						BHS: prps
# 						OSM: ATa - None
# 					Daniel 2:47 w371547 "ה֣וּא"
# 						BHS: prps
# 						OSM: ATa - None
# 					Daniel 3:15 w371956 "ה֣וּא"
# 						BHS: prps
# 						OSM: ATa - None
#
# >PW                        15x [then] "אֵפֹו"
# 	intj ~ D    (?  )      1x
# 					Hosea 13:10 w293827 "אֵפֹ֔וא"
# 						BHS: intj
# 						OSM: HD - None
#
# QHTJ/                      15x [Kohathite] "קְהָתִי"
# 	adjv ~ N    (NN )     12x
#
# XD/                        14x [one] "חַד"
# 	subs ~ A    (?  )      6x
# 					Daniel 2:9 w370696 "חֲדָה"
# 						BHS: subs
# 						OSM: AAcfsa - None
# 					Daniel 2:31 w371173 "חַד֙"
# 						BHS: subs
# 						OSM: AAcmsa - None
# 					Daniel 2:35 w371241 "חֲדָ֡ה"
# 						BHS: subs
# 						OSM: AAcfsa - None
# 					Daniel 3:19 w372040 "חַ֨ד"
# 						BHS: subs
# 						OSM: AAcmsa - None
# 					Daniel 4:16 w372697 "חֲדָ֔ה"
# 						BHS: subs
# 						OSM: AAcfsa - None
# 					Daniel 6:3 w373873 "חַֽד"
# 						BHS: subs
# 						OSM: AAcmsa - None
# 	subs ~ N    (OK?)      1x
#
# XKJM/                      14x [wise] "חַכִּים"
# 	adjv ~ N    (NN )     13x
#
# MH                         14x [what] "מָה"
# 	prin ~ P    (?  )      9x
# 					Daniel 2:15 w370840 "מָ֥ה"
# 						BHS: prin
# 						OSM: APixbs - None
# 					Daniel 2:22 w370966 "מָ֣ה"
# 						BHS: prin
# 						OSM: APfxbs - None
# 					Daniel 2:28 w371107 "מָ֛ה"
# 						BHS: prin
# 						OSM: APfxbs - None
# 					Daniel 2:29 w371127 "מָ֛ה"
# 						BHS: prin
# 						OSM: APfxbs - None
# 					Daniel 2:29 w371136 "מָה"
# 						BHS: prin
# 						OSM: APfxbs - None
# 					Daniel 2:45 w371507 "מָ֛ה"
# 						BHS: prin
# 						OSM: APfxbs - None
# 					Daniel 3:33 w372373 "מָ֣ה"
# 						BHS: prin
# 						OSM: APfxcs - None
# 					Daniel 3:33 w372378 "מָ֣ה"
# 						BHS: prin
# 						OSM: APfxcs - None
# 					Daniel 4:32 w373106 "מָ֥ה"
# 						BHS: prin
# 						OSM: APixbs - None
#
# >LP==/                     14x [group of thousand] "אֶלֶף"
# 	subs ~ A    (NN )     13x
# 	subs ~ N    (OK?)      1x
#
# JMJNJ/                     13x [Benjaminite] "יְמִינִי"
# 	adjv ~ N    (?  )      2x
# 					Judges 3:15 w129020 "יְמִינִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					Esther 2:5 w366136 "יְמִינִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# <DN/                       13x [time] "עִדָּן"
# 	subs ~ N    (OK?)      9x
# 	subs ~ A    (?  )      1x
# 					Daniel 4:20 w372826 "עִדָּנִ֖ין"
# 						BHS: subs
# 						OSM: AAcbsa - None
#
# GRCNJ/                     13x [Gershonite] "גֵּרְשֻׁנִּי"
# 	adjv ~ N    (NN )     11x
#
# XRY[                       12x [cut off] "חרץ"
# 	verb ~ V    (OK?)      8x
# 	verb ~ N    (?  )      2x
# 					Joel 4:14 w295245 "חָר֑וּץ"
# 						BHS: verb
# 						OSM: HNp - None
# 					Joel 4:14 w295253 "חָרֽוּץ"
# 						BHS: verb
# 						OSM: HNp - None
#
# >PH/                       12x [baker] "אֹפֶה"
# 	subs ~ V    (?  )      2x
# 					Hosea 7:4 w292417 "אֹפֶ֑ה"
# 						BHS: subs
# 						OSM: HVqrmsa - None
# 					Hosea 7:6 w292448 "אֹֽפֵהֶ֔ם"
# 						BHS: subs
# 						OSM: HVqrmsc - HSp3mp
#
# QJNJ/                      12x [Kenite] "קֵינִי"
# 	adjv ~ N    (?  )      5x
# 					Judges 1:16 w127766 "קֵינִי֩"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					Judges 4:11 w129612 "קֵּינִי֙"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					Judges 4:17 w129765 "קֵּינִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					Judges 4:17 w129777 "קֵּינִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
# 					Judges 5:24 w130299 "קֵּינִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# GL<DJ/                     11x [Gileadite] "גִּלְעָדִי"
# 	adjv ~ N    (NN )     10x
#
# BHL[                       11x [disturb] "בהל"
# 	verb ~ V    (OK?)      9x
# 	verb ~ N    (?  )      1x
# 					Daniel 6:20 w374320 "הִ֨תְבְּהָלָ֔ה"
# 						BHS: verb
# 						OSM: ANcfsa - None
#
# TLT/                       11x [three] "תְּלָת"
# 	subs ~ A    (?  )      5x
# 					Daniel 3:23 w372118 "תְּלָ֣תֵּהֹ֔ון"
# 						BHS: subs
# 						OSM: AAcmsc - ASp3mp
# 					Daniel 3:24 w372146 "תְּלָתָ֜א"
# 						BHS: subs
# 						OSM: AAcmsa - None
# 					Daniel 6:3 w373870 "תְּלָתָ֔א"
# 						BHS: subs
# 						OSM: AAcmsa - None
# 					Daniel 6:11 w374071 "תְּלָתָ֨ה"
# 						BHS: subs
# 						OSM: AAcbsa - None
# 					Daniel 6:14 w374181 "תְּלָתָה֙"
# 						BHS: subs
# 						OSM: AAcbsa - None
#
# RBW>/                      10x [ten thousand] "רִבֹּוא"
# 	subs ~ A    (?  )      1x
# 					Jonah 4:11 w299528 "רִבֹּ֜ו"
# 						BHS: subs
# 						OSM: HAcfsa - None
#
# MN=                        10x [who] "מַן"
# 	prin ~ P    (?  )      9x
# 					Daniel 3:6 w371722 "מַן"
# 						BHS: prin
# 						OSM: APf3bs - None
# 					Daniel 3:11 w371823 "מַן"
# 						BHS: prin
# 						OSM: APf3cs - None
# 					Daniel 3:15 w371955 "מַן"
# 						BHS: prin
# 						OSM: APi3cs - None
# 					Daniel 4:14 w372649 "מַן"
# 						BHS: prin
# 						OSM: APfxcs - None
# 					Daniel 4:22 w372880 "מַן"
# 						BHS: prin
# 						OSM: APrxcs - None
# 					Daniel 4:29 w373009 "מַן"
# 						BHS: prin
# 						OSM: APrxcs - None
# 					Ezra 5:3 w380084 "מַן"
# 						BHS: prin
# 						OSM: APi - None
# 					Ezra 5:4 w380101 "מַן"
# 						BHS: prin
# 						OSM: APi - None
# 					Ezra 5:9 w380205 "מַן"
# 						BHS: prin
# 						OSM: APi - None
#
# JHWDJ/                     10x [Jew] "יְהוּדָי"
# 	adjv ~ N    (?  )      2x
# 					Daniel 3:8 w371784 "יְהוּדָיֵֽא"
# 						BHS: adjv
# 						OSM: ANgmpd - ATd
# 					Daniel 3:12 w371837 "יְהוּדָאיִ֗ן"
# 						BHS: adjv
# 						OSM: ANgmpa - None
#
# <LJ/                       10x [highest] "עִלָּי"
# 	adjv ~ A    (OK?)      8x
# 	adjv ~ N    (?  )      1x
# 					Daniel 4:14 w372643 "עליא"
# 						BHS: adjv
# 						OSM: ANcmsd - ATd
#
# KRTJ/                      10x [Cherethite] "כְּרֵתִי"
# 	adjv ~ N    (?  )      1x
# 					Zephaniah 2:5 w303541 "כְּרֵתִ֑ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
#
# <ML=/                       9x [labouring] "עָמֵל"
# 	adjv ~ A    (OK?)      8x
# 	adjv ~ N    (?  )      1x
# 					Judges 5:26 w130324 "עֲמֵלִ֑ים"
# 						BHS: adjv
# 						OSM: HNcmpa - None
#
# PWQ[                        9x [totter] "פוק"
# 	verb ~ V    (OK?)      6x
# 	verb ~ N    (?  )      1x
# 					Proverbs 3:13 w347564 "יָפִ֥יק"
# 						BHS: verb
# 						OSM: HNcfsa - None
#
# CB<=/                       9x [Sheba] "שֶׁבַע"
# 	nmpr ~ A    (?  )      9x
# 					2_Samuel 20:1 w173091 "שֶׁ֥בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					2_Samuel 20:2 w173128 "שֶׁ֣בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					2_Samuel 20:6 w173220 "שֶׁ֥בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					2_Samuel 20:7 w173263 "שֶׁ֥בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					2_Samuel 20:10 w173353 "שֶׁ֥בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					2_Samuel 20:13 w173432 "שֶׁ֥בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					2_Samuel 20:21 w173587 "שֶׁ֧בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					2_Samuel 20:22 w173635 "שֶׁ֤בַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
# 					1_Chronicles 5:13 w393655 "שֶׁבַע"
# 						BHS: nmpr
# 						OSM: HAcfsa - None
#
# KFDJ/                       9x [Chaldaean] "כַּשְׂדָּי"
# 	adjv ~ N    (?  )      6x
# 					Daniel 2:5 w370622 "כשׂדיא"
# 						BHS: adjv
# 						OSM: ANgmsd - ATd
# 					Daniel 2:10 w370722 "כשׂדיא"
# 						BHS: adjv
# 						OSM: ANgmsd - ATd
# 					Daniel 2:10 w370758 "כַשְׂדָּֽי"
# 						BHS: adjv
# 						OSM: ANgbsa - None
# 					Daniel 3:8 w371779 "כַּשְׂדָּאִ֑ין"
# 						BHS: adjv
# 						OSM: ANgmpa - None
# 					Daniel 4:4 w372431 "כשׂדיא"
# 						BHS: adjv
# 						OSM: ANgmpd - ATd
# 					Daniel 5:7 w373296 "כשׂדיא"
# 						BHS: adjv
# 						OSM: ANgmpd - ATd
#
# KBR/                        9x [long time] "כְּבָר"
# 	subs ~ D    (?  )      7x
# 					Ecclesiastes 1:10 w359420 "כְּבָר֙"
# 						BHS: subs
# 						OSM: HD - None
# 					Ecclesiastes 2:12 w359817 "כְּבָ֖ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Ecclesiastes 2:16 w359899 "כְּבָ֞ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Ecclesiastes 3:15 w360364 "כְּבָ֣ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Ecclesiastes 3:15 w360370 "כְּבָ֣ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Ecclesiastes 4:2 w360586 "כְּבָ֣ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Ecclesiastes 6:10 w361418 "כְּבָר֙"
# 						BHS: subs
# 						OSM: HD - None
#
# HSH[                        8x [be still] "הסה"
# 	verb ~ V    (OK?)      4x
# 	verb ~ Tj   (?  )      2x
# 					Habakkuk 2:20 w302794 "הַ֥ס"
# 						BHS: verb
# 						OSM: HTj - None
# 					Zephaniah 1:7 w303207 "הַ֕ס"
# 						BHS: verb
# 						OSM: HTj - None
#
# M>H/                        8x [hundred] "מְאָה"
# 	subs ~ A    (?  )      1x
# 					Daniel 6:2 w373858 "מְאָ֣ה"
# 						BHS: subs
# 						OSM: AAcbsa - None
#
# JCM<>LJ/                    8x [Ishmaelite] "יִשְׁמְעֵאלִי"
# 	adjv ~ N    (?  )      3x
# 					Genesis 37:25 w20631 "יִשְׁמְעֵאלִ֔ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					Judges 8:24 w132654 "יִשְׁמְעֵאלִ֖ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
# 					Psalms 83:7 w324890 "יִשְׁמְעֵאלִ֗ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
#
# >RB</                       8x [four] "אַרְבַּע"
# 	subs ~ A    (?  )      2x
# 					Daniel 3:25 w372166 "אַרְבְּעָ֗ה"
# 						BHS: subs
# 						OSM: AAcbsa - None
# 					Daniel 7:6 w374665 "אַרְבַּ֛ע"
# 						BHS: subs
# 						OSM: AAcbsa - None
#
# HJ>                         7x [she] "הִיא"
# 	prps ~ P    (OK?)      6x
# 	prps ~ Ta   (?  )      1x
# 					Daniel 2:20 w370939 "הִֽיא"
# 						BHS: prps
# 						OSM: ATa - None
#
# >LP/                        7x [cattle] "אֶלֶף"
# 	subs ~ N    (OK?)      6x
# 	subs ~ A    (?  )      1x
# 					Proverbs 14:4 w350421 "אֲ֭לָפִים"
# 						BHS: subs
# 						OSM: HAcbpa - None
#
# PT</                        7x [instant] "פֶּתַע"
# 	subs ~ N    (OK?)      2x
# 	subs ~ D    (?  )      1x
# 					Habakkuk 2:7 w302585 "פֶ֗תַע"
# 						BHS: subs
# 						OSM: HD - None
#
# <FR/                        6x [ten] "עֲשַׂר"
# 	subs ~ A    (?  )      1x
# 					Daniel 4:26 w372931 "עֲשַׂ֑ר"
# 						BHS: subs
# 						OSM: AAcmsa - None
#
# Z<P/                        6x [rage] "זַעַף"
# 	subs ~ N    (OK?)      3x
# 	subs ~ V    (?  )      1x
# 					Jonah 1:15 w298910 "זַּעְפֹּֽו"
# 						BHS: subs
# 						OSM: HVqc - HSp3ms
#
# PLNJ/                       6x [a certain] "פְּלֹנִי"
# 	subs ~ P    (?  )      1x
# 					Ruth 4:1 w357142 "פְּלֹנִ֣י"
# 						BHS: subs
# 						OSM: HPf - None
#
# CB</                        6x [seven] "שְׁבַע"
# 	subs ~ A    (?  )      5x
# 					Daniel 3:19 w372041 "שִׁבְעָ֔ה"
# 						BHS: subs
# 						OSM: AAcmsa - None
# 					Daniel 4:13 w372624 "שִׁבְעָ֥ה"
# 						BHS: subs
# 						OSM: AAcbsa - None
# 					Daniel 4:20 w372825 "שִׁבְעָ֥ה"
# 						BHS: subs
# 						OSM: AAcbsa - None
# 					Daniel 4:22 w372865 "שִׁבְעָ֥ה"
# 						BHS: subs
# 						OSM: AAcbsa - None
# 					Daniel 4:29 w372994 "שִׁבְעָ֥ה"
# 						BHS: subs
# 						OSM: AAcbsa - None
#
# TXWT/                       5x [underneath] "תְּחֹות"
# 	subs ~ R    (?  )      3x
# 					Daniel 4:9 w372531 "תְּחֹתֹ֜והִי"
# 						BHS: subs
# 						OSM: AR - ASp3ms
# 					Daniel 4:11 w372580 "תַּחְתֹּ֔והִי"
# 						BHS: subs
# 						OSM: AR - ASp3ms
# 					Daniel 4:18 w372751 "תְּחֹתֹ֗והִי"
# 						BHS: subs
# 						OSM: AR - ASp3ms
#
# >RMJ=/                      5x [in Aramaic] "אֲרָמִי"
# 	adjv ~ N    (?  )      1x
# 					Daniel 2:4 w370605 "אֲרָמִ֑ית"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# VWB==/                      5x [perfume] "טֹוב"
# 	subs ~ A    (?  )      1x
# 					Song_of_songs 7:10 w358990 "טֹּ֛וב"
# 						BHS: subs
# 						OSM: HAamsa - None
#
# >PRTJ/                      5x [Ephrathite] "אֶפְרָתִי"
# 	adjv ~ N    (?  )      1x
# 					Ruth 1:2 w355838 "אֶפְרָתִ֔ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
#
# BRM                         5x [but] "בְּרַם"
# 	advb ~ C    (?  )      3x
# 					Daniel 2:28 w371095 "בְּרַ֡ם"
# 						BHS: advb
# 						OSM: AC - None
# 					Daniel 4:12 w372585 "בְּרַ֨ם"
# 						BHS: advb
# 						OSM: AC - None
# 					Daniel 4:20 w372796 "בְּרַ֨ם"
# 						BHS: advb
# 						OSM: AC - None
# 	advb ~ D    (OK?)      2x
#
# TRJN/                       4x [two] "תְּרֵין"
# 	subs ~ A    (?  )      2x
# 					Daniel 4:26 w372930 "תְּרֵֽי"
# 						BHS: subs
# 						OSM: AAcmsc - None
# 					Daniel 6:1 w373848 "תַרְתֵּֽין"
# 						BHS: subs
# 						OSM: AAcbpa - None
#
# MGN=/                       4x [insolent] "מָגֵן"
# 	adjv ~ N    (?  )      1x
# 					Hosea 4:18 w291977 "מָגִנֶּֽיהָ"
# 						BHS: adjv
# 						OSM: HNcbpc - HSp3fs
#
# >LP/                        4x [thousand] "אֲלַף"
# 	subs ~ A    (?  )      2x
# 					Daniel 5:1 w373170 "אֲלַ֑ף"
# 						BHS: subs
# 						OSM: AAcmsa - None
# 					Daniel 5:1 w373174 "אַלְפָּ֖א"
# 						BHS: subs
# 						OSM: AAcmsd - ATd
#
# LWBJ/                       4x [Libyan] "לוּבִי"
# 	adjv ~ N    (?  )      1x
# 					Nahum 3:9 w302009 "לוּבִ֔ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
#
# RB=/                        4x [chief] "רַב"
# 	subs ~ A    (?  )      3x
# 					Daniel 2:14 w370820 "רַב"
# 						BHS: subs
# 						OSM: AAamsc - None
# 					Daniel 2:48 w371580 "רַב"
# 						BHS: subs
# 						OSM: AAamsc - None
# 					Daniel 4:6 w372467 "רַ֣ב"
# 						BHS: subs
# 						OSM: AAamsc - None
#
# TXT==/                      4x [Tahath] "תַּחַת"
# 	nmpr ~ R    (?  )      2x
# 					1_Chronicles 6:9 w394165 "תַּ֤חַת"
# 						BHS: nmpr
# 						OSM: HR - None
# 					1_Chronicles 6:22 w394298 "תַּ֨חַת֙"
# 						BHS: nmpr
# 						OSM: HR - None
# 	nmpr ~ N    (OK?)      2x
#
# CTJN/                       4x [sixty] "שִׁתִּין"
# 	subs ~ A    (?  )      2x
# 					Daniel 3:1 w371616 "שִׁתִּ֔ין"
# 						BHS: subs
# 						OSM: AAcfpa - None
# 					Daniel 6:1 w373846 "שִׁתִּ֥ין"
# 						BHS: subs
# 						OSM: AAcbpa - None
#
# L>_RXMH/                    3x [Lo-Ruhamah] "לֹא רֻחָמָה"
# 	nmpr ~ Tn   (?  )      3x
# 					Hosea 1:6 w291032 "לֹ֣א רֻחָ֑מָה"
# 						BHS: nmpr
# 						OSM: HTn - HNp
# 					Hosea 1:8 w291074 "לֹ֣א רֻחָ֑מָה"
# 						BHS: nmpr
# 						OSM: HTn - HNp
# 					Hosea 2:25 w291573 "לֹ֣א רֻחָ֑מָה"
# 						BHS: nmpr
# 						OSM: HTn - HNp
#
# TLT=/                       3x [triumvir] "תְּלָת"
# 	subs ~ A    (?  )      1x
# 					Daniel 5:7 w373325 "תַלְתִּ֥י"
# 						BHS: subs
# 						OSM: AAomsa - None
#
# LHN                         3x [therefore] "לָהֵן"
# 	advb ~ C    (?  )      3x
# 					Daniel 2:6 w370653 "לָהֵ֕ן"
# 						BHS: advb
# 						OSM: AC - None
# 					Daniel 2:9 w370712 "לָהֵ֗ן"
# 						BHS: advb
# 						OSM: AC - None
# 					Daniel 4:24 w372902 "לָהֵ֣ן"
# 						BHS: advb
# 						OSM: AC - None
#
# <QB==/                      3x [something knobby] "עָקֹב"
# 	subs ~ N    (OK?)      1x
# 	subs ~ A    (?  )      1x
# 					Hosea 6:8 w292331 "עֲקֻבָּ֖ה"
# 						BHS: subs
# 						OSM: HAafsa - None
#
# >XR/                        3x [after] "אַחַר"
# 	subs ~ R    (?  )      2x
# 					Daniel 2:29 w371130 "אַחֲרֵ֣י"
# 						BHS: subs
# 						OSM: HR - None
# 					Daniel 2:45 w371510 "אַחֲרֵ֣י"
# 						BHS: subs
# 						OSM: AR - None
#
# DWMM                        3x [silently] "דּוּמָם"
# 	advb ~ D    (OK?)      1x
# 	advb ~ N    (?  )      1x
# 					Habakkuk 2:19 w302774 "דּוּמָ֑ם"
# 						BHS: advb
# 						OSM: HNcmsa - None
#
# HMWN                        3x [they] "הִמֹּון"
# 	prps ~ P    (OK?)      2x
# 	prps ~ S    (?  )      1x
# 					Daniel 2:35 w371257 "הִמֹּון֙"
# 						BHS: prps
# 						OSM: ASp3mp - None
#
# >LMNJ/                      3x [stranger] "אַלְמֹנִי"
# 	subs ~ A    (?  )      1x
# 					Ruth 4:1 w357143 "אַלְמֹנִ֑י"
# 						BHS: subs
# 						OSM: HAabsa - None
#
# CC==/                       3x [alabaster] "שֵׁשׁ"
# 	subs ~ A    (?  )      3x
# 					Song_of_songs 5:15 w358658 "שֵׁ֔שׁ"
# 						BHS: subs
# 						OSM: HAcfsa - None
# 					Esther 1:6 w365583 "שֵׁ֑שׁ"
# 						BHS: subs
# 						OSM: HAcfsa - None
# 					Esther 1:6 w365592 "שֵׁ֖שׁ"
# 						BHS: subs
# 						OSM: HAcfsa - None
#
# >J=                         2x [how] "אִי"
# 	inrg ~ Tj   (?  )      1x
# 					Ecclesiastes 10:16 w362940 "אִֽי"
# 						BHS: inrg
# 						OSM: HTj - None
#
# L>_<MJ/                     2x [Lo-Ammi] "לֹא עַמִּי"
# 	nmpr ~ Tn   (?  )      1x
# 					Hosea 1:9 w291084 "לֹ֣א עַמִּ֑י"
# 						BHS: nmpr
# 						OSM: HTn - HNp
# 	nmpr ~ N    (OK?)      1x
#
# M>H=/                       2x [the Hundred] "מֵאָה"
# 	nmpr ~ A    (?  )      2x
# 					Nehemiah 3:1 w384288 "מֵּאָה֙"
# 						BHS: nmpr
# 						OSM: HAcbsa - None
# 					Nehemiah 12:39 w390299 "מֵּאָ֔ה"
# 						BHS: nmpr
# 						OSM: HAcbsa - None
#
# >HB/                        2x [display of love] "אֹהַב"
# 	subs ~ V    (?  )      1x
# 					Hosea 9:10 w292956 "אָהֳבָֽם"
# 						BHS: subs
# 						OSM: HVqc - HSp3mp
# 	subs ~ N    (OK?)      1x
#
# TLTJN/                      2x [thirty] "תְּלָתִין"
# 	subs ~ A    (?  )      2x
# 					Daniel 6:8 w374013 "תְּלָתִ֗ין"
# 						BHS: subs
# 						OSM: AAcmpa - None
# 					Daniel 6:13 w374132 "תְּלָתִ֗ין"
# 						BHS: subs
# 						OSM: AAcmpa - None
#
# BJN/                        2x [between] "בֵּין"
# 	subs ~ R    (?  )      1x
# 					Daniel 7:5 w374643 "בֵּ֣ין"
# 						BHS: subs
# 						OSM: AR - None
#
# >ZD>                        2x [publicly known] "אַזְדָּא"
# 	advb ~ A    (?  )      2x
# 					Daniel 2:5 w370625 "אַזְדָּ֑א"
# 						BHS: advb
# 						OSM: AAafsa - None
# 					Daniel 2:8 w370688 "אַזְדָּ֖א"
# 						BHS: advb
# 						OSM: AAafsa - None
#
# >WJL_MRDK/                  2x [Evil-merodach] "אֱוִיל מְרֹדַךְ"
# 	nmpr ~ A    (?  )      2x
# 					2_Kings 25:27 w212008 "אֱוִ֣יל מְרֹדַךְ֩"
# 						BHS: nmpr
# 						OSM: HAamsa -
# 					Jeremiah 52:31 w264667 "אֱוִ֣יל מְרֹדַךְ֩"
# 						BHS: nmpr
# 						OSM: HAamsa -
#
# GBWRH/                      2x [power] "גְּבוּרָה"
# 	subs ~ N    (OK?)      1x
# 	subs ~ Td   (?  )      1x
# 					Daniel 2:23 w370983 "גְבוּרְתָ֖א"
# 						BHS: subs
# 						OSM: ATd - ATd
#
# >NH=[                       2x [mourn] "אנה"
# 	verb ~ D    (?  )      2x
# 					Isaiah 3:26 w213275 "אָנ֥וּ"
# 						BHS: verb
# 						OSM: HD - None
# 					Isaiah 19:8 w218260 "אָנוּ֙"
# 						BHS: verb
# 						OSM: HD - None
#
# >JKBWD/                     2x [Ichabod] "אִיכָבֹוד"
# 	nmpr ~ Tj   (?  )      1x
# 					1_Samuel 4:21 w143795 "אִֽי־כָבֹוד֙"
# 						BHS: nmpr
# 						OSM: HTj -
# 	nmpr ~ N    (OK?)      1x
#
# MD<=/                       2x [kinsman] "מֹדָע"
# 	subs ~ N    (OK?)      1x
# 	subs ~ V    (?  )      1x
# 					Ruth 2:1 w356231 "מידע"
# 						BHS: subs
# 						OSM: HVPrmsa - None
#
# CT/                         2x [six] "שֵׁת"
# 	subs ~ A    (?  )      1x
# 					Daniel 3:1 w371619 "שִׁ֑ת"
# 						BHS: subs
# 						OSM: AAcfsa - None
#
# LHN                         2x [therefore] "לָהֵן"
# 	advb ~ C    (?  )      2x
# 					Ruth 1:13 w356036 "לָהֵ֣ן"
# 						BHS: advb
# 						OSM: HC - None
# 					Ruth 1:13 w356042 "לָהֵן֙"
# 						BHS: advb
# 						OSM: HC - None
#
# CWLMJ/                      2x [Shulammite] "שׁוּלַמִּי"
# 	adjv ~ N    (?  )      2x
# 					Song_of_songs 7:1 w358858 "שּׁ֣וּלַמִּ֔ית"
# 						BHS: adjv
# 						OSM: HNgfsa - None
# 					Song_of_songs 7:1 w358868 "שּׁ֣וּלַמִּ֔ית"
# 						BHS: adjv
# 						OSM: HNgfsa - None
#
# >CRJ/                       1x [from Asher] "אָשֵׁרִי"
# 	adjv ~ N    (?  )      1x
# 					Judges 1:32 w128117 "אָ֣שֵׁרִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# <NH/                        1x [humble] "עֲנֵה"
# 	adjv ~ N    (?  )      1x
# 					Daniel 4:24 w372916 "עֲנָ֑יִן"
# 						BHS: adjv
# 						OSM: ANcmpa - None
#
# RXMH==/                     1x [Ruhamah] "רֻחָמָה"
# 	nmpr ~ V    (?  )      1x
# 					Hosea 2:3 w291153 "רֻחָֽמָה"
# 						BHS: nmpr
# 						OSM: HVPp3fs - None
#
# <WD/                        1x [still] "עֹוד"
# 	subs ~ D    (?  )      1x
# 					Daniel 4:28 w372962 "עֹ֗וד"
# 						BHS: subs
# 						OSM: AD - None
#
# JWNJ/                       1x [Greek] "יְוָנִי"
# 	adjv ~ N    (?  )      1x
# 					Joel 4:6 w295121 "יְּוָנִ֑ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
#
# XLC/                        1x [weak man] "חַלָּשׁ"
# 	subs ~ A    (?  )      1x
# 					Joel 4:10 w295187 "חַלָּ֔שׁ"
# 						BHS: subs
# 						OSM: HAamsa - None
#
# MDJ=/                       1x [Median] "מָדַי"
# 	adjv ~ N    (?  )      1x
# 					Daniel 6:1 w373840 "מדיא"
# 						BHS: adjv
# 						OSM: ANgmsd - ATd
#
# <FRJN/                      1x [twenty] "עֶשְׂרִין"
# 	subs ~ A    (?  )      1x
# 					Daniel 6:2 w373860 "עֶשְׂרִ֑ין"
# 						BHS: subs
# 						OSM: AAcbpa - None
#
# >PL/                        1x [darkness] "אָפֵל"
# 	subs ~ A    (?  )      1x
# 					Amos 5:20 w296852 "אָפֵ֖ל"
# 						BHS: subs
# 						OSM: HAamsa - None
#
# NGD/                        1x [toward] "נֶגֶד"
# 	subs ~ R    (?  )      1x
# 					Daniel 6:11 w374067 "נֶ֖גֶד"
# 						BHS: subs
# 						OSM: AR - None
#
# PRSJ/                       1x [Persian] "פַּרְסָי"
# 	adjv ~ N    (?  )      1x
# 					Daniel 6:29 w374543 "פרסיא"
# 						BHS: adjv
# 						OSM: ANgmsd - ATd
#
# N>/                         1x [raw] "נָא"
# 	adjv ~ Te   (?  )      1x
# 					Exodus 12:9 w34847 "נָ֔א"
# 						BHS: adjv
# 						OSM: HTe - None
#
# >LQCJ/                      1x [Elkoshite] "אֶלְקֹשִׁי"
# 	adjv ~ N    (?  )      1x
# 					Nahum 1:1 w301441 "אֶלְקֹשִֽׁי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# TNJNWT                      1x [again] "תִּנְיָנוּת"
# 	advb ~ A    (?  )      1x
# 					Daniel 2:7 w370659 "תִנְיָנ֖וּת"
# 						BHS: advb
# 						OSM: AAobpa - None
#
# >J==                        1x [not] "אִי"
# 	nega ~ Tj   (?  )      1x
# 					Job 22:30 w341757 "אִֽי"
# 						BHS: nega
# 						OSM: HTj - None
#
# KDBH/                       1x [lie] "כִּדְבָה"
# 	subs ~ A    (?  )      1x
# 					Daniel 2:9 w370701 "כִדְבָ֤ה"
# 						BHS: subs
# 						OSM: AAafsa - None
#
# NVJL/                       1x [weighing] "נָטִיל"
# 	adjv ~ N    (?  )      1x
# 					Zephaniah 1:11 w303303 "נְטִ֥ילֵי"
# 						BHS: adjv
# 						OSM: HNcmpc - None
#
# PWYJ/                       1x [<uncertain>] "פּוּצַי"
# 	subs ~ V    (?  )      1x
# 					Zephaniah 3:10 w303914 "פּוּצַ֔י"
# 						BHS: subs
# 						OSM: HVqsmsc - HSp1cs
#
# KJ/                         1x [branding] "כִּי"
# 	subs ~ C    (?  )      1x
# 					Isaiah 3:24 w213261 "כִּי"
# 						BHS: subs
# 						OSM: HC - None
#
# CB<H/                       1x [Shibah] "שִׁבְעָה"
# 	nmpr ~ A    (?  )      1x
# 					Genesis 26:33 w13591 "שִׁבְעָ֑ה"
# 						BHS: nmpr
# 						OSM: HAcmsa - None
#
# YD>                         1x [really] "צְדָא"
# 	advb ~ N    (?  )      1x
# 					Daniel 3:14 w371896 "צְדָּ֕א"
# 						BHS: advb
# 						OSM: ANcmsa - None
#
# >XZ/                        1x [holding] "אָחֻז"
# 	adjv ~ V    (?  )      1x
# 					Song_of_songs 3:8 w358155 "אֲחֻ֣זֵי"
# 						BHS: adjv
# 						OSM: HVqsmpc - None
#
# >L==                        1x [where] "אַל"
# 	inrg ~ Tn   (?  )      1x
# 					1_Samuel 27:10 w158427 "אַל"
# 						BHS: inrg
# 						OSM: HTn - None

# %% [markdown]
# # SP versus PDP
#
# Here is the computation that shows that the BHS feature
# [sp](https://etcbc.github.io/bhsa/features/hebrew/2017/sp)
# matches the OSM part-of-speech better than
# [pdp](https://etcbc.github.io/bhsa/features/hebrew/2017/pdp).

# %%
discrepancies = {}

for w in F.otype.s('word'):
    osm = osmPsp[w]
    if osm == '×': continue
    lex = F.lex.v(w)
    trans = pspBhsFromOsm[osm]
    if F.sp.v(w) not in trans:
        discrepancies.setdefault('sp', set()).add(w)
    if F.pdp.v(w) not in trans:
        discrepancies.setdefault('pdp', set()).add(w)
        
lexDiscrepancies = {} # discrepancies per lexeme
for (ft, ws) in sorted(discrepancies.items()):
    for w in sorted(ws):
        lexNode = L.u(w, otype='lex')[0]
        lexInfo = lexDiscrepancies.setdefault(ft, {})
        if lexNode in lexInfo:
            continue
        lexInfo[lexNode] = w

if discrepancies:
    print('Discrepancies')
    for (ft, lexInfo) in sorted(lexDiscrepancies.items()):
        print('\n--- {:<4}: {:>4} lexemes ---\n'.format(ft, len(lexInfo)))
        
    for (ft, ws) in sorted(discrepancies.items()):
        n = len(ws)
        print('\n--- {:<4}: {:>6}x ---\n'.format(ft, n))
        for w in sorted(ws)[0:10]:
            show(T, F, [w], Fs(ft).v, getOSMpsp)
        if n > 10:
            print('\tand {} more'.format(n - 10))
# Out:
# Discrepancies
#
# --- pdp :  916 lexemes ---
#
#
# --- sp  :  207 lexemes ---
#
#
# --- pdp :  15469x ---
#
# Genesis 1:5 w78 "אֶחָֽד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# Genesis 1:9 w152 "אֶחָ֔ד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# Genesis 1:16 w286 "שְׁנֵ֥י"
# 	BHS: subs
# 	OSM: HAcmdc - None
# Genesis 1:21 w392 "הַֽ"
# 	BHS: conj
# 	OSM: HTd - None
# Genesis 1:21 w394 "הָֽ"
# 	BHS: conj
# 	OSM: HTd - None
# Genesis 1:26 w529 "הָֽ"
# 	BHS: conj
# 	OSM: HTd - None
# Genesis 1:28 w585 "הָֽ"
# 	BHS: conj
# 	OSM: HTd - None
# Genesis 1:30 w637 "רֹומֵ֣שׂ"
# 	BHS: subs
# 	OSM: HVqrmsa - None
# Genesis 1:31 w673 "שִּׁשִּֽׁי"
# 	BHS: subs
# 	OSM: HAomsa - None
# Genesis 2:3 w713 "שְּׁבִיעִ֔י"
# 	BHS: subs
# 	OSM: HAomsa - None
# 	and 15459 more
#
# --- sp  :  11915x ---
#
# Genesis 1:4 w51 "בֵּ֥ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:4 w55 "בֵ֥ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:5 w78 "אֶחָֽד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# Genesis 1:6 w91 "בֵּ֥ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:7 w103 "בֵּ֤ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:7 w113 "בֵ֣ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:9 w152 "אֶחָ֔ד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# Genesis 1:14 w247 "בֵּ֥ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:14 w251 "בֵ֣ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:16 w286 "שְׁנֵ֥י"
# 	BHS: subs
# 	OSM: HAcmdc - None
# 	and 11905 more

# %%
strangePsp = {}
strangeSuffix = {}

for w in F.otype.s('word'):
    osm = osmPsp[w]
    if osm == '×': continue

    if osm == 'S' or osm not in pspBhsFromOsm:
        strangePsp.setdefault(osm, set()).add(w)

    osm_sf = F.osm_sf.v(w)
    if osm_sf:
        osmSuffix = None if len(osm_sf) < 2 else osm_sf[1]
        if osmSuffix != 'S':           
            strangeSuffix.setdefault(osmSuffix, set()).add(w)
            
if strangePsp:
    print('Strange psp')
    for (ln, ws) in sorted(strangePsp.items()):
        print('\t{:<5}: {:>5}x'.format(ln, len(ws)))
        for w in sorted(ws)[0:5]:
            show(T, F, [w], F.sp.v, getOSMpsp, indent='\t\t')
        n = len(ws)
        if n > 5:
            print('and {} more'.format(n - 5))
else:
    print('No other psps encountered than {}'.format(', '.join(pspBhsFromOsm)))
if strangeSuffix:
    print('Strange suffix psp')
    for (ln, ws) in sorted(strangeSuffix.items()):
        print('\t{:<5}: {:>5}x'.format(ln, len(ws)))
        for w in sorted(ws)[0:5]:
            show(T, F, [w], F.sp.v, getOSMpsp, indent='\t\t')
        n = len(ws)
        if n > 5:
            print('and {} more'.format(n - 5))
else:
    print('No other suffix psps encountered than S')
# Out:
# Strange psp
# 	S    :     3x
# 		Jeremiah 18:3 w243708 "הו"
# 			BHS: prps
# 			OSM: HSp3ms - None
# 		Song_of_songs 6:5 w358742 "הֵ֖ם"
# 			BHS: prps
# 			OSM: HSp3mp - None
# 		Daniel 2:35 w371257 "הִמֹּון֙"
# 			BHS: prps
# 			OSM: ASp3mp - None
# Strange suffix psp
# 	A    :     6x
# 		Numbers 2:9 w70538 "אֶ֜לֶף"
# 			BHS: subs
# 			OSM: HAcbsc - HAcbsa
# 		Numbers 2:16 w70633 "אֶ֜לֶף"
# 			BHS: subs
# 			OSM: HAcbsc - HAcbsa
# 		Numbers 2:24 w70744 "אֶ֛לֶף"
# 			BHS: subs
# 			OSM: HAcbsc - HAcbsa
# 		Numbers 2:31 w70834 "אֶ֗לֶף"
# 			BHS: subs
# 			OSM: HAcbsc - HAcbsa
# 		Judges 1:10 w127653 "קִרְיַ֣ת אַרְבַּ֑ע"
# 			BHS: nmpr
# 			OSM: HNp - HAcfsa
# and 1 more
# 	C    :     2x
# 		Ruth 3:12 w356979 "כִּ֥י אם"
# 			BHS: conj
# 			OSM: HC - HC
# 		Ecclesiastes 8:12 w362111 "וּ"
# 			BHS: conj
# 			OSM: HAcbsc - HC
# 	D    :   194x
# 		Genesis 4:15 w1911 "לָכֵן֙"
# 			BHS: advb
# 			OSM: HR - HD
# 		Genesis 30:15 w15823 "לָכֵן֙"
# 			BHS: advb
# 			OSM: HR - HD
# 		Exodus 6:6 w31334 "לָכֵ֞ן"
# 			BHS: advb
# 			OSM: HR - HD
# 		Numbers 16:11 w80256 "לָכֵ֗ן"
# 			BHS: advb
# 			OSM: HR - HD
# 		Numbers 20:12 w82792 "לָכֵ֗ן"
# 			BHS: advb
# 			OSM: HR - HD
# and 189 more
# 	N    :    79x
# 		Genesis 11:10 w5143 "שָׁנָ֔ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 21:5 w9687 "שָׁנָ֑ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 25:7 w12529 "שָׁנָ֛ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 25:17 w12674 "שָׁנָ֛ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 35:28 w19527 "שָׁנָ֖ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# and 74 more
# 	P    :     6x
# 		2_Samuel 24:3 w175489 "כָּהֵ֤ם"
# 			BHS: prep
# 			OSM: HR - HPp3mp
# 		2_Samuel 24:3 w175491 "כָהֵם֙"
# 			BHS: prep
# 			OSM: HR - HPp3mp
# 		Ecclesiastes 9:12 w362645 "כָּהֵ֗ם"
# 			BHS: prep
# 			OSM: HR - HPp3mp
# 		Daniel 6:6 w373962 "עֲלֹ֖והִי"
# 			BHS: prep
# 			OSM: AR - APp3ms
# 		1_Chronicles 21:3 w401846 "כָּהֵם֙"
# 			BHS: prep
# 			OSM: HR - HPp3mp
# and 1 more
# 	T    :   777x
# 		Genesis 4:6 w1759 "לָ֚מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 4:6 w1763 "לָ֖מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 12:18 w5826 "לָ֚מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 12:19 w5833 "לָמָ֤ה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 18:13 w8030 "לָ֣מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# and 772 more
