# %% [markdown]
# # BHSA and OSM: comparison on part-of-speech
#
# We will investigate how the morphology marked up in the OSM corresponds and differs from the BHSA linguistic features.
#
# In this notebook we investigate the markup of *part-of-speech*.
#
# We use the `osm` and `osm_sf` features compiled by the
# [BHSAbridgeOSM notebook](BHSAbridgeOSM.ipynb).

# %%
import operator
import collections
from functools import reduce

from tf.fabric import Fabric
from utils import show

# %% [markdown]
# # Load data
# We load the BHSA data in the standard way, and we add the OSM data as a module of the features `osm` and `osm_sf`.
# Note that we only need to point TF to the right directories, and then we can load all features
# that are present in those directories.

# %%
BHSA = "BHSA/tf/2021"
OSM = "bridging/tf/2021"

TF = Fabric(locations="~/github/etcbc", modules=[BHSA, OSM])
api = TF.load(
    """
    sp pdp
    lex voc_lex_utf8 freq_lex
    gloss
    osm osm_sf
    g_word_utf8
"""
)
api.makeAvailableIn(globals())
# Out:
# This is Text-Fabric 9.0.3
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 117 features found and 0 ignored
#   0.00s loading features ...
#    |     0.00s Dataset without structure sections in otext:no structure functions in the T-API
#   3.65s All features loaded/computed - for details use TF.isLoaded()
# [('Computed',
#   'computed-data',
#   ('C Computed', 'Call AllComputeds', 'Cs ComputedString')),
#  ('Features', 'edge-features', ('E Edge', 'Eall AllEdges', 'Es EdgeString')),
#  ('Fabric', 'loading', ('TF',)),
#  ('Locality', 'locality', ('L Locality',)),
#  ('Nodes', 'navigating-nodes', ('N Nodes',)),
#  ('Features',
#   'node-features',
#   ('F Feature', 'Fall AllFeatures', 'Fs FeatureString')),
#  ('Search', 'search', ('S Search',)),
#  ('Text', 'text', ('T Text',))]

# %% [markdown]
# # Part of speech
#
# The BHSA has two features for part-of-speech:
# [sp](https://etcbc.github.io/bhsa/features/hebrew/2017/sp)
# and
# [pdp](https://etcbc.github.io/bhsa/features/hebrew/2017/pdp).
#
# The first one, `sp`, is lexical part of speech, a context-insensitve assignment of part-of-speech labels to
# occurrences of lexemes.
#
# The second one, `pdp`, is *phrase dependent part of speech*. This assignment is sensitive to
# cases where adjectives are used as noun, nouns as prepositions, etc.
#
# A preliminary check has revealed that the OSM part-of-speech is resembles `sp` more than `pdp`, so
# we stick to `sp`.
#
# The OSM has part-of-speech as the second letter of the morph string.
# See [here](http://openscriptures.github.io/morphhb/parsing/HebrewMorphologyCodes.html).
#
# The BHSA makes a few more distinctions in its [sp](https://etcbc.github.io/bhsa/features/hebrew/2017/sp) feature,
# so we map the OSM values to sets of BHSA values.
#
# But the OSM has a subclassification of particles (`T`) that we should use.
#
# One of the OSM values is `S` (suffix).
# The BHSA has no counterpart for this, but we expect that all morph strings in the `osm_sf` features will show
# the `S`.
#
# We'll test that as well.

# %% [markdown]
# Here is the default mapping between OSM part-of-speech and BHSA part-of-speech.
#
# We'll see later that this results in many discrepancies.
#
# We'll analyze the discrepancies, and try to overcome them by making lexeme-dependent exceptions to these rules.
#
# It turns out that we need a few dozen lexeme-based exception rules and we'll have nearly 1000
# left-over cases that merit closer inspection.

# %%
particleTypes = dict(
    a="affirmation",
    d="definite article",
    e="exhortation",
    i="interrogative",
    j="interjection",
    m="demonstrative",
    n="negative",
    o="direct object marker",
    r="relative",
)

# %%
pspBhsFromOsm = {
    "A": {"adjv"},  # adjective
    "C": {"conj"},  # conjunction
    "D": {"advb"},  # adverb
    "N": {"subs", "nmpr"},  # noun
    "P": {"prps", "prde"},  # pronoun
    "R": {"prep"},  # preposition
    "S": {"_suffix_"},  # suffix
    "Ta": {"advb"},
    "Td": {"art"},
    "Te": {"intj"},
    "Ti": {"prin", "inrg"},
    "Tj": {"intj"},
    "Tm": {"intj", "advb"},
    "Tn": {"nega"},
    "To": {"prep"},  # object marker
    "Tr": {"conj"},  # relative
    "T": {"intj"},
    "V": {"verb"},  # verb
    "×": set(),  # no morphology
}

# %% [markdown]
# Just for ease of processing, we make a mapping from slots to OSM part-of-speech.
#
# We assign `×` slot `w` if there is no valid OSM part-of-speech label available for `w`.

# %%
osmPsp = {}
noPsp = 0
for w in F.otype.s("word"):
    osm = F.osm.v(w)
    if osm is None or osm == "" or osm == "*" or len(osm) < 2:
        psp = "×"
        noPsp += 1
    else:
        psp = osm[1]
        if psp == "T":
            psp = osm[1:3]
    osmPsp[w] = psp

allPsp = len(osmPsp)
withPsp = allPsp - noPsp
print(
    """{} BHSA words:
    having  OSM part of speech: {:>3}% = {:>6}
    without OSM part of speech: {:>3}% = {:>6}
""".format(
        F.otype.maxSlot,
        round(100 * withPsp / allPsp),
        withPsp,
        round(100 * noPsp / allPsp),
        noPsp,
    )
)
# Out:
# 426590 BHSA words:
#     having  OSM part of speech:  98% = 419849
#     without OSM part of speech:   2% =   6741

# %% [markdown]
# We organize the osm-bhs combinations that show up in the text in several ways.
#
# `psp` is keyed by: osm, bhs, lexeme node.
#
# `pspLex` is keyed by: lexeme node, osm, bhs, and then contains a list of slots where this combination occurs.
#
# Both mappings contains a list of slots where the combinations occur.

# %%
psp = {}
pspLex = {}
for lx in F.otype.s("lex"):
    ws = L.d(lx, otype="word")
    for w in ws:
        osm = osmPsp[w]
        bhs = F.sp.v(w)
        psp.setdefault(osm, {}).setdefault(bhs, {}).setdefault(lx, set()).add(w)
        pspLex.setdefault(lx, {}).setdefault(osm, {}).setdefault(bhs, set()).add(w)

# %% [markdown]
# For each osm-bhs combination, we want to see how many lexemes and how many occurrences have that combination.

# %%
pspCount = {}
for (osm, osmData) in psp.items():
    for (bhs, bhsData) in osmData.items():
        nlex = len(bhsData)
        noccs = reduce(operator.add, (len(x) for x in bhsData.values()), 0)
        pspCount.setdefault(osm, {})[bhs] = (nlex, noccs)

# %% [markdown]
# Now we are going to present an overview of osm-bhs combinations.
#
# We mark a combination with `OK` if the combination is according to the default OSM-BHS mapping.
#
# We use the mark `*` if there is no OSM part-of-speech available.
#
# Otherwise we mark it with a `?`.

# %%
mismatches = []
for osm in pspCount:
    print(osm)
    totalOccs = sum(x[1] for x in pspCount[osm].values())
    for (bhs, (nlex, noccs)) in sorted(
        pspCount[osm].items(), key=lambda x: (-x[1][1], -x[1][0], x[0])
    ):
        perc = round(100 * noccs / totalOccs)
        status = bhs in pspBhsFromOsm[osm]
        statusLabel = "OK" if status else "?"
        if not status:
            if osm == "×":
                statusLabel = "*"
            else:
                mismatches.append((osm, bhs, nlex, noccs))
        print(
            "\t=> {:<4} ({:<2}) in {:>4} lexemes and {:>3}% = {:>6} occurrences".format(
                bhs,
                statusLabel,
                nlex,
                perc,
                noccs,
            )
        )
total = 0
for (osm, bhs, nlex, noccs) in mismatches:
    total += noccs
print("\n{:<24} {:>6} occurrences".format("Total number of mismatches", total))
# Out:
# R
# 	=> prep (OK) in   23 lexemes and  96% =  61788 occurrences
# 	=> subs (? ) in   29 lexemes and   3% =   2105 occurrences
# 	=> advb (? ) in    1 lexemes and   0% =    200 occurrences
# 	=> inrg (? ) in    1 lexemes and   0% =    178 occurrences
# 	=> art  (? ) in    1 lexemes and   0% =      9 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      5 occurrences
# 	=> nmpr (? ) in    3 lexemes and   0% =      4 occurrences
# 	=> verb (? ) in    3 lexemes and   0% =      4 occurrences
# 	=> nega (? ) in    2 lexemes and   0% =      3 occurrences
# 	=> adjv (? ) in    2 lexemes and   0% =      2 occurrences
# 	=> prin (? ) in    1 lexemes and   0% =      2 occurrences
# ×
# 	=> art  (* ) in    1 lexemes and  97% =   6515 occurrences
# 	=> subs (* ) in   31 lexemes and   1% =     46 occurrences
# 	=> verb (* ) in   24 lexemes and   1% =     42 occurrences
# 	=> nmpr (* ) in   28 lexemes and   1% =     38 occurrences
# 	=> conj (* ) in    3 lexemes and   1% =     35 occurrences
# 	=> prep (* ) in    5 lexemes and   0% =     32 occurrences
# 	=> adjv (* ) in   14 lexemes and   0% =     21 occurrences
# 	=> prde (* ) in    3 lexemes and   0% =     10 occurrences
# 	=> advb (* ) in    1 lexemes and   0% =      1 occurrences
# 	=> prps (* ) in    1 lexemes and   0% =      1 occurrences
# N
# 	=> subs (OK) in 3954 lexemes and  76% = 110122 occurrences
# 	=> nmpr (OK) in 2577 lexemes and  23% =  32921 occurrences
# 	=> adjv (? ) in  267 lexemes and   1% =   1929 occurrences
# 	=> verb (? ) in   38 lexemes and   0% =     65 occurrences
# 	=> prep (? ) in    6 lexemes and   0% =      7 occurrences
# 	=> advb (? ) in    2 lexemes and   0% =      2 occurrences
# V
# 	=> verb (OK) in 1738 lexemes and 100% =  73481 occurrences
# 	=> subs (? ) in   64 lexemes and   0% =    105 occurrences
# 	=> adjv (? ) in   25 lexemes and   0% =     54 occurrences
# 	=> nmpr (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# To
# 	=> prep (OK) in    4 lexemes and 100% =  11017 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      1 occurrences
# C
# 	=> conj (OK) in   11 lexemes and  99% =  57027 occurrences
# 	=> subs (? ) in   11 lexemes and   0% =    233 occurrences
# 	=> prep (? ) in    8 lexemes and   0% =    103 occurrences
# 	=> verb (? ) in   13 lexemes and   0% =     13 occurrences
# 	=> advb (? ) in    4 lexemes and   0% =     10 occurrences
# 	=> prde (? ) in    1 lexemes and   0% =      8 occurrences
# 	=> adjv (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> inrg (? ) in    1 lexemes and   0% =      1 occurrences
# Td
# 	=> art  (OK) in    1 lexemes and 100% =  23858 occurrences
# 	=> subs (? ) in    6 lexemes and   0% =      7 occurrences
# 	=> inrg (? ) in    1 lexemes and   0% =      6 occurrences
# 	=> nmpr (? ) in    3 lexemes and   0% =      3 occurrences
# 	=> adjv (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# Ti
# 	=> inrg (OK) in   15 lexemes and  52% =   1064 occurrences
# 	=> prin (OK) in    4 lexemes and  48% =    997 occurrences
# 	=> art  (? ) in    1 lexemes and   0% =      3 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> subs (? ) in    1 lexemes and   0% =      1 occurrences
# Tr
# 	=> conj (OK) in    3 lexemes and  95% =   5651 occurrences
# 	=> prep (? ) in    1 lexemes and   5% =    286 occurrences
# 	=> subs (? ) in    2 lexemes and   0% =      2 occurrences
# 	=> verb (? ) in    2 lexemes and   0% =      2 occurrences
# 	=> adjv (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> art  (? ) in    1 lexemes and   0% =      1 occurrences
# A
# 	=> adjv (OK) in  356 lexemes and  52% =   7499 occurrences
# 	=> subs (? ) in   84 lexemes and  47% =   6699 occurrences
# 	=> verb (? ) in   18 lexemes and   1% =     97 occurrences
# 	=> nmpr (? ) in    5 lexemes and   0% =     30 occurrences
# 	=> advb (? ) in    3 lexemes and   0% =      4 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# Tn
# 	=> nega (OK) in    5 lexemes and  88% =   6049 occurrences
# 	=> subs (? ) in    4 lexemes and  12% =    822 occurrences
# 	=> prep (? ) in    3 lexemes and   0% =     21 occurrences
# 	=> nmpr (? ) in    2 lexemes and   0% =      4 occurrences
# 	=> conj (? ) in    2 lexemes and   0% =      2 occurrences
# 	=> inrg (? ) in    1 lexemes and   0% =      1 occurrences
# D
# 	=> advb (OK) in   46 lexemes and  69% =   2845 occurrences
# 	=> subs (? ) in   28 lexemes and  28% =   1139 occurrences
# 	=> intj (? ) in    5 lexemes and   2% =     75 occurrences
# 	=> inrg (? ) in    2 lexemes and   1% =     33 occurrences
# 	=> adjv (? ) in    1 lexemes and   0% =      3 occurrences
# 	=> verb (? ) in    1 lexemes and   0% =      2 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# Tm
# 	=> intj (OK) in    6 lexemes and  67% =   1140 occurrences
# 	=> advb (OK) in    1 lexemes and  25% =    422 occurrences
# 	=> subs (? ) in    1 lexemes and   8% =    138 occurrences
# 	=> adjv (? ) in    1 lexemes and   1% =     10 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      1 occurrences
# Tj
# 	=> intj (OK) in   17 lexemes and  96% =    319 occurrences
# 	=> subs (? ) in    3 lexemes and   2% =      5 occurrences
# 	=> verb (? ) in    1 lexemes and   1% =      4 occurrences
# 	=> inrg (? ) in    1 lexemes and   1% =      2 occurrences
# 	=> nega (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> nmpr (? ) in    1 lexemes and   0% =      1 occurrences
# P
# 	=> prps (OK) in   24 lexemes and  65% =   4997 occurrences
# 	=> prde (OK) in   15 lexemes and  34% =   2642 occurrences
# 	=> prin (? ) in    2 lexemes and   0% =     22 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      7 occurrences
# 	=> subs (? ) in    2 lexemes and   0% =      4 occurrences
# 	=> adjv (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> advb (? ) in    1 lexemes and   0% =      1 occurrences
# Ta
# 	=> advb (OK) in    5 lexemes and  92% =   1065 occurrences
# 	=> subs (? ) in    3 lexemes and   7% =     80 occurrences
# 	=> prps (? ) in    4 lexemes and   1% =      8 occurrences
# S
# 	=> prps (? ) in    4 lexemes and 100% =      5 occurrences
# Te
# 	=> intj (OK) in    3 lexemes and  99% =    351 occurrences
# 	=> adjv (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> subs (? ) in    1 lexemes and   0% =      1 occurrences
# T
# 	=> prep (? ) in    1 lexemes and 100% =      7 occurrences
#
# Total number of mismatches  14594 occurrences

# %% [markdown]
# It is not as bad as it seems.
# The number of *lexemes* involved in a mismatch is limited:

# %%
mismatchLexemes = set()
for (osm, bhs, nlex, noccs) in mismatches:
    lexemes = psp[osm][bhs].keys()
    mismatchLexemes |= lexemes
print("Lexemes to be researched: {}".format(len(mismatchLexemes)))
# Out:
# Lexemes to be researched: 663

# %% [markdown]
# We are going to investigate the lexemes that are involved in a mismatch.
#
# It turns out that:
#
# * for most of the lexemes there is a dominant combination of OSM and BHSA assigned part-of-speech;
# * non-dominant combinations mostly have a very limited number of occurrences.
#
# This is what we are going to do:
#
# * for each lexeme we go along with the dominant combination.
#   If that is different from the default marking, we add a lexeme-bound exception to the rule
#   that maps OSM part-of-speech to BHSA part-of-speech.
# * if even the dominant combination has less than 10 occurrences, we do not add a lexeme-bound rule,
#   but we add the case to the list of exceptional cases.
# * we spell out the exceptional cases, so that readers can manually check the part-of-speeches as assigned by
#   OSM and BHSA.
#
# In order to determine what is dominant: if a combination has 50% or more of occurrences of a lexeme.
# then that combination is dominant.
# So, for each lexeme there is at least one dominant case.
#
# There may not be a dominant case if not all occurrences of a lexeme have been marked up in the OSM.

# %% [markdown]
# The next cell computes the new rules and the exceptions.
# It will show all new rules, and all kinds of exceptions.
# But it only shows at most 10 instances of each kind of exception.
#
# All exceptions are written to a tab-separated file
# [pspCases.tsv](pspCases.tsv).

# %%
closerLook = set()

rules = []
text = []


def getOSMpsp(w):
    return "{} - {}".format(str(F.osm.v(w)), str(F.osm_sf.v(w)))


fields = """
    passage
    slot
    occurrence
    lex-node
    lex
    lex-pointed
    gloss
    bhsa-psp
    osm-psp
    #cases-like-this
""".strip().split()
lineFormat = ("{}\t" * (len(fields) - 1)) + "{}\n"

casesLikeThis = {}

for lx in sorted(mismatchLexemes, key=lambda x: -F.freq_lex.v(x)):
    freqLex = F.freq_lex.v(lx)
    text.append(
        '\n{:<15}        {:>6}x [{}] "{}"'.format(
            F.lex.v(lx),
            freqLex,
            F.gloss.v(lx),
            F.voc_lex_utf8.v(lx),
        )
    )
    nRealCases = freqLex
    if "×" in pspLex[lx]:
        for (bhs, ws) in pspLex[lx]["×"].items():
            nRealCases -= len(ws)

    osmCount = collections.Counter()
    for (osm, osmData) in pspLex[lx].items():
        for ws in osmData.values():
            osmCount[osm] += len(ws)

    for osm in sorted(pspLex[lx], key=lambda x: -osmCount[x]):
        if osm == "×":
            continue
        osmData = pspLex[lx][osm]
        for (bhs, ws) in sorted(osmData.items(), key=lambda x: (-len(x[1]), x[0])):
            showCases = False
            nws = len(ws)
            status = bhs in pspBhsFromOsm[osm]
            statusLabel = "OK" if status else "?"

            if 2 * nws > freqLex and nws >= 10:
                if status:
                    pass
                else:
                    statusLabel = "NN"
                    rules.append((lx, osm, bhs, ws))
            else:
                if status:
                    statusLabel = "OK?"
                else:
                    showCases = True

            text.append(
                "\t{:<2} ~ {:<4} ({:<3}) {:>6}x".format(
                    bhs,
                    osm,
                    statusLabel,
                    nws,
                )
            )

            if showCases:
                for w in sorted(ws)[0:10]:
                    text.append(
                        show(
                            T,
                            F,
                            [w],
                            F.sp.v,
                            getOSMpsp,
                            indent="\t\t\t\t\t",
                            asString=True,
                        )
                    )
                if nws > 10:
                    text.append("\t\t\t\t\tand {} more occurrences".format(nws - 10))
                closerLook |= set(ws)
                for w in ws:
                    casesLikeThis[w] = nws

with open("pspCases.tsv", "w") as fh:
    fh.write(lineFormat.format(*fields))
    for w in sorted(closerLook):
        closerLook.add(w)
        fh.write(
            lineFormat.format(
                "{} {}:{}".format(*T.sectionFromNode(w)),
                w,
                F.g_word_utf8.v(w),
                lx,
                F.lex.v(lx),
                F.voc_lex_utf8.v(lx),
                F.gloss.v(lx),
                F.sp.v(w),
                F.osm.v(w),
                casesLikeThis[w],
            )
        )
print("Written {} cases to file".format(len(closerLook)))

if rules:
    print("Lexeme-bound exceptions  : {:>4}".format(len(rules)))
else:
    print("No lexeme-bound exceptions")

if closerLook or text:
    print("Cases that need attention: {:>4}".format(len(closerLook)))
else:
    print("All cases clear")

print("\nLEXEME-BOUND EXCEPTIONS\n")
casesSolved = set()
for (lx, osm, bhs, ws) in rules:
    casesSolved |= set(ws)
    print(
        '\t{:<15} {:<4} ~ {:<2} ({:>5}x) [{:<20}] "{}"'.format(
            F.lex.v(lx),
            bhs,
            osm,
            len(ws),
            F.gloss.v(lx),
            F.voc_lex_utf8.v(lx),
        )
    )
print("This solves {} cases".format(len(casesSolved)))
print("Remaining cases: {}".format(total - len(casesSolved)))

print("\nCASES FOR ATTENTION\n")
for t in text:
    print(t)
# Out:
# Written 1551 cases to file
# Lexeme-bound exceptions  :   95
# Cases that need attention: 1551
#
# LEXEME-BOUND EXCEPTIONS
#
# 	>XD/            subs ~ A  (  970x) [one                 ] "אֶחָד"
# 	>JN/            subs ~ Tn (  784x) [<NEG>               ] "אַיִן"
# 	CNJM/           subs ~ A  (  768x) [two                 ] "שְׁנַיִם"
# 	>XR/            subs ~ R  (  679x) [after               ] "אַחַר"
# 	CLC/            subs ~ A  (  602x) [three               ] "שָׁלֹשׁ"
# 	M>H/            subs ~ A  (  578x) [hundred             ] "מֵאָה"
# 	XMC/            subs ~ A  (  506x) [five                ] "חָמֵשׁ"
# 	TXT/            subs ~ R  (  502x) [under part          ] "תַּחַת"
# 	>LP=/           subs ~ A  (  492x) [thousand            ] "אֶלֶף"
# 	CB</            subs ~ A  (  487x) [seven               ] "שֶׁבַע"
# 	<WD/            subs ~ D  (  490x) [duration            ] "עֹוד"
# 	>RB</           subs ~ A  (  454x) [four                ] "אַרְבַּע"
# 	BJN/            subs ~ R  (  407x) [interval            ] "בַּיִן"
# 	DJ              prep ~ Tr (  286x) [<relative>          ] "דִּי"
# 	<FRJM/          subs ~ A  (  315x) [twenty              ] "עֶשְׂרִים"
# 	M>D/            subs ~ D  (  297x) [might               ] "מְאֹד"
# 	LWJ/            adjv ~ N  (  292x) [Levite              ] "לֵוִי"
# 	PLCTJ/          adjv ~ N  (  287x) [Philistine          ] "פְּלִשְׁתִּי"
# 	CC/             subs ~ A  (  274x) [six                 ] "שֵׁשׁ"
# 	<FR/            subs ~ A  (  203x) [-teen               ] "עָשָׂר"
# 	LKN             advb ~ R  (  200x) [therefore           ] "לָכֵן"
# 	LMH             inrg ~ R  (  178x) [why                 ] "לָמָה"
# 	GBWR/           subs ~ A  (  159x) [vigorous            ] "גִּבֹּור"
# 	NGD/            subs ~ R  (  151x) [counterpart         ] "נֶגֶד"
# 	CMNH/           subs ~ A  (  147x) [eight               ] "שְׁמֹנֶה"
# 	M<L/            subs ~ D  (  140x) [top                 ] "מַעַל"
# 	JC/             subs ~ Tm (  138x) [existence           ] "יֵשׁ"
# 	<FRH/           subs ~ A  (  134x) [-teen               ] "עֶשְׂרֵה"
# 	<FRH=/          subs ~ A  (  120x) [ten                 ] "עֲשָׂרָה"
# 	BLT/            subs ~ C  (  103x) [failure             ] "בֵּלֶת"
# 	B<D/            subs ~ R  (  105x) [distance            ] "בַּעַד"
# 	J<N/            subs ~ C  (   99x) [motive              ] "יַעַן"
# 	>MRJ/           adjv ~ N  (   87x) [Amorite             ] "אֱמֹרִי"
# 	JHWDJ/          adjv ~ N  (   80x) [Jewish              ] "יְהוּדִי"
# 	TC</            subs ~ A  (   78x) [nine                ] "תֵּשַׁע"
# 	KN<NJ/          adjv ~ N  (   73x) [Canaanite           ] "כְּנַעֲנִי"
# 	VWBH/           subs ~ A  (   65x) [what is good        ] "טֹובָה"
# 	KFDJ/           adjv ~ N  (   64x) [Chaldean            ] "כַּשְׂדִּי"
# 	>YL/            subs ~ R  (   61x) [side                ] "אֵצֶל"
# 	BLJ/            subs ~ Tn (   31x) [destruction         ] "בְּלִי"
# 	VRM/            subs ~ D  (   56x) [beginning           ] "טֶרֶם"
# 	<FR=/           subs ~ A  (   56x) [ten                 ] "עֶשֶׂר"
# 	XTJ/            adjv ~ N  (   48x) [Hittite             ] "חִתִּי"
# 	JXD/            subs ~ D  (   30x) [gathering           ] "יַחַד"
# 	<MD/            subs ~ R  (   45x) [company             ] "עִמָּד"
# 	VWB[            verb ~ A  (   25x) [be good             ] "טוב"
# 	QDM/            subs ~ R  (   40x) [before              ] "קֳדָם"
# 	JBWSJ/          adjv ~ N  (   41x) [Jebusite            ] "יְבוּסִי"
# 	>N              inrg ~ D  (   32x) [whither             ] "אָן"
# 	CC=/            subs ~ A  (   31x) [linen               ] "שֵׁשׁ"
# 	MWL/            subs ~ R  (   36x) [front               ] "מוּל"
# 	<BRJ/           adjv ~ N  (   34x) [Hebrew              ] "עִבְרִי"
# 	MYRJ/           adjv ~ N  (   30x) [Egyptian            ] "מִצְרִי"
# 	>MN             intj ~ D  (   30x) [surely              ] "אָמֵן"
# 	QBL/            subs ~ C  (   23x) [opposite            ] "קֳבֵל"
# 	XWJ/            adjv ~ N  (   25x) [Hivite              ] "חִוִּי"
# 	KCJ/            adjv ~ N  (   25x) [Ethiopian           ] "כֻּשִׁי"
# 	NKX=/           subs ~ R  (   23x) [straightness        ] "נֹכַח"
# 	PRZJ/           adjv ~ N  (   23x) [Perizzite           ] "פְּרִזִּי"
# 	TMWL/           subs ~ D  (   23x) [yesterday           ] "תְּמֹול"
# 	<MWNJ/          adjv ~ N  (   21x) [Ammonite            ] "עַמֹּונִי"
# 	CKN/            subs ~ A  (   20x) [inhabitant          ] "שָׁכֵן"
# 	<CTJ/           subs ~ A  (   19x) [eleven              ] "עַשְׁתֵּי"
# 	MVH==/          subs ~ D  (   19x) [low place           ] "מַטָּה"
# 	R>WBNJ/         adjv ~ N  (   18x) [Reubenite           ] "רְאוּבֵנִי"
# 	>KN             intj ~ D  (   18x) [surely              ] "אָכֵן"
# 	JWYR/           subs ~ V  (   11x) [potter              ] "יֹוצֵר"
# 	>JTJ/           subs ~ Ta (   17x) [existence           ] "אִיתַי"
# 	GDJ=/           adjv ~ N  (   16x) [Gadite              ] "גָּדִי"
# 	ZWLH/           subs ~ R  (   15x) [except              ] "זוּלָה"
# 	MW>BJ/          adjv ~ N  (   16x) [Moabite             ] "מֹואָבִי"
# 	YJDNJ/          adjv ~ N  (   16x) [Sidonian            ] "צִידֹנִי"
# 	QHTJ/           adjv ~ N  (   15x) [Kohathite           ] "קְהָתִי"
# 	>PW             intj ~ D  (   15x) [then                ] "אֵפֹו"
# 	>LP==/          subs ~ A  (   13x) [group of thousand   ] "אֶלֶף"
# 	XD/             subs ~ A  (   13x) [one                 ] "חַד"
# 	XKJM/           adjv ~ N  (   14x) [wise                ] "חַכִּים"
# 	MH              prin ~ P  (   12x) [what                ] "מָה"
# 	LBWC=/          adjv ~ V  (   11x) [clad                ] "לָבוּשׁ"
# 	JZR<>LJ/        adjv ~ N  (   13x) [Jezreelite          ] "יִזְרְעֵאלִי"
# 	GRCNJ/          adjv ~ N  (   13x) [Gershonite          ] "גֵּרְשֻׁנִּי"
# 	JMJNJ/          adjv ~ N  (   12x) [Benjaminite         ] "יְמִינִי"
# 	<MLQJ/          adjv ~ N  (   12x) [Amalekite           ] "עֲמָלֵקִי"
# 	QJNJ/           adjv ~ N  (   12x) [Kenite              ] "קֵינִי"
# 	>RMJ/           adjv ~ N  (   12x) [Aramean             ] "אֲרַמִּי"
# 	>DMJ/           adjv ~ N  (   12x) [Edomite             ] "אֲדֹמִי"
# 	>PH/            subs ~ V  (   12x) [baker               ] "אֹפֶה"
# 	NVWPTJ/         adjv ~ N  (   11x) [Netophathite        ] "נְטֹופָתִי"
# 	>BL             intj ~ D  (   11x) [verily              ] "אֲבָל"
# 	GL<DJ/          adjv ~ N  (   11x) [Gileadite           ] "גִּלְעָדִי"
# 	TLT/            subs ~ A  (   11x) [three               ] "תְּלָת"
# 	KRTJ/           adjv ~ N  (   10x) [Cherethite          ] "כְּרֵתִי"
# 	GTJ/            adjv ~ N  (   10x) [Gittite             ] "גִּתִּי"
# 	MN=             prin ~ P  (   10x) [who                 ] "מַן"
# 	JHWDJ/          adjv ~ N  (   10x) [Jew                 ] "יְהוּדָי"
# This solves 13043 cases
# Remaining cases: 1551
#
# CASES FOR ATTENTION
#
#
# W                       50272x [and] "וְ"
# 	conj ~ C    (OK )  50234x
# 	conj ~ R    (?  )      5x
# 					Isaiah 1:5 w212149"וְ"
# 						BHS: conj
# 						OSM: HR - None
# 					Jeremiah 49:37 w261838"וְ"
# 						BHS: conj
# 						OSM: HR - None
# 					Jonah 2:4 w298983"וְ"
# 						BHS: conj
# 						OSM: HR - None
# 					Jonah 3:5 w299160"וְ"
# 						BHS: conj
# 						OSM: HR - None
# 					Jonah 4:11 w299540"וּ"
# 						BHS: conj
# 						OSM: HR - None
#
# H                       30386x [the] "הַ"
# 	art ~ Td   (OK )  23858x
# 	art ~ R    (?  )      9x
# 					Judges 13:8 w135894"הַ"
# 						BHS: art
# 						OSM: HRd - None
# 					Judges 14:14 w136543"הָֽ"
# 						BHS: art
# 						OSM: HRd - None
# 					2_Samuel 15:18 w169279"הַ"
# 						BHS: art
# 						OSM: HRd - None
# 					2_Samuel 19:4 w172015"הַ"
# 						BHS: art
# 						OSM: HR - None
# 					2_Samuel 19:32 w172761"ב"
# 						BHS: art
# 						OSM: HR - None
# 					Haggai 2:6 w304609"הֶ"
# 						BHS: art
# 						OSM: HR - None
# 					Haggai 2:19 w304903"הַ"
# 						BHS: art
# 						OSM: HRd - None
# 					Zechariah 9:12 w307691"הַ"
# 						BHS: art
# 						OSM: HRd - None
# 					2_Chronicles 30:2 w421878"הַ"
# 						BHS: art
# 						OSM: HRd - None
# 	art ~ Ti   (?  )      3x
# 					Deuteronomy 20:19 w104749"הָֽ"
# 						BHS: art
# 						OSM: HTi - None
# 					Isaiah 51:10 w230046"הַ"
# 						BHS: art
# 						OSM: HTi - None
# 					Amos 5:25 w296903"הַ"
# 						BHS: art
# 						OSM: HTi - None
# 	art ~ Tr   (?  )      1x
# 					2_Chronicles 29:36 w421816"הַ"
# 						BHS: art
# 						OSM: HTr - None
#
# L                       20069x [to] "לְ"
# 	prep ~ R    (OK )  20029x
# 	prep ~ Tn   (?  )     18x
# 					Exodus 21:8 w40142"לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Leviticus 11:21 w58185"לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Leviticus 25:30 w67709"לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					1_Samuel 2:3 w142163"לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					2_Samuel 16:18 w170180"לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					2_Kings 8:10 w199810"לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Isaiah 9:2 w215180"לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Isaiah 49:5 w229224"לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Isaiah 63:9 w233608"לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					Psalms 100:3 w327595"לא"
# 						BHS: prep
# 						OSM: HTn - None
# 					and 8 more occurrences
# 	prep ~ C    (?  )      3x
# 					Isaiah 5:14 w213670"לִ"
# 						BHS: prep
# 						OSM: HC - None
# 					Psalms 88:1 w325547"לְ"
# 						BHS: prep
# 						OSM: HC - None
# 					Job 30:24 w343333"לָהֶ֥ן"
# 						BHS: prep
# 						OSM: HC - None
# 	prep ~ Td   (?  )      1x
# 					Psalms 68:19 w321430"לַ"
# 						BHS: prep
# 						OSM: HTd - None
# 	prep ~ V    (?  )      1x
# 					Song_of_songs 2:13 w357961"לכי"
# 						BHS: prep
# 						OSM: HVqv2fs - None
#
# B                       15542x [in] "בְּ"
# 	prep ~ R    (OK )  15534x
# 	prep ~ N    (?  )      1x
# 					Isaiah 62:4 w233305"בָ֔הּ"
# 						BHS: prep
# 						OSM: HNp - None
#
# >T                      10987x [<object marker>] "אֵת"
# 	prep ~ To   (OK )  10950x
# 	prep ~ R    (OK?)     36x
# 	prep ~ C    (?  )      1x
# 					2_Kings 16:17 w205493"ואת"
# 						BHS: prep
# 						OSM: HC - HTo
#
# MN                       7562x [from] "מִן"
# 	prep ~ R    (OK )   7555x
# 	prep ~ C    (?  )      1x
# 					1_Samuel 5:1 w143835"מֵ"
# 						BHS: prep
# 						OSM: HC - None
# 	prep ~ N    (?  )      1x
# 					Isaiah 44:24 w227813"מי"
# 						BHS: prep
# 						OSM: HNcmpc - None
# 	prep ~ Ti   (?  )      1x
# 					1_Chronicles 15:13 w399241"מַ"
# 						BHS: prep
# 						OSM: HTi - None
#
# >L                       5517x [to] "אֶל"
# 	prep ~ R    (OK )   5512x
# 	prep ~ Tn   (?  )      2x
# 					Judges 19:23 w139678"אַל"
# 						BHS: prep
# 						OSM: HTn - None
# 					Jeremiah 47:6 w260353"אַל"
# 						BHS: prep
# 						OSM: HTn - None
# 	prep ~ N    (?  )      1x
# 					Ezekiel 31:14 w280049"אֵלֵיהֶ֛ם"
# 						BHS: prep
# 						OSM: HNcmpc - HSp3mp
#
# >CR                      5500x [<relative>] "אֲשֶׁר"
# 	conj ~ Tr   (OK )   5499x
# 	conj ~ To   (?  )      1x
# 					Jeremiah 38:16 w256032"את אֲשֶׁר֩"
# 						BHS: conj
# 						OSM: HTo - HTr
#
# KL/                      5412x [whole] "כֹּל"
# 	subs ~ N    (OK )   5409x
# 	subs ~ R    (?  )      1x
# 					Ecclesiastes 5:15 w361138"כָּל"
# 						BHS: subs
# 						OSM: HR - HR
# 	subs ~ C    (?  )      1x
# 					Lamentations 4:12 w365120"וכל"
# 						BHS: subs
# 						OSM: HC - HNcmsc
#
# L>                       5167x [not] "לֹא"
# 	nega ~ Tn   (OK )   5165x
# 	nega ~ R    (?  )      2x
# 					1_Samuel 2:16 w142413"לו"
# 						BHS: nega
# 						OSM: HR - HSp3ms
# 					1_Samuel 20:2 w153448"לו"
# 						BHS: nega
# 						OSM: HR - HSp3ms
#
# K                        2902x [as] "כְּ"
# 	prep ~ R    (OK )   2898x
# 	prep ~ C    (?  )      2x
# 					Judges 16:25 w137798"כי"
# 						BHS: prep
# 						OSM: HC - None
# 					Lamentations 4:3 w364992"כי"
# 						BHS: prep
# 						OSM: HC - None
#
# <FH[                     2629x [make] "עשׂה"
# 	verb ~ V    (OK )   2627x
# 	verb ~ A    (?  )      1x
# 					1_Kings 22:49 w194648"עשׂר"
# 						BHS: verb
# 						OSM: HAcmsa - None
# 	verb ~ C    (?  )      1x
# 					Ezekiel 46:15 w289435"ועשׂו"
# 						BHS: verb
# 						OSM: HC - HVqq3cp
#
# BW>[                     2570x [come] "בוא"
# 	verb ~ V    (OK )   2552x
# 	verb ~ R    (?  )      2x
# 					Genesis 30:11 w15747"ב"
# 						BHS: verb
# 						OSM: HR - None
# 					Ezekiel 14:4 w270435"בה"
# 						BHS: verb
# 						OSM: HR - HSp3fs
# 	verb ~ N    (?  )      1x
# 					Ezekiel 42:9 w286866"מבוא"
# 						BHS: verb
# 						OSM: HNcmsa - None
#
# JFR>L/                   2506x [Israel] "יִשְׂרָאֵל"
# 	nmpr ~ N    (OK )   2505x
# 	nmpr ~ R    (?  )      1x
# 					2_Samuel 10:9 w165489"בישׂראל"
# 						BHS: nmpr
# 						OSM: HR - HNp
#
# >JC/                     2186x [man] "אִישׁ"
# 	subs ~ N    (OK )   2184x
# 	subs ~ Tr   (?  )      1x
# 					2_Samuel 23:21 w175246"אשׁר"
# 						BHS: subs
# 						OSM: HTr - None
#
# BJT/                     2063x [house] "בַּיִת"
# 	subs ~ N    (OK )   2061x
# 	subs ~ R    (?  )      2x
# 					2_Kings 22:5 w209332"בבית"
# 						BHS: subs
# 						OSM: HR - HNcmsc
# 					Jeremiah 52:11 w264158"בבית"
# 						BHS: subs
# 						OSM: HR - HNcmsc
#
# JD/                      1618x [hand] "יָד"
# 	subs ~ N    (OK )   1617x
# 	subs ~ V    (?  )      1x
# 					1_Samuel 4:13 w143581"יך"
# 						BHS: subs
# 						OSM: HVhc - None
#
# DBR/                     1441x [word] "דָּבָר"
# 	subs ~ N    (OK )   1440x
# 	subs ~ C    (?  )      1x
# 					Jeremiah 23:18 w246312"דברי"
# 						BHS: subs
# 						OSM: HC - HVqw3ms
#
# HW>                      1394x [he] "הוּא"
# 	prps ~ P    (OK )   1393x
# 	prps ~ S    (?  )      1x
# 					Jeremiah 18:3 w243711"הו"
# 						BHS: prps
# 						OSM: HSp3ms - None
#
# R>H[                     1298x [see] "ראה"
# 	verb ~ V    (OK )   1297x
# 	verb ~ C    (?  )      1x
# 					2_Kings 11:1 w202008"וראתה"
# 						BHS: verb
# 						OSM: HC - HVqp3fs
#
# <D                       1263x [unto] "עַד"
# 	prep ~ R    (OK )   1260x
# 	prep ~ N    (?  )      2x
# 					Psalms 83:18 w324995"עֲדֵי"
# 						BHS: prep
# 						OSM: HNcmpc - None
# 					Psalms 92:8 w326635"עֲדֵי"
# 						BHS: prep
# 						OSM: HNcmpc - None
# 	prep ~ D    (?  )      1x
# 					Ruth 1:13 w356042"עַ֚ד"
# 						BHS: prep
# 						OSM: HD - None
#
# >B/                      1217x [father] "אָב"
# 	subs ~ N    (OK )   1215x
# 	subs ~ Te   (?  )      1x
# 					2_Kings 5:13 w197770"אָבִי֙"
# 						BHS: subs
# 						OSM: HTe - None
# 	subs ~ Tj   (?  )      1x
# 					Job 34:36 w344714"אָבִ֗י"
# 						BHS: subs
# 						OSM: HTj - None
#
# DBR[                     1138x [speak] "דבר"
# 	verb ~ V    (OK )   1136x
# 	verb ~ N    (?  )      1x
# 					Jeremiah 5:13 w237333"דִּבֵּ֖ר"
# 						BHS: verb
# 						OSM: HNcmsa - None
#
# JCB[                     1082x [sit] "ישׁב"
# 	verb ~ V    (OK )   1079x
# 	verb ~ Tr   (?  )      1x
# 					Ezekiel 3:15 w265794"אשׁר"
# 						BHS: verb
# 						OSM: HTr - None
# 	verb ~ N    (?  )      1x
# 					Obadiah 1:3 w298209"שִׁבְתֹּ֑ו"
# 						BHS: verb
# 						OSM: HNcfsc - HSp3ms
#
# JY>[                     1068x [go out] "יצא"
# 	verb ~ V    (OK )   1067x
# 	verb ~ C    (?  )      1x
# 					Jeremiah 8:1 w238957"ויציאו"
# 						BHS: verb
# 						OSM: HC - HVhi3mp
#
# <M                       1049x [with] "עִם"
# 	prep ~ R    (OK )   1048x
# 	prep ~ N    (?  )      1x
# 					Isaiah 8:8 w214885"עִמָּ֥נוּ"
# 						BHS: prep
# 						OSM: HNp - None
#
# CWB[                     1038x [return] "שׁוב"
# 	verb ~ V    (OK )   1037x
# 	verb ~ A    (?  )      1x
# 					Jeremiah 50:6 w261986"שׁובבים"
# 						BHS: verb
# 						OSM: HAampa - None
#
# >XD/                      970x [one] "אֶחָד"
# 	subs ~ A    (NN )    970x
#
# <LH[                      890x [ascend] "עלה"
# 	verb ~ V    (OK )    889x
# 	verb ~ N    (?  )      1x
# 					Ezekiel 40:26 w285552"עלותו"
# 						BHS: verb
# 						OSM: HNcfsc - HSp3ms
#
# CNH/                      876x [year] "שָׁנָה"
# 	subs ~ N    (OK )    848x
# 	subs ~ A    (?  )     28x
# 					Genesis 11:10 w5148"שְׁנָתַ֖יִם"
# 						BHS: subs
# 						OSM: HAcfda - None
# 					Genesis 23:1 w10747"שְׁנֵ֖י"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 25:7 w12524"שְׁנֵֽי"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 25:17 w12671"שְׁנֵי֙"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 41:1 w22357"שְׁנָתַ֣יִם"
# 						BHS: subs
# 						OSM: HAcfda - None
# 					Genesis 41:27 w22857"שְׁנֵ֥י"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 41:30 w22886"שְׁנֵ֤י"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 41:34 w22974"שְׁנֵ֥י"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 41:36 w23013"שְׁנֵ֣י"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					Genesis 41:47 w23221"שְׁנֵ֣י"
# 						BHS: subs
# 						OSM: HAcmdc - None
# 					and 18 more occurrences
#
# >JN/                      788x [<NEG>] "אַיִן"
# 	subs ~ Tn   (NN )    784x
# 	subs ~ N    (OK?)      3x
# 	subs ~ Ti   (?  )      1x
# 					Jeremiah 11:14 w240654"אֵינֶ֣נִּי"
# 						BHS: subs
# 						OSM: HTi - HSp1cs
#
# CNJM/                     768x [two] "שְׁנַיִם"
# 	subs ~ A    (NN )    768x
#
# H=                        743x [<interrogative>] "הֲ"
# 	inrg ~ Ti   (OK )    737x
# 	inrg ~ Td   (?  )      6x
# 					Exodus 10:7 w33969"הֲ"
# 						BHS: inrg
# 						OSM: HTd - None
# 					Numbers 23:19 w85020"הַ"
# 						BHS: inrg
# 						OSM: HTd - None
# 					Judges 12:5 w135520"הַֽ"
# 						BHS: inrg
# 						OSM: HTd - None
# 					Judges 14:15 w136592"הַ"
# 						BHS: inrg
# 						OSM: HTd - None
# 					2_Samuel 15:27 w169519"הֲ"
# 						BHS: inrg
# 						OSM: HTd - None
# 					Song_of_songs 6:11 w358845"הֲ"
# 						BHS: inrg
# 						OSM: HTd - None
#
# QR>[                      732x [call] "קרא"
# 	verb ~ V    (OK )    730x
# 	verb ~ A    (?  )      1x
# 					Numbers 1:16 w69765"קריאי"
# 						BHS: verb
# 						OSM: HAampc - None
#
# >L=                       726x [not] "אַל"
# 	nega ~ Tn   (OK )    725x
# 	nega ~ R    (?  )      1x
# 					Ezekiel 9:5 w268212"על"
# 						BHS: nega
# 						OSM: HR - None
#
# >XR/                      715x [after] "אַחַר"
# 	subs ~ R    (NN )    679x
# 	subs ~ D    (?  )     35x
# 					Genesis 10:18 w4778"אַחַ֣ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Genesis 30:21 w15924"אַחַ֖ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Genesis 33:7 w18203"אַחַ֗ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Genesis 38:30 w21405"אַחַר֙"
# 						BHS: subs
# 						OSM: HD - None
# 					Exodus 5:1 w30809"אַחַ֗ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Leviticus 14:8 w60374"אַחַ֖ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Leviticus 14:19 w60680"אַחַ֖ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Leviticus 14:36 w61053"אַ֥חַר"
# 						BHS: subs
# 						OSM: HD - None
# 					Leviticus 15:28 w62072"אַחַ֥ר"
# 						BHS: subs
# 						OSM: HD - None
# 					Leviticus 22:7 w65502"אַחַר֙"
# 						BHS: subs
# 						OSM: HD - None
# 					and 25 more occurrences
# 	subs ~ N    (OK?)      1x
#
# QWM[                      629x [arise] "קום"
# 	verb ~ V    (OK )    627x
# 	verb ~ N    (?  )      2x
# 					Jeremiah 51:1 w262760"קָמָ֑י"
# 						BHS: verb
# 						OSM: HNp - None
# 					Psalms 139:21 w334548"תְקֹומְמֶ֗יךָ"
# 						BHS: verb
# 						OSM: HNcmpc - HSp2ms
#
# CLC/                      602x [three] "שָׁלֹשׁ"
# 	subs ~ A    (NN )    602x
#
# LB/                       601x [heart] "לֵב"
# 	subs ~ N    (OK )    600x
# 	subs ~ R    (?  )      1x
# 					1_Kings 12:33 w186762"לבד"
# 						BHS: subs
# 						OSM: HR - HNcmsa
#
# M>H/                      579x [hundred] "מֵאָה"
# 	subs ~ A    (NN )    578x
# 	subs ~ N    (OK?)      1x
#
# KH                        577x [thus] "כֹּה"
# 	advb ~ D    (OK )    576x
# 	advb ~ C    (?  )      1x
# 					2_Samuel 16:10 w170001"כי"
# 						BHS: advb
# 						OSM: HC - None
#
# MH                        573x [what] "מָה"
# 	prin ~ Ti   (OK )    571x
# 	prin ~ R    (?  )      2x
# 					Isaiah 3:15 w213130"מ"
# 						BHS: prin
# 						OSM: HR - None
# 					Ezekiel 8:6 w267779"מ"
# 						BHS: prin
# 						OSM: HR - None
#
# HR/                       558x [mountain] "הַר"
# 	subs ~ N    (OK )    557x
# 	subs ~ V    (?  )      1x
# 					Psalms 75:7 w323092"הָרִֽים"
# 						BHS: subs
# 						OSM: HVhc - None
#
# <BR[                      548x [pass] "עבר"
# 	verb ~ V    (OK )    547x
# 	verb ~ C    (?  )      1x
# 					2_Samuel 19:41 w172967"ויעברו"
# 						BHS: verb
# 						OSM: HC - HVhw3mp
#
# GDWL/                     526x [great] "גָּדֹול"
# 	adjv ~ A    (OK )    524x
# 	adjv ~ N    (?  )      2x
# 					Joshua 15:47 w122036"גבול"
# 						BHS: adjv
# 						OSM: HNcmsa - None
# 					Proverbs 19:19 w352021"גרל"
# 						BHS: adjv
# 						OSM: HNcmsc - None
#
# XMC/                      506x [five] "חָמֵשׁ"
# 	subs ~ A    (NN )    506x
#
# TXT/                      505x [under part] "תַּחַת"
# 	subs ~ R    (NN )    502x
# 	subs ~ N    (OK?)      2x
# 	subs ~ D    (?  )      1x
# 					Exodus 20:4 w39644"תַָּ֑֜חַת"
# 						BHS: subs
# 						OSM: HD - None
#
# >LP=/                     492x [thousand] "אֶלֶף"
# 	subs ~ A    (NN )    492x
#
# CB</                      490x [seven] "שֶׁבַע"
# 	subs ~ A    (NN )    487x
# 	subs ~ N    (OK?)      3x
#
# <WD/                      490x [duration] "עֹוד"
# 	subs ~ D    (NN )    490x
#
# VWB/                      469x [good] "טֹוב"
# 	adjv ~ A    (OK )    466x
# 	adjv ~ V    (?  )      3x
# 					1_Samuel 16:16 w150635"טֹ֥וב"
# 						BHS: adjv
# 						OSM: HVqq3ms - None
# 					1_Samuel 16:23 w150779"טֹ֣וב"
# 						BHS: adjv
# 						OSM: HVqp3ms - None
# 					2_Samuel 3:36 w162531"טֹֽוב"
# 						BHS: adjv
# 						OSM: HVqp3ms - None
#
# >RB</                     454x [four] "אַרְבַּע"
# 	subs ~ A    (NN )    454x
#
# RB/                       424x [much] "רַב"
# 	adjv ~ A    (OK )    422x
# 	adjv ~ N    (?  )      1x
# 					Amos 6:2 w296971"רַבָּ֑ה"
# 						BHS: adjv
# 						OSM: HNp - None
# 	adjv ~ V    (?  )      1x
# 					Psalms 18:15 w312825"רָ֝ב"
# 						BHS: adjv
# 						OSM: HVqp3ms - None
#
# MCPV/                     422x [justice] "מִשְׁפָּט"
# 	subs ~ N    (OK )    421x
# 	subs ~ V    (?  )      1x
# 					Ezekiel 44:24 w288284"שׁפט"
# 						BHS: subs
# 						OSM: HVqc - None
#
# BJN/                      407x [interval] "בַּיִן"
# 	subs ~ R    (NN )    407x
#
# L                         378x [to] "לְ"
# 	prep ~ R    (OK )    313x
# 	prep ~ To   (OK?)     40x
# 	prep ~ C    (?  )     25x
# 					Daniel 2:8 w370687"ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:10 w370743"ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:12 w370786"ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:24 w371001"ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:40 w371355"ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:41 w371397"ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:45 w371485"ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:3 w371674"לַ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:7 w371741"ל"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:8 w371776"ל"
# 						BHS: prep
# 						OSM: AC - None
# 					and 15 more occurrences
#
# R</                       347x [evil] "רַע"
# 	adjv ~ A    (OK )    345x
# 	adjv ~ N    (?  )      2x
# 					Jeremiah 18:10 w243834"רעה"
# 						BHS: adjv
# 						OSM: HNcfsa - None
# 					Proverbs 1:16 w347073"רַ֣ע"
# 						BHS: adjv
# 						OSM: HNcmsa - None
#
# DJ                        345x [<relative>] "דִּי"
# 	prep ~ Tr   (NN )    286x
# 	prep ~ C    (?  )     44x
# 					Daniel 2:8 w370689"דִּ֣י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:10 w370745"דִּ֚י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:18 w370898"דִּ֣י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:20 w370937"דִּ֧י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:23 w370996"דִּֽי"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:40 w371357"דִּ֤י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:41 w371374"דִֽי"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:41 w371399"דִּ֣י"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:43 w371424"די"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:43 w371445"דִ֣י"
# 						BHS: prep
# 						OSM: AC - None
# 					and 34 more occurrences
# 	prep ~ P    (?  )      7x
# 					Daniel 3:6 w371727"דִּי"
# 						BHS: prep
# 						OSM: APf3bs - None
# 					Daniel 3:11 w371828"דִּי"
# 						BHS: prep
# 						OSM: APf3cs - None
# 					Daniel 4:14 w372654"דִּ֤י"
# 						BHS: prep
# 						OSM: APfxcs - None
# 					Daniel 4:22 w372885"דִּ֥י"
# 						BHS: prep
# 						OSM: APrxcs - None
# 					Daniel 4:29 w373014"דִּ֥י"
# 						BHS: prep
# 						OSM: APrxcs - None
# 					Daniel 5:21 w373690"דִּ֥י"
# 						BHS: prep
# 						OSM: APf3cs - None
# 					Ezra 7:18 w381276"דִי֩"
# 						BHS: prep
# 						OSM: APfxcs - None
# 	prep ~ T    (?  )      7x
# 					Daniel 4:12 w372604"דִּ֣י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 4:20 w372815"דִּ֣י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 4:26 w372939"דִּ֥י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 5:5 w373253"דִּ֣י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 5:5 w373263"דִּֽי"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 5:5 w373266"דִּ֣י"
# 						BHS: prep
# 						OSM: AT - None
# 					Daniel 5:7 w373324"דִֽי"
# 						BHS: prep
# 						OSM: AT - None
# 	prep ~ A    (?  )      1x
# 					Daniel 4:23 w372901"דִּ֣י"
# 						BHS: prep
# 						OSM: AAafsa - None
#
# SBJB/                     336x [surrounding] "סָבִיב"
# 	subs ~ N    (OK )    335x
# 	subs ~ D    (?  )      1x
# 					Jeremiah 20:3 w244604"סָּבִֽיב"
# 						BHS: subs
# 						OSM: HD - None
#
# JR>[                      332x [fear] "ירא"
# 	verb ~ V    (OK )    324x
# 	verb ~ A    (?  )      7x
# 					1_Kings 18:3 w190377"יָרֵ֛א"
# 						BHS: verb
# 						OSM: HAamsa - None
# 					1_Kings 18:12 w190578"יָרֵ֥א"
# 						BHS: verb
# 						OSM: HAamsa - None
# 					2_Kings 17:32 w206302"יְרֵאִ֖ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					2_Kings 17:33 w206323"יְרֵאִ֑ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					2_Kings 17:34 w206351"יְרֵאִים֙"
# 						BHS: verb
# 						OSM: HAampa - None
# 					2_Kings 17:41 w206501"יְרֵאִים֙"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Jeremiah 26:19 w248339"יָרֵ֣א"
# 						BHS: verb
# 						OSM: HAamsa - None
# 	verb ~ N    (?  )      1x
# 					Psalms 119:38 w331600"יִרְאָתֶֽךָ"
# 						BHS: verb
# 						OSM: HNcfsc - HSp2ms
#
# <FRJM/                    315x [twenty] "עֶשְׂרִים"
# 	subs ~ A    (NN )    315x
#
# R<H/                      313x [evil] "רָעָה"
# 	subs ~ N    (OK )    307x
# 	subs ~ A    (?  )      6x
# 					Jeremiah 11:15 w240679"רָעָתֵ֖כִי"
# 						BHS: subs
# 						OSM: HAafsc - HSp2fs
# 					Jeremiah 15:11 w242421"רָעָ֛ה"
# 						BHS: subs
# 						OSM: HAafsa - None
# 					Jeremiah 28:8 w249270"רָעָ֥ה"
# 						BHS: subs
# 						OSM: HAafsa - None
# 					Psalms 71:20 w322260"רָ֫עֹ֥ות"
# 						BHS: subs
# 						OSM: HAafpa - None
# 					Ecclesiastes 9:12 w362656"רָעָ֔ה"
# 						BHS: subs
# 						OSM: HAafsa - None
# 					Ecclesiastes 10:13 w362912"רָעָֽה"
# 						BHS: subs
# 						OSM: HAafsa - None
#
# M>D/                      300x [might] "מְאֹד"
# 	subs ~ D    (NN )    297x
# 	subs ~ N    (OK?)      3x
#
# <T/                       297x [time] "עֵת"
# 	subs ~ N    (OK )    296x
# 	subs ~ V    (?  )      1x
# 					Psalms 105:19 w328741"עֵ֥ת"
# 						BHS: subs
# 						OSM: HVqc - None
#
# LWJ/                      292x [Levite] "לֵוִי"
# 	adjv ~ N    (NN )    292x
#
# ML>[                      292x [be full] "מלא"
# 	verb ~ V    (OK )    250x
# 	verb ~ A    (?  )     42x
# 					Numbers 7:13 w74147"מְלֵאִ֗ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Numbers 7:14 w74159"מְלֵאָ֥ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					Numbers 7:19 w74229"מְלֵאִ֗ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Numbers 7:20 w74241"מְלֵאָ֥ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					Numbers 7:25 w74310"מְלֵאִ֗ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Numbers 7:26 w74322"מְלֵאָ֥ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					Numbers 7:31 w74391"מְלֵאִ֗ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Numbers 7:32 w74403"מְלֵאָ֥ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					Numbers 7:37 w74472"מְלֵאִ֗ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Numbers 7:38 w74484"מְלֵאָ֥ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					and 32 more occurrences
#
# HMH                       291x [they] "הֵמָּה"
# 	prps ~ P    (OK )    290x
# 	prps ~ S    (?  )      1x
# 					Jeremiah 36:32 w255103"הֵֽמָּה"
# 						BHS: prps
# 						OSM: HSp3mp - None
#
# PLCTJ/                    288x [Philistine] "פְּלִשְׁתִּי"
# 	adjv ~ N    (NN )    287x
# 	adjv ~ Td   (?  )      1x
# 					2_Samuel 21:12 w174041"הפלשׁתים"
# 						BHS: adjv
# 						OSM: HTd - HNgmpa
#
# XDC=/                     284x [month] "חֹדֶשׁ"
# 	subs ~ N    (OK )    283x
# 	subs ~ A    (?  )      1x
# 					Isaiah 66:22 w234938"חֳדָשִׁים"
# 						BHS: subs
# 						OSM: HAampa - None
#
# QRB[                      281x [approach] "קרב"
# 	verb ~ V    (OK )    280x
# 	verb ~ A    (?  )      1x
# 					Zephaniah 1:14 w303368"קָרֹ֖וב"
# 						BHS: verb
# 						OSM: HAamsa - None
#
# >P/                       277x [nose] "אַף"
# 	subs ~ N    (OK )    216x
# 	subs ~ Ta   (?  )     61x
# 					Genesis 27:45 w14451"אַף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Genesis 30:2 w15621"אַ֥ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Exodus 4:14 w30442"אַ֨ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Exodus 32:19 w46924"אַ֣ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Exodus 32:22 w46989"אַ֖ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Numbers 11:10 w76983"אַ֤ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Numbers 12:9 w77734"אַ֧ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Numbers 22:22 w84243"אַ֣ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Numbers 22:27 w84375"אַ֣ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					Numbers 24:10 w85353"אַ֤ף"
# 						BHS: subs
# 						OSM: HTa - None
# 					and 51 more occurrences
#
# CC/                       274x [six] "שֵׁשׁ"
# 	subs ~ A    (NN )    274x
#
# HM                        269x [they] "הֵם"
# 	prps ~ P    (OK )    266x
# 	prps ~ S    (?  )      2x
# 					Ezekiel 8:6 w267780"הם"
# 						BHS: prps
# 						OSM: HSp3mp - None
# 					Song_of_songs 6:5 w358746"הֵ֖ם"
# 						BHS: prps
# 						OSM: HSp3mp - None
#
# XSD/                      245x [loyalty] "חֶסֶד"
# 	subs ~ N    (OK )    244x
# 	subs ~ C    (?  )      1x
# 					Nehemiah 9:17 w388162"וחסד"
# 						BHS: subs
# 						OSM: HC - HNcmsa
#
# XJL/                      244x [power] "חַיִל"
# 	subs ~ N    (OK )    242x
# 	subs ~ A    (?  )      1x
# 					2_Samuel 23:20 w175213"חי"
# 						BHS: subs
# 						OSM: HAamsa - None
#
# XJ/                       239x [alive] "חַי"
# 	adjv ~ A    (OK )    234x
# 	adjv ~ N    (?  )      5x
# 					2_Samuel 11:11 w165979"חֵ֣י"
# 						BHS: adjv
# 						OSM: HNcbsc - None
# 					2_Samuel 15:21 w169359"חֵי֙"
# 						BHS: adjv
# 						OSM: HNcbsc - None
# 					Ruth 3:13 w357013"חַי"
# 						BHS: adjv
# 						OSM: HNcbsa - None
# 					Ecclesiastes 7:2 w361514"חַ֖י"
# 						BHS: adjv
# 						OSM: HNcbsa - None
# 					Daniel 12:7 w378044"חֵ֣י"
# 						BHS: adjv
# 						OSM: HNcbsc - None
#
# RBH[                      224x [be many] "רבה"
# 	verb ~ V    (OK )    223x
# 	verb ~ C    (?  )      1x
# 					2_Chronicles 24:27 w418874"ורב"
# 						BHS: verb
# 						OSM: HC - HNcbsc
#
# <FR/                      203x [-teen] "עָשָׂר"
# 	subs ~ A    (NN )    203x
#
# LKN                       200x [therefore] "לָכֵן"
# 	advb ~ R    (NN )    200x
#
# XYR/                      192x [court] "חָצֵר"
# 	subs ~ N    (OK )    191x
# 	subs ~ Td   (?  )      1x
# 					2_Kings 20:4 w208263"העיר"
# 						BHS: subs
# 						OSM: HTd - HNcfsa
#
# >BD[                      186x [perish] "אבד"
# 	verb ~ V    (OK )    183x
# 	verb ~ N    (?  )      2x
# 					Numbers 24:20 w85550"אֹבֵֽד"
# 						BHS: verb
# 						OSM: HNcmsa - None
# 					Numbers 24:24 w85605"אֹבֵֽד"
# 						BHS: verb
# 						OSM: HNcmsa - None
#
# SPR/                      185x [letter] "סֵפֶר"
# 	subs ~ N    (OK )    183x
# 	subs ~ Td   (?  )      2x
# 					1_Kings 21:8 w193187"הספרים"
# 						BHS: subs
# 						OSM: HTd - HNcmpa
# 					Isaiah 29:11 w221546"הספר"
# 						BHS: subs
# 						OSM: HTd - HNcmsa
#
# ZQN/                      181x [old] "זָקֵן"
# 	adjv ~ A    (OK )    178x
# 	adjv ~ V    (?  )      3x
# 					1_Samuel 2:22 w142525"זָקֵ֣ן"
# 						BHS: adjv
# 						OSM: HVqp3ms - None
# 					1_Samuel 4:18 w143730"זָקֵ֥ן"
# 						BHS: adjv
# 						OSM: HVqp3ms - None
# 					1_Samuel 17:12 w151031"זָקֵ֖ן"
# 						BHS: adjv
# 						OSM: HVqp3ms - None
#
# LMH                       178x [why] "לָמָה"
# 	inrg ~ R    (NN )    178x
#
# MWT/                      161x [death] "מָוֶת"
# 	subs ~ N    (OK )    158x
# 	subs ~ V    (?  )      2x
# 					1_Kings 13:31 w187546"מֹותִי֙"
# 						BHS: subs
# 						OSM: HVqc - HSp1cs
# 					2_Chronicles 24:22 w418754"מֹותֹ֣ו"
# 						BHS: subs
# 						OSM: HVqc - HSp3ms
#
# GBWR/                     159x [vigorous] "גִּבֹּור"
# 	subs ~ A    (NN )    159x
#
# CNJ/                      156x [second] "שֵׁנִי"
# 	adjv ~ A    (OK )    155x
# 	adjv ~ N    (?  )      1x
# 					2_Chronicles 30:2 w421879"שֵּׁנִֽי"
# 						BHS: adjv
# 						OSM: HNcbsa - None
#
# FMX[                      154x [rejoice] "שׂמח"
# 	verb ~ V    (OK )    153x
# 	verb ~ C    (?  )      1x
# 					Proverbs 23:24 w353239"וישׂמח"
# 						BHS: verb
# 						OSM: HC - HVqi3ms
#
# NGD/                      151x [counterpart] "נֶגֶד"
# 	subs ~ R    (NN )    151x
#
# CMNH/                     147x [eight] "שְׁמֹנֶה"
# 	subs ~ A    (NN )    147x
#
# NWX[                      141x [settle] "נוח"
# 	verb ~ V    (OK )    140x
# 	verb ~ N    (?  )      1x
# 					Esther 9:18 w369595"נֹ֗וחַ"
# 						BHS: verb
# 						OSM: HNcmsa - None
#
# M<L/                      140x [top] "מַעַל"
# 	subs ~ D    (NN )    140x
#
# JC/                       138x [existence] "יֵשׁ"
# 	subs ~ Tm   (NN )    138x
#
# XKM/                      138x [wise] "חָכָם"
# 	adjv ~ A    (OK )    137x
# 	adjv ~ N    (?  )      1x
# 					Proverbs 1:5 w346972"חָ֭כָם"
# 						BHS: adjv
# 						OSM: HNcmsa - None
#
# <FRH/                     134x [-teen] "עֶשְׂרֵה"
# 	subs ~ A    (NN )    134x
#
# <FRH=/                    120x [ten] "עֲשָׂרָה"
# 	subs ~ A    (NN )    120x
#
# MN                        119x [from] "מִן"
# 	prep ~ R    (OK )    117x
# 	prep ~ C    (?  )      1x
# 					Daniel 3:22 w372096"מִן"
# 						BHS: prep
# 						OSM: AC - None
# 	prep ~ N    (?  )      1x
# 					Ezra 6:11 w380670"מִנִּי֮"
# 						BHS: prep
# 						OSM: ANcmpc - ASp3ms
#
# GDL[                      117x [be strong] "גדל"
# 	verb ~ V    (OK )    116x
# 	verb ~ A    (?  )      1x
# 					2_Chronicles 2:8 w407475"גָּדֹ֥ול"
# 						BHS: verb
# 						OSM: HAamsa - None
#
# NB>[                      115x [speak as prophet] "נבא"
# 	verb ~ V    (OK )    114x
# 	verb ~ N    (?  )      1x
# 					1_Chronicles 25:1 w403896"נביאים"
# 						BHS: verb
# 						OSM: HNcmpa - None
#
# BLT/                      112x [failure] "בֵּלֶת"
# 	subs ~ C    (NN )    103x
# 	subs ~ Tn   (?  )      6x
# 					Numbers 14:16 w78744"בִּלְתִּ֞י"
# 						BHS: subs
# 						OSM: HTn - None
# 					2_Kings 12:9 w202743"בִלְתִּ֥י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Jeremiah 17:23 w243530"בִלְתִּ֖י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Jeremiah 17:27 w243658"בִלְתִּ֣י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Ezekiel 13:3 w269915"בִלְתִּ֥י"
# 						BHS: subs
# 						OSM: HTn - None
# 					Ezekiel 16:28 w271513"בִּלְתִּ֖י"
# 						BHS: subs
# 						OSM: HTn - None
# 	subs ~ R    (?  )      3x
# 					Jeremiah 33:20 w253015"בִלְתִּ֛י"
# 						BHS: subs
# 						OSM: HR - None
# 					Jeremiah 35:9 w253925"בִלְתִּ֛י"
# 						BHS: subs
# 						OSM: HR - None
# 					Hosea 13:4 w293775"בִּלְתִּֽי"
# 						BHS: subs
# 						OSM: HR - HSp1cs
#
# KNP/                      109x [wing] "כָּנָף"
# 	subs ~ N    (OK )    108x
# 	subs ~ Td   (?  )      1x
# 					Ecclesiastes 10:20 w363025"הכנפים"
# 						BHS: subs
# 						OSM: HTd - HNcfda
#
# SPR[                      108x [count] "ספר"
# 	verb ~ V    (OK )    107x
# 	verb ~ N    (?  )      1x
# 					Ezra 7:11 w381139"סֹפֵ֞ר"
# 						BHS: verb
# 						OSM: HNcmsc - None
#
# B<D/                      105x [distance] "בַּעַד"
# 	subs ~ R    (NN )    105x
#
# CKX[                      104x [forget] "שׁכח"
# 	verb ~ V    (OK )    102x
# 	verb ~ A    (?  )      2x
# 					Isaiah 65:11 w234148"שְּׁכֵחִ֖ים"
# 						BHS: verb
# 						OSM: HAampa - None
# 					Psalms 9:18 w311737"שְׁכֵחֵ֥י"
# 						BHS: verb
# 						OSM: HAampc - None
#
# R<<[                      103x [be evil] "רעע"
# 	verb ~ V    (OK )     99x
# 	verb ~ A    (?  )      4x
# 					Exodus 21:8 w40137"רָעָ֞ה"
# 						BHS: verb
# 						OSM: HAafsa - None
# 					Numbers 11:10 w76990"רָֽע"
# 						BHS: verb
# 						OSM: HAamsa - None
# 					Joshua 24:15 w127006"רַ֨ע"
# 						BHS: verb
# 						OSM: HAamsa - None
# 					Jeremiah 2:19 w235683"רַ֣ע"
# 						BHS: verb
# 						OSM: HAamsa - None
#
# M<V/                      101x [little] "מְעַט"
# 	subs ~ N    (OK )     80x
# 	subs ~ A    (?  )     16x
# 					Numbers 13:18 w78052"מְעַ֥ט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Numbers 26:54 w86682"מְעַ֕ט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Numbers 26:56 w86712"מְעָֽט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Numbers 33:54 w91338"מְעַט֙"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Numbers 35:8 w92000"מְעַ֖ט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Joshua 22:17 w125678"מְעַט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					1_Samuel 14:6 w148475"מְעָֽט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Hosea 1:4 w290995"מְעַ֗ט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Hosea 8:10 w292729"מְּעָ֔ט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					Haggai 1:6 w304220"מְעָ֗ט"
# 						BHS: subs
# 						OSM: HAamsa - None
# 					and 6 more occurrences
# 	subs ~ D    (?  )      5x
# 					Deuteronomy 7:22 w97911"מְעַ֣ט"
# 						BHS: subs
# 						OSM: HD - None
# 					Deuteronomy 7:22 w97912"מְעָ֑ט"
# 						BHS: subs
# 						OSM: HD - None
# 					Zechariah 1:15 w305313"מְּעָ֔ט"
# 						BHS: subs
# 						OSM: HD - None
# 					Job 10:20 w338791"מְּעָֽט"
# 						BHS: subs
# 						OSM: HD - None
# 					Job 24:24 w342169"מְּעַ֨ט"
# 						BHS: subs
# 						OSM: HD - None
#
# J<N/                      100x [motive] "יַעַן"
# 	subs ~ C    (NN )     99x
# 	subs ~ N    (OK?)      1x
#
# VHR/                       96x [pure] "טָהֹר"
# 	adjv ~ A    (OK )     95x
# 	adjv ~ N    (?  )      1x
# 					Psalms 89:45 w326140"טְּהָרֹ֑ו"
# 						BHS: adjv
# 						OSM: HNcmsc - HSp3ms
#
# D<T/                       93x [knowledge] "דַּעַת"
# 	subs ~ N    (OK )     91x
# 	subs ~ V    (?  )      2x
# 					Isaiah 32:4 w222713"דָ֑עַת"
# 						BHS: subs
# 						OSM: HVqc - None
# 					Ecclesiastes 1:17 w359557"דַ֥עַת"
# 						BHS: subs
# 						OSM: HVqc - None
#
# ZNH[                       93x [fornicate] "זנה"
# 	verb ~ V    (OK )     90x
# 	verb ~ N    (?  )      3x
# 					Leviticus 21:7 w65068"זֹנָ֤ה"
# 						BHS: verb
# 						OSM: HNcfsa - None
# 					Leviticus 21:14 w65193"זֹנָ֔ה"
# 						BHS: verb
# 						OSM: HNcfsa - None
# 					Joel 4:3 w295064"זֹּונָ֔ה"
# 						BHS: verb
# 						OSM: HNcfsa - None
#
# CJR[                       88x [sing] "שׁיר"
# 	verb ~ V    (OK )     87x
# 	verb ~ N    (?  )      1x
# 					Isaiah 23:16 w219632"שִׁ֔יר"
# 						BHS: verb
# 						OSM: HNcbsa - None
#
# QDM/                       87x [front] "קֶדֶם"
# 	subs ~ N    (OK )     85x
# 	subs ~ D    (?  )      2x
# 					Leviticus 1:16 w52844"קֵ֔דְמָה"
# 						BHS: subs
# 						OSM: HD - HSd
# 					2_Chronicles 4:10 w408325"קֵ֖דְמָה"
# 						BHS: subs
# 						OSM: HD - HSd
#
# >MRJ/                      87x [Amorite] "אֱמֹרִי"
# 	adjv ~ N    (NN )     87x
#
# HMWN/                      84x [commotion] "הָמֹון"
# 	subs ~ N    (OK )     83x
# 	subs ~ Td   (?  )      1x
# 					2_Kings 7:13 w199325"ההמון"
# 						BHS: subs
# 						OSM: HTd - HNcmsa
#
# KL/                        83x [whole] "כֹּל"
# 	subs ~ N    (OK )     82x
# 	subs ~ V    (?  )      1x
# 					Daniel 7:23 w375052"כָּל"
# 						BHS: subs
# 						OSM: AVqi3fs - None
#
# ZKR=/                      82x [male] "זָכָר"
# 	adjv ~ A    (OK )     58x
# 	adjv ~ N    (?  )     24x
# 					Exodus 13:12 w36000"זְּכָרִ֖ים"
# 						BHS: adjv
# 						OSM: HNcmpa - None
# 					Exodus 13:15 w36078"זְּכָרִ֔ים"
# 						BHS: adjv
# 						OSM: HNcmpa - None
# 					Leviticus 12:7 w58837"זָּכָ֖ר"
# 						BHS: adjv
# 						OSM: HNcmsa - None
# 					Leviticus 15:33 w62166"זָּכָ֖ר"
# 						BHS: adjv
# 						OSM: HNcmsa - None
# 					Leviticus 27:3 w68994"זָּכָ֔ר"
# 						BHS: adjv
# 						OSM: HNcmsa - None
# 					Leviticus 27:5 w69038"זָּכָ֖ר"
# 						BHS: adjv
# 						OSM: HNcmsa - None
# 					Leviticus 27:6 w69061"זָּכָ֔ר"
# 						BHS: adjv
# 						OSM: HNcmsa - None
# 					Numbers 5:3 w72752"זָּכָ֤ר"
# 						BHS: adjv
# 						OSM: HNcmsa - None
# 					Deuteronomy 15:19 w102391"זָּכָ֔ר"
# 						BHS: adjv
# 						OSM: HNcmsa - None
# 					Joshua 5:4 w115038"זְּכָרִ֜ים"
# 						BHS: adjv
# 						OSM: HNcmpa - None
# 					and 14 more occurrences
#
# JHWDJ/                     82x [Jewish] "יְהוּדִי"
# 	adjv ~ N    (NN )     80x
# 	adjv ~ A    (OK?)      2x
#
# MHR[                       81x [hasten] "מהר"
# 	verb ~ V    (OK )     80x
# 	verb ~ A    (?  )      1x
# 					Zephaniah 1:14 w303370"מַהֵ֣ר"
# 						BHS: verb
# 						OSM: HAamsa - None
#
# TC</                       78x [nine] "תֵּשַׁע"
# 	subs ~ A    (NN )     78x
#
# XPY[                       77x [desire] "חפץ"
# 	verb ~ V    (OK )     74x
# 	verb ~ A    (?  )      3x
# 					Psalms 5:5 w311074"חָפֵ֘ץ"
# 						BHS: verb
# 						OSM: HAamsc - None
# 					Psalms 34:13 w315702"חָפֵ֣ץ"
# 						BHS: verb
# 						OSM: HAamsa - None
# 					Psalms 35:27 w316079"חָפֵ֗ץ"
# 						BHS: verb
# 						OSM: HAamsa - None
#
# M>S[                       75x [reject] "מאס"
# 	verb ~ V    (OK )     74x
# 	verb ~ N    (?  )      1x
# 					Lamentations 3:45 w364795"מָאֹ֛וס"
# 						BHS: verb
# 						OSM: HNcmsa - None
#
# NYB[                       74x [stand] "נצב"
# 	verb ~ V    (OK )     73x
# 	verb ~ N    (?  )      1x
# 					2_Chronicles 8:10 w410806"נציבים"
# 						BHS: verb
# 						OSM: HNcmpa - None
#
# KN<NJ/                     73x [Canaanite] "כְּנַעֲנִי"
# 	adjv ~ N    (NN )     73x
#
# MDW<                       72x [why] "מַדּוּעַ"
# 	inrg ~ Ti   (OK )     71x
# 	inrg ~ D    (?  )      1x
# 					Judges 11:7 w134603"מַדּ֜וּעַ"
# 						BHS: inrg
# 						OSM: HD - None
#
# KSJL/                      70x [insolent] "כְּסִיל"
# 	adjv ~ A    (OK )     69x
# 	adjv ~ N    (?  )      1x
# 					Proverbs 3:35 w347778"כְסִילִ֗ים"
# 						BHS: adjv
# 						OSM: HNcmpa - None
#
# LJN[                       70x [lodge] "לין"
# 	verb ~ V    (OK )     69x
# 	verb ~ R    (?  )      1x
# 					Isaiah 10:29 w216023"לָ֑נוּ"
# 						BHS: verb
# 						OSM: HR - HSp1cp
#
# CQH[                       68x [give drink] "שׁקה"
# 	verb ~ V    (OK )     61x
# 	verb ~ N    (?  )      7x
# 					Genesis 40:2 w21943"מַּשְׁקִ֔ים"
# 						BHS: verb
# 						OSM: HNcmpa - None
# 					Genesis 40:5 w21997"מַּשְׁקֶ֣ה"
# 						BHS: verb
# 						OSM: HNcmsa - None
# 					Genesis 40:9 w22067"מַּשְׁקִ֛ים"
# 						BHS: verb
# 						OSM: HNcmpa - None
# 					Genesis 40:20 w22307"מַּשְׁקִ֗ים"
# 						BHS: verb
# 						OSM: HNcmpa - None
# 					Genesis 40:21 w22322"מַּשְׁקִ֖ים"
# 						BHS: verb
# 						OSM: HNcmpa - None
# 					Genesis 40:23 w22348"מַּשְׁקִ֛ים"
# 						BHS: verb
# 						OSM: HNcmpa - None
# 					Genesis 41:9 w22517"מַּשְׁקִ֔ים"
# 						BHS: verb
# 						OSM: HNcmpa - None
#
# TQ<[                       67x [blow] "תקע"
# 	verb ~ V    (OK )     66x
# 	verb ~ C    (?  )      1x
# 					Jeremiah 4:5 w236639"ותקעו"
# 						BHS: verb
# 						OSM: HC - HVqv2mp
#
# PWY[                       65x [disperse] "פוץ"
# 	verb ~ V    (OK )     64x
# 	verb ~ N    (?  )      1x
# 					Jeremiah 25:34 w247790"תְפֹוצֹ֣ותִיכֶ֔ם"
# 						BHS: verb
# 						OSM: HNcfpc - HSp2mp
#
# VWBH/                      65x [what is good] "טֹובָה"
# 	subs ~ A    (NN )     65x
#
# KFDJ/                      64x [Chaldean] "כַּשְׂדִּי"
# 	adjv ~ N    (NN )     64x
#
# K                          63x [like] "כְּ"
# 	prep ~ R    (OK )     37x
# 	prep ~ C    (?  )     26x
# 					Daniel 2:8 w370686"כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:10 w370742"כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:12 w370785"כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:24 w371000"כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:40 w371354"כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:41 w371396"כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:43 w371444"כְ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 2:45 w371484"כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:7 w371740"כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					Daniel 3:8 w371775"כָּ"
# 						BHS: prep
# 						OSM: AC - None
# 					and 16 more occurrences
#
# NYR[                       62x [watch] "נצר"
# 	verb ~ V    (OK )     61x
# 	verb ~ A    (?  )      1x
# 					Isaiah 49:6 w229248"נצירי"
# 						BHS: verb
# 						OSM: HAampc - None
#
# >YL/                       61x [side] "אֵצֶל"
# 	subs ~ R    (NN )     61x
#
# RJB/                       59x [law-case] "רִיב"
# 	subs ~ N    (OK )     58x
# 	subs ~ V    (?  )      1x
# 					Job 31:13 w343527"רִבָ֗ם"
# 						BHS: subs
# 						OSM: HVNc - HSp3mp
#
# BLJ/                       58x [destruction] "בְּלִי"
# 	subs ~ Tn   (NN )     31x
# 	subs ~ N    (OK?)     24x
# 	subs ~ D    (?  )      3x
# 					2_Kings 1:3 w194825"בְּלִ֤י"
# 						BHS: subs
# 						OSM: HD - None
# 					2_Kings 1:6 w194895"בְּלִ֤י"
# 						BHS: subs
# 						OSM: HD - None
# 					2_Kings 1:16 w195188"בְּלִ֤י"
# 						BHS: subs
# 						OSM: HD - None
#
# DNH                        58x [this] "דְּנָה"
# 	prde ~ P    (OK )     50x
# 	prde ~ C    (?  )      8x
# 					Daniel 2:12 w370788"דְּנָ֔ה"
# 						BHS: prde
# 						OSM: AC - None
# 					Daniel 2:24 w371003"דְּנָ֗ה"
# 						BHS: prde
# 						OSM: AC - None
# 					Daniel 3:7 w371743"דְּנָ֡ה"
# 						BHS: prde
# 						OSM: AC - None
# 					Daniel 3:8 w371778"דְּנָה֙"
# 						BHS: prde
# 						OSM: AC - None
# 					Daniel 3:22 w372095"דְּנָ֗ה"
# 						BHS: prde
# 						OSM: AC - None
# 					Daniel 6:10 w374047"דְּנָ֑ה"
# 						BHS: prde
# 						OSM: AC - None
# 					Ezra 4:16 w379862"דְּנָ֔ה"
# 						BHS: prde
# 						OSM: AC - None
# 					Ezra 7:17 w381250"דְּנָה֩"
# 						BHS: prde
# 						OSM: AC - None
#
# VRM/                       56x [beginning] "טֶרֶם"
# 	subs ~ D    (NN )     56x
#
# <FR=/                      56x [ten] "עֶשֶׂר"
# 	subs ~ A    (NN )     56x
#
# HNH==                      50x [here] "הֵנָּה"
# 	advb ~ D    (OK )     49x
# 	advb ~ P    (?  )      1x
# 					2_Samuel 4:6 w162726"הֵנָּה"
# 						BHS: advb
# 						OSM: HPp3fp - None
#
# <BWR/                      49x [way] "עֲבוּר"
# 	subs ~ N    (OK )     44x
# 	subs ~ R    (?  )      4x
# 					Exodus 20:20 w39898"עֲבוּר֙"
# 						BHS: subs
# 						OSM: HR - None
# 					Exodus 20:20 w39906"עֲב֗וּר"
# 						BHS: subs
# 						OSM: HR - None
# 					2_Samuel 14:20 w168522"עֲב֤וּר"
# 						BHS: subs
# 						OSM: HR - None
# 					Job 20:2 w340926"עֲב֗וּר"
# 						BHS: subs
# 						OSM: HR - None
# 	subs ~ C    (?  )      1x
# 					2_Samuel 17:14 w170641"עֲב֗וּר"
# 						BHS: subs
# 						OSM: HC - None
#
# JR>/                       49x [afraid] "יָרֵא"
# 	adjv ~ A    (OK )     46x
# 	adjv ~ V    (?  )      3x
# 					Judges 7:10 w131678"יָרֵ֥א"
# 						BHS: adjv
# 						OSM: HVqrmsa - None
# 					Psalms 147:11 w335659"יְרֵאָ֑יו"
# 						BHS: adjv
# 						OSM: HVqrmpc - HSp3cs
# 					Ecclesiastes 8:13 w362150"יָרֵ֖א"
# 						BHS: adjv
# 						OSM: HVqrmsa - None
#
# >WR[                       49x [be light] "אור"
# 	verb ~ V    (OK )     43x
# 	verb ~ N    (?  )      6x
# 					Judges 16:2 w137244"אֹ֥ור"
# 						BHS: verb
# 						OSM: HNcbsc - None
# 					1_Samuel 14:36 w149164"אֹ֣ור"
# 						BHS: verb
# 						OSM: HNcbsc - None
# 					1_Samuel 25:34 w157306"אֹ֥ור"
# 						BHS: verb
# 						OSM: HNcbsc - None
# 					1_Samuel 25:36 w157370"אֹ֥ור"
# 						BHS: verb
# 						OSM: HNcbsc - None
# 					2_Samuel 17:22 w170875"אֹ֣ור"
# 						BHS: verb
# 						OSM: HNcbsc - None
# 					2_Kings 7:9 w199192"אֹ֥ור"
# 						BHS: verb
# 						OSM: HNcbsc - None
#
# HNH=                       48x [they] "הֵנָּה"
# 	prps ~ P    (OK )     47x
# 	prps ~ S    (?  )      1x
# 					Zechariah 5:9 w306339"הֵ֥נָּה"
# 						BHS: prps
# 						OSM: HSp3fp - None
#
# XTJ/                       48x [Hittite] "חִתִּי"
# 	adjv ~ N    (NN )     48x
#
# XNJT/                      47x [spear] "חֲנִית"
# 	subs ~ N    (OK )     46x
# 	subs ~ Td   (?  )      1x
# 					1_Samuel 26:22 w158119"החנית"
# 						BHS: subs
# 						OSM: HTd - HNcfsa
#
# JXD/                       47x [gathering] "יַחַד"
# 	subs ~ D    (NN )     30x
# 	subs ~ N    (OK?)     15x
# 	subs ~ V    (?  )      2x
# 					Proverbs 27:17 w354461"יָ֑חַד"
# 						BHS: subs
# 						OSM: HVhi3ms - None
# 					Proverbs 27:17 w354464"יַ֣חַד"
# 						BHS: subs
# 						OSM: HVhi3ms - None
#
# BXWR/                      46x [young man] "בָּחוּר"
# 	subs ~ N    (OK )     44x
# 	subs ~ V    (?  )      2x
# 					2_Samuel 6:1 w163428"בָּח֥וּר"
# 						BHS: subs
# 						OSM: HVqsmsa - None
# 					1_Chronicles 19:10 w401387"בָּחוּר֙"
# 						BHS: subs
# 						OSM: HVqsmsa - None
#
# <MD/                       45x [company] "עִמָּד"
# 	subs ~ R    (NN )     45x
#
# JR>H/                      44x [fear] "יִרְאָה"
# 	subs ~ N    (OK )     43x
# 	subs ~ V    (?  )      1x
# 					Isaiah 29:13 w221600"יִרְאָתָם֙"
# 						BHS: subs
# 						OSM: HVqc - HSp3mp
#
# VWB[                       44x [be good] "טוב"
# 	verb ~ A    (NN )     25x
# 	verb ~ V    (OK?)     19x
#
# >PS/                       43x [end] "אֶפֶס"
# 	subs ~ N    (OK )     42x
# 	subs ~ D    (?  )      1x
# 					Jeremiah 16:19 w243077"אַפְסֵי"
# 						BHS: subs
# 						OSM: HD - None
#
# BZH[                       43x [despise] "בזה"
# 	verb ~ V    (OK )     42x
# 	verb ~ N    (?  )      1x
# 					1_Samuel 15:9 w149744"נְמִבְזָ֥ה"
# 						BHS: verb
# 						OSM: HNcfsa - None
#
# YRR[                       43x [wrap, be narrow] "צרר"
# 	verb ~ V    (OK )     42x
# 	verb ~ A    (?  )      1x
# 					Lamentations 1:20 w363905"צַר"
# 						BHS: verb
# 						OSM: HAamsa - None
#
# TBW>H/                     43x [yield] "תְּבוּאָה"
# 	subs ~ N    (OK )     42x
# 	subs ~ V    (?  )      1x
# 					Job 22:21 w341684"תְּֽבֹואַתְךָ֥"
# 						BHS: subs
# 						OSM: HVqi3fs - HSp2ms
#
# QDM/                       42x [before] "קֳדָם"
# 	subs ~ R    (NN )     40x
# ...
# 	adjv ~ N    (?  )      1x
# 					1_Chronicles 27:29 w405405"שָּׁרֹונִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# RMTJ/                       1x [Ramathite] "רָמָתִי"
# 	adjv ~ N    (?  )      1x
# 					1_Chronicles 27:27 w405360"רָֽמָתִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# NMW>LJ/                     1x [Nemuelite] "נְמוּאֵלִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:12 w86127"נְּמ֣וּאֵלִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# JMJNJ=/                     1x [Jaminite] "יָמִינִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:12 w86132"יָּמִינִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# JKJNJ/                      1x [Jakinite] "יָכִינִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:12 w86137"יָּכִינִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# C>WLJ/                      1x [Shaulite] "שָׁאוּלִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:13 w86147"שָּׁאוּלִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# YPWNJ/                      1x [Zephonite] "צְפֹונִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:15 w86166"צְּפֹונִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# XGJ/                        1x [Haggite] "חַגִּי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:15 w86171"חַגִּ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# CWNJ/                       1x [Shunite] "שׁוּנִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:15 w86176"שּׁוּנִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# CDWN/                       1x [<uncertain>] "שַׁדּוּן"
# 	subs ~ Tr   (?  )      1x
# 					Job 19:29 w340913"שׁדין"
# 						BHS: subs
# 						OSM: HTr - HNcmsa
#
# >ZNJ/                       1x [Oznite] "אָזְנִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:16 w86181"אָזְנִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# <RJ/                        1x [Erite] "עֵרִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:16 w86186"עֵרִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# >RWDJ=/                     1x [Arodite] "אֲרֹודִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:17 w86191"אֲרֹודִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# >R>LJ/                      1x [Arelite] "אַרְאֵלִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:17 w86196"אַרְאֵלִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# CLNJ/                       1x [Shelanite] "שֵׁלָנִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:20 w86231"שֵּׁ֣לָנִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# PRYJ/                       1x [Perezite] "פַּרְצִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:20 w86236"פַּרְצִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# XMWLJ/                      1x [Hamulite] "חָמוּלִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:21 w86255"חָמוּלִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# CL>NN/                      1x [<uncertain>] "שַׁלְאֲנַן"
# 	subs ~ A    (?  )      1x
# 					Job 21:23 w341389"שַׁלְאֲנַ֥ן"
# 						BHS: subs
# 						OSM: HAamsa - None
#
# TWL<J/                      1x [Tolaite] "תֹּולָעִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:23 w86275"תֹּולָעִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# PWNJ/                       1x [Puite] "פּוּנִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:23 w86280"פּוּנִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# JCBJ/                       1x [Jashubite] "יָשֻׁבִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:24 w86285"יָּשׁוּבִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# CMRNJ/                      1x [Shimronite] "שִׁמְרֹנִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:24 w86290"שִּׁמְרֹנִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# SRDJ/                       1x [Seredite] "סַרְדִּי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:26 w86311"סַּרְדִּ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# >LNJ/                       1x [Elonite] "אֵלֹנִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:26 w86316"אֵלֹנִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# JXL>LJ/                     1x [Jahleelite] "יַחְלְאֵלִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:26 w86321"יַּחְלְאֵלִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# MKJRJ/                      1x [Makirite] "מָכִירִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:29 w86346"מָּכִירִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# SKJ/                        1x [Sukkite] "סֻכִּי"
# 	adjv ~ N    (?  )      1x
# 					2_Chronicles 12:3 w412681"סֻכִּיִּ֖ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
#
# >J<ZRJ/                     1x [Iezerite] "אִיעֶזְרִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:30 w86363"אִֽיעֶזְרִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# XLQJ/                       1x [Helekite] "חֶלְקִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:30 w86368"חֶלְקִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# >FRJ>LJ/                    1x [Asrielite] "אַשְׂרִיאֵלִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:31 w86373"אַשְׂרִֽאֵלִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# CKMJ/                       1x [Shechemite] "שִׁכְמִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:31 w86378"שִּׁכְמִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# CMJD<J/                     1x [Shemidaite] "שְׁמִידָעִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:32 w86383"שְּׁמִידָעִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# PRFZ/                       1x [<uncertain>] "פַּרְשֵׂז"
# 	subs ~ V    (?  )      1x
# 					Job 26:9 w342322"פַּרְשֵׁ֖ז"
# 						BHS: subs
# 						OSM: HVia - None
#
# XPRJ/                       1x [Hepherite] "חֶפְרִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:32 w86388"חֶפְרִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# >L=/                        1x [nothingness] "אַל"
# 	subs ~ Tn   (?  )      1x
# 					Job 24:25 w342192"אַ֗ל"
# 						BHS: subs
# 						OSM: HTn - None
#
# CTLXJ/                      1x [Shuthelahite] "שֻׁתַלְחִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:35 w86432"שֻּׁ֣תַלְחִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# BKRJ/                       1x [Bekerite] "בַּכְרִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:35 w86437"בַּכְרִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# TXNJ/                       1x [Tahanite] "תַּחֲנִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:35 w86442"תַּחֲנִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# <RNJ/                       1x [Eranite] "עֵרָנִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:36 w86451"עֵרָנִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# BL<J/                       1x [Belaite] "בַּלְעִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:38 w86478"בַּלְעִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# >CBLJ/                      1x [Ashbelite] "אַשְׁבֵּלִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:38 w86483"אַשְׁבֵּלִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# >XJRMJ/                     1x [Ahiramite] "אֲחִירָמִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:38 w86488"אֲחִירָמִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# CWPMJ/                      1x [Shuphamite] "שׁוּפָמִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:39 w86493"שּׁוּפָמִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# XWPMJ/                      1x [Huphamite] "חוּפָמִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:39 w86498"חוּפָמִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# >RDJ/                       1x [Ardite] "אַרְדִּי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:40 w86508"אַרְדִּ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# N<MJ/                       1x [Naamite] "נַעֲמִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:40 w86513"נַּעֲמִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# JCWJ/                       1x [Ishvite] "יִשְׁוִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:44 w86569"יִּשְׁוִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# BRJ<J/                      1x [Beriite] "בְּרִיעִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:44 w86574"בְּרִיעִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# XBRJ/                       1x [Heberite] "חֶבְרִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:45 w86582"חֶבְרִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# MLKJ>LJ/                    1x [Malkielite] "מַלְכִּיאֵלִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:45 w86587"מַּלְכִּיאֵלִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# JXY>LJ/                     1x [Jahzeelite] "יַחְצְאֵלִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:48 w86614"יַּחְצְאֵלִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# GWNJ/                       1x [Gunite] "גּוּנִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:48 w86619"גּוּנִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# CLMJ/                       1x [Shillemite] "שִׁלֵּמִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:49 w86629"שִּׁלֵּמִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# MRRJ/                       1x [Merarite] "מְרָרִי"
# 	adjv ~ N    (?  )      1x
# 					Numbers 26:57 w86734"מְּרָרִֽי"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# CPL==/                      1x [low] "שָׁפֵל"
# 	adjv ~ V    (?  )      1x
# 					Isaiah 2:12 w212752"שָׁפֵֽל"
# 						BHS: adjv
# 						OSM: HVqq3ms - None
#
# HXJRWT/                     1x [Pi Hahiroth] "הַחִירֹות"
# 	nmpr ~ Td   (?  )      1x
# 					Numbers 33:8 w90793"הַֽחִירֹ֔ת"
# 						BHS: nmpr
# 						OSM: HTd - HNp
#
# KJ/                         1x [branding] "כִּי"
# 	subs ~ C    (?  )      1x
# 					Isaiah 3:24 w213264"כִּי"
# 						BHS: subs
# 						OSM: HC - None
#
# CB<NH/                      1x [twice seven] "שִׁבְעָנָה"
# 	subs ~ A    (?  )      1x
# 					Job 42:13 w346870"שִׁבְעָ֥נָה"
# 						BHS: subs
# 						OSM: HAcmsa - None
#
# XVB=[                       1x [be coloured] "חטב"
# 	verb ~ N    (?  )      1x
# 					Proverbs 7:16 w348736"חֲ֝טֻבֹ֗ות"
# 						BHS: verb
# 						OSM: HNcfpc - None
#
# C>LH=/                      1x [<uncertain>] "שְׁאָלָה"
# 	subs ~ V    (?  )      1x
# 					Isaiah 7:11 w214443"שְׁאָ֔לָה"
# 						BHS: subs
# 						OSM: HVqc - None
#
# CB<H/                       1x [Shibah] "שִׁבְעָה"
# 	nmpr ~ A    (?  )      1x
# 					Genesis 26:33 w13592"שִׁבְעָ֑ה"
# 						BHS: nmpr
# 						OSM: HAcmsa - None
#
# <TWD=/                      1x [ready] "עָתוּד"
# 	subs ~ A    (?  )      1x
# 					Isaiah 10:13 w215742"עתידתיהם"
# 						BHS: subs
# 						OSM: HAampc - HSp3mp
#
# >BWJ/                       1x [desire] "אֲבֹוי"
# 	subs ~ Tj   (?  )      1x
# 					Proverbs 23:29 w353279"אֲבֹ֡וי"
# 						BHS: subs
# 						OSM: HTj - None
#
# MVH=====/                   1x [coming] "מָטֶה"
# 	subs ~ V    (?  )      1x
# 					Proverbs 24:11 w353454"מָטִ֥ים"
# 						BHS: subs
# 						OSM: HVqrmpa - None
#
# B<JM/                       1x [<uncertain>] "בַּעְיָם"
# 	subs ~ R    (?  )      1x
# 					Isaiah 11:15 w216378"בַּעְיָ֣ם"
# 						BHS: subs
# 						OSM: HR - HNcmsc
#
# >LQWM/                      1x [<uncertain>] "אַלְקוּם"
# 	subs ~ D    (?  )      1x
# 					Proverbs 30:31 w355473"אַלְק֥וּם"
# 						BHS: subs
# 						OSM: HD - None
#
# >XZ/                        1x [holding] "אָחֻז"
# 	adjv ~ V    (?  )      1x
# 					Song_of_songs 3:8 w358159"אֲחֻ֣זֵי"
# 						BHS: adjv
# 						OSM: HVqsmpc - None
#
# XFWPJ/                      1x [<uncertain>] "חֲשׂוּפַי"
# 	subs ~ V    (?  )      1x
# 					Isaiah 20:4 w218687"חֲשׂוּפַ֥י"
# 						BHS: subs
# 						OSM: HVqsmpc - None
#
# DDNJ/                       1x [Dedanites] "דְּדָנִי"
# 	adjv ~ N    (?  )      1x
# 					Isaiah 21:13 w218923"דְּדָנִֽים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
#
# JXJL/                       1x [<uncertain>] "יָחִיל"
# 	subs ~ A    (?  )      1x
# 					Lamentations 3:26 w364645"יָחִיל֙"
# 						BHS: subs
# 						OSM: HAamsa - None
#
# YBH=/                       1x [<uncertain>] "צֹבֶה"
# 	subs ~ V    (?  )      1x
# 					Isaiah 29:7 w221446"צֹבֶ֨יהָ֙"
# 						BHS: subs
# 						OSM: HVqrmpc - HSp3fs
#
# Y>/                         1x [dirt] "צֵא"
# 	subs ~ V    (?  )      1x
# 					Isaiah 30:22 w222214"צֵ֖א"
# 						BHS: subs
# 						OSM: HVqv2ms - None
#
# XMJY/                       1x [sorrelfodder] "חָמִיץ"
# 	subs ~ A    (?  )      1x
# 					Isaiah 30:24 w222255"חָמִ֖יץ"
# 						BHS: subs
# 						OSM: HAamsa - None
#
# MDNJ/                       1x [Medanite] "מְדָנִי"
# 	adjv ~ N    (?  )      1x
# 					Genesis 37:36 w20834"מְּדָנִ֔ים"
# 						BHS: adjv
# 						OSM: HNgmpa - None
#
# TNJNWT                      1x [again] "תִּנְיָנוּת"
# 	advb ~ A    (?  )      1x
# 					Daniel 2:7 w370663"תִנְיָנ֖וּת"
# 						BHS: advb
# 						OSM: AAobpa - None
#
# KDBH/                       1x [lie] "כִּדְבָה"
# 	subs ~ A    (?  )      1x
# 					Daniel 2:9 w370705"כִדְבָ֤ה"
# 						BHS: subs
# 						OSM: AAafsa - None
#
# >CQLWNJ/                    1x [Ashkelonite] "אֶשְׁקְלֹונִי"
# 	adjv ~ N    (?  )      1x
# 					Joshua 13:3 w120424"אֶשְׁקְלֹונִ֣י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# YNM/                        1x [barren] "צָנֻם"
# 	adjv ~ V    (?  )      1x
# 					Genesis 41:23 w22768"צְנֻמֹ֥ות"
# 						BHS: adjv
# 						OSM: HVqsfpa - None
#
# QWJ/                        1x [<uncertain>] "קֹוי"
# 	subs ~ V    (?  )      1x
# 					Isaiah 40:31 w226051"קֹויֵ֤"
# 						BHS: subs
# 						OSM: HVqrmpc - None
#
# >BRK                        1x [<uncertain>] "אַבְרֵךְ"
# 	intj ~ D    (?  )      1x
# 					Genesis 41:43 w23138"אַבְרֵ֑ךְ"
# 						BHS: intj
# 						OSM: HD - None
#
# NFW>H/                      1x [load] "נְשׂוּאָה"
# 	subs ~ V    (?  )      1x
# 					Isaiah 46:1 w228339"נְשֻׂאֹתֵיכֶ֣ם"
# 						BHS: subs
# 						OSM: HVqsfpc - HSp2mp
#
# CBJH/                       1x [captive] "שְׁבִיָּה"
# 	subs ~ A    (?  )      1x
# 					Isaiah 52:2 w230335"שְׁבִיָּ֖ה"
# 						BHS: subs
# 						OSM: HAafsa - None
#
# JPLVJ/                      1x [Japhletite] "יַפְלֵטִי"
# 	adjv ~ N    (?  )      1x
# 					Joshua 16:3 w122224"יַּפְלֵטִ֗י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# XMWY/                       1x [coloured] "חָמוּץ"
# 	adjv ~ V    (?  )      1x
# 					Isaiah 63:1 w233469"חֲמ֤וּץ"
# 						BHS: adjv
# 						OSM: HVqsmsc - None
#
# YD>                         1x [really] "צְדָא"
# 	advb ~ N    (?  )      1x
# 					Daniel 3:14 w371900"צְדָּ֕א"
# 						BHS: advb
# 						OSM: ANcmsa - None
#
# >CRJ/                       1x [from Asher] "אָשֵׁרִי"
# 	adjv ~ N    (?  )      1x
# 					Judges 1:32 w128119"אָ֣שֵׁרִ֔י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# <NH/                        1x [humble] "עֲנֵה"
# 	adjv ~ N    (?  )      1x
# 					Daniel 4:24 w372920"עֲנָ֑יִן"
# 						BHS: adjv
# 						OSM: ANcmpa - None
#
# <WD/                        1x [still] "עֹוד"
# 	subs ~ D    (?  )      1x
# 					Daniel 4:28 w372966"עֹ֗וד"
# 						BHS: subs
# 						OSM: AD - None
#
# YBW</                       1x [hyena] "צָבוּעַ"
# 	subs ~ A    (?  )      1x
# 					Jeremiah 12:9 w240992"צָב֤וּעַ"
# 						BHS: subs
# 						OSM: HAamsa - None
#
# MDJ=/                       1x [Median] "מָדַי"
# 	adjv ~ N    (?  )      1x
# 					Daniel 6:1 w373844"מדיא"
# 						BHS: adjv
# 						OSM: ANgmsd - ATd
#
# <FRJN/                      1x [twenty] "עֶשְׂרִין"
# 	subs ~ A    (?  )      1x
# 					Daniel 6:2 w373864"עֶשְׂרִ֑ין"
# 						BHS: subs
# 						OSM: AAcbpa - None
#
# NGD/                        1x [toward] "נֶגֶד"
# 	subs ~ R    (?  )      1x
# 					Daniel 6:11 w374071"נֶ֖גֶד"
# 						BHS: subs
# 						OSM: AR - None
#
# PRSJ/                       1x [Persian] "פַּרְסָי"
# 	adjv ~ N    (?  )      1x
# 					Daniel 6:29 w374547"פרסיא"
# 						BHS: adjv
# 						OSM: ANgmsd - ATd
#
# N>/                         1x [raw] "נָא"
# 	adjv ~ Te   (?  )      1x
# 					Exodus 12:9 w34848"נָ֔א"
# 						BHS: adjv
# 						OSM: HTe - None
#
# TMNJ/                       1x [Timnite] "תִּמְנִי"
# 	adjv ~ N    (?  )      1x
# 					Judges 15:6 w136867"תִּמְנִ֔י"
# 						BHS: adjv
# 						OSM: HNp - None
#
# PJH/                        1x [<uncertain>] "פִּיָּה"
# 	subs ~ A    (?  )      1x
# 					Jeremiah 46:20 w260048"פִיָּ֖ה"
# 						BHS: subs
# 						OSM: HAafsa - None
#
# PLMNJ/                      1x [a certain] "פַּלְמֹנִי"
# 	subs ~ P    (?  )      1x
# 					Daniel 8:13 w375489"פַּֽלְמֹונִ֣י"
# 						BHS: subs
# 						OSM: HPf - None
#
# MDJ=/                       1x [Mede] "מָדִי"
# 	adjv ~ N    (?  )      1x
# 					Daniel 11:1 w376930"מָּדִ֑י"
# 						BHS: adjv
# 						OSM: HNgmsa - None
#
# >LMN=/                      1x [widower] "אַלְמָן"
# 	subs ~ A    (?  )      1x
# 					Jeremiah 51:5 w262812"אַלְמָ֨ן"
# 						BHS: subs
# 						OSM: HAamsa - None
#
# SRB/                        1x [obstinate] "סָרָב"
# 	adjv ~ N    (?  )      1x
# 					Ezekiel 2:6 w265431"סָרָבִ֤ים"
# 						BHS: adjv
# 						OSM: HNcmpa - None
#
# >MLH/                       1x [<uncertain>] "אֲמֻלָה"
# 	subs ~ V    (?  )      1x
# 					Ezekiel 16:30 w271536"אֲמֻלָה֙"
# 						BHS: subs
# 						OSM: HVqsfsa - None

# %% [markdown]
# # SP versus PDP
#
# Here is the computation that shows that the BHS feature
# [sp](https://etcbc.github.io/bhsa/features/hebrew/2017/sp)
# matches the OSM part-of-speech better than
# [pdp](https://etcbc.github.io/bhsa/features/hebrew/2017/pdp).

# %%
discrepancies = {}

for w in F.otype.s("word"):
    osm = osmPsp[w]
    if osm == "×":
        continue
    lex = F.lex.v(w)
    trans = pspBhsFromOsm[osm]
    if F.sp.v(w) not in trans:
        discrepancies.setdefault("sp", set()).add(w)
    if F.pdp.v(w) not in trans:
        discrepancies.setdefault("pdp", set()).add(w)

lexDiscrepancies = {}  # discrepancies per lexeme
for (ft, ws) in sorted(discrepancies.items()):
    for w in sorted(ws):
        lexNode = L.u(w, otype="lex")[0]
        lexInfo = lexDiscrepancies.setdefault(ft, {})
        if lexNode in lexInfo:
            continue
        lexInfo[lexNode] = w

if discrepancies:
    print("Discrepancies")
    for (ft, lexInfo) in sorted(lexDiscrepancies.items()):
        print("\n--- {:<4}: {:>4} lexemes ---\n".format(ft, len(lexInfo)))

    for (ft, ws) in sorted(discrepancies.items()):
        n = len(ws)
        print("\n--- {:<4}: {:>6}x ---\n".format(ft, n))
        for w in sorted(ws)[0:10]:
            show(T, F, [w], Fs(ft).v, getOSMpsp)
        if n > 10:
            print("\tand {} more".format(n - 10))
# Out:
# Discrepancies
#
# --- pdp : 1285 lexemes ---
#
#
# --- sp  :  663 lexemes ---
#
#
# --- pdp :  18993x ---
#
# Genesis 1:4 w47"טֹ֑וב"
# 	BHS: verb
# 	OSM: HAamsa - None
# Genesis 1:5 w78"אֶחָֽד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# Genesis 1:7 w108"תַּ֣חַת"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:9 w147"תַּ֤חַת"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:9 w152"אֶחָ֔ד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# Genesis 1:10 w178"טֹֽוב"
# 	BHS: verb
# 	OSM: HAamsa - None
# Genesis 1:12 w227"טֹֽוב"
# 	BHS: verb
# 	OSM: HAamsa - None
# Genesis 1:16 w286"שְׁנֵ֥י"
# 	BHS: subs
# 	OSM: HAcmdc - None
# Genesis 1:18 w351"טֹֽוב"
# 	BHS: verb
# 	OSM: HAamsa - None
# Genesis 1:21 w392"הַֽ"
# 	BHS: conj
# 	OSM: HTd - None
# 	and 18983 more
#
# --- sp  :  14594x ---
#
# Genesis 1:4 w47"טֹ֑וב"
# 	BHS: verb
# 	OSM: HAamsa - None
# Genesis 1:4 w51"בֵּ֥ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:4 w55"בֵ֥ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:5 w78"אֶחָֽד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# Genesis 1:6 w91"בֵּ֥ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:7 w103"בֵּ֤ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:7 w108"תַּ֣חַת"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:7 w113"בֵ֣ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:9 w147"תַּ֤חַת"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:9 w152"אֶחָ֔ד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# 	and 14584 more

# %%
strangePsp = {}
strangeSuffix = {}

for w in F.otype.s("word"):
    osm = osmPsp[w]
    if osm == "×":
        continue

    if osm == "S" or osm not in pspBhsFromOsm:
        strangePsp.setdefault(osm, set()).add(w)

    osm_sf = F.osm_sf.v(w)
    if osm_sf:
        osmSuffix = None if len(osm_sf) < 2 else osm_sf[1]
        if osmSuffix != "S":
            strangeSuffix.setdefault(osmSuffix, set()).add(w)

if strangePsp:
    print("Strange psp")
    for (ln, ws) in sorted(strangePsp.items()):
        print("\t{:<5}: {:>5}x".format(ln, len(ws)))
        for w in sorted(ws)[0:5]:
            show(T, F, [w], F.sp.v, getOSMpsp, indent="\t\t")
        n = len(ws)
        if n > 5:
            print("and {} more".format(n - 5))
else:
    print("No other psps encountered than {}".format(", ".join(pspBhsFromOsm)))
if strangeSuffix:
    print("Strange suffix psp")
    for (ln, ws) in sorted(strangeSuffix.items()):
        print("\t{:<5}: {:>5}x".format(ln, len(ws)))
        for w in sorted(ws)[0:5]:
            show(T, F, [w], F.sp.v, getOSMpsp, indent="\t\t")
        n = len(ws)
        if n > 5:
            print("and {} more".format(n - 5))
else:
    print("No other suffix psps encountered than S")
# Out:
# Strange psp
# 	S    :     5x
# 		Jeremiah 18:3 w243711"הו"
# 			BHS: prps
# 			OSM: HSp3ms - None
# 		Jeremiah 36:32 w255103"הֵֽמָּה"
# 			BHS: prps
# 			OSM: HSp3mp - None
# 		Ezekiel 8:6 w267780"הם"
# 			BHS: prps
# 			OSM: HSp3mp - None
# 		Zechariah 5:9 w306339"הֵ֥נָּה"
# 			BHS: prps
# 			OSM: HSp3fp - None
# 		Song_of_songs 6:5 w358746"הֵ֖ם"
# 			BHS: prps
# 			OSM: HSp3mp - None
# Strange suffix psp
# 	A    :    19x
# 		Genesis 23:2 w10754"קִרְיַ֥ת אַרְבַּ֛ע"
# 			BHS: nmpr
# 			OSM: HNp - HAcfsa
# 		Joshua 14:15 w121375"קִרְיַ֣ת אַרְבַּ֔ע"
# 			BHS: nmpr
# 			OSM: HNp - HAcfsa
# 		Joshua 15:13 w121692"קִרְיַ֥ת אַרְבַּ֛ע"
# 			BHS: nmpr
# 			OSM: HNp - HAcfsa
# 		Joshua 15:54 w122085"קִרְיַ֥ת אַרְבַּ֛ע"
# 			BHS: nmpr
# 			OSM: HNp - HAcfsa
# 		Joshua 20:7 w124314"קִרְיַ֥ת אַרְבַּ֛ע"
# 			BHS: nmpr
# 			OSM: HNp - HAcfsa
# and 14 more
# 	C    :     3x
# 		2_Samuel 16:10 w170003"וכי"
# 			BHS: conj
# 			OSM: HC - HC
# 		Jeremiah 39:12 w256632"כִּ֗י אם"
# 			BHS: conj
# 			OSM: HC - HC
# 		Ruth 3:12 w356983"כִּ֥י אם"
# 			BHS: conj
# 			OSM: HC - HC
# 	D    :   200x
# 		Genesis 4:15 w1911"לָכֵן֙"
# 			BHS: advb
# 			OSM: HR - HD
# 		Genesis 30:15 w15824"לָכֵן֙"
# 			BHS: advb
# 			OSM: HR - HD
# 		Exodus 6:6 w31335"לָכֵ֞ן"
# 			BHS: advb
# 			OSM: HR - HD
# 		Numbers 16:11 w80257"לָכֵ֗ן"
# 			BHS: advb
# 			OSM: HR - HD
# 		Numbers 20:12 w82793"לָכֵ֗ן"
# 			BHS: advb
# 			OSM: HR - HD
# and 195 more
# 	N    :   691x
# 		Genesis 4:22 w2033"תּ֣וּבַל קַ֔יִן"
# 			BHS: nmpr
# 			OSM: HNp - HNp
# 		Genesis 4:22 w2042"תּֽוּבַל־קַ֖יִן"
# 			BHS: nmpr
# 			OSM: HNp - HNp
# 		Genesis 10:11 w4687"רְחֹבֹ֥ת עִ֖יר"
# 			BHS: nmpr
# 			OSM: HNp - HNp
# 		Genesis 12:8 w5642"בֵֽית־אֵ֖ל"
# 			BHS: nmpr
# 			OSM: HNp - HNp
# 		Genesis 12:8 w5646"בֵּֽית־אֵ֤ל"
# 			BHS: nmpr
# 			OSM: HNp - HNp
# and 686 more
# 	P    :    14x
# 		Judges 13:14 w136024"צִוִּיתִ֖יהָ"
# 			BHS: verb
# 			OSM: HVpp1cs - HPp3fs
# 		Judges 13:17 w136078"דבריך"
# 			BHS: subs
# 			OSM: HNcmpc - HPp2ms
# 		Judges 13:23 w136199"הֶרְאָ֖נוּ"
# 			BHS: verb
# 			OSM: HVhp3ms - HPp1cp
# 		Judges 14:15 w136594"יָרְשֵׁ֕נוּ"
# 			BHS: verb
# 			OSM: HVqc - HPp1cp
# 		2_Samuel 24:3 w175492"כָּהֵ֤ם"
# 			BHS: prep
# 			OSM: HR - HPp3mp
# and 9 more
# 	R    :     2x
# 		2_Samuel 16:2 w169797"ול"
# 			BHS: conj
# 			OSM: HC - HR
# 		Ecclesiastes 5:15 w361138"כָּל"
# 			BHS: subs
# 			OSM: HR - HR
# 	T    :  1050x
# 		Genesis 4:6 w1759"לָ֚מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 4:6 w1763"לָ֖מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 12:18 w5826"לָ֚מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 12:19 w5833"לָמָ֤ה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 18:13 w8030"לָ֣מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# and 1045 more
# 	V    :    14x
# 		2_Samuel 19:41 w172967"ויעברו"
# 			BHS: verb
# 			OSM: HC - HVhw3mp
# 		2_Kings 11:1 w202008"וראתה"
# 			BHS: verb
# 			OSM: HC - HVqp3fs
# 		Isaiah 5:29 w213937"ושׁאג"
# 			BHS: verb
# 			OSM: HC - HVqq3ms
# 		Jeremiah 4:5 w236639"ותקעו"
# 			BHS: verb
# 			OSM: HC - HVqv2mp
# 		Jeremiah 8:1 w238957"ויציאו"
# 			BHS: verb
# 			OSM: HC - HVhi3mp
# and 9 more
