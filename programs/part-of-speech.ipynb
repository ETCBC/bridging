# %% [markdown]
# # BHSA and OSM: comparison on part-of-speech
#
# We will investigate how the morphology marked up in the OSM corresponds and differs from the BHSA linguistic features.
#
# In this notebook we investigate the markup of *part-of-speech*.
#
# We use the `osm` and `osm_sf` features compiled by the
# [BHSAbridgeOSM notebook](BHSAbridgeOSM.ipynb).

# %%
import os
import operator
import collections
from functools import reduce

from tf.fabric import Fabric
from utils import show

# %% [markdown]
# # Load data
# We load the BHSA data in the standard way, and we add the OSM data as a module of the features `osm` and `osm_sf`.
# Note that we only need to point TF to the right directories, and then we can load all features
# that are present in those directories.

# %%
BHSA = 'BHSA/tf/2017'
OSM = 'bridging/tf/2017'

TF = Fabric(locations='~/github/etcbc', modules=[BHSA, OSM])
api = TF.load('''
    sp pdp
    lex voc_lex_utf8 freq_lex
    gloss
    osm osm_sf
    g_word_utf8
''')
api.makeAvailableIn(globals())
# Out:
# This is Text-Fabric 3.1.1
# Api reference : https://github.com/Dans-labs/text-fabric/wiki/Api
# Tutorial      : https://github.com/Dans-labs/text-fabric/blob/master/docs/tutorial.ipynb
# Example data  : https://github.com/Dans-labs/text-fabric-data
#
# 116 features found and 0 ignored
#   0.00s loading features ...
#    |     0.21s B g_word_utf8          from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.13s B sp                   from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.13s B pdp                  from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.13s B lex                  from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.01s B voc_lex_utf8         from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.10s B freq_lex             from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.01s B gloss                from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.13s B osm                  from /Users/dirk/github/etcbc/bridging/tf/2017
#    |     0.02s B osm_sf               from /Users/dirk/github/etcbc/bridging/tf/2017
#    |     0.00s Feature overview: 110 for nodes; 5 for edges; 1 configs; 7 computed
#   5.67s All features loaded/computed - for details use loadLog()

# %% [markdown]
# # Part of speech
#
# The BHSA has two features for part-of-speech:
# [sp](https://etcbc.github.io/bhsa/features/hebrew/2017/sp)
# and
# [pdp](https://etcbc.github.io/bhsa/features/hebrew/2017/pdp).
#
# The first one, `sp`, is lexical part of speech, a context-insensitve assignment of part-of-speech labels to
# occurrences of lexemes.
#
# The second one, `pdp`, is *phrase dependent part of speech*. This assignment is sensitive to
# cases where adjectives are used as noun, nouns as prepositions, etc.
#
# A preliminary check has revealed that the OSM part-of-speech is resembles `sp` more than `pdp`, so
# we stick to `sp`.
#
# The OSM has part-of-speech as the second letter of the morph string.
# See [here](http://openscriptures.github.io/morphhb/parsing/HebrewMorphologyCodes.html).
#
# The BHSA makes a few more distinctions in its [sp](https://etcbc.github.io/bhsa/features/hebrew/2017/sp) feature,
# so we map the OSM values to sets of BHSA values.
#
# One of the OSM values is `S` (suffix).
# The BHSA has no counterpart for this, but we expect that all morph strings in the `osm_sf` features will show
# the `S`.
#
# We'll test that as well.

# %% [markdown]
# Here is the default mapping between OSM part-of-speech and BHSA part-of-speech.
#
# We'll see later that this results in many discrepancies.
#
# We'll analyze the discrepancies, and try to overcome them by making lexeme-dependent exceptions to these rules.
#
# It turns out that we need **75** lexeme-based exception rules and we'll have **1206** left-over cases that
# merit closer inspection.

# %%
pspBhsFromOsm = {
    'A': {'adjv'}, # adjective
    'C': {'conj'}, # conjunction
    'D': {'advb'}, # adverb
    'N': {'subs', 'nmpr'}, # noun
    'P': {'prps', 'prde', 'prin', 'inrg'}, # pronoun
    'R': {'prep'}, # preposition 
    'S': {'_suffix_'}, # suffix
    'T': {'art', 'intj', 'nega'}, # particle 
    'V': {'verb'}, # verb
    '×': set(), # no morphology
}

# %% [markdown]
# Just for ease of processing, we make a mapping from slots to OSM part-of-speech.
#
# We assign `×` slot `w` if there is no valid OSM part-of-speech label available for `w`.

# %%
osmPsp = {}
noPsp = 0
for w in F.otype.s('word'):
    osm = F.osm.v(w)
    if osm == None or osm == '' or osm == '*' or len(osm) < 2:
        psp = '×'
        noPsp += 1
    else:
        psp = osm[1]
    osmPsp[w] = psp 

allPsp = len(osmPsp)
withPsp = allPsp - noPsp
print('''{} BHSA words:
    having  OSM part of speech: {:>3}% = {:>6}
    without OSM part of speech: {:>3}% = {:>6}
'''.format(
    F.otype.maxSlot,
    round(100 * withPsp / allPsp),
    withPsp,
    round(100 * noPsp / allPsp),
    noPsp,
))
# Out:
# 426584 BHSA words:
#     having  OSM part of speech:  87% = 372636
#     without OSM part of speech:  13% =  53948

# %% [markdown]
# We organize the osm-bhs combinations that show up in the text in several ways.
#
# `psp` is keyed by: osm, bhs, lexeme node.
#
# `pspLex` is keyed by: lexeme node, osm, bhs, and then contains a list of slots where this combination occurs.
#
# Both mappings contains a list of slots where the combinations occur.

# %%
psp = {}
pspLex = {}
for lx in F.otype.s('lex'):
    ws = L.d(lx, otype='word')
    for w in ws:
        osm = osmPsp[w]
        bhs = F.sp.v(w)
        psp.setdefault(osm, {}).setdefault(bhs, {}).setdefault(lx, set()).add(w)
        pspLex.setdefault(lx, {}).setdefault(osm, {}).setdefault(bhs, set()).add(w)

# %% [markdown]
# For each osm-bhs combination, we want to see how many lexemes and how many occurrences have that combination.

# %%
pspCount = {}
for (osm, osmData) in psp.items():
    for (bhs, bhsData) in osmData.items():
        nlex = len(bhsData)
        noccs = reduce(operator.add, (len(x) for x in bhsData.values()), 0)
        pspCount.setdefault(osm, {})[bhs] = (nlex, noccs)

# %% [markdown]
# Now we are going to present an overview of osm-bhs combinations.
#
# We mark a combination with `OK` if the combination is according to the default OSM-BHS mapping.
#
# We use the mark `*` if there is no OSM part-of-speech available.
#
# Otherwise we mark it with a `?`.

# %%
mismatches = []
for osm in pspCount:
    print(osm)
    totalOccs = sum(x[1] for x in pspCount[osm].values())
    for (bhs, (nlex, noccs)) in sorted(pspCount[osm].items(), key=lambda x: (-x[1][1], -x[1][0], x[0])):
        perc = round(100 * noccs / totalOccs)
        status = bhs in pspBhsFromOsm[osm]
        statusLabel = 'OK' if status else '?'
        if not status:
            if osm == '×':
                statusLabel = '*'
            else:
                mismatches.append((osm, bhs, nlex, noccs))
        print('\t=> {:<4} ({:<2}) in {:>4} lexemes and {:>3}% = {:>6} occurrences'.format(
            bhs, statusLabel, nlex, perc, noccs,
        ))
total = 0
for (osm, bhs, nlex, noccs) in mismatches:
    total += noccs
print('\n{:<24} {:>6} occurrences'.format('Total number of mismatches', total))
# Out:
# R
# 	=> prep (OK) in   22 lexemes and  96% =  55591 occurrences
# 	=> subs (? ) in   18 lexemes and   3% =   1658 occurrences
# 	=> advb (? ) in    1 lexemes and   0% =    194 occurrences
# 	=> inrg (? ) in    1 lexemes and   0% =    169 occurrences
# 	=> conj (? ) in    2 lexemes and   0% =      5 occurrences
# 	=> art  (? ) in    1 lexemes and   0% =      2 occurrences
# 	=> nmpr (? ) in    1 lexemes and   0% =      2 occurrences
# 	=> verb (? ) in    1 lexemes and   0% =      1 occurrences
# ×
# 	=> verb (* ) in 1189 lexemes and  25% =  13584 occurrences
# 	=> subs (* ) in 2427 lexemes and  23% =  12637 occurrences
# 	=> art  (* ) in    1 lexemes and  17% =   9384 occurrences
# 	=> conj (* ) in    9 lexemes and  14% =   7821 occurrences
# 	=> prep (* ) in   23 lexemes and  12% =   6495 occurrences
# 	=> adjv (* ) in  468 lexemes and   4% =   2090 occurrences
# 	=> nmpr (* ) in  452 lexemes and   2% =   1279 occurrences
# 	=> inrg (* ) in   12 lexemes and   0% =    246 occurrences
# 	=> intj (* ) in   12 lexemes and   0% =     97 occurrences
# 	=> advb (* ) in   20 lexemes and   0% =     93 occurrences
# 	=> prps (* ) in   15 lexemes and   0% =     93 occurrences
# 	=> prde (* ) in   17 lexemes and   0% =     92 occurrences
# 	=> nega (* ) in    3 lexemes and   0% =     26 occurrences
# 	=> prin (* ) in    3 lexemes and   0% =     11 occurrences
# N
# 	=> subs (OK) in 3226 lexemes and  75% =  98678 occurrences
# 	=> nmpr (OK) in 2305 lexemes and  24% =  31764 occurrences
# 	=> adjv (? ) in   44 lexemes and   1% =    910 occurrences
# 	=> verb (? ) in    7 lexemes and   0% =      8 occurrences
# 	=> advb (? ) in    2 lexemes and   0% =      2 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# V
# 	=> verb (OK) in 1533 lexemes and 100% =  60074 occurrences
# 	=> subs (? ) in    5 lexemes and   0% =      6 occurrences
# 	=> adjv (? ) in    2 lexemes and   0% =      3 occurrences
# 	=> nmpr (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# T
# 	=> art  (OK) in    1 lexemes and  42% =  21000 occurrences
# 	=> prep (? ) in    7 lexemes and  22% =  11101 occurrences
# 	=> nega (OK) in    6 lexemes and  12% =   6027 occurrences
# 	=> conj (? ) in    5 lexemes and  11% =   5643 occurrences
# 	=> intj (OK) in   20 lexemes and   4% =   1786 occurrences
# 	=> advb (? ) in    6 lexemes and   3% =   1483 occurrences
# 	=> prin (? ) in    3 lexemes and   2% =    992 occurrences
# 	=> subs (? ) in    8 lexemes and   2% =    877 occurrences
# 	=> inrg (? ) in   16 lexemes and   2% =    841 occurrences
# 	=> adjv (? ) in    2 lexemes and   0% =     11 occurrences
# 	=> nmpr (? ) in    3 lexemes and   0% =      5 occurrences
# 	=> prps (? ) in    2 lexemes and   0% =      5 occurrences
# 	=> verb (? ) in    2 lexemes and   0% =      3 occurrences
# C
# 	=> conj (OK) in   11 lexemes and 100% =  49250 occurrences
# 	=> subs (? ) in    4 lexemes and   0% =    122 occurrences
# 	=> prep (? ) in    4 lexemes and   0% =     77 occurrences
# 	=> advb (? ) in    3 lexemes and   0% =      8 occurrences
# 	=> prde (? ) in    1 lexemes and   0% =      6 occurrences
# A
# 	=> adjv (OK) in  305 lexemes and  50% =   6449 occurrences
# 	=> subs (? ) in   51 lexemes and  50% =   6438 occurrences
# 	=> verb (? ) in    6 lexemes and   0% =     38 occurrences
# 	=> nmpr (? ) in    5 lexemes and   0% =     30 occurrences
# 	=> advb (? ) in    2 lexemes and   0% =      3 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# P
# 	=> prps (OK) in   22 lexemes and  65% =   4910 occurrences
# 	=> prde (OK) in   10 lexemes and  34% =   2562 occurrences
# 	=> prin (OK) in    2 lexemes and   0% =     18 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      5 occurrences
# 	=> conj (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> subs (? ) in    1 lexemes and   0% =      1 occurrences
# D
# 	=> advb (OK) in   43 lexemes and  72% =   2767 occurrences
# 	=> subs (? ) in   11 lexemes and  28% =   1066 occurrences
# 	=> inrg (? ) in    1 lexemes and   1% =     29 occurrences
# 	=> intj (? ) in    2 lexemes and   0% =      2 occurrences
# 	=> verb (? ) in    1 lexemes and   0% =      2 occurrences
# 	=> adjv (? ) in    1 lexemes and   0% =      1 occurrences
# 	=> prep (? ) in    1 lexemes and   0% =      1 occurrences
# S
# 	=> prps (? ) in    3 lexemes and 100% =      3 occurrences
#
# Total number of mismatches  31760 occurrences

# %% [markdown]
# It is not as bad as it seems.
# The number of *lexemes* involved in a mismatch is limited:

# %%
mismatchLexemes = set()
for (osm, bhs, nlex, noccs) in mismatches:
    lexemes = psp[osm][bhs].keys()
    mismatchLexemes |= lexemes
print('Lexemes to be researched: {}'.format(len(mismatchLexemes)))
# Out:
# Lexemes to be researched: 229

# %% [markdown]
# We are going to investigate the lexemes that are involved in a mismatch.
#
# It turns out that:
#
# * for most of the lexemes there is a dominant combination of OSM and BHSA assigned part-of-speech;
# * non-dominant combinations have a very limited number of occurrences.
#
# This is what we are going to do:
#
# * for each lexeme we go along with the dominant combination.
#   If that is different from the default marking, we add a lexeme-bound exception to the rule
#   that maps OSM part-of-speech to BHSA part-of-speech.
# * if even the dominant combination has less than 10 occurrences, we do not add a lexeme-bound rule,
#   but we add the case to the list of exceptional cases.
# * we spell out the exceptional cases, so that readers can manually check the part-of-speeches as assigned by
#   OSM and BHSA.
#
# In order to determine what is dominant: if a combination has 50% or more of occurrences of a lexeme.
# then that combination is dominant.
# So, for each lexeme there is at least one dominant case.
#
# There may not be a dominant case if not all occurrences of a lexeme have been marked up in the OSM.

# %% [markdown]
# The next cell computes the new rules and the exceptions.
# It will show all new rules, and all kinds of exceptions.
# But it only shows at most 10 instances of each kind of exception.
#
# A .tsv file with all exceptions can be downloaded via this
# [link](https://github.com/ETCBC/bridging/blob/master/programs/pspCases.tsv).

# %%
researchCases = []

inspectCases = 0
rules = []

text = []

fh = open('pspCases.tsv', 'w')
fields = '''
    slot
    occurrence
    lex-node
    lex
    lex-pointed
    gloss
    bhsa-psp
    osm-psp
    #cases-like-this
'''.strip().split()
lineFormat = ('{}\t' * (len(fields) - 1)) + '{}\n'

def getOSMpsp(w):
    return '{} - {}'.format(str(F.osm.v(w)), str(F.osm_sf.v(w)))

for lx in sorted(mismatchLexemes, key=lambda x: -F.freq_lex.v(x)):
    freqLex = F.freq_lex.v(lx)
    text.append('\n{:<15}        {:>6}x [{}] "{}"'.format(
        F.lex.v(lx), 
        freqLex,
        F.gloss.v(lx),
        F.voc_lex_utf8.v(lx), 
    ))
    nRealCases = freqLex
    if '×' in pspLex[lx]:
        for (bhs, ws) in pspLex[lx]['×'].items():
            nRealCases -= len(ws)

    osmCount = collections.Counter()
    for (osm, osmData) in pspLex[lx].items():
        for ws in osmData.values():
            osmCount[osm] += len(ws)
            
    for osm in sorted(pspLex[lx], key=lambda x: -osmCount[x]):
        osmData = pspLex[lx][osm]
        for (bhs, ws) in sorted(osmData.items(), key=lambda x: (-len(x[1]), x[0])):
            showCases = False
            nws = len(ws)
            status = bhs in pspBhsFromOsm[osm]
            statusLabel = 'OK' if status else '?'

            if 2 * nws > freqLex and nws >= 10:
                if not status and osm != '×':
                    statusLabel = 'NN'
                    rules.append((lx, osm, bhs, nws))
            else:
                if status:
                    statusLabel = 'OK?'
                showCases = osm != '×'

            text.append('\t{} ~ {:<4} ({:<3}) {:>6}x'.format(
                bhs, osm, statusLabel, nws,
            ))
            
            if showCases:
                text.append('\n{}'.format('-' * 60))
                inspectCases += nws
                for w in sorted(ws)[0:10]:
                    text.append(show(T, F, [w], F.sp.v, getOSMpsp, indent='\t\t', asString=True))
                if nws > 10:
                    text.append('\tand {} more occurrences'.format(nws - 10))
                text.append('{}\n'.format('-' * 60))
                for w in ws:
                    fh.write(lineFormat.format(
                        w,
                        F.g_word_utf8.v(w),
                        lx, 
                        F.lex.v(lx),
                        F.voc_lex_utf8.v(lx),
                        F.gloss.v(lx),
                        F.sp.v(w),
                        F.osm.v(w),
                        nws,
                    ))

fh.close()

if rules:
    print('Lexeme-bound exceptions  : {:>4}'.format(len(rules)))
else:
    print('No lexeme-bound exceptions')

if inspectCases or text:
    print('Cases that need attention: {:>4}'.format(inspectCases))
else:
    print('All cases clear')

print('\nLEXEME-BOUND EXCEPTIONS\n')
casesSolved = 0
for (lx, osm, bhs, nws) in rules:
    casesSolved += nws
    print('\t{:<15} {:<4} ~ {} ({:>5}x) [{}] "{}"'.format(
        F.lex.v(lx),
        bhs,
        osm,
        nws,
        F.gloss.v(lx),
        F.voc_lex_utf8.v(lx),
))
print('This solves {} cases'.format(casesSolved))
print('Remaining cases: {}'.format(total - casesSolved))

print('\nCASES FOR ATTENTION\n')
for t in text: print(t)
# Out:
# Lexeme-bound exceptions  :   75
# Cases that need attention: 1206
#
# LEXEME-BOUND EXCEPTIONS
#
# 	>T              prep ~ T (10863x) [<object marker>] "אֵת"
# 	>CR             conj ~ T ( 5497x) [<relative>] "אֲשֶׁר"
# 	>XD/            subs ~ A (  910x) [one] "אֶחָד"
# 	>JN/            subs ~ T (  639x) [<NEG>] "אַיִן"
# 	GM              advb ~ T (  690x) [even] "גַּם"
# 	CNJM/           subs ~ A (  768x) [two] "שְׁנַיִם"
# 	H=              inrg ~ T (  536x) [<interrogative>] "הֲ"
# 	>XR/            subs ~ R (  586x) [after] "אַחַר"
# 	CLC/            subs ~ A (  600x) [three] "שָׁלֹשׁ"
# 	M>H/            subs ~ A (  565x) [hundred] "מֵאָה"
# 	MH              prin ~ T (  568x) [what] "מָה"
# 	KN              advb ~ T (  422x) [thus] "כֵּן"
# 	XMC/            subs ~ A (  506x) [five] "חָמֵשׁ"
# 	TXT/            subs ~ R (  370x) [under part] "תַּחַת"
# 	>LP=/           subs ~ A (  492x) [thousand] "אֶלֶף"
# 	CB</            subs ~ A (  482x) [seven] "שֶׁבַע"
# 	<WD/            subs ~ D (  423x) [duration] "עֹוד"
# 	>RB</           subs ~ A (  453x) [four] "אַרְבַּע"
# 	MJ              prin ~ T (  423x) [who] "מִי"
# 	BJN/            subs ~ R (  355x) [interval] "בַּיִן"
# 	DJ              prep ~ T (  175x) [<relative>] "דִּי"
# 	SBJB/           subs ~ D (  207x) [surrounding] "סָבִיב"
# 	<FRJM/          subs ~ A (  315x) [twenty] "עֶשְׂרִים"
# 	M>D/            subs ~ D (  290x) [might] "מְאֹד"
# 	LWJ/            adjv ~ N (  239x) [Levite] "לֵוִי"
# 	PLCTJ/          adjv ~ N (  262x) [Philistine] "פְּלִשְׁתִּי"
# 	CC/             subs ~ A (  274x) [six] "שֵׁשׁ"
# 	<FR/            subs ~ A (  203x) [-teen] "עָשָׂר"
# 	LKN             advb ~ R (  194x) [therefore] "לָכֵן"
# 	LMH             inrg ~ R (  169x) [why] "לָמָה"
# 	>K              advb ~ T (  158x) [only] "אַךְ"
# 	GBWR/           subs ~ A (  137x) [vigorous] "גִּבֹּור"
# 	NGD/            subs ~ R (  120x) [counterpart] "נֶגֶד"
# 	CMNH/           subs ~ A (  147x) [eight] "שְׁמֹנֶה"
# 	JC/             subs ~ T (  138x) [existence] "יֵשׁ"
# 	C               conj ~ T (  129x) [<relative>] "שַׁ"
# 	<FRH/           subs ~ A (  134x) [-teen] "עֶשְׂרֵה"
# 	>P              advb ~ T (  104x) [even] "אַף"
# 	<FRH=/          subs ~ A (  120x) [ten] "עֲשָׂרָה"
# 	BLT/            subs ~ C (  100x) [failure] "בֵּלֶת"
# 	RQ              advb ~ T (  108x) [only] "רַק"
# 	B<D/            subs ~ R (   67x) [distance] "בַּעַד"
# 	>MRJ/           adjv ~ N (   84x) [Amorite] "אֱמֹרִי"
# 	JHWDJ/          adjv ~ N (   45x) [Jewish] "יְהוּדִי"
# 	TC</            subs ~ A (   78x) [nine] "תֵּשַׁע"
# 	KN<NJ/          adjv ~ N (   62x) [Canaanite] "כְּנַעֲנִי"
# 	MDW<            inrg ~ T (   61x) [why] "מַדּוּעַ"
# 	VWBH/           subs ~ A (   65x) [what is good] "טֹובָה"
# 	>YL/            subs ~ R (   39x) [side] "אֵצֶל"
# 	>JK             inrg ~ T (   61x) [how] "אֵיךְ"
# 	<FR=/           subs ~ A (   56x) [ten] "עֶשֶׂר"
# 	VRM/            subs ~ D (   56x) [beginning] "טֶרֶם"
# 	XTJ/            adjv ~ N (   32x) [Hittite] "חִתִּי"
# 	>JH             inrg ~ T (   43x) [where] "אַיֵּה"
# 	<MD/            subs ~ R (   41x) [company] "עִמָּד"
# 	MTJ             inrg ~ T (   40x) [when] "מָתַי"
# 	QDM/            subs ~ R (   27x) [before] "קֳדָם"
# 	JBWSJ/          adjv ~ N (   34x) [Jebusite] "יְבוּסִי"
# 	>N              inrg ~ D (   29x) [whither] "אָן"
# 	>J              inrg ~ T (   38x) [where] "אֵי"
# 	CC=/            subs ~ A (   31x) [linen] "שֵׁשׁ"
# 	MWL/            subs ~ R (   24x) [front] "מוּל"
# 	QBL/            subs ~ C (   17x) [opposite] "קֳבֵל"
# 	XWJ/            adjv ~ N (   18x) [Hivite] "חִוִּי"
# 	PRZJ/           adjv ~ N (   15x) [Perizzite] "פְּרִזִּי"
# 	>JTJ/           subs ~ T (   14x) [existence] "אִיתַי"
# 	>JKH            inrg ~ T (   17x) [how] "אֵיכָה"
# 	>JN             inrg ~ T (   16x) [whence] "אַיִן"
# 	ZW              conj ~ T (   15x) [<relative>] "זוּ"
# 	QHTJ/           adjv ~ N (   12x) [Kohathite] "קְהָתִי"
# 	XKJM/           adjv ~ N (   13x) [wise] "חַכִּים"
# 	>LP==/          subs ~ A (   13x) [group of thousand] "אֶלֶף"
# 	GRCNJ/          adjv ~ N (   11x) [Gershonite] "גֵּרְשֻׁנִּי"
# 	GL<DJ/          adjv ~ N (   10x) [Gileadite] "גִּלְעָדִי"
# 	>JPH            inrg ~ T (   10x) [where] "אֵיפֹה"
# This solves 31065 cases
# Remaining cases: 695
#
# CASES FOR ATTENTION
#
#
# W                       50272x [and] "וְ"
# 	conj ~ C    (OK )  42715x
# 	conj ~ ×    (?  )   7552x
# 	conj ~ R    (?  )      4x
#
# ------------------------------------------------------------
# 		Isaiah 1:5 w212146 "וְ"
# 			BHS: conj
# 			OSM: HR - None
# 		Jonah 2:4 w298980 "וְ"
# 			BHS: conj
# 			OSM: HR - None
# 		Jonah 3:5 w299157 "וְ"
# 			BHS: conj
# 			OSM: HR - None
# 		Jonah 4:11 w299537 "וּ"
# 			BHS: conj
# 			OSM: HR - None
# ------------------------------------------------------------
#
# 	conj ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Ecclesiastes 8:12 w362111 "וּ"
# 			BHS: conj
# 			OSM: HAcbsc - HC
# ------------------------------------------------------------
#
#
# H                       30386x [the] "הַ"
# 	art ~ T    (OK )  21000x
# 	art ~ ×    (?  )   9384x
# 	art ~ R    (?  )      2x
#
# ------------------------------------------------------------
# 		Haggai 2:6 w304606 "הֶ"
# 			BHS: art
# 			OSM: HR - None
# 		Haggai 2:19 w304900 "הַ"
# 			BHS: art
# 			OSM: HRd - None
# ------------------------------------------------------------
#
#
# L                       20069x [to] "לְ"
# 	prep ~ R    (OK )  18032x
# 	prep ~ ×    (?  )   2023x
# 	prep ~ T    (?  )     13x
#
# ------------------------------------------------------------
# 		Exodus 21:8 w40141 "לא"
# 			BHS: prep
# 			OSM: HTn - None
# 		Leviticus 11:21 w58184 "לא"
# 			BHS: prep
# 			OSM: HTn - None
# 		Leviticus 25:30 w67708 "לא"
# 			BHS: prep
# 			OSM: HTn - None
# 		2_Samuel 16:18 w170177 "לא"
# 			BHS: prep
# 			OSM: HTn - None
# 		2_Kings 8:10 w199807 "לא"
# 			BHS: prep
# 			OSM: HTn - None
# 		Isaiah 9:2 w215177 "לא"
# 			BHS: prep
# 			OSM: HTn - None
# 		Isaiah 49:5 w229221 "לא"
# 			BHS: prep
# 			OSM: HTn - None
# 		Isaiah 63:9 w233605 "לא"
# 			BHS: prep
# 			OSM: HTn - None
# 		Job 6:21 w337759 "לא"
# 			BHS: prep
# 			OSM: HTn - None
# 		Job 13:15 w339385 "לא"
# 			BHS: prep
# 			OSM: HTn - None
# 	and 3 more occurrences
# ------------------------------------------------------------
#
# 	prep ~ V    (?  )      1x
#
# ------------------------------------------------------------
# 		Song_of_songs 2:13 w357957 "לכי"
# 			BHS: prep
# 			OSM: HVqv2fs - None
# ------------------------------------------------------------
#
#
# >T                      10997x [<object marker>] "אֵת"
# 	prep ~ T    (NN )  10863x
# 	prep ~ ×    (?  )    131x
# 	prep ~ R    (OK?)      3x
#
# ------------------------------------------------------------
# 		Hosea 12:4 w293548 "אֶת"
# 			BHS: prep
# 			OSM: HR - None
# 		Joel 2:20 w294741 "אֶת"
# 			BHS: prep
# 			OSM: HR - None
# 		Zephaniah 1:3 w303124 "אֶת"
# 			BHS: prep
# 			OSM: HR - None
# ------------------------------------------------------------
#
#
# >L                       5517x [to] "אֶל"
# 	prep ~ R    (OK )   5504x
# 	prep ~ ×    (?  )     11x
# 	prep ~ T    (?  )      2x
#
# ------------------------------------------------------------
# 		Judges 19:23 w139675 "אַל"
# 			BHS: prep
# 			OSM: HTn - None
# 		Jeremiah 47:6 w260350 "אַל"
# 			BHS: prep
# 			OSM: HTn - None
# ------------------------------------------------------------
#
#
# >CR                      5500x [<relative>] "אֲשֶׁר"
# 	conj ~ T    (NN )   5497x
# 	conj ~ ×    (?  )      2x
# 	conj ~ P    (?  )      1x
#
# ------------------------------------------------------------
# 		Ruth 2:9 w356432 "אֲשֶׁ֥ר"
# 			BHS: conj
# 			OSM: HPr - None
# ------------------------------------------------------------
#
#
# <FH[                     2629x [make] "עשׂה"
# 	verb ~ V    (OK )   2319x
# 	verb ~ ×    (?  )    309x
# 	verb ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		1_Kings 22:49 w194645 "עשׂר"
# 			BHS: verb
# 			OSM: HAcmsa - None
# ------------------------------------------------------------
#
#
# HW>                      1394x [he] "הוּא"
# 	prps ~ P    (OK )   1388x
# 	prps ~ ×    (?  )      5x
# 	prps ~ S    (?  )      1x
#
# ------------------------------------------------------------
# 		Jeremiah 18:3 w243708 "הו"
# 			BHS: prps
# 			OSM: HSp3ms - None
# ------------------------------------------------------------
#
#
# <D                       1263x [unto] "עַד"
# 	prep ~ R    (OK )   1259x
# 	prep ~ ×    (?  )      3x
# 	prep ~ D    (?  )      1x
#
# ------------------------------------------------------------
# 		Ruth 1:13 w356038 "עַ֚ד"
# 			BHS: prep
# 			OSM: HD - None
# ------------------------------------------------------------
#
#
# JCB[                     1082x [sit] "ישׁב"
# 	verb ~ V    (OK )    920x
# 	verb ~ ×    (?  )    161x
# 	verb ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Obadiah 1:3 w298206 "שִׁבְתֹּ֑ו"
# 			BHS: verb
# 			OSM: HNcfsc - HSp3ms
# ------------------------------------------------------------
#
#
# >XD/                      970x [one] "אֶחָד"
# 	subs ~ A    (NN )    910x
# 	subs ~ ×    (?  )     60x
#
# CNH/                      876x [year] "שָׁנָה"
# 	subs ~ N    (OK )    824x
# 	subs ~ A    (?  )     31x
#
# ------------------------------------------------------------
# 		Genesis 11:10 w5143 "שָׁנָ֔ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 21:5 w9687 "שָׁנָ֑ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 23:1 w10747 "שְׁנֵ֖י"
# 			BHS: subs
# 			OSM: HAcmdc - None
# 		Genesis 25:7 w12523 "שְׁנֵֽי"
# 			BHS: subs
# 			OSM: HAcmdc - None
# 		Genesis 25:7 w12529 "שָׁנָ֛ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 25:17 w12670 "שְׁנֵי֙"
# 			BHS: subs
# 			OSM: HAcmdc - None
# 		Genesis 25:17 w12674 "שָׁנָ֛ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 35:28 w19527 "שָׁנָ֖ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 41:27 w22856 "שְׁנֵ֥י"
# 			BHS: subs
# 			OSM: HAcmdc - None
# 		Genesis 41:30 w22885 "שְׁנֵ֤י"
# 			BHS: subs
# 			OSM: HAcmdc - None
# 	and 21 more occurrences
# ------------------------------------------------------------
#
# 	subs ~ ×    (?  )     21x
#
# >T==                      868x [together with] "אֵת"
# 	prep ~ R    (OK )    755x
# 	prep ~ ×    (?  )     98x
# 	prep ~ T    (?  )     15x
#
# ------------------------------------------------------------
# 		Exodus 34:23 w48233 "אֶת"
# 			BHS: prep
# 			OSM: HTo - None
# 		Exodus 34:24 w48259 "אֶת"
# 			BHS: prep
# 			OSM: HTo - None
# 		Leviticus 16:5 w62287 "אֵ֗ת"
# 			BHS: prep
# 			OSM: HTo - None
# 		Numbers 31:52 w89845 "אֵ֖ת"
# 			BHS: prep
# 			OSM: HTo - None
# 		Numbers 35:8 w91997 "אֵ֥ת"
# 			BHS: prep
# 			OSM: HTo - None
# 		Deuteronomy 16:16 w102816 "אֶת"
# 			BHS: prep
# 			OSM: HTo - None
# 		Deuteronomy 16:16 w102842 "אֶת"
# 			BHS: prep
# 			OSM: HTo - None
# 		Deuteronomy 31:11 w110898 "אֶת"
# 			BHS: prep
# 			OSM: HTo - None
# 		Joshua 22:32 w126125 "אֵ֨ת"
# 			BHS: prep
# 			OSM: HTo - None
# 		1_Kings 12:8 w186105 "אֶת"
# 			BHS: prep
# 			OSM: HTo - None
# 	and 5 more occurrences
# ------------------------------------------------------------
#
#
# >JN/                      788x [<NEG>] "אַיִן"
# 	subs ~ T    (NN )    639x
# 	subs ~ ×    (?  )    149x
#
# GM                        769x [even] "גַּם"
# 	advb ~ T    (NN )    690x
# 	advb ~ D    (OK?)     79x
#
# ------------------------------------------------------------
# 		Genesis 4:4 w1722 "גַם"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 4:22 w2029 "גַם"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 6:3 w2650 "גַּ֖ם"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 16:13 w7275 "גַ֥ם"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 19:38 w9231 "גַם"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 20:5 w9327 "גַם"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 22:20 w10669 "גַם"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 27:34 w14241 "גַם"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 27:38 w14321 "גַם"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 30:3 w15648 "גַם"
# 			BHS: advb
# 			OSM: HD - None
# 	and 69 more occurrences
# ------------------------------------------------------------
#
#
# CNJM/                     768x [two] "שְׁנַיִם"
# 	subs ~ A    (NN )    768x
#
# H=                        743x [<interrogative>] "הֲ"
# 	inrg ~ T    (NN )    536x
# 	inrg ~ ×    (?  )    207x
#
# W                         731x [and] "וְ"
# 	conj ~ C    (OK )    486x
# 	conj ~ ×    (?  )    243x
# 	conj ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 2:23 w370982 "וּ"
# 			BHS: conj
# 			OSM: ANcfsd - None
# ------------------------------------------------------------
#
# 	conj ~ R    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 6:28 w374522 "וּ"
# 			BHS: conj
# 			OSM: AR - None
# ------------------------------------------------------------
#
#
# >XR/                      715x [after] "אַחַר"
# 	subs ~ R    (NN )    586x
# 	subs ~ ×    (?  )    128x
# 	subs ~ N    (OK?)      1x
#
# ------------------------------------------------------------
# 		2_Samuel 2:23 w161445 "אַחֲרֵ֨י"
# 			BHS: subs
# 			OSM: HNcmpc - None
# ------------------------------------------------------------
#
#
# CLC/                      602x [three] "שָׁלֹשׁ"
# 	subs ~ A    (NN )    600x
# 	subs ~ ×    (?  )      2x
#
# M>H/                      579x [hundred] "מֵאָה"
# 	subs ~ A    (NN )    565x
# 	subs ~ R    (?  )     13x
#
# ------------------------------------------------------------
# 		Genesis 11:10 w5142 "מְאַ֣ת"
# 			BHS: subs
# 			OSM: HR - None
# 		Genesis 21:5 w9686 "מְאַ֣ת"
# 			BHS: subs
# 			OSM: HR - None
# 		Genesis 25:7 w12528 "מְאַ֥ת"
# 			BHS: subs
# 			OSM: HR - None
# 		Genesis 25:17 w12673 "מְאַ֥ת"
# 			BHS: subs
# 			OSM: HR - None
# 		Genesis 35:28 w19526 "מְאַ֥ת"
# 			BHS: subs
# 			OSM: HR - None
# 		Exodus 38:25 w50893 "מְאַ֣ת"
# 			BHS: subs
# 			OSM: HR - None
# 		Exodus 38:27 w50947 "מְאַת֙"
# 			BHS: subs
# 			OSM: HR - None
# 		Exodus 38:27 w50962 "מְאַ֧ת"
# 			BHS: subs
# 			OSM: HR - None
# 		Numbers 2:9 w70537 "מְאַ֨ת"
# 			BHS: subs
# 			OSM: HR - None
# 		Numbers 2:16 w70632 "מְאַ֨ת"
# 			BHS: subs
# 			OSM: HR - None
# 	and 3 more occurrences
# ------------------------------------------------------------
#
# 	subs ~ ×    (?  )      1x
#
# MH                        573x [what] "מָה"
# 	prin ~ T    (NN )    568x
# 	prin ~ ×    (?  )      5x
#
# KN                        546x [thus] "כֵּן"
# 	advb ~ T    (NN )    422x
# 	advb ~ D    (OK?)    116x
#
# ------------------------------------------------------------
# 		Genesis 1:7 w124 "כֵֽן"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 1:9 w159 "כֵֽן"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 1:11 w203 "כֵֽן"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 1:15 w281 "כֵֽן"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 1:24 w466 "כֵֽן"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 1:30 w653 "כֵֽן"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 6:4 w2674 "כֵ֗ן"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 15:14 w6912 "כֵ֥ן"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 23:19 w11071 "כֵן֩"
# 			BHS: advb
# 			OSM: HD - None
# 		Genesis 25:26 w12826 "כֵ֞ן"
# 			BHS: advb
# 			OSM: HD - None
# 	and 106 more occurrences
# ------------------------------------------------------------
#
# 	advb ~ ×    (?  )      8x
#
# XMC/                      506x [five] "חָמֵשׁ"
# 	subs ~ A    (NN )    506x
#
# TXT/                      505x [under part] "תַּחַת"
# 	subs ~ R    (NN )    370x
# 	subs ~ ×    (?  )    133x
# 	subs ~ N    (OK?)      2x
#
# ------------------------------------------------------------
# 		Genesis 49:25 w28096 "תָּ֑חַת"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Deuteronomy 33:13 w112438 "תָּֽחַת"
# 			BHS: subs
# 			OSM: HNcmsa - None
# ------------------------------------------------------------
#
#
# >LP=/                     492x [thousand] "אֶלֶף"
# 	subs ~ A    (NN )    492x
#
# CB</                      490x [seven] "שֶׁבַע"
# 	subs ~ A    (NN )    482x
# 	subs ~ ×    (?  )      5x
# 	subs ~ N    (OK?)      3x
#
# ------------------------------------------------------------
# 		Genesis 4:15 w1915 "שִׁבְעָתַ֖יִם"
# 			BHS: subs
# 			OSM: HNcfda - None
# 		Genesis 4:24 w2068 "שִׁבְעָתַ֖יִם"
# 			BHS: subs
# 			OSM: HNcfda - None
# 		Psalms 79:12 w324385 "שִׁ֭בְעָתַיִם"
# 			BHS: subs
# 			OSM: HNcfda - None
# ------------------------------------------------------------
#
#
# <WD/                      490x [duration] "עֹוד"
# 	subs ~ D    (NN )    423x
# 	subs ~ ×    (?  )     67x
#
# VWB/                      469x [good] "טֹוב"
# 	adjv ~ A    (OK )    445x
# 	adjv ~ ×    (?  )     22x
# 	adjv ~ V    (?  )      2x
#
# ------------------------------------------------------------
# 		1_Samuel 16:16 w150632 "טֹ֥וב"
# 			BHS: adjv
# 			OSM: HVqq3ms - None
# 		1_Samuel 16:23 w150776 "טֹ֣וב"
# 			BHS: adjv
# 			OSM: HVqp3ms - None
# ------------------------------------------------------------
#
#
# >RB</                     454x [four] "אַרְבַּע"
# 	subs ~ A    (NN )    453x
# 	subs ~ ×    (?  )      1x
#
# RB/                       429x [much] "רַב"
# 	adjv ~ A    (OK )    405x
# 	adjv ~ ×    (?  )     23x
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Amos 6:2 w296968 "רַבָּ֑ה"
# 			BHS: adjv
# 			OSM: HNp - None
# ------------------------------------------------------------
#
#
# MJ                        423x [who] "מִי"
# 	prin ~ T    (NN )    423x
#
# BJN/                      407x [interval] "בַּיִן"
# 	subs ~ R    (NN )    355x
# 	subs ~ ×    (?  )     52x
#
# L                         378x [to] "לְ"
# 	prep ~ R    (OK )    191x
# 	prep ~ ×    (?  )    137x
# 	prep ~ T    (?  )     32x
#
# ------------------------------------------------------------
# 		Daniel 2:12 w370794 "לְ"
# 			BHS: prep
# 			OSM: ATo - None
# 		Daniel 2:14 w370828 "לְ"
# 			BHS: prep
# 			OSM: ATo - None
# 		Daniel 2:19 w370916 "לֶ"
# 			BHS: prep
# 			OSM: ATo - None
# 		Daniel 2:24 w371009 "לְ"
# 			BHS: prep
# 			OSM: ATo - None
# 		Daniel 2:24 w371017 "לְ"
# 			BHS: prep
# 			OSM: ATo - None
# 		Daniel 2:25 w371035 "לְ"
# 			BHS: prep
# 			OSM: ATo - None
# 		Daniel 2:49 w371598 "לְ"
# 			BHS: prep
# 			OSM: ATo - None
# 		Daniel 3:2 w371633 "לַֽ"
# 			BHS: prep
# 			OSM: ATo - None
# 		Daniel 3:13 w371878 "לְ"
# 			BHS: prep
# 			OSM: ATo - None
# 		Daniel 3:19 w372038 "לְ"
# 			BHS: prep
# 			OSM: ATo - None
# 	and 22 more occurrences
# ------------------------------------------------------------
#
# 	prep ~ C    (?  )     18x
#
# ------------------------------------------------------------
# 		Daniel 2:8 w370683 "ל"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:10 w370739 "ל"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:12 w370782 "ל"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:24 w370997 "ל"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:40 w371351 "ל"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:41 w371393 "ל"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:45 w371481 "ל"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 3:3 w371670 "לַ"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 3:7 w371737 "ל"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 3:8 w371772 "ל"
# 			BHS: prep
# 			OSM: AC - None
# 	and 8 more occurrences
# ------------------------------------------------------------
#
#
# DJ                        345x [<relative>] "דִּי"
# 	prep ~ T    (NN )    175x
# 	prep ~ ×    (?  )    125x
# 	prep ~ C    (?  )     39x
#
# ------------------------------------------------------------
# 		Daniel 2:8 w370678 "דִּ֥י"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:8 w370685 "דִּ֣י"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:8 w370687 "דִּ֥י"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:9 w370718 "דִּ֥י"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:10 w370741 "דִּ֚י"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:16 w370859 "דִּ֚י"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:18 w370894 "דִּ֣י"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:20 w370933 "דִּ֧י"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:23 w370989 "דִּֽי"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:23 w370992 "דִּֽי"
# 			BHS: prep
# 			OSM: AC - None
# 	and 29 more occurrences
# ------------------------------------------------------------
#
# 	prep ~ P    (?  )      5x
#
# ------------------------------------------------------------
# 		Daniel 3:6 w371723 "דִּי"
# 			BHS: prep
# 			OSM: APf3bs - None
# 		Daniel 3:11 w371824 "דִּי"
# 			BHS: prep
# 			OSM: APf3cs - None
# 		Daniel 4:14 w372650 "דִּ֤י"
# 			BHS: prep
# 			OSM: APfxcs - None
# 		Daniel 4:22 w372881 "דִּ֥י"
# 			BHS: prep
# 			OSM: APrxcs - None
# 		Daniel 4:29 w373010 "דִּ֥י"
# 			BHS: prep
# 			OSM: APrxcs - None
# ------------------------------------------------------------
#
# 	prep ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 4:23 w372897 "דִּ֣י"
# 			BHS: prep
# 			OSM: AAafsa - None
# ------------------------------------------------------------
#
#
# SBJB/                     336x [surrounding] "סָבִיב"
# 	subs ~ D    (NN )    207x
# 	subs ~ ×    (?  )     82x
# 	subs ~ N    (OK?)     47x
#
# ------------------------------------------------------------
# 		Numbers 16:24 w80502 "סָּבִ֔יב"
# 			BHS: subs
# 			OSM: HNcbsa - None
# 		Numbers 16:27 w80563 "סָּבִ֑יב"
# 			BHS: subs
# 			OSM: HNcbsa - None
# 		Deuteronomy 12:10 w100517 "סָּבִ֖יב"
# 			BHS: subs
# 			OSM: HNcbsa - None
# 		Deuteronomy 25:19 w107136 "סָּבִ֗יב"
# 			BHS: subs
# 			OSM: HNcbsa - None
# 		Joshua 21:44 w125193 "סָּבִ֔יב"
# 			BHS: subs
# 			OSM: HNcbsa - None
# 		Joshua 23:1 w126210 "סָּבִ֑יב"
# 			BHS: subs
# 			OSM: HNcbsa - None
# 		Judges 2:12 w128459 "סְבִיבֹ֣ותֵיהֶ֔ם"
# 			BHS: subs
# 			OSM: HNcbpc - HSp3mp
# 		Judges 2:14 w128500 "סָּבִ֔יב"
# 			BHS: subs
# 			OSM: HNcbsa - None
# 		Judges 8:34 w132853 "סָּבִֽיב"
# 			BHS: subs
# 			OSM: HNcbsa - None
# 		1_Samuel 12:11 w147479 "סָּבִ֔יב"
# 			BHS: subs
# 			OSM: HNcbsa - None
# 	and 37 more occurrences
# ------------------------------------------------------------
#
#
# <FRJM/                    315x [twenty] "עֶשְׂרִים"
# 	subs ~ A    (NN )    315x
#
# M>D/                      300x [might] "מְאֹד"
# 	subs ~ D    (NN )    290x
# 	subs ~ ×    (?  )     10x
#
# LWJ/                      292x [Levite] "לֵוִי"
# 	adjv ~ N    (NN )    239x
# 	adjv ~ ×    (?  )     53x
#
# ML>[                      292x [be full] "מלא"
# 	verb ~ V    (OK )    196x
# 	verb ~ ×    (?  )     64x
# 	verb ~ A    (?  )     32x
#
# ------------------------------------------------------------
# 		Numbers 7:13 w74146 "מְלֵאִ֗ים"
# 			BHS: verb
# 			OSM: HAampa - None
# 		Numbers 7:14 w74158 "מְלֵאָ֥ה"
# 			BHS: verb
# 			OSM: HAafsa - None
# 		Numbers 7:19 w74228 "מְלֵאִ֗ים"
# 			BHS: verb
# 			OSM: HAampa - None
# 		Numbers 7:20 w74240 "מְלֵאָ֥ה"
# 			BHS: verb
# 			OSM: HAafsa - None
# 		Numbers 7:25 w74309 "מְלֵאִ֗ים"
# 			BHS: verb
# 			OSM: HAampa - None
# 		Numbers 7:26 w74321 "מְלֵאָ֥ה"
# 			BHS: verb
# 			OSM: HAafsa - None
# 		Numbers 7:31 w74390 "מְלֵאִ֗ים"
# 			BHS: verb
# 			OSM: HAampa - None
# 		Numbers 7:32 w74402 "מְלֵאָ֥ה"
# 			BHS: verb
# 			OSM: HAafsa - None
# 		Numbers 7:37 w74471 "מְלֵאִ֗ים"
# 			BHS: verb
# 			OSM: HAampa - None
# 		Numbers 7:38 w74483 "מְלֵאָ֥ה"
# 			BHS: verb
# 			OSM: HAafsa - None
# 	and 22 more occurrences
# ------------------------------------------------------------
#
#
# PLCTJ/                    288x [Philistine] "פְּלִשְׁתִּי"
# 	adjv ~ N    (NN )    262x
# 	adjv ~ ×    (?  )     26x
#
# QRB[                      281x [approach] "קרב"
# 	verb ~ V    (OK )    254x
# 	verb ~ ×    (?  )     26x
# 	verb ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Zephaniah 1:14 w303365 "קָרֹ֖וב"
# 			BHS: verb
# 			OSM: HAamsa - None
# ------------------------------------------------------------
#
#
# >P/                       277x [nose] "אַף"
# 	subs ~ N    (OK )    210x
# 	subs ~ T    (?  )     61x
#
# ------------------------------------------------------------
# 		Genesis 27:45 w14450 "אַף"
# 			BHS: subs
# 			OSM: HTa - None
# 		Genesis 30:2 w15620 "אַ֥ף"
# 			BHS: subs
# 			OSM: HTa - None
# 		Exodus 4:14 w30441 "אַ֨ף"
# 			BHS: subs
# 			OSM: HTa - None
# 		Exodus 32:19 w46923 "אַ֣ף"
# 			BHS: subs
# 			OSM: HTa - None
# 		Exodus 32:22 w46988 "אַ֖ף"
# 			BHS: subs
# 			OSM: HTa - None
# 		Numbers 11:10 w76982 "אַ֤ף"
# 			BHS: subs
# 			OSM: HTa - None
# 		Numbers 12:9 w77733 "אַ֧ף"
# 			BHS: subs
# 			OSM: HTa - None
# 		Numbers 22:22 w84242 "אַ֣ף"
# 			BHS: subs
# 			OSM: HTa - None
# 		Numbers 22:27 w84374 "אַ֣ף"
# 			BHS: subs
# 			OSM: HTa - None
# 		Numbers 24:10 w85352 "אַ֤ף"
# 			BHS: subs
# 			OSM: HTa - None
# 	and 51 more occurrences
# ------------------------------------------------------------
#
# 	subs ~ ×    (?  )      6x
#
# CC/                       274x [six] "שֵׁשׁ"
# 	subs ~ A    (NN )    274x
#
# HM                        269x [they] "הֵם"
# 	prps ~ P    (OK )    266x
# 	prps ~ ×    (?  )      2x
# 	prps ~ S    (?  )      1x
#
# ------------------------------------------------------------
# 		Song_of_songs 6:5 w358742 "הֵ֖ם"
# 			BHS: prps
# 			OSM: HSp3mp - None
# ------------------------------------------------------------
#
#
# XJ/                       239x [alive] "חַי"
# 	adjv ~ A    (OK )    234x
# 	adjv ~ ×    (?  )      4x
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Ruth 3:13 w357009 "חַי"
# 			BHS: adjv
# 			OSM: HNcmsa - None
# ------------------------------------------------------------
#
#
# B                         226x [in] "בְּ"
# 	prep ~ R    (OK )    141x
# 	prep ~ ×    (?  )     84x
# 	prep ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 6:28 w374523 "בְ"
# 			BHS: prep
# 			OSM: ANcmpd - None
# ------------------------------------------------------------
#
#
# <FR/                      203x [-teen] "עָשָׂר"
# 	subs ~ A    (NN )    203x
#
# LKN                       200x [therefore] "לָכֵן"
# 	advb ~ R    (NN )    194x
# 	advb ~ ×    (?  )      6x
#
# LMH                       178x [why] "לָמָה"
# 	inrg ~ R    (NN )    169x
# 	inrg ~ ×    (?  )      8x
# 	inrg ~ T    (?  )      1x
#
# ------------------------------------------------------------
# 		1_Samuel 1:8 w141686 "לָ֣מֶה"
# 			BHS: inrg
# 			OSM: HTi -
# ------------------------------------------------------------
#
#
# >K                        161x [only] "אַךְ"
# 	advb ~ T    (NN )    158x
# 	advb ~ D    (OK?)      3x
#
# ------------------------------------------------------------
# 		Genesis 9:5 w4110 "אַ֨ךְ"
# 			BHS: advb
# 			OSM: HD - None
# 		Numbers 22:20 w84216 "אַ֗ךְ"
# 			BHS: advb
# 			OSM: HD - None
# 		Joshua 22:19 w125721 "אַ֨ךְ"
# 			BHS: advb
# 			OSM: HD - None
# ------------------------------------------------------------
#
#
# GBWR/                     159x [vigorous] "גִּבֹּור"
# 	subs ~ A    (NN )    137x
# 	subs ~ ×    (?  )     22x
#
# NGD/                      151x [counterpart] "נֶגֶד"
# 	subs ~ R    (NN )    120x
# 	subs ~ ×    (?  )     31x
#
# CMNH/                     147x [eight] "שְׁמֹנֶה"
# 	subs ~ A    (NN )    147x
#
# M<L/                      140x [top] "מַעַל"
# 	subs ~ ×    (?  )     75x
# 	subs ~ D    (?  )     63x
#
# ------------------------------------------------------------
# 		Genesis 6:16 w2900 "מַ֔עְלָה"
# 			BHS: subs
# 			OSM: HD - HSd
# 		Genesis 7:20 w3440 "מַ֔עְלָה"
# 			BHS: subs
# 			OSM: HD - HSd
# 		Exodus 25:20 w42254 "מַ֗עְלָה"
# 			BHS: subs
# 			OSM: HD - HSd
# 		Exodus 37:9 w50072 "מַ֗עְלָה"
# 			BHS: subs
# 			OSM: HD - HSd
# 		Exodus 38:26 w50932 "מַ֔עְלָה"
# 			BHS: subs
# 			OSM: HD - HSd
# 		Leviticus 27:7 w69079 "מַ֨עְלָה֙"
# 			BHS: subs
# 			OSM: HD - HSd
# 		Numbers 1:3 w69665 "מַ֔עְלָה"
# 			BHS: subs
# 			OSM: HD - HSd
# 		Numbers 1:18 w69816 "מַ֖עְלָה"
# 			BHS: subs
# 			OSM: HD - HSd
# 		Numbers 1:20 w69854 "מַ֔עְלָה"
# 			BHS: subs
# 			OSM: HD - HSd
# 		Numbers 1:22 w69891 "מַ֔עְלָה"
# 			BHS: subs
# 			OSM: HD - HSd
# 	and 53 more occurrences
# ------------------------------------------------------------
#
# 	subs ~ R    (?  )      2x
#
# ------------------------------------------------------------
# 		Haggai 2:18 w304862 "מָ֑עְלָה"
# 			BHS: subs
# 			OSM: HR - HSd
# 		Ecclesiastes 3:21 w360509 "מָ֑עְלָה"
# 			BHS: subs
# 			OSM: HR - HSd
# ------------------------------------------------------------
#
#
# JC/                       138x [existence] "יֵשׁ"
# 	subs ~ T    (NN )    138x
#
# C                         138x [<relative>] "שַׁ"
# 	conj ~ T    (NN )    129x
# 	conj ~ ×    (?  )      9x
#
# XKM/                      138x [wise] "חָכָם"
# 	adjv ~ A    (OK )    125x
# 	adjv ~ ×    (?  )     12x
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Proverbs 1:5 w346968 "חָ֭כָם"
# 			BHS: adjv
# 			OSM: HNcmsa - None
# ------------------------------------------------------------
#
#
# <FRH/                     134x [-teen] "עֶשְׂרֵה"
# 	subs ~ A    (NN )    134x
#
# >P                        133x [even] "אַף"
# 	advb ~ T    (NN )    104x
# 	advb ~ D    (OK?)     23x
#
# ------------------------------------------------------------
# 		Leviticus 26:39 w68799 "אַ֛ף"
# 			BHS: advb
# 			OSM: HD - None
# 		Leviticus 26:40 w68819 "אַ֕ף"
# 			BHS: advb
# 			OSM: HD - None
# 		Leviticus 26:42 w68854 "אַף֩"
# 			BHS: advb
# 			OSM: HD - None
# 		Leviticus 26:42 w68859 "אַ֨ף"
# 			BHS: advb
# 			OSM: HD - None
# 		Leviticus 26:44 w68898 "אַף"
# 			BHS: advb
# 			OSM: HD - None
# 		Deuteronomy 15:17 w102349 "אַ֥ף"
# 			BHS: advb
# 			OSM: HD - None
# 		Deuteronomy 31:27 w111359 "אַ֖ף"
# 			BHS: advb
# 			OSM: HD - None
# 		1_Samuel 21:6 w154495 "אַ֕ף"
# 			BHS: advb
# 			OSM: HD - None
# 		1_Samuel 23:3 w155384 "אַף֙"
# 			BHS: advb
# 			OSM: HD - None
# 		2_Samuel 16:11 w170032 "אַ֨ף"
# 			BHS: advb
# 			OSM: HD - None
# 	and 13 more occurrences
# ------------------------------------------------------------
#
# 	advb ~ ×    (?  )      6x
#
# <FRH=/                    120x [ten] "עֲשָׂרָה"
# 	subs ~ A    (NN )    120x
#
# MN                        119x [from] "מִן"
# 	prep ~ R    (OK )    103x
# 	prep ~ ×    (?  )     15x
# 	prep ~ C    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 3:22 w372092 "מִן"
# 			BHS: prep
# 			OSM: AC - None
# ------------------------------------------------------------
#
#
# BLT/                      112x [failure] "בֵּלֶת"
# 	subs ~ C    (NN )    100x
# 	subs ~ ×    (?  )     11x
# 	subs ~ R    (?  )      1x
#
# ------------------------------------------------------------
# 		Hosea 13:4 w293772 "בִּלְתִּֽי"
# 			BHS: subs
# 			OSM: HR - HSp1cs
# ------------------------------------------------------------
#
#
# RQ                        109x [only] "רַק"
# 	advb ~ T    (NN )    108x
# 	advb ~ D    (OK?)      1x
#
# ------------------------------------------------------------
# 		Numbers 12:2 w77610 "רַ֤ק"
# 			BHS: advb
# 			OSM: HD - None
# ------------------------------------------------------------
#
#
# KNP/                      109x [wing] "כָּנָף"
# 	subs ~ N    (OK )     59x
# 	subs ~ ×    (?  )     42x
# 	subs ~ D    (?  )      8x
#
# ------------------------------------------------------------
# 		Deuteronomy 32:11 w111587 "כְּנָפָיו֙"
# 			BHS: subs
# 			OSM: HD -
# 		1_Kings 6:24 w180572 "כְּנָפָ֖יו"
# 			BHS: subs
# 			OSM: HD -
# 		1_Kings 6:24 w180576 "כְּנָפָֽיו"
# 			BHS: subs
# 			OSM: HD -
# 		Isaiah 8:8 w214878 "כְּנָפָ֔יו"
# 			BHS: subs
# 			OSM: HD -
# 		Jeremiah 48:40 w260991 "כְּנָפָ֖יו"
# 			BHS: subs
# 			OSM: HD -
# 		Jeremiah 49:22 w261544 "כְּנָפָ֖יו"
# 			BHS: subs
# 			OSM: HD -
# 		Psalms 91:4 w326442 "כְּנָפָ֣יו"
# 			BHS: subs
# 			OSM: HD -
# 		Ruth 2:12 w356507 "כְּנָפָֽיו"
# 			BHS: subs
# 			OSM: HD -
# ------------------------------------------------------------
#
#
# B<D/                      105x [distance] "בַּעַד"
# 	subs ~ R    (NN )     67x
# 	subs ~ ×    (?  )     38x
#
# M<V/                      101x [little] "מְעַט"
# 	subs ~ N    (OK )     54x
# 	subs ~ ×    (?  )     42x
# 	subs ~ A    (?  )      5x
#
# ------------------------------------------------------------
# 		Hosea 1:4 w290992 "מְעַ֗ט"
# 			BHS: subs
# 			OSM: HAamsa - None
# 		Hosea 8:10 w292726 "מְּעָ֔ט"
# 			BHS: subs
# 			OSM: HAamsa - None
# 		Haggai 1:6 w304217 "מְעָ֗ט"
# 			BHS: subs
# 			OSM: HAamsa - None
# 		Haggai 1:9 w304272 "מְעָ֔ט"
# 			BHS: subs
# 			OSM: HAamsa - None
# 		Ruth 2:7 w356376 "מְעָֽט"
# 			BHS: subs
# 			OSM: HAamsa - None
# ------------------------------------------------------------
#
#
# J<N/                      100x [motive] "יַעַן"
# 	subs ~ ×    (?  )     96x
# 	subs ~ C    (?  )      4x
#
# ------------------------------------------------------------
# 		Hosea 8:1 w292616 "יַ֚עַן"
# 			BHS: subs
# 			OSM: HC - None
# 		Amos 5:11 w296673 "יַ֣עַן"
# 			BHS: subs
# 			OSM: HC - None
# 		Haggai 1:9 w304280 "יַ֣עַן"
# 			BHS: subs
# 			OSM: HC - None
# 		Haggai 1:9 w304285 "יַ֗עַן"
# 			BHS: subs
# 			OSM: HC - None
# ------------------------------------------------------------
#
#
# ZNH[                       93x [fornicate] "זנה"
# 	verb ~ V    (OK )     61x
# 	verb ~ ×    (?  )     31x
# 	verb ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Joel 4:3 w295061 "זֹּונָ֔ה"
# 			BHS: verb
# 			OSM: HNcfsa - None
# ------------------------------------------------------------
#
#
# >MRJ/                      87x [Amorite] "אֱמֹרִי"
# 	adjv ~ N    (NN )     84x
# 	adjv ~ ×    (?  )      3x
#
# JHWDJ/                     82x [Jewish] "יְהוּדִי"
# 	adjv ~ N    (NN )     45x
# 	adjv ~ ×    (?  )     35x
# 	adjv ~ A    (OK?)      2x
#
# ------------------------------------------------------------
# 		Esther 5:13 w367881 "יְּהוּדִ֔י"
# 			BHS: adjv
# 			OSM: HAamsa - None
# 		Esther 9:13 w369453 "יְּהוּדִים֙"
# 			BHS: adjv
# 			OSM: HAampa - None
# ------------------------------------------------------------
#
#
# MHR[                       81x [hasten] "מהר"
# 	verb ~ V    (OK )     55x
# 	verb ~ ×    (?  )     25x
# 	verb ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Zephaniah 1:14 w303367 "מַהֵ֣ר"
# 			BHS: verb
# 			OSM: HAamsa - None
# ------------------------------------------------------------
#
#
# TC</                       78x [nine] "תֵּשַׁע"
# 	subs ~ A    (NN )     78x
#
# KN<NJ/                     73x [Canaanite] "כְּנַעֲנִי"
# 	adjv ~ N    (NN )     62x
# 	adjv ~ ×    (?  )     11x
#
# MDW<                       72x [why] "מַדּוּעַ"
# 	inrg ~ T    (NN )     61x
# 	inrg ~ ×    (?  )     11x
#
# KSJL/                      70x [insolent] "כְּסִיל"
# 	adjv ~ ×    (?  )     69x
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Proverbs 3:35 w347774 "כְסִילִ֗ים"
# 			BHS: adjv
# 			OSM: HNcmpa - None
# ------------------------------------------------------------
#
#
# KKR/                       68x [disk] "כִּכָּר"
# 	subs ~ N    (OK )     51x
# 	subs ~ ×    (?  )     15x
# 	subs ~ A    (?  )      2x
#
# ------------------------------------------------------------
# 		Exodus 38:25 w50894 "כִּכָּ֑ר"
# 			BHS: subs
# 			OSM: HAcbsc - HNcbsa
# 		Exodus 38:27 w50948 "כִּכַּ֣ר"
# 			BHS: subs
# 			OSM: HAcbsc - HNcbsc
# ------------------------------------------------------------
#
#
# VWBH/                      65x [what is good] "טֹובָה"
# 	subs ~ A    (NN )     65x
#
# K                          63x [like] "כְּ"
# 	prep ~ R    (OK?)     30x
#
# ------------------------------------------------------------
# 		Daniel 2:10 w370748 "כִ"
# 			BHS: prep
# 			OSM: AR - None
# 		Daniel 2:35 w371240 "כַ"
# 			BHS: prep
# 			OSM: AR - None
# 		Daniel 2:35 w371250 "כְּ"
# 			BHS: prep
# 			OSM: AR - None
# 		Daniel 2:40 w371348 "כְּ"
# 			BHS: prep
# 			OSM: AR - None
# 		Daniel 2:40 w371360 "כְ"
# 			BHS: prep
# 			OSM: AR - None
# 		Daniel 3:29 w372330 "כִּ"
# 			BHS: prep
# 			OSM: AR - None
# 		Daniel 3:33 w372372 "כְּ"
# 			BHS: prep
# 			OSM: AR - None
# 		Daniel 3:33 w372377 "כְּ"
# 			BHS: prep
# 			OSM: AR - None
# 		Daniel 4:5 w372453 "כְּ"
# 			BHS: prep
# 			OSM: AR - None
# 		Daniel 4:16 w372695 "כְּ"
# 			BHS: prep
# 			OSM: AR - None
# 	and 20 more occurrences
# ------------------------------------------------------------
#
# 	prep ~ C    (?  )     19x
#
# ------------------------------------------------------------
# 		Daniel 2:8 w370682 "כָּ"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:10 w370738 "כָּ"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:12 w370781 "כָּ"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:24 w370996 "כָּ"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:40 w371350 "כָּ"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:41 w371392 "כָּ"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 2:45 w371480 "כָּ"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 3:7 w371736 "כָּ"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 3:8 w371771 "כָּ"
# 			BHS: prep
# 			OSM: AC - None
# 		Daniel 3:22 w372088 "כָּ"
# 			BHS: prep
# 			OSM: AC - None
# 	and 9 more occurrences
# ------------------------------------------------------------
#
# 	prep ~ ×    (?  )     14x
#
# >YL/                       61x [side] "אֵצֶל"
# 	subs ~ R    (NN )     39x
# 	subs ~ ×    (?  )     22x
#
# >JK                        61x [how] "אֵיךְ"
# 	inrg ~ T    (NN )     61x
#
# DNH                        58x [this] "דְּנָה"
# 	prde ~ P    (OK?)     27x
#
# ------------------------------------------------------------
# 		Daniel 2:10 w370749 "דְנָה֙"
# 			BHS: prde
# 			OSM: APdxms - None
# 		Daniel 2:18 w370893 "דְּנָ֑ה"
# 			BHS: prde
# 			OSM: APdxms - None
# 		Daniel 2:28 w371119 "דְּנָ֥ה"
# 			BHS: prde
# 			OSM: APdxms - None
# 		Daniel 2:29 w371131 "דְנָ֑ה"
# 			BHS: prde
# 			OSM: APdxms - None
# 		Daniel 2:30 w371151 "דְנָ֖ה"
# 			BHS: prde
# 			OSM: APdxms - None
# 		Daniel 2:36 w371279 "דְּנָ֣ה"
# 			BHS: prde
# 			OSM: APdxms - None
# 		Daniel 2:43 w371436 "דְּנָ֣ה"
# 			BHS: prde
# 			OSM: APdxms - None
# 		Daniel 2:43 w371438 "דְּנָ֑ה"
# 			BHS: prde
# 			OSM: APdxms - None
# 		Daniel 2:45 w371511 "דְנָ֑ה"
# 			BHS: prde
# 			OSM: APdxms - None
# 		Daniel 2:47 w371561 "דְנָֽה"
# 			BHS: prde
# 			OSM: APdxms - None
# 	and 17 more occurrences
# ------------------------------------------------------------
#
# 	prde ~ ×    (?  )     25x
# 	prde ~ C    (?  )      6x
#
# ------------------------------------------------------------
# 		Daniel 2:12 w370784 "דְּנָ֔ה"
# 			BHS: prde
# 			OSM: AC - None
# 		Daniel 2:24 w370999 "דְּנָ֗ה"
# 			BHS: prde
# 			OSM: AC - None
# 		Daniel 3:7 w371739 "דְּנָ֡ה"
# 			BHS: prde
# 			OSM: AC - None
# 		Daniel 3:8 w371774 "דְּנָה֙"
# 			BHS: prde
# 			OSM: AC - None
# 		Daniel 3:22 w372091 "דְּנָ֗ה"
# 			BHS: prde
# 			OSM: AC - None
# 		Daniel 6:10 w374043 "דְּנָ֑ה"
# 			BHS: prde
# 			OSM: AC - None
# ------------------------------------------------------------
#
#
# BLJ/                       58x [destruction] "בְּלִי"
# 	subs ~ T    (?  )     20x
#
# ------------------------------------------------------------
# 		Genesis 31:20 w16737 "בְּלִי֙"
# 			BHS: subs
# 			OSM: HTn - None
# 		2_Samuel 1:21 w160870 "בְּלִ֖י"
# 			BHS: subs
# 			OSM: HTn - None
# 		Isaiah 14:6 w216934 "בְּלִ֥י"
# 			BHS: subs
# 			OSM: HTn - None
# 		Isaiah 28:8 w220950 "בְּלִ֖י"
# 			BHS: subs
# 			OSM: HTn - None
# 		Isaiah 32:10 w222800 "בְּלִ֥י"
# 			BHS: subs
# 			OSM: HTn - None
# 		Isaiah 38:17 w225311 "בְּלִ֔י"
# 			BHS: subs
# 			OSM: HTn - None
# 		Hosea 7:8 w292480 "בְּלִ֥י"
# 			BHS: subs
# 			OSM: HTn - None
# 		Hosea 8:7 w292687 "בְּלִ֣י"
# 			BHS: subs
# 			OSM: HTn - None
# 		Malachi 3:10 w310378 "בְּלִי"
# 			BHS: subs
# 			OSM: HTn - None
# 		Psalms 19:4 w313207 "בְּ֝לִ֗י"
# 			BHS: subs
# 			OSM: HTn - None
# 	and 10 more occurrences
# ------------------------------------------------------------
#
# 	subs ~ N    (OK?)     20x
#
# ------------------------------------------------------------
# 		Deuteronomy 9:28 w99078 "בְּלִי֙"
# 			BHS: subs
# 			OSM: HNcmsc - None
# 		Deuteronomy 28:55 w109152 "בְּלִ֥י"
# 			BHS: subs
# 			OSM: HNcmsc - None
# 		Isaiah 5:13 w213650 "בְּלִי"
# 			BHS: subs
# 			OSM: HNcmsc - None
# 		Jeremiah 2:15 w235625 "בְּלִ֥י"
# 			BHS: subs
# 			OSM: HNcmsc - None
# 		Jeremiah 9:9 w239564 "בְּלִי"
# 			BHS: subs
# 			OSM: HNcmsc - None
# 		Jeremiah 9:10 w239596 "בְּלִ֖י"
# 			BHS: subs
# 			OSM: HNcmsc - None
# 		Jeremiah 9:11 w239625 "בְּלִ֖י"
# 			BHS: subs
# 			OSM: HNcmsc - None
# 		Ezekiel 14:15 w270677 "בְּלִ֣י"
# 			BHS: subs
# 			OSM: HNcmsc - None
# 		Ezekiel 34:5 w281616 "בְּלִ֣י"
# 			BHS: subs
# 			OSM: HNcmsc - None
# 		Hosea 4:6 w291784 "בְּלִ֣י"
# 			BHS: subs
# 			OSM: HNcmsc - None
# 	and 10 more occurrences
# ------------------------------------------------------------
#
# 	subs ~ ×    (?  )     18x
#
# >DN/                       57x [pedestal] "אֶדֶן"
# 	subs ~ N    (OK )     56x
# 	subs ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Exodus 38:27 w50963 "אֲדָנִ֛ים"
# 			BHS: subs
# 			OSM: HAcbsc - HNcmpa
# ------------------------------------------------------------
#
#
# <FR=/                      56x [ten] "עֶשֶׂר"
# 	subs ~ A    (NN )     56x
#
# VRM/                       56x [beginning] "טֶרֶם"
# 	subs ~ D    (NN )     56x
#
# XTJ/                       48x [Hittite] "חִתִּי"
# 	adjv ~ N    (NN )     32x
# 	adjv ~ ×    (?  )     16x
#
# JXD/                       47x [gathering] "יַחַד"
# 	subs ~ ×    (?  )     30x
# 	subs ~ N    (OK?)     14x
#
# ------------------------------------------------------------
# 		1_Samuel 11:11 w147123 "יָֽחַד"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		1_Samuel 17:10 w150987 "יָֽחַד"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		2_Samuel 10:15 w165599 "יָֽחַד"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		2_Samuel 21:9 w173945 "יָ֑חַד"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Isaiah 42:14 w226742 "יָֽחַד"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Isaiah 43:26 w227321 "יָ֑חַד"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Isaiah 44:11 w227528 "יָֽחַד"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Psalms 62:10 w320564 "יָֽחַד"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Psalms 74:8 w322861 "יָ֑חַד"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Psalms 88:18 w325714 "יָֽחַד"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 	and 4 more occurrences
# ------------------------------------------------------------
#
# 	subs ~ D    (?  )      3x
#
# ------------------------------------------------------------
# 		Hosea 11:7 w293404 "יַ֖חַד"
# 			BHS: subs
# 			OSM: HD - None
# 		Hosea 11:8 w293422 "יַ֖חַד"
# 			BHS: subs
# 			OSM: HD - None
# 		Psalms 2:2 w310753 "יָ֑חַד"
# 			BHS: subs
# 			OSM: HD - None
# ------------------------------------------------------------
#
#
# >JH                        45x [where] "אַיֵּה"
# 	inrg ~ T    (NN )     43x
# 	inrg ~ ×    (?  )      2x
#
# <MD/                       45x [company] "עִמָּד"
# 	subs ~ R    (NN )     41x
# 	subs ~ ×    (?  )      4x
#
# VWB[                       44x [be good] "טוב"
# 	verb ~ ×    (?  )     34x
# 	verb ~ V    (OK?)      8x
#
# ------------------------------------------------------------
# 		Numbers 11:18 w77188 "טֹ֥וב"
# 			BHS: verb
# 			OSM: HVqp3ms - None
# 		Numbers 24:1 w85212 "טֹ֞וב"
# 			BHS: verb
# 			OSM: HVqp3ms - None
# 		Numbers 24:5 w85282 "טֹּ֥בוּ"
# 			BHS: verb
# 			OSM: HVqp3cp - None
# 		Deuteronomy 5:33 w96953 "טֹ֣וב"
# 			BHS: verb
# 			OSM: HVqq3ms - None
# 		Deuteronomy 15:16 w102327 "טֹ֥וב"
# 			BHS: verb
# 			OSM: HVqp3ms - None
# 		1_Kings 8:18 w182439 "הֱטִיבֹ֔תָ"
# 			BHS: verb
# 			OSM: HVhp2ms - None
# 		2_Kings 10:30 w201853 "הֱטִיבֹ֨תָ֙"
# 			BHS: verb
# 			OSM: HVhp2ms - None
# 		Song_of_songs 4:10 w358367 "טֹּ֤בוּ"
# 			BHS: verb
# 			OSM: HVqp3cp - None
# ------------------------------------------------------------
#
# 	verb ~ A    (?  )      2x
#
# ------------------------------------------------------------
# 		Hosea 2:9 w291267 "טֹ֥וב"
# 			BHS: verb
# 			OSM: HAamsa - None
# 		Hosea 10:1 w293076 "טֹ֣וב"
# 			BHS: verb
# 			OSM: HAamsa - None
# ------------------------------------------------------------
#
#
# MTJ                        43x [when] "מָתַי"
# 	inrg ~ T    (NN )     40x
# 	inrg ~ ×    (?  )      3x
#
# QDM/                       42x [before] "קֳדָם"
# 	subs ~ R    (NN )     27x
# 	subs ~ ×    (?  )     15x
#
# JBWSJ/                     41x [Jebusite] "יְבוּסִי"
# 	adjv ~ N    (NN )     34x
# 	adjv ~ ×    (?  )      7x
#
# >N                         41x [whither] "אָן"
# 	inrg ~ D    (NN )     29x
# 	inrg ~ ×    (?  )      8x
# 	inrg ~ T    (?  )      4x
#
# ------------------------------------------------------------
# 		Genesis 16:8 w7188 "אָ֣נָה"
# 			BHS: inrg
# 			OSM: HTi - None
# 		Genesis 32:18 w17786 "אָ֣נָה"
# 			BHS: inrg
# 			OSM: HTi - None
# 		Isaiah 10:3 w215568 "אָ֥נָה"
# 			BHS: inrg
# 			OSM: HTi - None
# 		Psalms 139:7 w334403 "אָ֗נָה"
# 			BHS: inrg
# 			OSM: HTi - None
# ------------------------------------------------------------
#
#
# MCJX/                      39x [anointed] "מָשִׁיחַ"
# 	subs ~ N    (OK )     21x
# 	subs ~ ×    (?  )     17x
# 	subs ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Psalms 2:2 w310758 "מְשִׁיחֹֽו"
# 			BHS: subs
# 			OSM: HAamsc - HSp3ms
# ------------------------------------------------------------
#
#
# >J                         39x [where] "אֵי"
# 	inrg ~ T    (NN )     38x
# 	inrg ~ ×    (?  )      1x
#
# CC=/                       38x [linen] "שֵׁשׁ"
# 	subs ~ A    (NN )     31x
# 	subs ~ N    (OK?)      5x
#
# ------------------------------------------------------------
# 		Exodus 28:5 w43832 "שֵּֽׁשׁ"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Exodus 35:25 w48960 "שֵּֽׁשׁ"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Exodus 35:35 w49152 "שֵּׁ֖שׁ"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Exodus 38:23 w50855 "שֵּֽׁשׁ"
# 			BHS: subs
# 			OSM: HNcmsa - None
# 		Exodus 39:3 w51137 "שֵּׁ֑שׁ"
# 			BHS: subs
# 			OSM: HNcmsa - None
# ------------------------------------------------------------
#
# 	subs ~ ×    (?  )      2x
#
# MR/                        37x [bitter] "מַר"
# 	adjv ~ A    (OK )     31x
# 	adjv ~ ×    (?  )      5x
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Ruth 1:20 w356181 "מָרָ֔א"
# 			BHS: adjv
# 			OSM: HNp - None
# ------------------------------------------------------------
#
#
# >J/                        36x [coast, island] "אִי"
# 	subs ~ N    (OK )     25x
# 	subs ~ ×    (?  )      8x
# 	subs ~ T    (?  )      3x
#
# ------------------------------------------------------------
# 		Isaiah 23:2 w219430 "אִ֑י"
# 			BHS: subs
# 			OSM: HTj - None
# 		Isaiah 23:6 w219483 "אִֽי"
# 			BHS: subs
# 			OSM: HTj - None
# 		Jeremiah 47:4 w260328 "אִ֥י"
# 			BHS: subs
# 			OSM: HTj - None
# ------------------------------------------------------------
#
#
# MWL/                       36x [front] "מוּל"
# 	subs ~ R    (NN )     24x
# 	subs ~ ×    (?  )     12x
#
# CB<==/                     35x [Sheba] "שֶׁבַע"
# 	nmpr ~ N    (OK )     19x
# 	nmpr ~ A    (?  )     16x
#
# ------------------------------------------------------------
# 		Genesis 26:33 w13598 "שֶׁ֔בַע"
# 			BHS: nmpr
# 			OSM: HAcfsa - None
# 		Joshua 15:28 w121878 "שֶׁ֖בַע"
# 			BHS: nmpr
# 			OSM: HAcfsa - None
# 		Joshua 19:2 w123440 "שֶׁ֥בַע"
# 			BHS: nmpr
# 			OSM: HAcfsa - None
# 		Joshua 19:2 w123442 "שֶׁ֖בַע"
# 			BHS: nmpr
# 			OSM: HAcfsa - None
# 		Judges 20:1 w139905 "שֶׁ֔בַע"
# 			BHS: nmpr
# 			OSM: HAcfsa - None
# 		2_Samuel 17:11 w170533 "שֶׁ֔בַע"
# 			BHS: nmpr
# 			OSM: HAcfsa - None
# 		2_Samuel 24:2 w175464 "שֶׁ֔בַע"
# 			BHS: nmpr
# 			OSM: HAcfsa - None
# 		2_Samuel 24:15 w175800 "שֶׁ֔בַע"
# 			BHS: nmpr
# 			OSM: HAcfsa - None
# 		1_Kings 19:3 w191454 "שֶׁ֖בַע"
# 			BHS: nmpr
# 			OSM: HAcfsa - None
# 		Amos 5:5 w296582 "שֶׁ֖בַע"
# 			BHS: nmpr
# 			OSM: HAcfsa - None
# 	and 6 more occurrences
# ------------------------------------------------------------
#
#
# <BRJ/                      34x [Hebrew] "עִבְרִי"
# 	adjv ~ ×    (?  )     21x
# 	adjv ~ N    (?  )     13x
#
# ------------------------------------------------------------
# 		Genesis 40:15 w22188 "עִבְרִ֑ים"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# 		Genesis 43:32 w24786 "עִבְרִים֙"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# 		Exodus 2:6 w29235 "עִבְרִ֖ים"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# 		Exodus 5:3 w30858 "עִבְרִ֖ים"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# 		Exodus 7:16 w32063 "עִבְרִים֙"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# 		Exodus 9:1 w33037 "עִבְרִ֔ים"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# 		Exodus 9:13 w33301 "עִבְרִ֔ים"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# 		Exodus 10:3 w33847 "עִבְרִ֔ים"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# 		1_Samuel 4:6 w143432 "עִבְרִ֑ים"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# 		1_Samuel 13:3 w147857 "עִבְרִֽים"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# 	and 3 more occurrences
# ------------------------------------------------------------
#
#
# XTN[                       33x [be father-in-law] "חתן"
# 	verb ~ ×    (?  )     25x
# 	verb ~ V    (OK?)      7x
#
# ------------------------------------------------------------
# 		Genesis 34:9 w18601 "הִֽתְחַתְּנ֖וּ"
# 			BHS: verb
# 			OSM: HVtv2mp - None
# 		Deuteronomy 7:3 w97483 "תִתְחַתֵּ֖ן"
# 			BHS: verb
# 			OSM: HVti2ms - None
# 		Joshua 23:12 w126453 "הִֽתְחַתַּנְתֶּ֥ם"
# 			BHS: verb
# 			OSM: HVtq2mp - None
# 		1_Samuel 18:22 w152620 "הִתְחַתֵּ֥ן"
# 			BHS: verb
# 			OSM: HVtv2ms - None
# 		1_Samuel 18:23 w152643 "הִתְחַתֵּ֣ן"
# 			BHS: verb
# 			OSM: HVtc - None
# 		1_Samuel 18:26 w152720 "הִתְחַתֵּ֖ן"
# 			BHS: verb
# 			OSM: HVtc - None
# 		1_Samuel 18:27 w152755 "הִתְחַתֵּ֖ן"
# 			BHS: verb
# 			OSM: HVtc - None
# ------------------------------------------------------------
#
# 	verb ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Judges 4:11 w129619 "חֹתֵ֣ן"
# 			BHS: verb
# 			OSM: HNcmsc - None
# ------------------------------------------------------------
#
#
# XZH[                       31x [see] "חזה"
# 	verb ~ V    (OK )     28x
# 	verb ~ ×    (?  )      2x
# 	verb ~ T    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 2:26 w371072 "חֲזֵ֖ית"
# 			BHS: verb
# 			OSM: ATr - None
# ------------------------------------------------------------
#
#
# MWL[                       30x [circumcise] "מול"
# 	verb ~ V    (OK )     28x
# 	verb ~ ×    (?  )      1x
# 	verb ~ R    (?  )      1x
#
# ------------------------------------------------------------
# 		Jeremiah 9:24 w239863 "מ֖וּל"
# 			BHS: verb
# 			OSM: HR - None
# ------------------------------------------------------------
#
#
# MYRJ/                      30x [Egyptian] "מִצְרִי"
# 	adjv ~ ×    (?  )     20x
# 	adjv ~ N    (?  )     10x
#
# ------------------------------------------------------------
# 		Genesis 39:2 w21452 "מִּצְרִֽי"
# 			BHS: adjv
# 			OSM: HNgmsa - None
# 		Genesis 39:5 w21508 "מִּצְרִ֖י"
# 			BHS: adjv
# 			OSM: HNgmsa - None
# ...
# 			BHS: nmpr
# 			OSM: HTn - HNp
# ------------------------------------------------------------
#
#
# >HJ                         3x [where] "אֱהִי"
# 	inrg ~ T    (?  )      3x
#
# ------------------------------------------------------------
# 		Hosea 13:10 w293825 "אֱהִ֤י"
# 			BHS: inrg
# 			OSM: HTi - None
# 		Hosea 13:14 w293878 "אֱהִ֨י"
# 			BHS: inrg
# 			OSM: HTi - None
# 		Hosea 13:14 w293881 "אֱהִ֤י"
# 			BHS: inrg
# 			OSM: HTi - None
# ------------------------------------------------------------
#
#
# TLT=/                       3x [triumvir] "תְּלָת"
# 	subs ~ ×    (?  )      2x
# 	subs ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 5:7 w373325 "תַלְתִּ֥י"
# 			BHS: subs
# 			OSM: AAomsa - None
# ------------------------------------------------------------
#
#
# LHN                         3x [therefore] "לָהֵן"
# 	advb ~ C    (?  )      3x
#
# ------------------------------------------------------------
# 		Daniel 2:6 w370653 "לָהֵ֕ן"
# 			BHS: advb
# 			OSM: AC - None
# 		Daniel 2:9 w370712 "לָהֵ֗ן"
# 			BHS: advb
# 			OSM: AC - None
# 		Daniel 4:24 w372902 "לָהֵ֣ן"
# 			BHS: advb
# 			OSM: AC - None
# ------------------------------------------------------------
#
#
# <QB==/                      3x [something knobby] "עָקֹב"
# 	subs ~ N    (OK?)      1x
#
# ------------------------------------------------------------
# 		Isaiah 40:4 w225628 "עָקֹב֙"
# 			BHS: subs
# 			OSM: HNcmsa - None
# ------------------------------------------------------------
#
# 	subs ~ ×    (?  )      1x
# 	subs ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Hosea 6:8 w292331 "עֲקֻבָּ֖ה"
# 			BHS: subs
# 			OSM: HAafsa - None
# ------------------------------------------------------------
#
#
# >XR/                        3x [after] "אַחַר"
# 	subs ~ R    (?  )      2x
#
# ------------------------------------------------------------
# 		Daniel 2:29 w371130 "אַחֲרֵ֣י"
# 			BHS: subs
# 			OSM: HR - None
# 		Daniel 2:45 w371510 "אַחֲרֵ֣י"
# 			BHS: subs
# 			OSM: AR - None
# ------------------------------------------------------------
#
# 	subs ~ ×    (?  )      1x
#
# DWMM                        3x [silently] "דּוּמָם"
# 	advb ~ D    (OK?)      1x
#
# ------------------------------------------------------------
# 		Isaiah 47:5 w228576 "דוּמָ֛ם"
# 			BHS: advb
# 			OSM: HD - None
# ------------------------------------------------------------
#
# 	advb ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Habakkuk 2:19 w302774 "דּוּמָ֑ם"
# 			BHS: advb
# 			OSM: HNcmsa - None
# ------------------------------------------------------------
#
# 	advb ~ ×    (?  )      1x
#
# HMWN                        3x [they] "הִמֹּון"
# 	prps ~ P    (OK?)      2x
#
# ------------------------------------------------------------
# 		Daniel 2:34 w371236 "הִמֹּֽון"
# 			BHS: prps
# 			OSM: APp3mp - None
# 		Daniel 3:22 w372111 "הִמֹּ֔ון"
# 			BHS: prps
# 			OSM: APp3mp - None
# ------------------------------------------------------------
#
# 	prps ~ S    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 2:35 w371257 "הִמֹּון֙"
# 			BHS: prps
# 			OSM: ASp3mp - None
# ------------------------------------------------------------
#
#
# >LMNJ/                      3x [stranger] "אַלְמֹנִי"
# 	subs ~ ×    (?  )      2x
# 	subs ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Ruth 4:1 w357143 "אַלְמֹנִ֑י"
# 			BHS: subs
# 			OSM: HAabsa - None
# ------------------------------------------------------------
#
#
# CC==/                       3x [alabaster] "שֵׁשׁ"
# 	subs ~ A    (?  )      3x
#
# ------------------------------------------------------------
# 		Song_of_songs 5:15 w358658 "שֵׁ֔שׁ"
# 			BHS: subs
# 			OSM: HAcfsa - None
# 		Esther 1:6 w365583 "שֵׁ֑שׁ"
# 			BHS: subs
# 			OSM: HAcfsa - None
# 		Esther 1:6 w365592 "שֵׁ֖שׁ"
# 			BHS: subs
# 			OSM: HAcfsa - None
# ------------------------------------------------------------
#
#
# >J=                         2x [how] "אִי"
# 	inrg ~ ×    (?  )      1x
# 	inrg ~ T    (?  )      1x
#
# ------------------------------------------------------------
# 		Ecclesiastes 10:16 w362940 "אִֽי"
# 			BHS: inrg
# 			OSM: HTj - None
# ------------------------------------------------------------
#
#
# L>_<MJ/                     2x [Lo-Ammi] "לֹא עַמִּי"
# 	nmpr ~ T    (?  )      1x
#
# ------------------------------------------------------------
# 		Hosea 1:9 w291084 "לֹ֣א עַמִּ֑י"
# 			BHS: nmpr
# 			OSM: HTn - HNp
# ------------------------------------------------------------
#
# 	nmpr ~ N    (OK?)      1x
#
# ------------------------------------------------------------
# 		Hosea 2:25 w291577 "לֹֽא־עַמִּי֙"
# 			BHS: nmpr
# 			OSM: HNp - HNp
# ------------------------------------------------------------
#
#
# M>H=/                       2x [the Hundred] "מֵאָה"
# 	nmpr ~ A    (?  )      2x
#
# ------------------------------------------------------------
# 		Nehemiah 3:1 w384288 "מֵּאָה֙"
# 			BHS: nmpr
# 			OSM: HAcbsa - None
# 		Nehemiah 12:39 w390299 "מֵּאָ֔ה"
# 			BHS: nmpr
# 			OSM: HAcbsa - None
# ------------------------------------------------------------
#
#
# >HB/                        2x [display of love] "אֹהַב"
# 	subs ~ V    (?  )      1x
#
# ------------------------------------------------------------
# 		Hosea 9:10 w292956 "אָהֳבָֽם"
# 			BHS: subs
# 			OSM: HVqc - HSp3mp
# ------------------------------------------------------------
#
# 	subs ~ N    (OK?)      1x
#
# ------------------------------------------------------------
# 		Proverbs 7:18 w348749 "אֳהָבִֽים"
# 			BHS: subs
# 			OSM: HNcmpa - None
# ------------------------------------------------------------
#
#
# TLTJN/                      2x [thirty] "תְּלָתִין"
# 	subs ~ A    (?  )      2x
#
# ------------------------------------------------------------
# 		Daniel 6:8 w374013 "תְּלָתִ֗ין"
# 			BHS: subs
# 			OSM: AAcmpa - None
# 		Daniel 6:13 w374132 "תְּלָתִ֗ין"
# 			BHS: subs
# 			OSM: AAcmpa - None
# ------------------------------------------------------------
#
#
# BJN/                        2x [between] "בֵּין"
# 	subs ~ R    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 7:5 w374643 "בֵּ֣ין"
# 			BHS: subs
# 			OSM: AR - None
# ------------------------------------------------------------
#
# 	subs ~ ×    (?  )      1x
#
# >ZD>                        2x [publicly known] "אַזְדָּא"
# 	advb ~ A    (?  )      2x
#
# ------------------------------------------------------------
# 		Daniel 2:5 w370625 "אַזְדָּ֑א"
# 			BHS: advb
# 			OSM: AAafsa - None
# 		Daniel 2:8 w370688 "אַזְדָּ֖א"
# 			BHS: advb
# 			OSM: AAafsa - None
# ------------------------------------------------------------
#
#
# >WJL_MRDK/                  2x [Evil-merodach] "אֱוִיל מְרֹדַךְ"
# 	nmpr ~ A    (?  )      2x
#
# ------------------------------------------------------------
# 		2_Kings 25:27 w212008 "אֱוִ֣יל מְרֹדַךְ֩"
# 			BHS: nmpr
# 			OSM: HAamsa -
# 		Jeremiah 52:31 w264667 "אֱוִ֣יל מְרֹדַךְ֩"
# 			BHS: nmpr
# 			OSM: HAamsa -
# ------------------------------------------------------------
#
#
# GBWRH/                      2x [power] "גְּבוּרָה"
# 	subs ~ N    (OK?)      1x
#
# ------------------------------------------------------------
# 		Daniel 2:20 w370936 "גְבוּרְתָ֖א"
# 			BHS: subs
# 			OSM: ANcfsd - ATd
# ------------------------------------------------------------
#
# 	subs ~ T    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 2:23 w370983 "גְבוּרְתָ֖א"
# 			BHS: subs
# 			OSM: ATd - ATd
# ------------------------------------------------------------
#
#
# >NH=[                       2x [mourn] "אנה"
# 	verb ~ D    (?  )      2x
#
# ------------------------------------------------------------
# 		Isaiah 3:26 w213275 "אָנ֥וּ"
# 			BHS: verb
# 			OSM: HD - None
# 		Isaiah 19:8 w218260 "אָנוּ֙"
# 			BHS: verb
# 			OSM: HD - None
# ------------------------------------------------------------
#
#
# >JKBWD/                     2x [Ichabod] "אִיכָבֹוד"
# 	nmpr ~ T    (?  )      1x
#
# ------------------------------------------------------------
# 		1_Samuel 4:21 w143795 "אִֽי־כָבֹוד֙"
# 			BHS: nmpr
# 			OSM: HTj -
# ------------------------------------------------------------
#
# 	nmpr ~ N    (OK?)      1x
#
# ------------------------------------------------------------
# 		1_Samuel 14:3 w148366 "אִיכָבֹ֣וד"
# 			BHS: nmpr
# 			OSM: HNp - None
# ------------------------------------------------------------
#
#
# MD<=/                       2x [kinsman] "מֹדָע"
# 	subs ~ N    (OK?)      1x
#
# ------------------------------------------------------------
# 		Proverbs 7:4 w348616 "מֹדָ֗ע"
# 			BHS: subs
# 			OSM: HNcmsa - None
# ------------------------------------------------------------
#
# 	subs ~ V    (?  )      1x
#
# ------------------------------------------------------------
# 		Ruth 2:1 w356231 "מידע"
# 			BHS: subs
# 			OSM: HVPrmsa - None
# ------------------------------------------------------------
#
#
# CT/                         2x [six] "שֵׁת"
# 	subs ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 3:1 w371619 "שִׁ֑ת"
# 			BHS: subs
# 			OSM: AAcfsa - None
# ------------------------------------------------------------
#
# 	subs ~ ×    (?  )      1x
#
# LHN                         2x [therefore] "לָהֵן"
# 	advb ~ C    (?  )      2x
#
# ------------------------------------------------------------
# 		Ruth 1:13 w356036 "לָהֵ֣ן"
# 			BHS: advb
# 			OSM: HC - None
# 		Ruth 1:13 w356042 "לָהֵן֙"
# 			BHS: advb
# 			OSM: HC - None
# ------------------------------------------------------------
#
#
# CWLMJ/                      2x [Shulammite] "שׁוּלַמִּי"
# 	adjv ~ N    (?  )      2x
#
# ------------------------------------------------------------
# 		Song_of_songs 7:1 w358858 "שּׁ֣וּלַמִּ֔ית"
# 			BHS: adjv
# 			OSM: HNgfsa - None
# 		Song_of_songs 7:1 w358868 "שּׁ֣וּלַמִּ֔ית"
# 			BHS: adjv
# 			OSM: HNgfsa - None
# ------------------------------------------------------------
#
#
# >CRJ/                       1x [from Asher] "אָשֵׁרִי"
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Judges 1:32 w128117 "אָ֣שֵׁרִ֔י"
# 			BHS: adjv
# 			OSM: HNgmsa - None
# ------------------------------------------------------------
#
#
# <NH/                        1x [humble] "עֲנֵה"
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 4:24 w372916 "עֲנָ֑יִן"
# 			BHS: adjv
# 			OSM: ANcmpa - None
# ------------------------------------------------------------
#
#
# RXMH==/                     1x [Ruhamah] "רֻחָמָה"
# 	nmpr ~ V    (?  )      1x
#
# ------------------------------------------------------------
# 		Hosea 2:3 w291153 "רֻחָֽמָה"
# 			BHS: nmpr
# 			OSM: HVPp3fs - None
# ------------------------------------------------------------
#
#
# <WD/                        1x [still] "עֹוד"
# 	subs ~ D    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 4:28 w372962 "עֹ֗וד"
# 			BHS: subs
# 			OSM: AD - None
# ------------------------------------------------------------
#
#
# JWNJ/                       1x [Greek] "יְוָנִי"
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Joel 4:6 w295121 "יְּוָנִ֑ים"
# 			BHS: adjv
# 			OSM: HNgmpa - None
# ------------------------------------------------------------
#
#
# XLC/                        1x [weak man] "חַלָּשׁ"
# 	subs ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Joel 4:10 w295187 "חַלָּ֔שׁ"
# 			BHS: subs
# 			OSM: HAamsa - None
# ------------------------------------------------------------
#
#
# MDJ=/                       1x [Median] "מָדַי"
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 6:1 w373840 "מדיא"
# 			BHS: adjv
# 			OSM: ANgmsd - ATd
# ------------------------------------------------------------
#
#
# <FRJN/                      1x [twenty] "עֶשְׂרִין"
# 	subs ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 6:2 w373860 "עֶשְׂרִ֑ין"
# 			BHS: subs
# 			OSM: AAcbpa - None
# ------------------------------------------------------------
#
#
# >PL/                        1x [darkness] "אָפֵל"
# 	subs ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Amos 5:20 w296852 "אָפֵ֖ל"
# 			BHS: subs
# 			OSM: HAamsa - None
# ------------------------------------------------------------
#
#
# NGD/                        1x [toward] "נֶגֶד"
# 	subs ~ R    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 6:11 w374067 "נֶ֖גֶד"
# 			BHS: subs
# 			OSM: AR - None
# ------------------------------------------------------------
#
#
# PRSJ/                       1x [Persian] "פַּרְסָי"
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 6:29 w374543 "פרסיא"
# 			BHS: adjv
# 			OSM: ANgmsd - ATd
# ------------------------------------------------------------
#
#
# N>/                         1x [raw] "נָא"
# 	adjv ~ T    (?  )      1x
#
# ------------------------------------------------------------
# 		Exodus 12:9 w34847 "נָ֔א"
# 			BHS: adjv
# 			OSM: HTe - None
# ------------------------------------------------------------
#
#
# >LQCJ/                      1x [Elkoshite] "אֶלְקֹשִׁי"
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Nahum 1:1 w301441 "אֶלְקֹשִֽׁי"
# 			BHS: adjv
# 			OSM: HNgmsa - None
# ------------------------------------------------------------
#
#
# TNJNWT                      1x [again] "תִּנְיָנוּת"
# 	advb ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 2:7 w370659 "תִנְיָנ֖וּת"
# 			BHS: advb
# 			OSM: AAobpa - None
# ------------------------------------------------------------
#
#
# KDBH/                       1x [lie] "כִּדְבָה"
# 	subs ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 2:9 w370701 "כִדְבָ֤ה"
# 			BHS: subs
# 			OSM: AAafsa - None
# ------------------------------------------------------------
#
#
# NVJL/                       1x [weighing] "נָטִיל"
# 	adjv ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Zephaniah 1:11 w303303 "נְטִ֥ילֵי"
# 			BHS: adjv
# 			OSM: HNcmpc - None
# ------------------------------------------------------------
# PWYJ/                       1x [<uncertain>] "פּוּצַי"
# 	subs ~ V    (?  )      1x
#
# ------------------------------------------------------------
# 		Zephaniah 3:10 w303914 "פּוּצַ֔י"
# 			BHS: subs
# 			OSM: HVqsmsc - HSp1cs
# ------------------------------------------------------------
#
#
# MN=                         1x [what] "מָן"
# 	prin ~ T    (?  )      1x
#
# ------------------------------------------------------------
# 		Exodus 16:15 w37694 "מָ֣ן"
# 			BHS: prin
# 			OSM: HTi - None
# ------------------------------------------------------------
#
#
# KJ/                         1x [branding] "כִּי"
# 	subs ~ C    (?  )      1x
#
# ------------------------------------------------------------
# 		Isaiah 3:24 w213261 "כִּי"
# 			BHS: subs
# 			OSM: HC - None
# ------------------------------------------------------------
#
#
# CB<H/                       1x [Shibah] "שִׁבְעָה"
# 	nmpr ~ A    (?  )      1x
#
# ------------------------------------------------------------
# 		Genesis 26:33 w13591 "שִׁבְעָ֑ה"
# 			BHS: nmpr
# 			OSM: HAcmsa - None
# ------------------------------------------------------------
#
#
# JT                          1x [<nota accusativi>] "יָת"
# 	prep ~ T    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 3:12 w371840 "יָתְהֹון֙"
# 			BHS: prep
# 			OSM: ATo - ASp3mp
# ------------------------------------------------------------
#
#
# YD>                         1x [really] "צְדָא"
# 	advb ~ N    (?  )      1x
#
# ------------------------------------------------------------
# 		Daniel 3:14 w371896 "צְדָּ֕א"
# 			BHS: advb
# 			OSM: ANcmsa - None
# ------------------------------------------------------------
#
#
# >XZ/                        1x [holding] "אָחֻז"
# 	adjv ~ V    (?  )      1x
#
# ------------------------------------------------------------
# 		Song_of_songs 3:8 w358155 "אֲחֻ֣זֵי"
# 			BHS: adjv
# 			OSM: HVqsmpc - None
# ------------------------------------------------------------
#
#
# >L==                        1x [where] "אַל"
# 	inrg ~ T    (?  )      1x
#
# ------------------------------------------------------------
# 		1_Samuel 27:10 w158427 "אַל"
# 			BHS: inrg
# 			OSM: HTn - None
# ------------------------------------------------------------

# %% [markdown]
# # SP versus PDP
#
# Here is the computation that shows that the BHS feature
# [sp](https://etcbc.github.io/bhsa/features/hebrew/2017/sp)
# matches the OSM part-of-speech better than
# [pdp](https://etcbc.github.io/bhsa/features/hebrew/2017/pdp).

# %%
discrepancies = {}

for w in F.otype.s('word'):
    osm = osmPsp[w]
    if osm == '×': continue
    lex = F.lex.v(w)
    trans = pspBhsFromOsm[osm]
    if F.sp.v(w) not in trans:
        discrepancies.setdefault('sp', set()).add(w)
    if F.pdp.v(w) not in trans:
        discrepancies.setdefault('pdp', set()).add(w)
        
lexDiscrepancies = {} # discrepancies per lexeme
for (ft, ws) in sorted(discrepancies.items()):
    for w in sorted(ws):
        lexNode = L.u(w, otype='lex')[0]
        lexInfo = lexDiscrepancies.setdefault(ft, {})
        if lexNode in lexInfo:
            continue
        lexInfo[lexNode] = w

if discrepancies:
    print('Discrepancies')
    for (ft, lexInfo) in sorted(lexDiscrepancies.items()):
        print('\n--- {:<4}: {:>4} lexemes ---\n'.format(ft, len(lexInfo)))
        
    for (ft, ws) in sorted(discrepancies.items()):
        n = len(ws)
        print('\n--- {:<4}: {:>6}x ---\n'.format(ft, n))
        for w in sorted(ws)[0:10]:
            show(T, F, [w], Fs(ft).v, getOSMpsp)
        if n > 10:
            print('\tand {} more'.format(n - 10))
# Out:
# Discrepancies
#
# --- pdp :  938 lexemes ---
#
#
# --- sp  :  229 lexemes ---
#
#
# --- pdp :  35443x ---
#
# Genesis 1:1 w5 "אֵ֥ת"
# 	BHS: prep
# 	OSM: HTo - None
# Genesis 1:1 w9 "אֵ֥ת"
# 	BHS: prep
# 	OSM: HTo - None
# Genesis 1:4 w43 "אֶת"
# 	BHS: prep
# 	OSM: HTo - None
# Genesis 1:5 w78 "אֶחָֽד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# Genesis 1:7 w98 "אֶת"
# 	BHS: prep
# 	OSM: HTo - None
# Genesis 1:7 w106 "אֲשֶׁר֙"
# 	BHS: conj
# 	OSM: HTr - None
# Genesis 1:7 w116 "אֲשֶׁ֖ר"
# 	BHS: conj
# 	OSM: HTr - None
# Genesis 1:9 w152 "אֶחָ֔ד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# Genesis 1:11 w195 "אֲשֶׁ֥ר"
# 	BHS: conj
# 	OSM: HTr - None
# Genesis 1:12 w218 "אֲשֶׁ֥ר"
# 	BHS: conj
# 	OSM: HTr - None
# 	and 35433 more
#
# --- sp  :  31760x ---
#
# Genesis 1:1 w5 "אֵ֥ת"
# 	BHS: prep
# 	OSM: HTo - None
# Genesis 1:1 w9 "אֵ֥ת"
# 	BHS: prep
# 	OSM: HTo - None
# Genesis 1:4 w43 "אֶת"
# 	BHS: prep
# 	OSM: HTo - None
# Genesis 1:4 w51 "בֵּ֥ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:4 w55 "בֵ֥ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:5 w78 "אֶחָֽד"
# 	BHS: subs
# 	OSM: HAcmsa - None
# Genesis 1:6 w91 "בֵּ֥ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:7 w98 "אֶת"
# 	BHS: prep
# 	OSM: HTo - None
# Genesis 1:7 w103 "בֵּ֤ין"
# 	BHS: subs
# 	OSM: HR - None
# Genesis 1:7 w106 "אֲשֶׁר֙"
# 	BHS: conj
# 	OSM: HTr - None
# 	and 31750 more

# %%
strangePsp = {}
strangeSuffix = {}

for w in F.otype.s('word'):
    osm = osmPsp[w]
    if osm == '×': continue

    if osm == 'S' or osm not in pspBhsFromOsm:
        strangePsp.setdefault(osm, set()).add(w)

    osm_sf = F.osm_sf.v(w)
    if osm_sf:
        osmSuffix = None if len(osm_sf) < 2 else osm_sf[1]
        if osmSuffix != 'S':           
            strangeSuffix.setdefault(osmSuffix, set()).add(w)
            
if strangePsp:
    print('Strange psp')
    for (ln, ws) in sorted(strangePsp.items()):
        print('\t{:<5}: {:>5}x'.format(ln, len(ws)))
        for w in sorted(ws)[0:5]:
            show(T, F, [w], F.sp.v, getOSMpsp, indent='\t\t')
        n = len(ws)
        if n > 5:
            print('and {} more'.format(n - 5))
else:
    print('No other psps encountered than {}'.format(', '.join(pspBhsFromOsm)))
if strangeSuffix:
    print('Strange suffix psp')
    for (ln, ws) in sorted(strangeSuffix.items()):
        print('\t{:<5}: {:>5}x'.format(ln, len(ws)))
        for w in sorted(ws)[0:5]:
            show(T, F, [w], F.sp.v, getOSMpsp, indent='\t\t')
        n = len(ws)
        if n > 5:
            print('and {} more'.format(n - 5))
else:
    print('No other suffix psps encountered than S')
# Out:
# Strange psp
# 	S    :     3x
# 		Jeremiah 18:3 w243708 "הו"
# 			BHS: prps
# 			OSM: HSp3ms - None
# 		Song_of_songs 6:5 w358742 "הֵ֖ם"
# 			BHS: prps
# 			OSM: HSp3mp - None
# 		Daniel 2:35 w371257 "הִמֹּון֙"
# 			BHS: prps
# 			OSM: ASp3mp - None
# Strange suffix psp
# 	A    :     6x
# 		Numbers 2:9 w70538 "אֶ֜לֶף"
# 			BHS: subs
# 			OSM: HAcbsc - HAcbsa
# 		Numbers 2:16 w70633 "אֶ֜לֶף"
# 			BHS: subs
# 			OSM: HAcbsc - HAcbsa
# 		Numbers 2:24 w70744 "אֶ֛לֶף"
# 			BHS: subs
# 			OSM: HAcbsc - HAcbsa
# 		Numbers 2:31 w70834 "אֶ֗לֶף"
# 			BHS: subs
# 			OSM: HAcbsc - HAcbsa
# 		Judges 1:10 w127653 "קִרְיַ֣ת אַרְבַּ֑ע"
# 			BHS: nmpr
# 			OSM: HNp - HAcfsa
# and 1 more
# 	C    :     2x
# 		Ruth 3:12 w356979 "כִּ֥י אם"
# 			BHS: conj
# 			OSM: HC - HC
# 		Ecclesiastes 8:12 w362111 "וּ"
# 			BHS: conj
# 			OSM: HAcbsc - HC
# 	D    :   194x
# 		Genesis 4:15 w1911 "לָכֵן֙"
# 			BHS: advb
# 			OSM: HR - HD
# 		Genesis 30:15 w15823 "לָכֵן֙"
# 			BHS: advb
# 			OSM: HR - HD
# 		Exodus 6:6 w31334 "לָכֵ֞ן"
# 			BHS: advb
# 			OSM: HR - HD
# 		Numbers 16:11 w80256 "לָכֵ֗ן"
# 			BHS: advb
# 			OSM: HR - HD
# 		Numbers 20:12 w82792 "לָכֵ֗ן"
# 			BHS: advb
# 			OSM: HR - HD
# and 189 more
# 	N    :    79x
# 		Genesis 11:10 w5143 "שָׁנָ֔ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 21:5 w9687 "שָׁנָ֑ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 25:7 w12529 "שָׁנָ֛ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 25:17 w12674 "שָׁנָ֛ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# 		Genesis 35:28 w19527 "שָׁנָ֖ה"
# 			BHS: subs
# 			OSM: HAcbsc - HNcfsa
# and 74 more
# 	P    :     6x
# 		2_Samuel 24:3 w175489 "כָּהֵ֤ם"
# 			BHS: prep
# 			OSM: HR - HPp3mp
# 		2_Samuel 24:3 w175491 "כָהֵם֙"
# 			BHS: prep
# 			OSM: HR - HPp3mp
# 		Ecclesiastes 9:12 w362645 "כָּהֵ֗ם"
# 			BHS: prep
# 			OSM: HR - HPp3mp
# 		Daniel 6:6 w373962 "עֲלֹ֖והִי"
# 			BHS: prep
# 			OSM: AR - APp3ms
# 		1_Chronicles 21:3 w401846 "כָּהֵם֙"
# 			BHS: prep
# 			OSM: HR - HPp3mp
# and 1 more
# 	T    :   777x
# 		Genesis 4:6 w1759 "לָ֚מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 4:6 w1763 "לָ֖מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 12:18 w5826 "לָ֚מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 12:19 w5833 "לָמָ֤ה"
# 			BHS: inrg
# 			OSM: HR - HTi
# 		Genesis 18:13 w8030 "לָ֣מָּה"
# 			BHS: inrg
# 			OSM: HR - HTi
# and 772 more
