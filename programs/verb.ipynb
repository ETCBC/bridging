# %% [markdown]
# # BHSA and OSM: comparison on verb attributes
#
# We will investigate how the morphology marked up in the OSM corresponds and differs from the BHSA linguistic features.
#
# In this notebook we investigate the markup of verb attributes.
# According to the [OSM specs](http://openscriptures.github.io/morphhb/parsing/HebrewMorphologyCodes.html)
# this is provided:
#
# * verb stem
# * conjugation type
# * person
# * gender
# * number
#
# We use the `osm` and `osm_sf` features compiled by the
# [BHSAbridgeOSM notebook](BHSAbridgeOSM.ipynb).
#
# # Results
#
# See below, where most of the cases are mentioned.
# We also collect all cases in [verbs.tsv](verbs.tsv) , a tab delimited file.

# %%
import os
import collections

from tf.fabric import Fabric
from utils import show

# %% [markdown]
# # Load data
# We load the BHSA data in the standard way, and we add the OSM data as a module of the features `osm` and `osm_sf`.
# Note that we only need to point TF to the right directories, and then we can load all features
# that are present in those directories.

# %%
BHSA = 'BHSA/tf/2017'
OSM = 'bridging/tf/2017'

TF = Fabric(locations='~/github/etcbc', modules=[BHSA, OSM])
api = TF.load('''
    sp
    lex voc_lex_utf8 gloss
    languageISO
    osm osm_sf
    g_word_utf8
    vs vt ps gn nu
''')
api.makeAvailableIn(globals())
# Out:
# This is Text-Fabric 3.1.1
# Api reference : https://github.com/Dans-labs/text-fabric/wiki/Api
# Tutorial      : https://github.com/Dans-labs/text-fabric/blob/master/docs/tutorial.ipynb
# Example data  : https://github.com/Dans-labs/text-fabric-data
#
# 117 features found and 0 ignored
#   0.00s loading features ...
#    |     0.22s B g_word_utf8          from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.13s B sp                   from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.13s B lex                  from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.01s B voc_lex_utf8         from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.01s B gloss                from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.13s B languageISO          from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.13s B osm                  from /Users/dirk/github/etcbc/bridging/tf/2017
#    |     0.02s B osm_sf               from /Users/dirk/github/etcbc/bridging/tf/2017
#    |     0.13s B vs                   from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.13s B vt                   from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.12s B ps                   from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.11s B gn                   from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.12s B nu                   from /Users/dirk/github/etcbc/BHSA/tf/2017
#    |     0.00s Feature overview: 111 for nodes; 5 for edges; 1 configs; 7 computed
#   5.76s All features loaded/computed - for details use loadLog()

# %% [markdown]
# # Verb occurrences
#
# Let us first identify what the verb occurrences are, according to the OSM and to the BHSA.
# We'll show the differences.
# The OSM is not yet completed, so we focus on the cases where the OSM has morphology.
#
# We call the set of words that have a non-empty OSM morphology string the OSM-base.

# %%
verbsBHS = set(F.sp.s('verb'))
hasOSM = set()
for w in F.otype.s('word'):
    osm = F.osm.v(w)
    if osm and len(osm) > 1:
        hasOSM.add(w)

verbsBHSfocus = verbsBHS & hasOSM

verbsOSM = {w for w in hasOSM if F.osm.v(w)[1] == 'V'}

print('''
Number of verb occurrences in the Hebrew Bible:
\tin BHSA (total):                     {:>5}
\tin BHSA (intersected with OSM-base): {:>5}
\tin OSM:                              {:>5}
'''.format(
    len(verbsBHS),
    len(verbsBHSfocus),
    len(verbsOSM),
))
# Out:
# Number of verb occurrences in the Hebrew Bible:
# 	in BHSA (total):                     75450
# 	in BHSA (intersected with OSM-base): 60126
# 	in OSM:                              60085

# %% [markdown]
# As you see: very few discrepancies.
# Before we show them, we define functions that show a verb with BHSA morphology and OSM morphology.
#
# If a piece of moprhology is not present, we substitute a `?`.
# We also transform a not-applicable or unknown value in the BHSA by `?`, although
# there is a difference between missing markup and markup saying: insufficient information!

# %% [markdown]
# # Names
#
# We map the names for stems and conjugations found in the
# [OSM morphology description](http://openscriptures.github.io/morphhb/parsing/HebrewMorphologyCodes.html)
# to convenient names when comparing them with the morphology values in the BHSA features
# [vs](https://etcbc.github.io/bhsa/features/hebrew/2017/vt.html)
# and
# [vt](https://etcbc.github.io/bhsa/features/hebrew/2017/vt.html),
# and we map some BHSA names as well.

# %%
stemMapOSM = dict(
    H=dict(
        q='qal',
        N='niphal',
        p='piel',
        P='pual',
        h='hiphil',
        H='hophal',
        t='hithpael',
        o='polel',
        O='polal',
        r='hithpolel',
        m='poel',
        M='poal',
        k='palel',
        K='pulal',
        Q='qalpassive',
        l='pilpel',
        L='polpal',
        f='hithpalpel',
        D='nithpael',
        j='pealal',
        i='pilel',
        u='hothpaal',
        c='tiphil',
        v='hishtaphel',
        w='nithpalel',
        y='nithpoel',
        z='hithpoel',
    ),
    A=dict(
        q='peal',
        Q='peil',
        u='hithpeel',
        p='pael',
        P='ithpaal',
        M='hithpaal',
        a='aphel',
        h='haphel',
        s='saphel',
        e='shaphel',
        H='hophal',
        i='ithpeel',
        t='hishtaphel',
        v='ishtaphel',
        w='hithaphel',
        o='polel',
        z='ithpoel',
        r='hithpolel',
        f='hithpalpel',
        b='hephal',
        c='tiphel',
        m='poel',
        l='palpel',
        L='ithpalpel',
        O='ithpolel',
        G='ittaphal',
    ),
)

# %%
stemMapBHS = dict(
    hif='hiphil',
    hit='hithpael',
    htpo='hithpoel',
    hof='hophal',
    nif='niphal',
    piel='piel',
    poal='poal',
    poel='poel',
    pual='pual',
    qal='qal',
    afel='aphel',
    etpa='etpaal',
    etpe='etpeel',
    haf='haphel',
    hotp='hothpaal',
    hsht='hishtaphel',
    htpa='hithpaal',
    htpe='hithpeel',
    nit='nithpael',
    pael='pael',
    peal='peal',
    peil='peil',
    shaf='shaphel',
    tif='tiphal',
    pasq='qalpassive',
)

# %%
conjMapOSM = dict(
    p='perfect',
    q='weqatal',
    i='imperfect',
    w='wayyiqtol',
    h='cohortative',
    j='jussive',
    v='imperative',
    r='part act',
    s='part pass',
    a='inf abs',
    c='inf cons',
)
conjMapBHS = dict(
    impf='imperfect',
    impv='imperative',
    infa='inf abs',
    infc='inf cons',
    perf='perfect',
    ptca='part act',
    ptcp='part pass',
    wayq='wayyiqtol',    
)

# %%
naValues = {'NA', 'N/A'}
missingValues = {None, '', 'unknown'}
noPersonConj = {'r', 's', 'a', 'c'}

def getValue(x): return '_' if x in naValues else '?' if x in missingValues else x
def getValueHead(x): return '_' if x in naValues else '?' if x in missingValues else x[0]
def getValueTail(x): return '_' if x in naValues else '?' if x in missingValues else x[1:]

def extractFeature(x, n): return '?' if not x or len(x) <= n else x[n]

def getLangOSM(w): return extractFeature(F.osm.v(w), 0)

def getStemOSM(w): return extractFeature(F.osm.v(w), 2)
def getStemOSMX(w): return stemMapOSM.get(getLangOSM(w), {}).get(getStemOSM(w), '?')
def getConjOSM(w): return extractFeature(F.osm.v(w), 3)
def getConjOSMX(w): return conjMapOSM.get(getConjOSM(w), '?')
def getPersonOSM(w): return '_' if getConjOSM(w) in noPersonConj else extractFeature(F.osm.v(w), 4)
def getGenderOSM(w): return extractFeature(F.osm.v(w), 4 if getConjOSM(w) in noPersonConj else 5)
def getNumberOSM(w): return extractFeature(F.osm.v(w), 5 if getConjOSM(w) in noPersonConj else 6)

def getStemBHS(w): return getValue(F.vs.v(w))
def getStemBHSX(w): return stemMapBHS.get(getStemBHS(w), '?')
def getConjBHS(w): return getValue(F.vt.v(w))
def getConjBHSX(w): return conjMapBHS.get(getConjBHS(w), '?')
def getPersonBHS(w): return getValueTail(F.ps.v(w))
def getGenderBHS(w): return getValue(F.gn.v(w))
def getNumberBHS(w): return getValueHead(F.nu.v(w))

def getVerbBHS(w):
    return '{}-{}-{}{}{}'.format(
        getStemBHSX(w),
        getConjBHSX(w),
        getPersonBHS(w),
        getGenderBHS(w),
        getNumberBHS(w),
    )

def getVerbOSM(w):
    return '{}-{}-{}{}{}'.format(
        getStemOSMX(w),
        getConjOSMX(w),
        getPersonOSM(w),
        getGenderOSM(w),
        getNumberOSM(w),
    )

def getBHS(w): return F.sp.v(w)
def getOSM(w): return F.osm.v(w)

# %% [markdown]
# # Mappings
#
# We collect the numbers of cooccurrences of OSM stems and BHSA values for each verb feature,
# and see how they compare.

# %%
closerLook = set()

# %%
def showFeatures():
    cases = set()
    mappings = {}

    def makeMap(key, getBHS, getOSM):
        BHSFromOSM = {}
        OSMFromBHS = {}

        for w in verbBase:
            osm = getOSM(w)
            bhs = getBHS(w)
            BHSFromOSM.setdefault(osm, {}).setdefault(bhs, set()).add(w)
            OSMFromBHS.setdefault(bhs, {}).setdefault(osm, set()).add(w)
        mappings.setdefault(key, {})[True] = BHSFromOSM
        mappings.setdefault(key, {})[False] = OSMFromBHS

    def showMap(key, direction):
        dirLabel = 'OSM ===> BHS' if direction else 'BHS ===> OSM'
        print('''
---------------------------------------------------------------------------------
--- {} {}
---------------------------------------------------------------------------------
'''.format(key, dirLabel))
        cases = set()
        for (item, itemData) in sorted(mappings[key][direction].items()):
            print('{:<10}'.format(item))
            first = True
            for (itemOther, ws) in sorted(itemData.items(), key=lambda x: (-len(x[1]), x[0])):
                print('\t{:<15} ({:>5}x)'.format(itemOther, len(ws)))
                if not first and len(ws) < 100:
                    for w in sorted(ws):
                        show(T, F, [w], getVerbBHS, getVerbOSM, indent='\t\t\t\t')
                        cases.add(w)
                first = False
        print('\n{} ({}): {} cases'.format(key, dirLabel, len(cases)))
        return cases
    
    def showFeature(key):
        cases = set()
        print('''
o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
o-o COMPARING FEATURE {}
o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
'''.format(key))
        for direction in (True, False):
            theseCases = showMap(key, direction)
            cases |= theseCases
        print('\n{}: {} cases'.format(key, len(cases)))
        return cases
    
    for (key, getBHS, getOSM) in (
        ('stem', getStemBHSX, getStemOSMX),
        ('conjugation', getConjBHSX, getConjOSMX),
        ('person', getPersonBHS, getPersonOSM),
        ('gender', getGenderBHS, getGenderOSM),
        ('number', getNumberBHS, getNumberOSM),
    ):
        makeMap(key, getBHS, getOSM)
        cases |= showFeature(key)
    print('\n{}: {} cases'.format('All features', len(cases)))

    return cases

# %% [markdown]
# ## in BHSA but not in OSM

# %%
extraBHS = verbsBHSfocus - verbsOSM

print('Marked as verb in BHSA but not in OSM: {:>3}'.format(len(extraBHS)))
for w in sorted(extraBHS):
    show(T, F, [w], getVerbBHS, getOSM, indent='\t')
# Out:
# Marked as verb in BHSA but not in OSM:  52
# 	Numbers 7:13 w74146 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:14 w74158 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:19 w74228 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:20 w74240 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:25 w74309 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:26 w74321 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:31 w74390 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:32 w74402 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:37 w74471 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:38 w74483 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:43 w74552 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:44 w74564 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:49 w74633 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:50 w74645 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:55 w74714 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:56 w74726 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:61 w74795 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:62 w74807 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:67 w74876 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:68 w74888 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:73 w74957 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:74 w74969 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:79 w75038 "מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:80 w75050 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:86 w75143 "מְלֵאֹ֣ת"
# 		BHS: qal-part act-?fp
# 		OSM: HAafpa
# 	Deuteronomy 6:11 w97154 "מְלֵאִ֣ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Deuteronomy 33:23 w112581 "מָלֵ֖א"
# 		BHS: qal-part act-?ms
# 		OSM: HAamsa
# 	Deuteronomy 34:9 w112843 "מָלֵא֙"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Judges 4:11 w129619 "חֹתֵ֣ן"
# 		BHS: qal-part act-?ms
# 		OSM: HNcmsc
# 	1_Kings 22:49 w194645 "עשׂר"
# 		BHS: qal-perfect-3ms
# 		OSM: HAcmsa
# 	Isaiah 3:26 w213275 "אָנ֥וּ"
# 		BHS: qal-perfect-3?p
# 		OSM: HD
# 	Isaiah 19:8 w218260 "אָנוּ֙"
# 		BHS: qal-perfect-3?p
# 		OSM: HD
# 	Jeremiah 9:24 w239863 "מ֖וּל"
# 		BHS: qal-part pass-?ms
# 		OSM: HR
# 	Ezekiel 10:12 w268650 "מְלֵאִ֤ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Ezekiel 37:1 w283222 "מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Hosea 2:9 w291267 "טֹ֥וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Hosea 9:7 w292903 "רַבָּ֖ה"
# 		BHS: qal-perfect-3fs
# 		OSM: HAafsa
# 	Hosea 10:1 w293076 "טֹ֣וב"
# 		BHS: qal-inf cons-???
# 		OSM: HAamsa
# 	Joel 4:3 w295061 "זֹּונָ֔ה"
# 		BHS: qal-part act-?fs
# 		OSM: HNcfsa
# 	Joel 4:14 w295245 "חָר֑וּץ"
# 		BHS: qal-part pass-?ms
# 		OSM: HNp
# 	Joel 4:14 w295253 "חָרֽוּץ"
# 		BHS: qal-part pass-?ms
# 		OSM: HNp
# 	Obadiah 1:3 w298206 "שִׁבְתֹּ֑ו"
# 		BHS: qal-inf cons-???
# 		OSM: HNcfsc
# 	Nahum 3:1 w301880 "מְלֵאָ֔ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Habakkuk 2:20 w302794 "הַ֥ס"
# 		BHS: piel-imperative-2ms
# 		OSM: HTj
# 	Zephaniah 1:7 w303207 "הַ֕ס"
# 		BHS: piel-imperative-2ms
# 		OSM: HTj
# 	Zephaniah 1:14 w303365 "קָרֹ֖וב"
# 		BHS: qal-inf abs-???
# 		OSM: HAamsa
# 	Zephaniah 1:14 w303367 "מַהֵ֣ר"
# 		BHS: piel-inf abs-???
# 		OSM: HAamsa
# 	Proverbs 3:13 w347564 "יָפִ֥יק"
# 		BHS: hiphil-imperfect-3ms
# 		OSM: HNcfsa
# 	Daniel 2:26 w371072 "חֲזֵ֖ית"
# 		BHS: peal-perfect-1?s
# 		OSM: ATr
# 	Daniel 6:20 w374320 "הִ֨תְבְּהָלָ֔ה"
# 		BHS: hithpeel-inf cons-???
# 		OSM: ANcfsa
# 	Daniel 6:23 w374385 "הִשְׁתְּכַ֣חַת"
# 		BHS: hithpeel-perfect-3fs
# 		OSM: ANcfsa
# 	1_Chronicles 11:13 w397260 "מְלֵאָ֣ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa

# %%
cases = extraBHS
closerLook |= cases
print('{} cases merged into {} closer look items'.format(len(cases), len(closerLook)))
# Out:
# 52 cases merged into 52 closer look items

# %% [markdown]
# ## in OSM but not in BHSA

# %%
extraOSM = verbsOSM - verbsBHSfocus

print('Marked as verb in OSM but not in BHSA: {:>3}'.format(len(extraOSM)))
for w in sorted(extraOSM):
    show(T, F, [w], getBHS, getVerbOSM, indent='\t')
# Out:
# Marked as verb in OSM but not in BHSA:  11
# 	1_Samuel 16:16 w150632 "טֹ֥וב"
# 		BHS: adjv
# 		OSM: qal-weqatal-3ms
# 	1_Samuel 16:23 w150776 "טֹ֣וב"
# 		BHS: adjv
# 		OSM: qal-perfect-3ms
# 	Hosea 2:3 w291153 "רֻחָֽמָה"
# 		BHS: nmpr
# 		OSM: pual-perfect-3fs
# 	Hosea 7:4 w292417 "אֹפֶ֑ה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Hosea 7:6 w292448 "אֹֽפֵהֶ֔ם"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Hosea 9:10 w292956 "אָהֳבָֽם"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Jonah 1:15 w298910 "זַּעְפֹּֽו"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Zephaniah 3:10 w303914 "פּוּצַ֔י"
# 		BHS: subs
# 		OSM: qal-part pass-_ms
# 	Ruth 2:1 w356231 "מידע"
# 		BHS: subs
# 		OSM: pual-part act-_ms
# 	Song_of_songs 2:13 w357957 "לכי"
# 		BHS: prep
# 		OSM: qal-imperative-2fs
# 	Song_of_songs 3:8 w358155 "אֲחֻ֣זֵי"
# 		BHS: adjv
# 		OSM: qal-part pass-_mp

# %%
cases = extraOSM
closerLook |= cases
print('{} cases merged into {} closer look items'.format(len(cases), len(closerLook)))
# Out:
# 11 cases merged into 63 closer look items

# %% [markdown]
# ## Common verb base
# The rest of the comparison is carried out for the *common verb base*, i.e. those words
# that have been marked as verb in the BHSA and in the OSM.

# %%
verbBase = verbsOSM & verbsBHSfocus
print('Common verb base: {} occurrences'.format(len(verbBase)))
# Out:
# Common verb base: 60074 occurrences

# %%
closerLook |= cases
print('{} cases merged into {} closer look items'.format(len(cases), len(closerLook)))
# Out:
# 11 cases merged into 63 closer look items

# %% [markdown]
# # Feature comparison
# We are going to compare all features.

# %%
cases = showFeatures()
# Out:
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
# o-o COMPARING FEATURE stem
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
#
#
# ---------------------------------------------------------------------------------
# --- stem OSM ===> BHS
# ---------------------------------------------------------------------------------
#
# aphel
# 	haphel          (   10x)
# 	aphel           (    2x)
# 				Daniel 3:1 w371620 "אֲקִימֵהּ֙"
# 					BHS: aphel-perfect-3ms
# 					OSM: aphel-perfect-3ms
# 				Daniel 4:11 w372572 "אַתַּ֥רוּ"
# 					BHS: aphel-imperative-2mp
# 					OSM: aphel-imperative-2mp
# haphel
# 	haphel          (   97x)
# 	hithpeel        (    1x)
# 				Daniel 2:9 w370704 "הזמנתון"
# 					BHS: hithpeel-perfect-2mp
# 					OSM: haphel-perfect-2mp
# 	peal            (    1x)
# 				Daniel 2:31 w371168 "חָזֵ֤ה"
# 					BHS: peal-part act-?ms
# 					OSM: haphel-part act-_ms
# hiphil
# 	hiphil          ( 7105x)
# 	qal             (    6x)
# 				Amos 2:13 w295902 "תָּעִיק֙"
# 					BHS: qal-imperfect-3fs
# 					OSM: hiphil-imperfect-3fs
# 				Nahum 3:8 w301983 "תֵֽיטְבִי֙"
# 					BHS: qal-imperfect-2fs
# 					OSM: hiphil-imperfect-2fs
# 				Habakkuk 2:3 w302496 "יָפֵ֥חַ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Zephaniah 1:2 w303100 "אָסֵ֜ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303109 "אָסֵ֨ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303113 "אָסֵ֤ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# hishtaphel
# 	hishtaphel      (   10x)
# hithpaal
# 	hithpaal        (   21x)
# 	etpaal          (    2x)
# 				Daniel 2:9 w370711 "יִשְׁתַּנֵּ֑א"
# 					BHS: etpaal-imperfect-3ms
# 					OSM: hithpaal-imperfect-3ms
# 				Daniel 5:10 w373383 "יִשְׁתַּנֹּֽו"
# 					BHS: etpaal-imperfect-3mp
# 					OSM: hithpaal-imperfect-3mp
# 	hithpeel        (    1x)
# 				Daniel 2:13 w370810 "הִתְקְטָלָֽה"
# 					BHS: hithpeel-inf cons-???
# 					OSM: hithpaal-inf cons-_??
# hithpael
# 	hithpael        (  560x)
# 	hishtaphel      (   76x)
# 				Genesis 18:2 w7840 "יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 19:1 w8447 "יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 23:7 w10836 "יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 23:12 w10939 "יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 24:26 w11610 "יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 24:52 w12150 "יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 33:3 w18134 "יִּשְׁתַּ֤חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 33:7 w18200 "יִּֽשְׁתַּחֲו֑וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 33:7 w18208 "יִּֽשְׁתַּחֲוֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 37:10 w20375 "הִשְׁתַּחֲוֹ֥ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Genesis 42:6 w23530 "יִּשְׁתַּֽחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 43:26 w24671 "יִּשְׁתַּחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 47:31 w27291 "יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 48:12 w27525 "יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Exodus 12:27 w35321 "יִּֽשְׁתַּחֲוּֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Exodus 18:7 w38589 "יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Exodus 32:8 w46672 "יִּשְׁתַּֽחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Exodus 34:8 w47946 "יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Leviticus 26:1 w68166 "הִֽשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Numbers 22:31 w84473 "יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Deuteronomy 17:3 w102990 "יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Joshua 5:14 w115318 "יִּשְׁתָּ֔חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Judges 2:12 w128461 "יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Judges 2:17 w128555 "יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Judges 7:15 w131827 "יִּשְׁתָּ֑חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 1:3 w141594 "הִֽשְׁתַּחֲוֹ֧ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				1_Samuel 1:19 w141906 "יִּֽשְׁתַּחֲווּ֙"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				1_Samuel 1:28 w142109 "יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 2:36 w142847 "הִשְׁתַּחֲוֹ֣ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				1_Samuel 15:31 w150180 "יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 20:41 w154309 "יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 24:9 w156186 "יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 28:14 w158834 "יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 1:2 w160520 "יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 9:6 w165079 "יִּשְׁתָּ֑חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 9:8 w165119 "יִּשְׁתַּ֕חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 12:20 w166858 "יִּשְׁתָּ֑חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 14:22 w168578 "יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 14:33 w168862 "יִּשְׁתַּ֨חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 15:5 w168985 "הִשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				2_Samuel 18:21 w171619 "יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 18:28 w171796 "יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 24:20 w175929 "יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 1:23 w176553 "יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 1:47 w177136 "יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 1:53 w177264 "יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 2:19 w177686 "יִּשְׁתַּ֣חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 11:33 w185697 "יִּֽשְׁתַּחֲווּ֮"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				1_Kings 16:31 w189746 "יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Kings 2:15 w195621 "יִּשְׁתַּחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Kings 5:18 w197908 "הִשְׁתַּחֲוֹ֨ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				2_Kings 17:16 w205929 "יִּֽשְׁתַּחֲווּ֙"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Kings 21:3 w208740 "יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Kings 21:21 w209149 "יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Isaiah 2:20 w212868 "הִֽשְׁתַּחֲוֹ֔ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Isaiah 44:15 w227625 "יִּשְׁתָּ֔חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Isaiah 66:23 w234971 "הִשְׁתַּחֲוֹ֥ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Jeremiah 1:16 w235287 "יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Jeremiah 7:2 w238233 "הִֽשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Jeremiah 16:11 w242883 "יִּשְׁתַּחֲו֣וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Jeremiah 22:9 w245497 "יִּֽשְׁתַּחֲו֛וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Jeremiah 26:2 w247884 "הִשְׁתַּחֲוֹ֣ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Ezekiel 46:9 w289269 "הִֽשְׁתַּחֲוֹ֗ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Zechariah 14:16 w309314 "הִֽשְׁתַּחֲוֹת֙"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Zechariah 14:17 w309339 "הִֽשְׁתַּחֲוֹ֔ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Psalms 106:19 w329149 "יִּשְׁתַּחֲו֗וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Job 1:20 w336492 "יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Chronicles 21:21 w402289 "יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Chronicles 29:20 w406593 "יִּֽשְׁתַּחֲו֛וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 7:3 w410077 "יִּֽשְׁתַּֽחֲו֔וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 7:22 w410593 "יִּשְׁתַּחֲו֥וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 20:18 w416385 "הִֽשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				2_Chronicles 24:17 w418626 "יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 29:29 w421648 "יִּֽשְׁתַּחֲוֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 29:30 w421679 "יִּֽשְׁתַּחֲוֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 33:3 w423935 "יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# hithpalpel
# 	hithpael        (    3x)
# hithpeel
# 	hithpeel        (   24x)
# hithpolel
# 	hithpael        (    8x)
# hophal
# 	hophal          (  220x)
# hothpaal
# 	hothpaal        (    6x)
# ithpaal
# 	etpaal          (    2x)
# ithpeel
# 	etpeel          (    2x)
# ithpoel
# 	etpaal          (    1x)
# niphal
# 	niphal          ( 3148x)
# 	piel            (    1x)
# 				Song_of_songs 1:6 w357660 "נִֽחֲרוּ"
# 					BHS: piel-perfect-3?p
# 					OSM: niphal-perfect-3cp
# nithpael
# 	nithpael        (    1x)
# pael
# 	pael            (   56x)
# peal
# 	peal            (  494x)
# 	pael            (    1x)
# 				Daniel 2:40 w371363 "מְרָעַ֥ע"
# 					BHS: pael-part act-?ms
# 					OSM: peal-part act-_ms
# 	peil            (    1x)
# 				Daniel 6:27 w374479 "שִׂ֣ים"
# 					BHS: peil-perfect-3ms
# 					OSM: peal-perfect-3ms
# peil
# 	peil            (   25x)
# 	peal            (   12x)
# 				Daniel 2:9 w370703 "שְׁחִיתָה֙"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 2:31 w371186 "דְּחִֽיל"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Daniel 2:41 w371383 "פְלִיגָה֙"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 2:42 w371418 "תְבִירָֽה"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 3:25 w372167 "שְׁרַ֨יִן֙"
# 					BHS: peal-part pass-?mp
# 					OSM: peil-part pass-_mp
# 				Daniel 3:28 w372256 "בְּרִ֤יךְ"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Daniel 4:32 w373085 "חֲשִׁיבִ֔ין"
# 					BHS: peal-part pass-?mp
# 					OSM: peil-part pass-_mp
# 				Daniel 6:4 w373905 "עֲשִׁ֔ית"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Daniel 6:5 w373929 "שְׁחִיתָ֜ה"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 6:5 w373944 "שְׁחִיתָ֔ה"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 6:11 w374063 "פְּתִיחָ֥ן"
# 					BHS: peal-part pass-?fp
# 					OSM: peil-part pass-_fp
# 				Daniel 6:13 w374108 "קְרִ֨יבוּ"
# 					BHS: peal-perfect-3mp
# 					OSM: peil-perfect-3mp
# piel
# 	piel            ( 5061x)
# pilpel
# 	piel            (    3x)
# poal
# 	piel            (    1x)
# poel
# 	piel            (    7x)
# 	poel            (    1x)
# 				Hosea 13:3 w293749 "יְסֹעֵ֣ר"
# 					BHS: poel-imperfect-3ms
# 					OSM: poel-imperfect-3ms
# 	qal             (    1x)
# 				Amos 5:11 w296674 "בֹּושַׁסְכֶ֞ם"
# 					BHS: qal-inf cons-???
# 					OSM: poel-inf cons-_??
# polel
# 	piel            (   12x)
# 	pael            (    1x)
# 				Daniel 4:34 w373142 "מְרֹומֵ֤ם"
# 					BHS: pael-part act-?ms
# 					OSM: polel-part act-_ms
# pual
# 	pual            (  227x)
# pulal
# 	pual            (    5x)
# qal
# 	qal             (42838x)
# 	piel            (    3x)
# 				Judges 5:13 w130129 "יְרַ֣ד"
# 					BHS: piel-imperfect-3ms
# 					OSM: qal-perfect-3ms
# 				Judges 5:13 w130135 "יְרַד"
# 					BHS: piel-imperfect-3ms
# 					OSM: qal-perfect-3ms
# 				Song_of_songs 1:10 w357722 "נָאו֤וּ"
# 					BHS: piel-perfect-3?p
# 					OSM: qal-perfect-3cp
# 	hiphil          (    2x)
# 				Joel 4:1 w295015 "אשׁוב"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Jonah 4:6 w299394 "יַּ֣עַל"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# 	niphal          (    1x)
# 				Judges 5:5 w130015 "נָזְל֖וּ"
# 					BHS: niphal-perfect-3?p
# 					OSM: qal-perfect-3cp
# qalpassive
# 	pual            (    2x)
# 	hophal          (    1x)
# 				Hosea 10:14 w293285 "יוּשַּׁ֔ד"
# 					BHS: hophal-imperfect-3ms
# 					OSM: qalpassive-imperfect-3ms
# 	qal             (    1x)
# 				Song_of_songs 7:3 w358899 "סוּגָ֖ה"
# 					BHS: qal-part pass-?fs
# 					OSM: qalpassive-part act-_fs
# shaphel
# 	shaphel         (    9x)
# tiphil
# 	tiphal          (    1x)
#
# stem (OSM ===> BHS): 115 cases
#
# ---------------------------------------------------------------------------------
# --- stem BHS ===> OSM
# ---------------------------------------------------------------------------------
#
# aphel
# 	aphel           (    2x)
# etpaal
# 	hithpaal        (    2x)
# 	ithpaal         (    2x)
# 				Daniel 3:19 w372027 "אשׁתנו"
# 					BHS: etpaal-perfect-3ms
# 					OSM: ithpaal-perfect-3ms
# 				Daniel 6:8 w373983 "אִתְיָעַ֜טוּ"
# 					BHS: etpaal-perfect-3mp
# 					OSM: ithpaal-perfect-3mp
# 	ithpoel         (    1x)
# 				Daniel 4:16 w372694 "אֶשְׁתֹּומַם֙"
# 					BHS: etpaal-perfect-3ms
# 					OSM: ithpoel-perfect-3ms
# etpeel
# 	ithpeel         (    2x)
# haphel
# 	haphel          (   97x)
# 	aphel           (   10x)
# 				Daniel 2:44 w371453 "יְקִים֩"
# 					BHS: haphel-imperfect-3ms
# 					OSM: aphel-imperfect-3ms
# 				Daniel 3:22 w372096 "מַחְצְפָ֔ה"
# 					BHS: haphel-part act-?fs
# 					OSM: aphel-part act-_fs
# 				Daniel 3:25 w372168 "מַהְלְכִ֣ין"
# 					BHS: haphel-part act-?mp
# 					OSM: aphel-part act-_mp
# 				Daniel 4:9 w372532 "תַּטְלֵ֣ל"
# 					BHS: haphel-imperfect-3fs
# 					OSM: aphel-imperfect-3fs
# 				Daniel 4:14 w372656 "יְקִ֥ים"
# 					BHS: haphel-imperfect-3ms
# 					OSM: aphel-imperfect-3ms
# 				Daniel 4:34 w373157 "מַהְלְכִ֣ין"
# 					BHS: haphel-part act-?mp
# 					OSM: aphel-part act-_mp
# 				Daniel 6:9 w374023 "תְּקִ֥ים"
# 					BHS: haphel-imperfect-2ms
# 					OSM: aphel-imperfect-2ms
# 				Daniel 6:11 w374081 "מֹודֵא֙"
# 					BHS: haphel-part act-?ms
# 					OSM: aphel-part act-_ms
# 				Daniel 6:28 w374514 "מַצִּ֗ל"
# 					BHS: haphel-part act-?ms
# 					OSM: aphel-part act-_ms
# 				Daniel 7:2 w374581 "מְגִיחָ֖ן"
# 					BHS: haphel-part act-?fp
# 					OSM: aphel-part act-_fp
# hiphil
# 	hiphil          ( 7105x)
# 	qal             (    2x)
# 				Joel 4:1 w295015 "אשׁוב"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Jonah 4:6 w299394 "יַּ֣עַל"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# hishtaphel
# 	hithpael        (   76x)
# 	hishtaphel      (   10x)
# 				Judges 2:19 w128623 "הִשְׁתַּחֲוֹ֣ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hishtaphel-inf cons-_??
# 				1_Samuel 25:23 w157022 "תִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3fs
# 					OSM: hishtaphel-wayyiqtol-3fs
# 				1_Samuel 25:41 w157481 "תִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3fs
# 					OSM: hishtaphel-wayyiqtol-3fs
# 				1_Kings 1:16 w176411 "תִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3fs
# 					OSM: hishtaphel-wayyiqtol-3fs
# 				1_Kings 1:31 w176736 "תִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3fs
# 					OSM: hishtaphel-wayyiqtol-3fs
# 				2_Kings 4:37 w197260 "תִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3fs
# 					OSM: hishtaphel-wayyiqtol-3fs
# 				Zephaniah 1:5 w303170 "מִּשְׁתַּחֲוִ֥ים"
# 					BHS: hishtaphel-part act-?mp
# 					OSM: hishtaphel-part act-_mp
# 				Zephaniah 1:5 w303181 "מִּֽשְׁתַּחֲוִים֙"
# 					BHS: hishtaphel-part act-?mp
# 					OSM: hishtaphel-part act-_mp
# 				Zephaniah 2:11 w303659 "יִשְׁתַּֽחֲווּ"
# 					BHS: hishtaphel-imperfect-3mp
# 					OSM: hishtaphel-imperfect-3mp
# 				Ruth 2:10 w356441 "תִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3fs
# 					OSM: hishtaphel-wayyiqtol-3fs
# hithpaal
# 	hithpaal        (   21x)
# hithpael
# 	hithpael        (  560x)
# 	hithpolel       (    8x)
# 				Hosea 7:8 w292476 "יִתְבֹּולָ֑ל"
# 					BHS: hithpael-imperfect-3ms
# 					OSM: hithpolel-imperfect-3ms
# 				Hosea 7:14 w292575 "יִתְגֹּורָ֖רוּ"
# 					BHS: hithpael-imperfect-3mp
# 					OSM: hithpolel-imperfect-3mp
# 				Hosea 9:11 w292961 "יִתְעֹופֵ֣ף"
# 					BHS: hithpael-imperfect-3ms
# 					OSM: hithpolel-imperfect-3ms
# 				Amos 9:13 w298119 "תִּתְמֹוגַֽגְנָה"
# 					BHS: hithpael-imperfect-3fp
# 					OSM: hithpolel-imperfect-3fp
# 				Nahum 1:5 w301507 "הִתְמֹגָ֑גוּ"
# 					BHS: hithpael-perfect-3?p
# 					OSM: hithpolel-perfect-3cp
# 				Nahum 2:5 w301714 "יִתְהֹולְל֣וּ"
# 					BHS: hithpael-imperfect-3mp
# 					OSM: hithpolel-imperfect-3mp
# 				Habakkuk 3:6 w302875 "יִּתְפֹּֽצְצוּ֙"
# 					BHS: hithpael-wayyiqtol-3mp
# 					OSM: hithpolel-wayyiqtol-3mp
# 				Zephaniah 2:1 w303468 "הִֽתְקֹושְׁשׁ֖וּ"
# 					BHS: hithpael-imperative-2mp
# 					OSM: hithpolel-imperative-2mp
# 	hithpalpel      (    3x)
# 				Judges 3:26 w129257 "הִֽתְמַהְמְהָ֑ם"
# 					BHS: hithpael-inf cons-???
# 					OSM: hithpalpel-inf cons-_??
# 				Nahum 2:5 w301717 "יִֽשְׁתַּקְשְׁק֖וּן"
# 					BHS: hithpael-imperfect-3mp
# 					OSM: hithpalpel-imperfect-3mp
# 				Habakkuk 2:3 w302504 "יִתְמַהְמָהּ֙"
# 					BHS: hithpael-imperfect-3ms
# 					OSM: hithpalpel-imperfect-3ms
# hithpeel
# 	hithpeel        (   24x)
# 	haphel          (    1x)
# 				Daniel 2:9 w370704 "הזמנתון"
# 					BHS: hithpeel-perfect-2mp
# 					OSM: haphel-perfect-2mp
# 	hithpaal        (    1x)
# 				Daniel 2:13 w370810 "הִתְקְטָלָֽה"
# 					BHS: hithpeel-inf cons-???
# 					OSM: hithpaal-inf cons-_??
# hophal
# 	hophal          (  220x)
# 	qalpassive      (    1x)
# 				Hosea 10:14 w293285 "יוּשַּׁ֔ד"
# 					BHS: hophal-imperfect-3ms
# 					OSM: qalpassive-imperfect-3ms
# hothpaal
# 	hothpaal        (    6x)
# niphal
# 	niphal          ( 3148x)
# 	qal             (    1x)
# 				Judges 5:5 w130015 "נָזְל֖וּ"
# 					BHS: niphal-perfect-3?p
# 					OSM: qal-perfect-3cp
# nithpael
# 	nithpael        (    1x)
# pael
# 	pael            (   56x)
# 	peal            (    1x)
# 				Daniel 2:40 w371363 "מְרָעַ֥ע"
# 					BHS: pael-part act-?ms
# 					OSM: peal-part act-_ms
# 	polel           (    1x)
# 				Daniel 4:34 w373142 "מְרֹומֵ֤ם"
# 					BHS: pael-part act-?ms
# 					OSM: polel-part act-_ms
# peal
# 	peal            (  494x)
# 	peil            (   12x)
# 				Daniel 2:9 w370703 "שְׁחִיתָה֙"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 2:31 w371186 "דְּחִֽיל"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Daniel 2:41 w371383 "פְלִיגָה֙"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 2:42 w371418 "תְבִירָֽה"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 3:25 w372167 "שְׁרַ֨יִן֙"
# 					BHS: peal-part pass-?mp
# 					OSM: peil-part pass-_mp
# 				Daniel 3:28 w372256 "בְּרִ֤יךְ"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Daniel 4:32 w373085 "חֲשִׁיבִ֔ין"
# 					BHS: peal-part pass-?mp
# 					OSM: peil-part pass-_mp
# 				Daniel 6:4 w373905 "עֲשִׁ֔ית"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Daniel 6:5 w373929 "שְׁחִיתָ֜ה"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 6:5 w373944 "שְׁחִיתָ֔ה"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 6:11 w374063 "פְּתִיחָ֥ן"
# 					BHS: peal-part pass-?fp
# 					OSM: peil-part pass-_fp
# 				Daniel 6:13 w374108 "קְרִ֨יבוּ"
# 					BHS: peal-perfect-3mp
# 					OSM: peil-perfect-3mp
# 	haphel          (    1x)
# 				Daniel 2:31 w371168 "חָזֵ֤ה"
# 					BHS: peal-part act-?ms
# 					OSM: haphel-part act-_ms
# peil
# 	peil            (   25x)
# 	peal            (    1x)
# 				Daniel 6:27 w374479 "שִׂ֣ים"
# 					BHS: peil-perfect-3ms
# 					OSM: peal-perfect-3ms
# piel
# 	piel            ( 5061x)
# 	polel           (   12x)
# 				Judges 5:28 w130362 "בֹּשֵׁ֤שׁ"
# 					BHS: piel-perfect-3ms
# 					OSM: polel-perfect-3ms
# 				Hosea 7:5 w292435 "לֹצְצִֽים"
# 					BHS: piel-part act-?mp
# 					OSM: polel-part act-_mp
# 				Hosea 11:7 w293406 "יְרֹומֵם"
# 					BHS: piel-imperfect-3ms
# 					OSM: polel-imperfect-3ms
# 				Amos 8:12 w297750 "יְשֹֽׁוטְט֛וּ"
# 					BHS: piel-imperfect-3mp
# 					OSM: polel-imperfect-3mp
# 				Nahum 2:5 w301728 "יְרֹוצֵֽצוּ"
# 					BHS: piel-imperfect-3mp
# 					OSM: polel-imperfect-3mp
# 				Habakkuk 2:12 w302659 "כֹונֵ֥ן"
# 					BHS: piel-perfect-3ms
# 					OSM: polel-weqatal-3ms
# 				Habakkuk 3:6 w302868 "יְמֹ֣דֶד"
# 					BHS: piel-wayyiqtol-3ms
# 					OSM: polel-wayyiqtol-3ms
# 				Zephaniah 2:14 w303709 "יְשֹׁורֵ֤ר"
# 					BHS: piel-imperfect-3ms
# 					OSM: polel-imperfect-3ms
# 				Song_of_songs 2:7 w357865 "תְּעֹֽורְר֛וּ"
# 					BHS: piel-imperfect-2mp
# 					OSM: polel-imperfect-2mp
# 				Song_of_songs 3:5 w358118 "תְּעֹֽורְר֛וּ"
# 					BHS: piel-imperfect-2mp
# 					OSM: polel-imperfect-2mp
# 				Song_of_songs 8:4 w359094 "תְּעֹֽרְר֛וּ"
# 					BHS: piel-imperfect-2mp
# 					OSM: polel-imperfect-2mp
# 				Song_of_songs 8:5 w359113 "עֹֽורַרְתִּ֔יךָ"
# 					BHS: piel-perfect-1?s
# 					OSM: polel-perfect-1cs
# 	poel            (    7x)
# 				Judges 5:14 w130152 "מְחֹ֣קְקִ֔ים"
# 					BHS: piel-part act-?mp
# 					OSM: poel-part act-_mp
# 				Hosea 10:2 w293088 "יְשֹׁדֵ֖ד"
# 					BHS: piel-imperfect-3ms
# 					OSM: poel-imperfect-3ms
# 				Jonah 2:4 w298982 "יְסֹבְבֵ֑נִי"
# 					BHS: piel-imperfect-3ms
# 					OSM: poel-imperfect-3ms
# 				Jonah 2:6 w299008 "יְסֹבְבֵ֑נִי"
# 					BHS: piel-imperfect-3ms
# 					OSM: poel-imperfect-3ms
# 				Nahum 2:8 w301758 "מְתֹפְפֹ֖ת"
# 					BHS: piel-part act-?fp
# 					OSM: poel-part act-_fp
# 				Proverbs 26:10 w354112 "מְחֹֽולֵֽל"
# 					BHS: piel-part act-?ms
# 					OSM: poel-part act-_ms
# 				Song_of_songs 3:2 w358044 "אֲסֹובְבָ֣ה"
# 					BHS: piel-imperfect-1?s
# 					OSM: poel-cohortative-1cs
# 	pilpel          (    3x)
# 				Habakkuk 2:7 w302590 "מְזַעְזְעֶ֑יךָ"
# 					BHS: piel-part act-?mp
# 					OSM: pilpel-part act-_mp
# 				Malachi 3:2 w310175 "מְכַלְכֵּל֙"
# 					BHS: piel-part act-?ms
# 					OSM: pilpel-part act-_ms
# 				Ruth 4:15 w357495 "כַלְכֵּ֖ל"
# 					BHS: piel-inf cons-???
# 					OSM: pilpel-inf cons-_??
# 	qal             (    3x)
# 				Judges 5:13 w130129 "יְרַ֣ד"
# 					BHS: piel-imperfect-3ms
# 					OSM: qal-perfect-3ms
# 				Judges 5:13 w130135 "יְרַד"
# 					BHS: piel-imperfect-3ms
# 					OSM: qal-perfect-3ms
# 				Song_of_songs 1:10 w357722 "נָאו֤וּ"
# 					BHS: piel-perfect-3?p
# 					OSM: qal-perfect-3cp
# 	niphal          (    1x)
# 				Song_of_songs 1:6 w357660 "נִֽחֲרוּ"
# 					BHS: piel-perfect-3?p
# 					OSM: niphal-perfect-3cp
# 	poal            (    1x)
# 				Nahum 3:17 w302142 "נֹודַ֔ד"
# 					BHS: piel-perfect-3ms
# 					OSM: poal-perfect-3ms
# poel
# 	poel            (    1x)
# pual
# 	pual            (  227x)
# 	pulal           (    5x)
# 				Hosea 4:3 w291736 "אֻמְלַל֙"
# 					BHS: pual-perfect-3ms
# 					OSM: pulal-weqatal-3ms
# 				Joel 1:10 w294200 "אֻמְלַ֥ל"
# 					BHS: pual-perfect-3ms
# 					OSM: pulal-perfect-3ms
# 				Joel 1:12 w294221 "אֻמְלָ֑לָה"
# 					BHS: pual-perfect-3fs
# 					OSM: pulal-perfect-3fs
# 				Nahum 1:4 w301493 "אֻמְלַ֤ל"
# 					BHS: pual-perfect-3ms
# 					OSM: pulal-perfect-3ms
# 				Nahum 1:4 w301500 "אֻמְלָֽל"
# 					BHS: pual-perfect-3ms
# 					OSM: pulal-perfect-3ms
# 	qalpassive      (    2x)
# 				Nahum 1:10 w301582 "אֻ֨כְּל֔וּ"
# 					BHS: pual-perfect-3?p
# 					OSM: qalpassive-perfect-3cp
# 				Zephaniah 1:17 w303428 "שֻׁפַּ֤ךְ"
# 					BHS: pual-perfect-3ms
# 					OSM: qalpassive-weqatal-3ms
# qal
# 	qal             (42838x)
# 	hiphil          (    6x)
# 				Amos 2:13 w295902 "תָּעִיק֙"
# 					BHS: qal-imperfect-3fs
# 					OSM: hiphil-imperfect-3fs
# 				Nahum 3:8 w301983 "תֵֽיטְבִי֙"
# 					BHS: qal-imperfect-2fs
# 					OSM: hiphil-imperfect-2fs
# 				Habakkuk 2:3 w302496 "יָפֵ֥חַ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Zephaniah 1:2 w303100 "אָסֵ֜ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303109 "אָסֵ֨ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303113 "אָסֵ֤ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 	poel            (    1x)
# 				Amos 5:11 w296674 "בֹּושַׁסְכֶ֞ם"
# 					BHS: qal-inf cons-???
# 					OSM: poel-inf cons-_??
# 	qalpassive      (    1x)
# 				Song_of_songs 7:3 w358899 "סוּגָ֖ה"
# 					BHS: qal-part pass-?fs
# 					OSM: qalpassive-part act-_fs
# shaphel
# 	shaphel         (    9x)
# tiphal
# 	tiphil          (    1x)
#
# stem (BHS ===> OSM): 98 cases
#
# stem: 179 cases
#
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
# o-o COMPARING FEATURE conjugation
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
#
#
# ---------------------------------------------------------------------------------
# --- conjugation OSM ===> BHS
# ---------------------------------------------------------------------------------
#
# cohortative
# 	imperfect       (  413x)
# imperative
# 	imperative      ( 3794x)
# 	inf abs         (    4x)
# 				Nahum 2:2 w301671 "צַפֵּה"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301673 "חַזֵּ֣ק"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301675 "אַמֵּ֥ץ"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Proverbs 25:2 w353721 "הַסְתֵּ֣ר"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# 	perfect         (    2x)
# 				Joel 1:11 w294202 "הֹבִ֣ישׁוּ"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 				Joel 1:11 w294204 "הֵילִ֨ילוּ֙"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 	inf cons        (    1x)
# 				Amos 9:1 w297813 "בְצַ֨עַם֙"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# imperfect
# 	imperfect       (10127x)
# 	part act        (    4x)
# 				Zephaniah 1:2 w303100 "אָסֵ֜ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303109 "אָסֵ֨ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303113 "אָסֵ֤ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Daniel 3:17 w371986 "יָכִ֖ל"
# 					BHS: peal-part act-?ms
# 					OSM: peal-imperfect-3ms
# inf abs
# 	inf abs         (  647x)
# 	inf cons        (    2x)
# 				Habakkuk 3:13 w302969 "עָרֹ֛ות"
# 					BHS: piel-inf cons-???
# 					OSM: piel-inf abs-_??
# 				Ruth 2:16 w356588 "שֹׁל"
# 					BHS: qal-inf cons-???
# 					OSM: qal-inf abs-_??
# 	imperative      (    1x)
# 				Amos 4:5 w296306 "קַטֵּ֤ר"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
# inf cons
# 	inf cons        ( 5623x)
# 	part act        (    1x)
# 				Hosea 6:9 w292336 "חַכֵּ֨י"
# 					BHS: piel-part act-?mp
# 					OSM: piel-inf cons-_??
# jussive
# 	imperfect       (  691x)
# part act
# 	part act        ( 6610x)
# 	part pass       (    5x)
# 				Habakkuk 1:4 w302239 "מְעֻקָּֽל"
# 					BHS: pual-part pass-?ms
# 					OSM: pual-part act-_ms
# 				Song_of_songs 3:6 w358134 "מְקֻטֶּ֤רֶת"
# 					BHS: pual-part pass-?fs
# 					OSM: pual-part act-_fs
# 				Song_of_songs 3:8 w358157 "מְלֻמְּדֵ֖י"
# 					BHS: pual-part pass-?mp
# 					OSM: pual-part act-_mp
# 				Song_of_songs 7:3 w358899 "סוּגָ֖ה"
# 					BHS: qal-part pass-?fs
# 					OSM: qalpassive-part act-_fs
# 				Daniel 3:24 w372151 "מְכַפְּתִ֔ין"
# 					BHS: pael-part pass-?mp
# 					OSM: pael-part act-_mp
# 	perfect         (    5x)
# 				Ruth 2:4 w356297 "בָּ֚א"
# 					BHS: qal-perfect-3ms
# 					OSM: qal-part act-_ms
# 				Ruth 2:6 w356343 "שָּׁ֥בָה"
# 					BHS: qal-perfect-3fs
# 					OSM: qal-part act-_fs
# 				Daniel 2:24 w371012 "אֲזַ֣ל"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 				Daniel 2:24 w371015 "אֲמַר"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 				Daniel 6:15 w374193 "בְּאֵ֣שׁ"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# part pass
# 	part pass       (  861x)
# 	part act        (    3x)
# 				Malachi 2:9 w309940 "נִבְזִ֥ים"
# 					BHS: niphal-part act-?mp
# 					OSM: niphal-part pass-_mp
# 				Daniel 2:43 w371427 "מִתְעָרְבִ֤ין"
# 					BHS: hithpaal-part act-?mp
# 					OSM: hithpaal-part pass-_mp
# 				Daniel 5:6 w373281 "מִשְׁתָּרַ֔יִן"
# 					BHS: hithpaal-part act-?mp
# 					OSM: hithpaal-part pass-_mp
# perfect
# 	perfect         (13719x)
# 	imperfect       (    3x)
# 				Judges 5:13 w130129 "יְרַ֣ד"
# 					BHS: piel-imperfect-3ms
# 					OSM: qal-perfect-3ms
# 				Judges 5:13 w130135 "יְרַד"
# 					BHS: piel-imperfect-3ms
# 					OSM: qal-perfect-3ms
# 				Daniel 4:14 w372651 "יִצְבֵּא֙"
# 					BHS: peal-imperfect-3ms
# 					OSM: peal-perfect-3ms
# 	inf cons        (    1x)
# 				Hosea 11:3 w293343 "קָחָ֖ם"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 	part act        (    1x)
# 				Jonah 1:9 w298764 "יָרֵ֔א"
# 					BHS: qal-part act-?ms
# 					OSM: qal-perfect-3ms
# wayyiqtol
# 	wayyiqtol       (13945x)
# 	imperfect       (    1x)
# 				Hosea 14:9 w294037 "אֲשׁוּרֶ֗נּוּ"
# 					BHS: qal-imperfect-1?s
# 					OSM: qal-wayyiqtol-1cs
# weqatal
# 	perfect         ( 3610x)
#
# conjugation (OSM ===> BHS): 34 cases
#
# ---------------------------------------------------------------------------------
# --- conjugation BHS ===> OSM
# ---------------------------------------------------------------------------------
#
# imperative
# 	imperative      ( 3794x)
# 	inf abs         (    1x)
# 				Amos 4:5 w296306 "קַטֵּ֤ר"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
# imperfect
# 	imperfect       (10127x)
# 	jussive         (  691x)
# 	cohortative     (  413x)
# 	perfect         (    3x)
# 				Judges 5:13 w130129 "יְרַ֣ד"
# 					BHS: piel-imperfect-3ms
# 					OSM: qal-perfect-3ms
# 				Judges 5:13 w130135 "יְרַד"
# 					BHS: piel-imperfect-3ms
# 					OSM: qal-perfect-3ms
# 				Daniel 4:14 w372651 "יִצְבֵּא֙"
# 					BHS: peal-imperfect-3ms
# 					OSM: peal-perfect-3ms
# 	wayyiqtol       (    1x)
# 				Hosea 14:9 w294037 "אֲשׁוּרֶ֗נּוּ"
# 					BHS: qal-imperfect-1?s
# 					OSM: qal-wayyiqtol-1cs
# inf abs
# 	inf abs         (  647x)
# 	imperative      (    4x)
# 				Nahum 2:2 w301671 "צַפֵּה"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301673 "חַזֵּ֣ק"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301675 "אַמֵּ֥ץ"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Proverbs 25:2 w353721 "הַסְתֵּ֣ר"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# inf cons
# 	inf cons        ( 5623x)
# 	inf abs         (    2x)
# 				Habakkuk 3:13 w302969 "עָרֹ֛ות"
# 					BHS: piel-inf cons-???
# 					OSM: piel-inf abs-_??
# 				Ruth 2:16 w356588 "שֹׁל"
# 					BHS: qal-inf cons-???
# 					OSM: qal-inf abs-_??
# 	imperative      (    1x)
# 				Amos 9:1 w297813 "בְצַ֨עַם֙"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 	perfect         (    1x)
# 				Hosea 11:3 w293343 "קָחָ֖ם"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# part act
# 	part act        ( 6610x)
# 	imperfect       (    4x)
# 				Zephaniah 1:2 w303100 "אָסֵ֜ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303109 "אָסֵ֨ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303113 "אָסֵ֤ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Daniel 3:17 w371986 "יָכִ֖ל"
# 					BHS: peal-part act-?ms
# 					OSM: peal-imperfect-3ms
# 	part pass       (    3x)
# 				Malachi 2:9 w309940 "נִבְזִ֥ים"
# 					BHS: niphal-part act-?mp
# 					OSM: niphal-part pass-_mp
# 				Daniel 2:43 w371427 "מִתְעָרְבִ֤ין"
# 					BHS: hithpaal-part act-?mp
# 					OSM: hithpaal-part pass-_mp
# 				Daniel 5:6 w373281 "מִשְׁתָּרַ֔יִן"
# 					BHS: hithpaal-part act-?mp
# 					OSM: hithpaal-part pass-_mp
# 	inf cons        (    1x)
# 				Hosea 6:9 w292336 "חַכֵּ֨י"
# 					BHS: piel-part act-?mp
# 					OSM: piel-inf cons-_??
# 	perfect         (    1x)
# 				Jonah 1:9 w298764 "יָרֵ֔א"
# 					BHS: qal-part act-?ms
# 					OSM: qal-perfect-3ms
# part pass
# 	part pass       (  861x)
# 	part act        (    5x)
# 				Habakkuk 1:4 w302239 "מְעֻקָּֽל"
# 					BHS: pual-part pass-?ms
# 					OSM: pual-part act-_ms
# 				Song_of_songs 3:6 w358134 "מְקֻטֶּ֤רֶת"
# 					BHS: pual-part pass-?fs
# 					OSM: pual-part act-_fs
# 				Song_of_songs 3:8 w358157 "מְלֻמְּדֵ֖י"
# 					BHS: pual-part pass-?mp
# 					OSM: pual-part act-_mp
# 				Song_of_songs 7:3 w358899 "סוּגָ֖ה"
# 					BHS: qal-part pass-?fs
# 					OSM: qalpassive-part act-_fs
# 				Daniel 3:24 w372151 "מְכַפְּתִ֔ין"
# 					BHS: pael-part pass-?mp
# 					OSM: pael-part act-_mp
# perfect
# 	perfect         (13719x)
# 	weqatal         ( 3610x)
# 	part act        (    5x)
# 				Ruth 2:4 w356297 "בָּ֚א"
# 					BHS: qal-perfect-3ms
# 					OSM: qal-part act-_ms
# 				Ruth 2:6 w356343 "שָּׁ֥בָה"
# 					BHS: qal-perfect-3fs
# 					OSM: qal-part act-_fs
# 				Daniel 2:24 w371012 "אֲזַ֣ל"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 				Daniel 2:24 w371015 "אֲמַר"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 				Daniel 6:15 w374193 "בְּאֵ֣שׁ"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 	imperative      (    2x)
# 				Joel 1:11 w294202 "הֹבִ֣ישׁוּ"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 				Joel 1:11 w294204 "הֵילִ֨ילוּ֙"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# wayyiqtol
# 	wayyiqtol       (13945x)
#
# conjugation (BHS ===> OSM): 34 cases
#
# conjugation: 34 cases
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
# o-o COMPARING FEATURE person
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
#
#
# ---------------------------------------------------------------------------------
# --- person OSM ===> BHS
# ---------------------------------------------------------------------------------
#
# 1
# 	1               ( 4977x)
# 	2               (    3x)
# 				Ruth 3:3 w356811 "ירדתי"
# 					BHS: qal-perfect-2fs
# 					OSM: qal-weqatal-1cs
# 				Ruth 3:4 w356844 "שׁכבתי"
# 					BHS: qal-perfect-2fs
# 					OSM: qal-weqatal-1cs
# 				Ruth 4:5 w357240 "קניתי"
# 					BHS: qal-perfect-2ms
# 					OSM: qal-perfect-1cs
# 	?               (    3x)
# 				Zephaniah 1:2 w303100 "אָסֵ֜ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303109 "אָסֵ֨ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303113 "אָסֵ֤ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 2
# 	2               ( 8775x)
# 	?               (    5x)
# 				Amos 9:1 w297813 "בְצַ֨עַם֙"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Nahum 2:2 w301671 "צַפֵּה"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301673 "חַזֵּ֣ק"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301675 "אַמֵּ֥ץ"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Proverbs 25:2 w353721 "הַסְתֵּ֣ר"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# 	3               (    3x)
# 				Joel 1:11 w294202 "הֹבִ֣ישׁוּ"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 				Joel 1:11 w294204 "הֵילִ֨ילוּ֙"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 				Daniel 2:24 w371021 "תְּהֹובֵ֔ד"
# 					BHS: haphel-imperfect-3fs
# 					OSM: haphel-imperfect-2ms
# 3
# 	3               (32542x)
# 	2               (    5x)
# 				Amos 4:7 w296377 "תַמְטִ֥יר"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Amos 9:10 w298046 "תַגִּ֧ישׁ"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Amos 9:10 w298048 "תַקְדִּ֛ים"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Daniel 6:9 w374039 "תֶעְדֵּֽא"
# 					BHS: peal-imperfect-2ms
# 					OSM: peal-imperfect-3fs
# 				Daniel 6:13 w374153 "תֶעְדֵּֽא"
# 					BHS: peal-imperfect-2ms
# 					OSM: peal-imperfect-3fs
# 	?               (    3x)
# 				Hosea 11:3 w293343 "קָחָ֖ם"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				Jonah 1:9 w298764 "יָרֵ֔א"
# 					BHS: qal-part act-?ms
# 					OSM: qal-perfect-3ms
# 				Daniel 3:17 w371986 "יָכִ֖ל"
# 					BHS: peal-part act-?ms
# 					OSM: peal-imperfect-3ms
# _
# 	?               (13752x)
# 	3               (    5x)
# 				Ruth 2:4 w356297 "בָּ֚א"
# 					BHS: qal-perfect-3ms
# 					OSM: qal-part act-_ms
# 				Ruth 2:6 w356343 "שָּׁ֥בָה"
# 					BHS: qal-perfect-3fs
# 					OSM: qal-part act-_fs
# 				Daniel 2:24 w371012 "אֲזַ֣ל"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 				Daniel 2:24 w371015 "אֲמַר"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 				Daniel 6:15 w374193 "בְּאֵ֣שׁ"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 	2               (    1x)
# 				Amos 4:5 w296306 "קַטֵּ֤ר"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
#
# person (OSM ===> BHS): 28 cases
#
# ---------------------------------------------------------------------------------
# --- person BHS ===> OSM
# ---------------------------------------------------------------------------------
#
# 1
# 	1               ( 4977x)
# 2
# 	2               ( 8775x)
# 	3               (    5x)
# 				Amos 4:7 w296377 "תַמְטִ֥יר"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Amos 9:10 w298046 "תַגִּ֧ישׁ"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Amos 9:10 w298048 "תַקְדִּ֛ים"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Daniel 6:9 w374039 "תֶעְדֵּֽא"
# 					BHS: peal-imperfect-2ms
# 					OSM: peal-imperfect-3fs
# 				Daniel 6:13 w374153 "תֶעְדֵּֽא"
# 					BHS: peal-imperfect-2ms
# 					OSM: peal-imperfect-3fs
# 	1               (    3x)
# 				Ruth 3:3 w356811 "ירדתי"
# 					BHS: qal-perfect-2fs
# 					OSM: qal-weqatal-1cs
# 				Ruth 3:4 w356844 "שׁכבתי"
# 					BHS: qal-perfect-2fs
# 					OSM: qal-weqatal-1cs
# 				Ruth 4:5 w357240 "קניתי"
# 					BHS: qal-perfect-2ms
# 					OSM: qal-perfect-1cs
# 	_               (    1x)
# 				Amos 4:5 w296306 "קַטֵּ֤ר"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
# 3
# 	3               (32542x)
# 	_               (    5x)
# 				Ruth 2:4 w356297 "בָּ֚א"
# 					BHS: qal-perfect-3ms
# 					OSM: qal-part act-_ms
# 				Ruth 2:6 w356343 "שָּׁ֥בָה"
# 					BHS: qal-perfect-3fs
# 					OSM: qal-part act-_fs
# 				Daniel 2:24 w371012 "אֲזַ֣ל"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 				Daniel 2:24 w371015 "אֲמַר"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 				Daniel 6:15 w374193 "בְּאֵ֣שׁ"
# 					BHS: peal-perfect-3ms
# 					OSM: peal-part act-_ms
# 	2               (    3x)
# 				Joel 1:11 w294202 "הֹבִ֣ישׁוּ"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 				Joel 1:11 w294204 "הֵילִ֨ילוּ֙"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 				Daniel 2:24 w371021 "תְּהֹובֵ֔ד"
# 					BHS: haphel-imperfect-3fs
# 					OSM: haphel-imperfect-2ms
# ?
# 	_               (13752x)
# 	2               (    5x)
# 				Amos 9:1 w297813 "בְצַ֨עַם֙"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Nahum 2:2 w301671 "צַפֵּה"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301673 "חַזֵּ֣ק"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301675 "אַמֵּ֥ץ"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Proverbs 25:2 w353721 "הַסְתֵּ֣ר"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# 	1               (    3x)
# 				Zephaniah 1:2 w303100 "אָסֵ֜ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303109 "אָסֵ֨ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303113 "אָסֵ֤ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 	3               (    3x)
# 				Hosea 11:3 w293343 "קָחָ֖ם"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				Jonah 1:9 w298764 "יָרֵ֔א"
# 					BHS: qal-part act-?ms
# 					OSM: qal-perfect-3ms
# 				Daniel 3:17 w371986 "יָכִ֖ל"
# 					BHS: peal-part act-?ms
# 					OSM: peal-imperfect-3ms
#
# person (BHS ===> OSM): 28 cases
#
# person: 28 cases
#
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
# o-o COMPARING FEATURE gender
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
#
#
# ---------------------------------------------------------------------------------
# --- gender OSM ===> BHS
# ---------------------------------------------------------------------------------
#
# ?
# 	?               ( 6272x)
# 	m               (    2x)
# 				Hosea 6:9 w292336 "חַכֵּ֨י"
# 					BHS: piel-part act-?mp
# 					OSM: piel-inf cons-_??
# 				Amos 4:5 w296306 "קַטֵּ֤ר"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
# c
# 	?               ( 8378x)
# 	m               (    4x)
# 				Zephaniah 1:2 w303100 "אָסֵ֜ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303109 "אָסֵ֨ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303113 "אָסֵ֤ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Ruth 4:5 w357240 "קניתי"
# 					BHS: qal-perfect-2ms
# 					OSM: qal-perfect-1cs
# 	f               (    2x)
# 				Ruth 3:3 w356811 "ירדתי"
# 					BHS: qal-perfect-2fs
# 					OSM: qal-weqatal-1cs
# 				Ruth 3:4 w356844 "שׁכבתי"
# 					BHS: qal-perfect-2fs
# 					OSM: qal-weqatal-1cs
# f
# 	f               ( 4545x)
# 	m               (    5x)
# 				Amos 4:7 w296377 "תַמְטִ֥יר"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Amos 9:10 w298046 "תַגִּ֧ישׁ"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Amos 9:10 w298048 "תַקְדִּ֛ים"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Daniel 6:9 w374039 "תֶעְדֵּֽא"
# 					BHS: peal-imperfect-2ms
# 					OSM: peal-imperfect-3fs
# 				Daniel 6:13 w374153 "תֶעְדֵּֽא"
# 					BHS: peal-imperfect-2ms
# 					OSM: peal-imperfect-3fs
# m
# 	m               (40853x)
# 	?               (    8x)
# 				Hosea 11:3 w293343 "קָחָ֖ם"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				Joel 1:11 w294202 "הֹבִ֣ישׁוּ"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 				Joel 1:11 w294204 "הֵילִ֨ילוּ֙"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 				Amos 9:1 w297813 "בְצַ֨עַם֙"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Nahum 2:2 w301671 "צַפֵּה"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301673 "חַזֵּ֣ק"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301675 "אַמֵּ֥ץ"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Proverbs 25:2 w353721 "הַסְתֵּ֣ר"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# 	f               (    5x)
# 				Jonah 4:8 w299449 "תַּ֥ךְ"
# 					BHS: hiphil-wayyiqtol-3fs
# 					OSM: hiphil-wayyiqtol-3ms
# 				Daniel 2:24 w371021 "תְּהֹובֵ֔ד"
# 					BHS: haphel-imperfect-3fs
# 					OSM: haphel-imperfect-2ms
# 				Daniel 4:9 w372538 "ידרון"
# 					BHS: peal-imperfect-3fp
# 					OSM: peal-imperfect-3mp
# 				Daniel 4:18 w372758 "יִשְׁכְּנָ֖ן"
# 					BHS: peal-imperfect-3fp
# 					OSM: peal-imperfect-3ms
# 				Daniel 5:5 w373247 "נפקו"
# 					BHS: peal-perfect-3fp
# 					OSM: peal-perfect-3mp
#
# gender (OSM ===> BHS): 26 cases
#
# ---------------------------------------------------------------------------------
# --- gender BHS ===> OSM
# ---------------------------------------------------------------------------------
#
# ?
# 	c               ( 8378x)
# 	?               ( 6272x)
# 	m               (    8x)
# 				Hosea 11:3 w293343 "קָחָ֖ם"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				Joel 1:11 w294202 "הֹבִ֣ישׁוּ"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 				Joel 1:11 w294204 "הֵילִ֨ילוּ֙"
# 					BHS: hiphil-perfect-3?p
# 					OSM: hiphil-imperative-2mp
# 				Amos 9:1 w297813 "בְצַ֨עַם֙"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Nahum 2:2 w301671 "צַפֵּה"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301673 "חַזֵּ֣ק"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301675 "אַמֵּ֥ץ"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Proverbs 25:2 w353721 "הַסְתֵּ֣ר"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# f
# 	f               ( 4545x)
# 	m               (    5x)
# 				Jonah 4:8 w299449 "תַּ֥ךְ"
# 					BHS: hiphil-wayyiqtol-3fs
# 					OSM: hiphil-wayyiqtol-3ms
# 				Daniel 2:24 w371021 "תְּהֹובֵ֔ד"
# 					BHS: haphel-imperfect-3fs
# 					OSM: haphel-imperfect-2ms
# 				Daniel 4:9 w372538 "ידרון"
# 					BHS: peal-imperfect-3fp
# 					OSM: peal-imperfect-3mp
# 				Daniel 4:18 w372758 "יִשְׁכְּנָ֖ן"
# 					BHS: peal-imperfect-3fp
# 					OSM: peal-imperfect-3ms
# 				Daniel 5:5 w373247 "נפקו"
# 					BHS: peal-perfect-3fp
# 					OSM: peal-perfect-3mp
# 	c               (    2x)
# 				Ruth 3:3 w356811 "ירדתי"
# 					BHS: qal-perfect-2fs
# 					OSM: qal-weqatal-1cs
# 				Ruth 3:4 w356844 "שׁכבתי"
# 					BHS: qal-perfect-2fs
# 					OSM: qal-weqatal-1cs
# m
# 	m               (40853x)
# 	f               (    5x)
# 				Amos 4:7 w296377 "תַמְטִ֥יר"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Amos 9:10 w298046 "תַגִּ֧ישׁ"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Amos 9:10 w298048 "תַקְדִּ֛ים"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: hiphil-imperfect-3fs
# 				Daniel 6:9 w374039 "תֶעְדֵּֽא"
# 					BHS: peal-imperfect-2ms
# 					OSM: peal-imperfect-3fs
# 				Daniel 6:13 w374153 "תֶעְדֵּֽא"
# 					BHS: peal-imperfect-2ms
# 					OSM: peal-imperfect-3fs
# 	c               (    4x)
# 				Zephaniah 1:2 w303100 "אָסֵ֜ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303109 "אָסֵ֨ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303113 "אָסֵ֤ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Ruth 4:5 w357240 "קניתי"
# 					BHS: qal-perfect-2ms
# 					OSM: qal-perfect-1cs
# 	?               (    2x)
# 				Hosea 6:9 w292336 "חַכֵּ֨י"
# 					BHS: piel-part act-?mp
# 					OSM: piel-inf cons-_??
# 				Amos 4:5 w296306 "קַטֵּ֤ר"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
#
# gender (BHS ===> OSM): 26 cases
#
# gender: 26 cases
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
# o-o COMPARING FEATURE number
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
#
#
# ---------------------------------------------------------------------------------
# --- number OSM ===> BHS
# ---------------------------------------------------------------------------------
#
# ?
# 	?               ( 6272x)
# 	p               (    1x)
# 				Hosea 6:9 w292336 "חַכֵּ֨י"
# 					BHS: piel-part act-?mp
# 					OSM: piel-inf cons-_??
# 	s               (    1x)
# 				Amos 4:5 w296306 "קַטֵּ֤ר"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
# p
# 	p               (15129x)
# 	s               (    2x)
# 				Nahum 3:7 w301967 "רֹאַ֨יִךְ֙"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# 				Proverbs 24:17 w353525 "אויביך"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# s
# 	s               (38659x)
# 	?               (    6x)
# 				Hosea 11:3 w293343 "קָחָ֖ם"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				Amos 9:1 w297813 "בְצַ֨עַם֙"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Nahum 2:2 w301671 "צַפֵּה"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301673 "חַזֵּ֣ק"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301675 "אַמֵּ֥ץ"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Proverbs 25:2 w353721 "הַסְתֵּ֣ר"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# 	p               (    4x)
# 				Judges 1:27 w128004 "ישׁב"
# 					BHS: qal-part act-?mp
# 					OSM: qal-part act-_ms
# 				Ruth 2:20 w356704 "גֹּאֲלֵ֖נוּ"
# 					BHS: qal-part act-?mp
# 					OSM: qal-part act-_ms
# 				Daniel 4:18 w372758 "יִשְׁכְּנָ֖ן"
# 					BHS: peal-imperfect-3fp
# 					OSM: peal-imperfect-3ms
# 				Daniel 6:13 w374110 "אָמְרִ֥ין"
# 					BHS: peal-part act-?mp
# 					OSM: peal-part act-_ms
#
# number (OSM ===> BHS): 14 cases
#
# ---------------------------------------------------------------------------------
# --- number BHS ===> OSM
# ---------------------------------------------------------------------------------
#
# ?
# 	?               ( 6272x)
# 	s               (    6x)
# 				Hosea 11:3 w293343 "קָחָ֖ם"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				Amos 9:1 w297813 "בְצַ֨עַם֙"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Nahum 2:2 w301671 "צַפֵּה"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301673 "חַזֵּ֣ק"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301675 "אַמֵּ֥ץ"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Proverbs 25:2 w353721 "הַסְתֵּ֣ר"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# p
# 	p               (15129x)
# 	s               (    4x)
# 				Judges 1:27 w128004 "ישׁב"
# 					BHS: qal-part act-?mp
# 					OSM: qal-part act-_ms
# 				Ruth 2:20 w356704 "גֹּאֲלֵ֖נוּ"
# 					BHS: qal-part act-?mp
# 					OSM: qal-part act-_ms
# 				Daniel 4:18 w372758 "יִשְׁכְּנָ֖ן"
# 					BHS: peal-imperfect-3fp
# 					OSM: peal-imperfect-3ms
# 				Daniel 6:13 w374110 "אָמְרִ֥ין"
# 					BHS: peal-part act-?mp
# 					OSM: peal-part act-_ms
# 	?               (    1x)
# 				Hosea 6:9 w292336 "חַכֵּ֨י"
# 					BHS: piel-part act-?mp
# 					OSM: piel-inf cons-_??
# s
# 	s               (38659x)
# 	p               (    2x)
# 				Nahum 3:7 w301967 "רֹאַ֨יִךְ֙"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# 				Proverbs 24:17 w353525 "אויביך"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# 	?               (    1x)
# 				Amos 4:5 w296306 "קַטֵּ֤ר"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
#
# number (BHS ===> OSM): 14 cases
#
# number: 14 cases
#
# All features: 225 cases

# %%
closerLook |= cases
print('{} cases for a closer look'.format(len(closerLook)))
# Out:
# 288 cases for a closer look

# %% [markdown]
# # Result
#
# We are going to list all cases in [verbs.tsv](verbs.tsv) .

# %%
fields = '''
    passage
    node
    occurrence
    OSMmorph
    stemOSM
    stemBHS
    conjOSM
    conjBHS
    personOSM
    personBHS
    genderOSM
    genderBHS
    numberOSM
    numberBHS
'''.strip().split()
lineFormat = ('{}\t' * (len(fields) - 1)) + '{}\n'

with open('verbs.tsv', 'w') as fh:
    fh.write(lineFormat.format(*fields))
    for w in sorted(closerLook):
        fh.write(lineFormat.format(
            '{} {}:{}'.format(*T.sectionFromNode(w)),
            w,
            F.g_word_utf8.v(w),
            F.osm.v(w),
            getStemOSMX(w),
            getStemBHSX(w),
            getConjOSMX(w),
            getConjBHSX(w),
            getPersonOSM(w),
            getPersonBHS(w),
            getGenderOSM(w),
            getGenderBHS(w),
            getNumberOSM(w),
            getNumberBHS(w),
        ))
