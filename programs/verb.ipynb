# %% [markdown]
# # BHSA and OSM: comparison on verb attributes
#
# We will investigate how the morphology marked up in the OSM corresponds and differs from the BHSA linguistic features.
#
# In this notebook we investigate the markup of verb attributes.
# According to the [OSM specs](http://openscriptures.github.io/morphhb/parsing/HebrewMorphologyCodes.html)
# this is provided:
#
# * verb stem
# * conjugation type
# * person
# * gender
# * number
#
# We use the `osm` and `osm_sf` features compiled by the
# [BHSAbridgeOSM notebook](BHSAbridgeOSM.ipynb).
#
# # Results
#
# See below, where most of the cases are mentioned.
# We also collect all cases in [verbs.tsv](verbs.tsv) , a tab delimited file.

# %%
from tf.fabric import Fabric
from utils import show

# %% [markdown]
# # Load data
# We load the BHSA data in the standard way, and we add the OSM data as a module of the features `osm` and `osm_sf`.
# Note that we only need to point TF to the right directories, and then we can load all features
# that are present in those directories.

# %%
BHSA = "BHSA/tf/2021"
OSM = "bridging/tf/2021"

TF = Fabric(locations="~/github/etcbc", modules=[BHSA, OSM])
api = TF.load(
    """
    sp
    lex voc_lex_utf8 gloss
    languageISO
    osm osm_sf
    g_word_utf8
    vs vt ps gn nu
"""
)
api.makeAvailableIn(globals())
# Out:
# This is Text-Fabric 9.0.3
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 117 features found and 0 ignored
#   0.00s loading features ...
#    |     0.00s Dataset without structure sections in otext:no structure functions in the T-API
#   3.96s All features loaded/computed - for details use TF.isLoaded()
# [('Computed',
#   'computed-data',
#   ('C Computed', 'Call AllComputeds', 'Cs ComputedString')),
#  ('Features', 'edge-features', ('E Edge', 'Eall AllEdges', 'Es EdgeString')),
#  ('Fabric', 'loading', ('TF',)),
#  ('Locality', 'locality', ('L Locality',)),
#  ('Nodes', 'navigating-nodes', ('N Nodes',)),
#  ('Features',
#   'node-features',
#   ('F Feature', 'Fall AllFeatures', 'Fs FeatureString')),
#  ('Search', 'search', ('S Search',)),
#  ('Text', 'text', ('T Text',))]

# %% [markdown]
# # Verb occurrences
#
# Let us first identify what the verb occurrences are, according to the OSM and to the BHSA.
# We'll show the differences.
# The OSM is not yet completed, so we focus on the cases where the OSM has morphology.
#
# We call the set of words that have a non-empty OSM morphology string the OSM-base.

# %%
verbsBHS = set(F.sp.s("verb"))
hasOSM = set()
for w in F.otype.s("word"):
    osm = F.osm.v(w)
    if osm and len(osm) > 1:
        hasOSM.add(w)

verbsBHSfocus = verbsBHS & hasOSM

verbsOSM = {w for w in hasOSM if F.osm.v(w)[1] == "V"}

print(
    """
Number of verb occurrences in the Hebrew Bible:
\tin BHSA (total):                     {:>5}
\tin BHSA (intersected with OSM-base): {:>5}
\tin OSM:                              {:>5}
""".format(
        len(verbsBHS),
        len(verbsBHSfocus),
        len(verbsOSM),
    )
)
# Out:
# Number of verb occurrences in the Hebrew Bible:
# 	in BHSA (total):                     75451
# 	in BHSA (intersected with OSM-base): 73668
# 	in OSM:                              73642

# %% [markdown]
# As you see: very few discrepancies.
# Before we show them, we define functions that show a verb with BHSA morphology and OSM morphology.
#
# If a piece of moprhology is not present, we substitute a `?`.
# We also transform a not-applicable or unknown value in the BHSA by `?`, although
# there is a difference between missing markup and markup saying: insufficient information!

# %% [markdown]
# # Names
#
# We map the names for stems and conjugations found in the
# [OSM morphology description](http://openscriptures.github.io/morphhb/parsing/HebrewMorphologyCodes.html)
# to convenient names when comparing them with the morphology values in the BHSA features
# [vs](https://etcbc.github.io/bhsa/features/hebrew/2017/vt.html)
# and
# [vt](https://etcbc.github.io/bhsa/features/hebrew/2017/vt.html),
# and we map some BHSA names as well.

# %%
stemMapOSM = dict(
    H=dict(
        q="qal",
        N="niphal",
        p="piel",
        P="pual",
        h="hiphil",
        H="hophal",
        t="hithpael",
        o="polel",
        O="polal",
        r="hithpolel",
        m="poel",
        M="poal",
        k="palel",
        K="pulal",
        Q="qalpassive",
        l="pilpel",
        L="polpal",
        f="hithpalpel",
        D="nithpael",
        j="pealal",
        i="pilel",
        u="hothpaal",
        c="tiphil",
        v="hishtaphel",
        w="nithpalel",
        y="nithpoel",
        z="hithpoel",
    ),
    A=dict(
        q="peal",
        Q="peil",
        u="hithpeel",
        p="pael",
        P="ithpaal",
        M="hithpaal",
        a="aphel",
        h="haphel",
        s="saphel",
        e="shaphel",
        H="hophal",
        i="ithpeel",
        t="hishtaphel",
        v="ishtaphel",
        w="hithaphel",
        o="polel",
        z="ithpoel",
        r="hithpolel",
        f="hithpalpel",
        b="hephal",
        c="tiphel",
        m="poel",
        l="palpel",
        L="ithpalpel",
        O="ithpolel",
        G="ittaphal",
    ),
)

# %%
stemMapBHS = dict(
    hif="hiphil",
    hit="hithpael",
    htpo="hithpoel",
    hof="hophal",
    nif="niphal",
    piel="piel",
    poal="poal",
    poel="poel",
    pual="pual",
    qal="qal",
    afel="aphel",
    etpa="etpaal",
    etpe="etpeel",
    haf="haphel",
    hotp="hothpaal",
    hsht="hishtaphel",
    htpa="hithpaal",
    htpe="hithpeel",
    nit="nithpael",
    pael="pael",
    peal="peal",
    peil="peil",
    shaf="shaphel",
    tif="tiphal",
    pasq="qalpassive",
)

# %%
conjMapOSM = dict(
    p="perfect",
    q="weqatal",
    i="imperfect",
    w="wayyiqtol",
    h="cohortative",
    j="jussive",
    v="imperative",
    r="part act",
    s="part pass",
    a="inf abs",
    c="inf cons",
)
conjMapBHS = dict(
    impf="imperfect",
    impv="imperative",
    infa="inf abs",
    infc="inf cons",
    perf="perfect",
    ptca="part act",
    ptcp="part pass",
    wayq="wayyiqtol",
)

# %%
naValues = {"NA", "N/A"}
missingValues = {None, "", "unknown"}
noPersonConj = {"r", "s", "a", "c"}


def getValue(x):
    return "_" if x in naValues else "?" if x in missingValues else x


def getValueHead(x):
    return "_" if x in naValues else "?" if x in missingValues else x[0]


def getValueTail(x):
    return "_" if x in naValues else "?" if x in missingValues else x[1:]


def extractFeature(x, n):
    return "?" if not x or len(x) <= n else x[n]


def getLangOSM(w):
    return extractFeature(F.osm.v(w), 0)


def getStemOSM(w):
    return extractFeature(F.osm.v(w), 2)


def getStemOSMX(w):
    return stemMapOSM.get(getLangOSM(w), {}).get(getStemOSM(w), "?")


def getConjOSM(w):
    return extractFeature(F.osm.v(w), 3)


def getConjOSMX(w):
    return conjMapOSM.get(getConjOSM(w), "?")


def getPersonOSM(w):
    return "_" if getConjOSM(w) in noPersonConj else extractFeature(F.osm.v(w), 4)


def getGenderOSM(w):
    return extractFeature(F.osm.v(w), 4 if getConjOSM(w) in noPersonConj else 5)


def getNumberOSM(w):
    return extractFeature(F.osm.v(w), 5 if getConjOSM(w) in noPersonConj else 6)


def getStemBHS(w):
    return getValue(F.vs.v(w))


def getStemBHSX(w):
    return stemMapBHS.get(getStemBHS(w), "?")


def getConjBHS(w):
    return getValue(F.vt.v(w))


def getConjBHSX(w):
    return conjMapBHS.get(getConjBHS(w), "?")


def getPersonBHS(w):
    return getValueTail(F.ps.v(w))


def getGenderBHS(w):
    return getValue(F.gn.v(w))


def getNumberBHS(w):
    return getValueHead(F.nu.v(w))


def getVerbBHS(w):
    return "{}-{}-{}{}{}".format(
        getStemBHSX(w),
        getConjBHSX(w),
        getPersonBHS(w),
        getGenderBHS(w),
        getNumberBHS(w),
    )


def getVerbOSM(w):
    return "{}-{}-{}{}{}".format(
        getStemOSMX(w),
        getConjOSMX(w),
        getPersonOSM(w),
        getGenderOSM(w),
        getNumberOSM(w),
    )


def getBHS(w):
    return F.sp.v(w)


def getOSM(w):
    return F.osm.v(w)

# %% [markdown]
# # Mappings
#
# We collect the numbers of cooccurrences of OSM values and BHSA values for each verb feature,
# and see how they compare.

# %%
closerLook = set()

# %%
def showFeatures(base):
    cases = set()
    mappings = {}

    def makeMap(key, getBHS, getOSM):
        BHSFromOSM = {}
        OSMFromBHS = {}

        for w in base:
            osm = getOSM(w)
            bhs = getBHS(w)
            BHSFromOSM.setdefault(osm, {}).setdefault(bhs, set()).add(w)
            OSMFromBHS.setdefault(bhs, {}).setdefault(osm, set()).add(w)
        mappings.setdefault(key, {})[True] = BHSFromOSM
        mappings.setdefault(key, {})[False] = OSMFromBHS

    def showMap(key, direction):
        dirLabel = "OSM ===> BHS" if direction else "BHS ===> OSM"
        print(
            """
---------------------------------------------------------------------------------
--- {} {}
---------------------------------------------------------------------------------
""".format(
                key, dirLabel
            )
        )
        cases = set()
        for (item, itemData) in sorted(mappings[key][direction].items()):
            print("{:<10}".format(item))
            first = True
            for (itemOther, ws) in sorted(
                itemData.items(), key=lambda x: (-len(x[1]), x[0])
            ):
                print("\t{:<15} ({:>5}x)".format(itemOther, len(ws)))
                if not first and len(ws) < 100:
                    for w in sorted(ws):
                        show(T, F, [w], getVerbBHS, getVerbOSM, indent="\t\t\t\t")
                        cases.add(w)
                first = False
        print("\n{} ({}): {} cases".format(key, dirLabel, len(cases)))
        return cases

    def showFeature(key):
        cases = set()
        print(
            """
o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
o-o COMPARING FEATURE {}
o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
""".format(
                key
            )
        )
        for direction in (True, False):
            theseCases = showMap(key, direction)
            cases |= theseCases
        print("\n{}: {} cases".format(key, len(cases)))
        return cases

    for (key, getBHS, getOSM) in (
        ("stem", getStemBHSX, getStemOSMX),
        ("conjugation", getConjBHSX, getConjOSMX),
        ("person", getPersonBHS, getPersonOSM),
        ("gender", getGenderBHS, getGenderOSM),
        ("number", getNumberBHS, getNumberOSM),
    ):
        makeMap(key, getBHS, getOSM)
        cases |= showFeature(key)
    print("\n{}: {} cases".format("All features", len(cases)))

    return cases

# %% [markdown]
# ## in BHSA but not in OSM

# %%
extraBHS = verbsBHSfocus - verbsOSM

print("Marked as verb in BHSA but not in OSM: {:>3}".format(len(extraBHS)))
for w in sorted(extraBHS):
    show(T, F, [w], getVerbBHS, getOSM, indent="\t")
# Out:
# Marked as verb in BHSA but not in OSM: 187
# 	Genesis 1:4 w47"טֹ֑וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Genesis 1:10 w178"טֹֽוב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Genesis 1:12 w227"טֹֽוב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Genesis 1:18 w351"טֹֽוב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Genesis 1:21 w413"טֹֽוב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Genesis 1:25 w494"טֹֽוב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Genesis 18:1 w7815"חֹ֥ם"
# 		BHS: qal-inf cons-???
# 		OSM: HNcmsc
# 	Genesis 30:11 w15747"ב"
# 		BHS: qal-perfect-3ms
# 		OSM: HR
# 	Genesis 40:2 w21943"מַּשְׁקִ֔ים"
# 		BHS: hiphil-part act-?mp
# 		OSM: HNcmpa
# 	Genesis 40:5 w21997"מַּשְׁקֶ֣ה"
# 		BHS: hiphil-part act-?ms
# 		OSM: HNcmsa
# 	Genesis 40:9 w22067"מַּשְׁקִ֛ים"
# 		BHS: hiphil-part act-?mp
# 		OSM: HNcmpa
# 	Genesis 40:20 w22307"מַּשְׁקִ֗ים"
# 		BHS: hiphil-part act-?mp
# 		OSM: HNcmpa
# 	Genesis 40:21 w22322"מַּשְׁקִ֖ים"
# 		BHS: hiphil-part act-?mp
# 		OSM: HNcmpa
# 	Genesis 40:23 w22348"מַּשְׁקִ֛ים"
# 		BHS: hiphil-part act-?mp
# 		OSM: HNcmpa
# 	Genesis 41:9 w22517"מַּשְׁקִ֔ים"
# 		BHS: hiphil-part act-?mp
# 		OSM: HNcmpa
# 	Genesis 49:15 w27976"טֹ֔וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Exodus 21:8 w40137"רָעָ֞ה"
# 		BHS: qal-perfect-3fs
# 		OSM: HAafsa
# 	Leviticus 4:3 w53551"אַשְׁמַ֣ת"
# 		BHS: qal-inf cons-???
# 		OSM: HNcfsc
# 	Leviticus 5:24 w54857"אַשְׁמָתֹֽו"
# 		BHS: qal-inf cons-???
# 		OSM: HNcfsc
# 	Leviticus 21:7 w65068"זֹנָ֤ה"
# 		BHS: qal-part act-?fs
# 		OSM: HNcfsa
# 	Leviticus 21:14 w65193"זֹנָ֔ה"
# 		BHS: qal-part act-?fs
# 		OSM: HNcfsa
# 	Numbers 1:16 w69765"קריאי"
# 		BHS: qal-part pass-?mp
# 		OSM: HAampc
# 	Numbers 7:13 w74147"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:14 w74159"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:19 w74229"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:20 w74241"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:25 w74310"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:26 w74322"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:31 w74391"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:32 w74403"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:37 w74472"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:38 w74484"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:43 w74553"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:44 w74565"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:49 w74634"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:50 w74646"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:55 w74715"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:56 w74727"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:61 w74796"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:62 w74808"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:67 w74877"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:68 w74889"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:73 w74958"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:74 w74970"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:79 w75039"מְלֵאִ֗ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Numbers 7:80 w75051"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Numbers 7:86 w75144"מְלֵאֹ֣ת"
# 		BHS: qal-part act-?fp
# 		OSM: HAafpa
# 	Numbers 11:10 w76990"רָֽע"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Numbers 11:16 w77127"שֹׁטְרָ֑יו"
# 		BHS: qal-part act-?mp
# 		OSM: HNcmpc
# 	Numbers 24:20 w85550"אֹבֵֽד"
# 		BHS: qal-part act-?ms
# 		OSM: HNcmsa
# 	Numbers 24:24 w85605"אֹבֵֽד"
# 		BHS: qal-part act-?ms
# 		OSM: HNcmsa
# 	Deuteronomy 6:11 w97155"מְלֵאִ֣ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Deuteronomy 6:24 w97386"טֹ֥וב"
# 		BHS: qal-inf cons-???
# 		OSM: HAamsa
# 	Deuteronomy 10:13 w99437"טֹ֖וב"
# 		BHS: qal-inf cons-???
# 		OSM: HAamsa
# 	Deuteronomy 33:23 w112583"מָלֵ֖א"
# 		BHS: qal-part act-?ms
# 		OSM: HAamsa
# 	Deuteronomy 34:9 w112845"מָלֵא֙"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Joshua 1:10 w113145"שֹׁטְרֵ֥י"
# 		BHS: qal-part act-?mp
# 		OSM: HNcmpc
# 	Joshua 3:2 w113977"שֹּׁטְרִ֖ים"
# 		BHS: qal-part act-?mp
# 		OSM: HNcmpa
# 	Joshua 24:15 w127006"רַ֨ע"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Judges 16:2 w137244"אֹ֥ור"
# 		BHS: qal-inf cons-???
# 		OSM: HNcbsc
# 	1_Samuel 1:1 w141547"צֹופִ֖ים"
# 		BHS: qal-part act-?mp
# 		OSM: HNp
# 	1_Samuel 11:9 w147055"חם"
# 		BHS: qal-inf cons-???
# 		OSM: HNcmsc
# 	1_Samuel 11:11 w147112"חֹ֣ם"
# 		BHS: qal-inf cons-???
# 		OSM: HNcmsc
# 	1_Samuel 14:36 w149164"אֹ֣ור"
# 		BHS: qal-inf cons-???
# 		OSM: HNcbsc
# 	1_Samuel 15:9 w149744"נְמִבְזָ֥ה"
# 		BHS: niphal-part act-?fs
# 		OSM: HNcfsa
# 	1_Samuel 18:9 w152346"עון"
# 		BHS: qal-part act-?ms
# 		OSM: HNcbsa
# 	1_Samuel 25:34 w157306"אֹ֥ור"
# 		BHS: qal-inf cons-???
# 		OSM: HNcbsc
# 	1_Samuel 25:36 w157370"אֹ֥ור"
# 		BHS: qal-inf cons-???
# 		OSM: HNcbsc
# 	1_Samuel 31:3 w160241"מֹּורִֽים"
# 		BHS: hiphil-part act-?mp
# 		OSM: HNcmpa
# 	2_Samuel 4:5 w162712"חֹ֣ם"
# 		BHS: qal-inf cons-???
# 		OSM: HNcmsc
# 	2_Samuel 17:22 w170875"אֹ֣ור"
# 		BHS: qal-inf cons-???
# 		OSM: HNcbsc
# 	2_Samuel 19:41 w172967"ויעברו"
# 		BHS: hiphil-perfect-3?p
# 		OSM: HC
# 	2_Samuel 21:19 w174221"אֹרְגִ֜ים"
# 		BHS: qal-part act-?mp
# 		OSM: HNp
# 	2_Samuel 23:11 w175030"מְלֵאָ֣ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	1_Kings 11:22 w185450"חָסֵר֙"
# 		BHS: qal-part act-?ms
# 		OSM: HAamsa
# 	1_Kings 18:3 w190377"יָרֵ֛א"
# 		BHS: qal-part act-?ms
# 		OSM: HAamsa
# 	1_Kings 18:12 w190578"יָרֵ֥א"
# 		BHS: qal-part act-?ms
# 		OSM: HAamsa
# 	1_Kings 21:2 w193041"טֹ֣וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	1_Kings 22:49 w194648"עשׂר"
# 		BHS: qal-perfect-3ms
# 		OSM: HAcmsa
# 	2_Kings 7:9 w199192"אֹ֥ור"
# 		BHS: qal-inf cons-???
# 		OSM: HNcbsc
# 	2_Kings 7:15 w199369"מְלֵאָ֤ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	2_Kings 11:1 w202008"וראתה"
# 		BHS: qal-perfect-3fs
# 		OSM: HC
# 	2_Kings 17:32 w206302"יְרֵאִ֖ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	2_Kings 17:33 w206323"יְרֵאִ֑ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	2_Kings 17:34 w206351"יְרֵאִים֙"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	2_Kings 17:41 w206501"יְרֵאִים֙"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Isaiah 3:10 w213074"טֹ֑וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Isaiah 3:26 w213278"אָנ֥וּ"
# 		BHS: qal-perfect-3?p
# 		OSM: HD
# 	Isaiah 5:29 w213937"ושׁאג"
# 		BHS: qal-imperfect-3ms
# 		OSM: HC
# 	Isaiah 10:29 w216023"לָ֑נוּ"
# 		BHS: qal-perfect-3?p
# 		OSM: HR
# 	Isaiah 18:4 w218043"חֹ֥ם"
# 		BHS: qal-inf cons-???
# 		OSM: HNcmsc
# 	Isaiah 18:4 w218051"חֹ֥ם"
# 		BHS: qal-inf cons-???
# 		OSM: HNcmsc
# 	Isaiah 19:8 w218263"אָנוּ֙"
# 		BHS: qal-perfect-3?p
# 		OSM: HD
# 	Isaiah 22:2 w218997"מְלֵאָ֗ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Isaiah 23:16 w219632"שִׁ֔יר"
# 		BHS: qal-inf abs-???
# 		OSM: HNcbsa
# 	Isaiah 38:17 w225305"מַר"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Isaiah 49:6 w229248"נצירי"
# 		BHS: qal-part pass-?mp
# 		OSM: HAampc
# 	Isaiah 51:20 w230239"מְלֵאִ֥ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Isaiah 65:11 w234148"שְּׁכֵחִ֖ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Jeremiah 2:19 w235683"רַ֣ע"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Jeremiah 2:19 w235685"מָ֔ר"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Jeremiah 4:5 w236639"ותקעו"
# 		BHS: qal-imperative-2mp
# 		OSM: HC
# 	Jeremiah 4:18 w236882"מָ֔ר"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Jeremiah 5:13 w237333"דִּבֵּ֖ר"
# 		BHS: piel-perfect-3ms
# 		OSM: HNcmsa
# 	Jeremiah 5:27 w237597"מָ֣לֵא"
# 		BHS: qal-part act-?ms
# 		OSM: HAamsa
# 	Jeremiah 5:27 w237601"מְלֵאִ֣ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Jeremiah 8:1 w238957"ויציאו"
# 		BHS: hiphil-imperfect-3mp
# 		OSM: HC
# 	Jeremiah 9:24 w239866"מ֖וּל"
# 		BHS: qal-part pass-?ms
# 		OSM: HR
# 	Jeremiah 22:15 w245634"טֹ֥וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Jeremiah 22:16 w245642"טֹ֑וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Jeremiah 25:34 w247790"תְפֹוצֹ֣ותִיכֶ֔ם"
# 		BHS: tiphal-perfect-1?s
# 		OSM: HNcfpc
# 	Jeremiah 26:19 w248339"יָרֵ֣א"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Jeremiah 35:5 w253835"מְלֵאִ֥ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Jeremiah 40:4 w256879"טֹ֨וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Jeremiah 50:6 w261986"שׁובבים"
# 		BHS: piel-perfect-3?p
# 		OSM: HAampa
# 	Jeremiah 51:1 w262760"קָמָ֑י"
# 		BHS: qal-part act-?mp
# 		OSM: HNp
# 	Jeremiah 51:13 w262974"בִּצְעֵֽךְ"
# 		BHS: qal-inf cons-???
# 		OSM: HNcmsc
# 	Ezekiel 1:18 w265071"מְלֵאֹ֥ת"
# 		BHS: qal-part act-?fp
# 		OSM: HAafpa
# 	Ezekiel 3:15 w265794"אשׁר"
# 		BHS: qal-wayyiqtol-1?s
# 		OSM: HTr
# 	Ezekiel 10:12 w268653"מְלֵאִ֤ים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	Ezekiel 14:4 w270435"בה"
# 		BHS: qal-part act-?ms
# 		OSM: HR
# 	Ezekiel 37:1 w283225"מְלֵאָ֥ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Ezekiel 40:26 w285552"עלותו"
# 		BHS: qal-part act-?fp
# 		OSM: HNcfsc
# 	Ezekiel 42:9 w286866"מבוא"
# 		BHS: hiphil-part act-?ms
# 		OSM: HNcmsa
# 	Ezekiel 46:15 w289435"ועשׂו"
# 		BHS: qal-imperfect-3mp
# 		OSM: HC
# 	Hosea 2:9 w291270"טֹ֥וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Hosea 9:7 w292906"רַבָּ֖ה"
# 		BHS: qal-perfect-3fs
# 		OSM: HAafsa
# 	Hosea 10:1 w293079"טֹ֣וב"
# 		BHS: qal-inf cons-???
# 		OSM: HAamsa
# 	Joel 4:3 w295064"זֹּונָ֔ה"
# 		BHS: qal-part act-?fs
# 		OSM: HNcfsa
# 	Joel 4:14 w295248"חָר֑וּץ"
# 		BHS: qal-part pass-?ms
# 		OSM: HNp
# 	Joel 4:14 w295256"חָרֽוּץ"
# 		BHS: qal-part pass-?ms
# 		OSM: HNp
# 	Obadiah 1:3 w298209"שִׁבְתֹּ֑ו"
# 		BHS: qal-inf cons-???
# 		OSM: HNcfsc
# 	Nahum 3:1 w301883"מְלֵאָ֔ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	Habakkuk 2:20 w302797"הַ֥ס"
# 		BHS: piel-imperative-2ms
# 		OSM: HTj
# 	Zephaniah 1:7 w303210"הַ֕ס"
# 		BHS: piel-imperative-2ms
# 		OSM: HTj
# 	Zephaniah 1:14 w303368"קָרֹ֖וב"
# 		BHS: qal-inf abs-???
# 		OSM: HAamsa
# 	Zephaniah 1:14 w303370"מַהֵ֣ר"
# 		BHS: piel-inf abs-???
# 		OSM: HAamsa
# 	Zechariah 2:17 w305651"הַ֥ס"
# 		BHS: piel-imperative-2ms
# 		OSM: HTj
# 	Zechariah 11:12 w308238"טֹ֧וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Psalms 5:5 w311074"חָפֵ֘ץ"
# 		BHS: qal-part act-?ms
# 		OSM: HAamsc
# 	Psalms 9:18 w311737"שְׁכֵחֵ֥י"
# 		BHS: qal-part act-?mp
# 		OSM: HAampc
# 	Psalms 10:10 w311879"ודכה"
# 		BHS: qal-imperfect-3ms
# 		OSM: HC
# 	Psalms 17:14 w312628"צפינך"
# 		BHS: qal-part pass-?ms
# 		OSM: HNcmsc
# 	Psalms 34:9 w315664"טֹ֣וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Psalms 34:13 w315702"חָפֵ֣ץ"
# 		BHS: qal-part act-?ms
# 		OSM: HAamsa
# 	Psalms 35:27 w316079"חָפֵ֗ץ"
# 		BHS: qal-part act-?ms
# 		OSM: HAamsa
# 	Psalms 52:11 w319186"טֹ֝֗וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Psalms 54:8 w319351"טֹֽוב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Psalms 89:44 w326130"צ֣וּר"
# 		BHS: qal-inf cons-???
# 		OSM: HNcmsc
# 	Psalms 92:2 w326566"טֹ֗וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Psalms 106:1 w328980"טֹ֑וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Psalms 107:1 w329464"טֹ֑וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Psalms 118:1 w331078"טֹ֑וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Psalms 118:29 w331322"טֹ֑וב"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Psalms 119:38 w331600"יִרְאָתֶֽךָ"
# 		BHS: qal-inf cons-???
# 		OSM: HNcfsc
# 	Psalms 139:21 w334548"תְקֹומְמֶ֗יךָ"
# 		BHS: hithpael-part act-?mp
# 		OSM: HNcmpc
# 	Job 33:21 w344236"שׁפי"
# 		BHS: pual-perfect-3?p
# 		OSM: HNcmsc
# 	Proverbs 2:7 w347304"וצפן"
# 		BHS: qal-imperfect-3ms
# 		OSM: HC
# 	Proverbs 3:13 w347568"יָפִ֥יק"
# 		BHS: hiphil-imperfect-3ms
# 		OSM: HNcfsa
# 	Proverbs 7:16 w348736"חֲ֝טֻבֹ֗ות"
# 		BHS: qal-part pass-?fp
# 		OSM: HNcfpc
# 	Proverbs 10:4 w349366"רָ֗אשׁ"
# 		BHS: qal-part act-?ms
# 		OSM: HNcmsa
# 	Proverbs 13:20 w350345"וחכם"
# 		BHS: qal-imperfect-3ms
# 		OSM: HC
# 	Proverbs 14:14 w350518"ס֣וּג"
# 		BHS: qal-inf cons-???
# 		OSM: HAamsc
# 	Proverbs 17:1 w351345"מָלֵ֥א"
# 		BHS: qal-part act-?ms
# 		OSM: HAamsa
# 	Proverbs 23:5 w353047"ועיף"
# 		BHS: qal-imperfect-3ms
# 		OSM: HC
# 	Proverbs 23:24 w353239"וישׂמח"
# 		BHS: qal-imperfect-3ms
# 		OSM: HC
# 	Lamentations 1:20 w363905"צַר"
# 		BHS: qal-perfect-3ms
# 		OSM: HAamsa
# 	Lamentations 3:45 w364795"מָאֹ֛וס"
# 		BHS: qal-inf abs-???
# 		OSM: HNcmsa
# 	Esther 9:18 w369595"נֹ֗וחַ"
# 		BHS: qal-inf abs-???
# 		OSM: HNcmsa
# 	Daniel 2:26 w371076"חֲזֵ֖ית"
# 		BHS: peal-perfect-1?s
# 		OSM: ATr
# 	Daniel 6:20 w374324"הִ֨תְבְּהָלָ֔ה"
# 		BHS: hithpeel-inf cons-???
# 		OSM: ANcfsa
# 	Daniel 9:5 w375861"והרשׁענו"
# 		BHS: hiphil-perfect-1?p
# 		OSM: HC
# 	Ezra 4:22 w379972"הַנְזָקַ֖ת"
# 		BHS: haphel-inf cons-???
# 		OSM: ANcfsc
# 	Ezra 7:11 w381139"סֹפֵ֞ר"
# 		BHS: qal-part act-?ms
# 		OSM: HNcmsc
# 	Ezra 7:16 w381236"הִתְנַדָּב֨וּת"
# 		BHS: hithpaal-inf cons-???
# 		OSM: ANcfsc
# 	Nehemiah 8:11 w387494"הַ֔סּוּ"
# 		BHS: piel-imperative-2mp
# 		OSM: HTj
# 	Nehemiah 9:25 w388355"מְלֵֽאִים"
# 		BHS: qal-part act-?mp
# 		OSM: HAampa
# 	1_Chronicles 9:33 w396543"פטירים"
# 		BHS: qal-part pass-?mp
# 		OSM: HNcmpa
# 	1_Chronicles 11:13 w397264"מְלֵאָ֣ה"
# 		BHS: qal-part act-?fs
# 		OSM: HAafsa
# 	1_Chronicles 25:1 w403896"נביאים"
# 		BHS: niphal-part act-?mp
# 		OSM: HNcmpa
# 	1_Chronicles 26:29 w404756"שֹׁטְרִ֖ים"
# 		BHS: qal-part act-?mp
# 		OSM: HNcmpa
# 	1_Chronicles 27:1 w404871"שֹׁטְרֵיהֶם֩"
# 		BHS: qal-part act-?mp
# 		OSM: HNcmpc
# 	2_Chronicles 2:8 w407475"גָּדֹ֥ול"
# 		BHS: qal-inf abs-???
# 		OSM: HAamsa
# 	2_Chronicles 8:10 w410806"נציבים"
# 		BHS: niphal-part act-?mp
# 		OSM: HNcmpa
# 	2_Chronicles 24:27 w418874"ורב"
# 		BHS: qal-imperfect-3ms
# 		OSM: HC
# 	2_Chronicles 28:19 w420804"מַ֖עַל"
# 		BHS: qal-perfect-3ms
# 		OSM: HNcmsa
# 	2_Chronicles 34:13 w424813"שֹׁטְרִ֖ים"
# 		BHS: qal-part act-?mp
# 		OSM: HNcmpa

# %%
cases = extraBHS
closerLook |= cases
print("{} cases merged into {} closer look items".format(len(cases), len(closerLook)))
# Out:
# 187 cases merged into 187 closer look items

# %% [markdown]
# ## in OSM but not in BHSA

# %%
extraOSM = verbsOSM - verbsBHSfocus

print("Marked as verb in OSM but not in BHSA: {:>3}".format(len(extraOSM)))
for w in sorted(extraOSM):
    show(T, F, [w], getBHS, getVerbOSM, indent="\t")
# Out:
# Marked as verb in OSM but not in BHSA: 161
# 	Genesis 24:59 w12263"מֵנִקְתָּ֑הּ"
# 		BHS: subs
# 		OSM: hiphil-part act-_fs
# 	Genesis 26:13 w13242"גָדֵ֔ל"
# 		BHS: adjv
# 		OSM: qal-part act-_ms
# 	Genesis 30:42 w16354"עֲטֻפִים֙"
# 		BHS: adjv
# 		OSM: qal-part pass-_mp
# 	Genesis 39:20 w21838"אסורי"
# 		BHS: subs
# 		OSM: qal-part pass-_mp
# 	Genesis 40:1 w21928"אֹפֶ֑ה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Genesis 40:2 w21948"אֹופִֽים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Genesis 40:5 w22000"אֹפֶ֗ה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Genesis 40:16 w22206"אֹפִ֖ים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Genesis 40:17 w22236"אֹפֶ֑ה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Genesis 40:20 w22313"אֹפִ֖ים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Genesis 40:22 w22336"אֹפִ֖ים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Genesis 41:10 w22546"אֹפִֽים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Genesis 41:23 w22768"צְנֻמֹ֥ות"
# 		BHS: adjv
# 		OSM: qal-part pass-_fp
# 	Genesis 49:22 w28044"פֹּרָת֙"
# 		BHS: subs
# 		OSM: qal-part act-_fs
# 	Genesis 49:22 w28047"פֹּרָ֖ת"
# 		BHS: subs
# 		OSM: qal-part act-_fs
# 	Exodus 25:33 w42483"מְֽשֻׁקָּדִ֞ים"
# 		BHS: adjv
# 		OSM: pual-part pass-_mp
# 	Exodus 25:33 w42495"מְשֻׁקָּדִ֛ים"
# 		BHS: adjv
# 		OSM: pual-part pass-_mp
# 	Exodus 25:34 w42520"מְשֻׁקָּדִ֔ים"
# 		BHS: adjv
# 		OSM: pual-part pass-_mp
# 	Exodus 26:13 w42898"סָר֜וּחַ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Exodus 37:19 w50254"מְֽשֻׁקָּדִ֞ים"
# 		BHS: adjv
# 		OSM: pual-part pass-_mp
# 	Exodus 37:19 w50266"מְשֻׁקָּדִ֛ים"
# 		BHS: adjv
# 		OSM: pual-part pass-_mp
# 	Exodus 37:20 w50289"מְשֻׁ֨קָּדִ֔ים"
# 		BHS: adjv
# 		OSM: pual-part pass-_mp
# 	Leviticus 22:22 w65763"חָר֣וּץ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Numbers 18:16 w81647"פְדוּיָו֙"
# 		BHS: subs
# 		OSM: qal-part pass-_ms
# 	Numbers 24:3 w85267"שְׁתֻ֥ם"
# 		BHS: subs
# 		OSM: qal-part pass-_ms
# 	Numbers 24:15 w85469"שְׁתֻ֥ם"
# 		BHS: subs
# 		OSM: qal-part pass-_ms
# 	Numbers 24:17 w85509"קַרְקַ֖ר"
# 		BHS: subs
# 		OSM: pilpel-perfect-3ms
# 	Numbers 26:9 w86068"קרואי"
# 		BHS: adjv
# 		OSM: qal-part pass-_mp
# 	Judges 7:10 w131678"יָרֵ֥א"
# 		BHS: adjv
# 		OSM: qal-part act-_ms
# 	Judges 9:6 w133012"מֻצָּ֖ב"
# 		BHS: subs
# 		OSM: hophal-part pass-_ms
# 	1_Samuel 2:22 w142525"זָקֵ֣ן"
# 		BHS: adjv
# 		OSM: qal-perfect-3ms
# 	1_Samuel 2:26 w142618"גָדֵ֖ל"
# 		BHS: adjv
# 		OSM: qal-part act-_ms
# 	1_Samuel 4:13 w143581"יך"
# 		BHS: subs
# 		OSM: hiphil-inf cons-_??
# 	1_Samuel 4:18 w143730"זָקֵ֥ן"
# 		BHS: adjv
# 		OSM: qal-perfect-3ms
# 	1_Samuel 8:13 w145338"אֹפֹֽות"
# 		BHS: subs
# 		OSM: qal-part act-_fp
# 	1_Samuel 9:9 w145726"רֹאֶ֑ה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	1_Samuel 9:9 w145737"רֹאֶֽה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	1_Samuel 9:11 w145779"רֹאֶֽה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	1_Samuel 9:18 w145951"רֹאֶֽה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	1_Samuel 9:19 w145961"רֹאֶ֔ה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	1_Samuel 16:16 w150635"טֹ֥וב"
# 		BHS: adjv
# 		OSM: qal-weqatal-3ms
# 	1_Samuel 16:23 w150779"טֹ֣וב"
# 		BHS: adjv
# 		OSM: qal-perfect-3ms
# 	1_Samuel 17:12 w151031"זָקֵ֖ן"
# 		BHS: adjv
# 		OSM: qal-perfect-3ms
# 	2_Samuel 3:36 w162531"טֹֽוב"
# 		BHS: adjv
# 		OSM: qal-perfect-3ms
# 	2_Samuel 6:1 w163428"בָּח֥וּר"
# 		BHS: subs
# 		OSM: qal-part pass-_ms
# 	2_Samuel 14:11 w168260"הרבית"
# 		BHS: subs
# 		OSM: hiphil-inf cons-_??
# 	2_Samuel 15:27 w169520"רֹואֶ֣ה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	2_Samuel 22:51 w174792"מגדיל"
# 		BHS: subs
# 		OSM: hiphil-part act-_ms
# 	1_Kings 11:2 w185063"אַהֲבָֽה"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	1_Kings 13:31 w187546"מֹותִי֙"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	2_Kings 12:13 w202883"חָזְקָֽה"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Isaiah 2:12 w212752"שָׁפֵֽל"
# 		BHS: adjv
# 		OSM: qal-weqatal-3ms
# 	Isaiah 7:11 w214443"שְׁאָ֔לָה"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Isaiah 8:6 w214830"מְשֹׂ֥ושׂ"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Isaiah 20:4 w218687"חֲשׂוּפַ֥י"
# 		BHS: subs
# 		OSM: qal-part pass-_mp
# 	Isaiah 26:3 w220320"בָּטֽוּחַ"
# 		BHS: subs
# 		OSM: qal-part pass-_ms
# 	Isaiah 29:7 w221446"צֹבֶ֨יהָ֙"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Isaiah 29:8 w221484"שֹׁוקֵקָ֑ה"
# 		BHS: adjv
# 		OSM: qal-part act-_fs
# 	Isaiah 29:13 w221600"יִרְאָתָם֙"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Isaiah 30:10 w221962"רֹאִים֙"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Isaiah 30:10 w221968"חֹזִ֔ים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Isaiah 30:22 w222214"צֵ֖א"
# 		BHS: subs
# 		OSM: qal-imperative-2ms
# 	Isaiah 32:4 w222713"דָ֑עַת"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Isaiah 38:17 w225307"מָ֑ר"
# 		BHS: adjv
# 		OSM: qal-perfect-3ms
# 	Isaiah 40:31 w226051"קֹויֵ֤"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Isaiah 46:1 w228339"נְשֻׂאֹתֵיכֶ֣ם"
# 		BHS: subs
# 		OSM: qal-part pass-_fp
# 	Isaiah 49:23 w229551"מֵינִ֣יקֹתַ֔יִךְ"
# 		BHS: subs
# 		OSM: hiphil-part act-_fp
# 	Isaiah 54:16 w231032"מַשְׁחִ֖ית"
# 		BHS: subs
# 		OSM: hiphil-part act-_ms
# 	Isaiah 62:3 w233284"צנוף"
# 		BHS: subs
# 		OSM: qal-inf abs-_??
# 	Isaiah 63:1 w233469"חֲמ֤וּץ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Jeremiah 6:28 w238164"סָרֵ֣י"
# 		BHS: adjv
# 		OSM: qal-part act-_ms
# 	Jeremiah 8:5 w239073"שֹׁובְבָ֜ה"
# 		BHS: adjv
# 		OSM: polel-perfect-3fs
# 	Jeremiah 9:5 w239492"שִׁבְתְּךָ֖"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Jeremiah 18:2 w243698"יֹּוצֵ֑ר"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Jeremiah 18:3 w243708"יֹּוצֵ֑ר"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Jeremiah 18:4 w243730"יֹּוצֵ֑ר"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Jeremiah 18:4 w243743"יֹּוצֵ֖ר"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Jeremiah 18:6 w243756"יֹּוצֵ֨ר"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Jeremiah 18:6 w243775"יֹּוצֵ֔ר"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Jeremiah 19:1 w244135"יֹוצֵ֣ר"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Jeremiah 19:11 w244406"יֹּוצֵ֔ר"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Jeremiah 22:7 w245451"מַשְׁחִתִ֖ים"
# 		BHS: subs
# 		OSM: hiphil-part act-_mp
# 	Jeremiah 37:21 w255562"אֹפִ֔ים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Ezekiel 9:2 w268120"לָבֻ֣שׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Ezekiel 9:3 w268158"לָּבֻ֣שׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Ezekiel 9:11 w268357"לְבֻ֣שׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Ezekiel 10:2 w268400"לְבֻ֣שׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Ezekiel 10:6 w268508"לְבֻֽשׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Ezekiel 10:7 w268556"לְבֻ֣שׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Ezekiel 16:26 w271479"גִּדְלֵ֣י"
# 		BHS: adjv
# 		OSM: qal-part act-_mp
# 	Ezekiel 16:30 w271536"אֲמֻלָה֙"
# 		BHS: subs
# 		OSM: qal-part pass-_fs
# 	Ezekiel 17:9 w272366"מַשְׂאֹ֥ות"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Ezekiel 23:15 w275933"סְרוּחֵ֤י"
# 		BHS: adjv
# 		OSM: qal-part pass-_mp
# 	Ezekiel 23:42 w276431"סובאים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Ezekiel 27:25 w278188"שָׁרֹותַ֖יִךְ"
# 		BHS: subs
# 		OSM: qal-part act-_fp
# 	Ezekiel 28:17 w278643"רַ֥אֲוָה"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Ezekiel 36:3 w282457"שַׁמֹּות֩"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Ezekiel 42:5 w286778"קְצֻרֹ֑ות"
# 		BHS: adjv
# 		OSM: qal-part pass-_fp
# 	Ezekiel 44:24 w288284"שׁפט"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Hosea 2:3 w291156"רֻחָֽמָה"
# 		BHS: nmpr
# 		OSM: pual-perfect-3fs
# 	Hosea 7:4 w292420"אֹפֶ֑ה"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Hosea 7:6 w292451"אֹֽפֵהֶ֔ם"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Hosea 9:10 w292959"אָהֳבָֽם"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Amos 6:4 w297003"סְרֻחִ֖ים"
# 		BHS: adjv
# 		OSM: qal-part pass-_mp
# 	Amos 6:7 w297052"סְרוּחִֽים"
# 		BHS: adjv
# 		OSM: qal-part pass-_mp
# 	Jonah 1:15 w298913"זַּעְפֹּֽו"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Micah 3:7 w300185"חֹזִ֗ים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Zephaniah 3:10 w303917"פּוּצַ֔י"
# 		BHS: subs
# 		OSM: qal-part pass-_ms
# 	Zechariah 3:3 w305712"לָבֻ֖שׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Zechariah 11:2 w308050"בצור"
# 		BHS: subs
# 		OSM: qal-part pass-_ms
# 	Zechariah 11:13 w308260"יֹּוצֵ֔ר"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Zechariah 11:13 w308280"יֹּוצֵֽר"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	Psalms 18:15 w312825"רָ֝ב"
# 		BHS: adjv
# 		OSM: qal-perfect-3ms
# 	Psalms 55:23 w319601"מֹ֗וט"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Psalms 66:9 w321056"מֹּ֣וט"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Psalms 69:26 w321892"נְשַׁמָּ֑ה"
# 		BHS: subs
# 		OSM: niphal-part act-_fs
# 	Psalms 75:7 w323092"הָרִֽים"
# 		BHS: subs
# 		OSM: hiphil-inf cons-_??
# 	Psalms 103:14 w328142"זָ֝כ֗וּר"
# 		BHS: adjv
# 		OSM: qal-part act-_ms
# 	Psalms 105:19 w328741"עֵ֥ת"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Psalms 107:9 w329541"שֹׁקֵקָ֑ה"
# 		BHS: adjv
# 		OSM: qal-part act-_fs
# 	Psalms 112:7 w330531"בָּטֻ֥חַ"
# 		BHS: subs
# 		OSM: qal-part pass-_ms
# 	Psalms 121:3 w332745"מֹּ֣וט"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Psalms 140:10 w334669"מְסִבָּ֑י"
# 		BHS: subs
# 		OSM: hiphil-part act-_mp
# 	Psalms 144:14 w335225"יֹוצֵ֑את"
# 		BHS: subs
# 		OSM: qal-part act-_fs
# 	Psalms 147:11 w335659"יְרֵאָ֑יו"
# 		BHS: adjv
# 		OSM: qal-part act-_mp
# 	Job 8:14 w338200"יָקֹ֥וט"
# 		BHS: subs
# 		OSM: qal-imperfect-3ms
# 	Job 11:17 w338975"תָּ֝עֻ֗פָה"
# 		BHS: subs
# 		OSM: qal-imperfect-3fs
# 	Job 22:21 w341684"תְּֽבֹואַתְךָ֥"
# 		BHS: subs
# 		OSM: qal-imperfect-3fs
# 	Job 26:9 w342322"פַּרְשֵׁ֖ז"
# 		BHS: subs
# 		OSM: pilel-inf abs-_??
# 	Job 30:22 w343313"תשׁוה"
# 		BHS: subs
# 		OSM: pual-imperfect-2ms
# 	Job 31:13 w343527"רִבָ֗ם"
# 		BHS: subs
# 		OSM: niphal-inf cons-_??
# 	Proverbs 20:30 w352405"תמריק"
# 		BHS: subs
# 		OSM: hiphil-imperfect-3fs
# 	Proverbs 24:7 w353417"רָאמֹ֣ות"
# 		BHS: subs
# 		OSM: qal-part act-_fp
# 	Proverbs 24:11 w353454"מָטִ֥ים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	Proverbs 27:17 w354461"יָ֑חַד"
# 		BHS: subs
# 		OSM: hiphil-imperfect-3ms
# 	Proverbs 27:17 w354464"יַ֣חַד"
# 		BHS: subs
# 		OSM: hiphil-imperfect-3ms
# 	Proverbs 29:6 w354926"שָׂמֵֽחַ"
# 		BHS: adjv
# 		OSM: qal-weqatal-3ms
# 	Proverbs 31:21 w355702"לָבֻ֥שׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Ruth 2:1 w356235"מידע"
# 		BHS: subs
# 		OSM: pual-part pass-_ms
# 	Song_of_songs 2:13 w357961"לכי"
# 		BHS: prep
# 		OSM: qal-imperative-2fs
# 	Song_of_songs 3:8 w358159"אֲחֻ֣זֵי"
# 		BHS: adjv
# 		OSM: qal-part pass-_mp
# 	Ecclesiastes 1:17 w359557"דַ֥עַת"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	Ecclesiastes 4:1 w360559"עֲשֻׁקִ֔ים"
# 		BHS: subs
# 		OSM: qal-part pass-_mp
# 	Ecclesiastes 8:13 w362150"יָרֵ֖א"
# 		BHS: adjv
# 		OSM: qal-part act-_ms
# 	Lamentations 2:19 w364388"עֲטוּפִ֥ים"
# 		BHS: adjv
# 		OSM: qal-part pass-_mp
# 	Lamentations 4:8 w365069"יָבֵ֖שׁ"
# 		BHS: adjv
# 		OSM: qal-perfect-3ms
# 	Lamentations 4:10 w365095"בָרֹות֙"
# 		BHS: subs
# 		OSM: piel-inf cons-_??
# 	Lamentations 5:18 w365419"שָּׁמֵ֔ם"
# 		BHS: adjv
# 		OSM: qal-perfect-3ms
# 	Daniel 7:23 w375052"כָּל"
# 		BHS: subs
# 		OSM: peal-imperfect-3fs
# 	Daniel 10:5 w376539"לָב֣וּשׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Daniel 12:6 w378003"לְב֣וּשׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Daniel 12:7 w378023"לְב֣וּשׁ"
# 		BHS: adjv
# 		OSM: qal-part pass-_ms
# 	Ezra 6:17 w380826"חטיא"
# 		BHS: subs
# 		OSM: pael-inf cons-_??
# 	Ezra 8:17 w381809"נתונים"
# 		BHS: subs
# 		OSM: qal-part pass-_mp
# 	Nehemiah 13:21 w391024"לֵנִים֙"
# 		BHS: adjv
# 		OSM: qal-part act-_mp
# 	1_Chronicles 4:23 w393168"יֹּ֣וצְרִ֔ים"
# 		BHS: subs
# 		OSM: qal-part act-_mp
# 	1_Chronicles 19:10 w401387"בָּחוּר֙"
# 		BHS: subs
# 		OSM: qal-part pass-_ms
# 	2_Chronicles 17:12 w414807"גָדֵ֖ל"
# 		BHS: adjv
# 		OSM: qal-part act-_ms
# 	2_Chronicles 19:2 w415723"חֹזֶה֒"
# 		BHS: subs
# 		OSM: qal-part act-_ms
# 	2_Chronicles 24:22 w418754"מֹותֹ֣ו"
# 		BHS: subs
# 		OSM: qal-inf cons-_??
# 	2_Chronicles 33:18 w424305"חֹזִ֔ים"
# 		BHS: subs
# 		OSM: qal-part act-_mp

# %%
cases = extraOSM
closerLook |= cases
print("{} cases merged into {} closer look items".format(len(cases), len(closerLook)))
# Out:
# 161 cases merged into 348 closer look items

# %% [markdown]
# ## Common verb base
# The rest of the comparison is carried out for the *common verb base*, i.e. those words
# that have been marked as verb in the BHSA and in the OSM.

# %%
verbBase = verbsOSM & verbsBHSfocus
print("Common verb base: {} occurrences".format(len(verbBase)))
# Out:
# Common verb base: 73481 occurrences

# %%
closerLook |= cases
print("{} cases merged into {} closer look items".format(len(cases), len(closerLook)))
# Out:
# 161 cases merged into 348 closer look items

# %% [markdown]
# # Feature comparison
# We are going to compare all features.

# %%
cases = showFeatures(verbBase)
# Out:
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
# o-o COMPARING FEATURE stem
# o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o-o
#
#
# ---------------------------------------------------------------------------------
# --- stem OSM ===> BHS
# ---------------------------------------------------------------------------------
#
# aphel
# 	haphel          (   20x)
# 	aphel           (    3x)
# 				Daniel 3:1 w371624"אֲקִימֵהּ֙"
# 					BHS: aphel-perfect-3ms
# 					OSM: aphel-perfect-3ms
# 				Daniel 4:11 w372576"אַתַּ֥רוּ"
# 					BHS: aphel-imperative-2mp
# 					OSM: aphel-imperative-2mp
# 				Ezra 5:15 w380360"אֲחֵ֣ת"
# 					BHS: aphel-imperative-2ms
# 					OSM: aphel-imperative-2ms
# 	pael            (    1x)
# 				Ezra 4:12 w379764"יַחִֽיטוּ"
# 					BHS: pael-perfect-3mp
# 					OSM: aphel-imperfect-3mp
# haphel
# 	haphel          (  141x)
# 	aphel           (    1x)
# 				Daniel 5:12 w373436"אַֽחֲוָיַ֨ת"
# 					BHS: aphel-inf cons-???
# 					OSM: haphel-inf cons-_??
# 	hithpeel        (    1x)
# 				Daniel 2:9 w370708"הזמנתון"
# 					BHS: hithpeel-perfect-2mp
# 					OSM: haphel-perfect-2mp
# 	peal            (    1x)
# 				Daniel 2:31 w371172"חָזֵ֤ה"
# 					BHS: peal-part act-?ms
# 					OSM: haphel-part act-_ms
# hiphil
# 	hiphil          ( 9351x)
# 	qal             (   38x)
# 				Judges 7:21 w132009"יניסו"
# 					BHS: qal-wayyiqtol-3mp
# 					OSM: hiphil-wayyiqtol-3mp
# 				1_Samuel 17:39 w151660"יֹּ֣אֶל"
# 					BHS: qal-wayyiqtol-3ms
# 					OSM: hiphil-wayyiqtol-3ms
# 				2_Samuel 15:8 w169063"ישׁיב"
# 					BHS: qal-inf abs-???
# 					OSM: hiphil-imperfect-3ms
# 				2_Samuel 18:3 w171145"עזיר"
# 					BHS: qal-inf cons-???
# 					OSM: hiphil-inf cons-_??
# 				2_Samuel 22:15 w174458"יהמם"
# 					BHS: qal-wayyiqtol-3ms
# 					OSM: hiphil-wayyiqtol-3ms
# 				1_Kings 20:33 w192731"יַּחְלְט֣וּ"
# 					BHS: qal-wayyiqtol-3mp
# 					OSM: hiphil-wayyiqtol-3mp
# 				Isaiah 63:3 w233524"אֶגְאָֽלְתִּי"
# 					BHS: qal-imperfect-1?s
# 					OSM: hiphil-perfect-1cs
# 				Jeremiah 8:13 w239233"אֲסִיפֵ֖ם"
# 					BHS: qal-imperfect-1?s
# 					OSM: hiphil-imperfect-1cs
# 				Jeremiah 34:11 w253428"יכבישׁום"
# 					BHS: qal-wayyiqtol-3mp
# 					OSM: hiphil-wayyiqtol-3mp
# 				Ezekiel 21:36 w275173"אָפִ֣יחַ"
# 					BHS: qal-imperfect-1?s
# 					OSM: hiphil-imperfect-1cs
# 				Amos 2:13 w295905"תָּעִיק֙"
# 					BHS: qal-imperfect-3fs
# 					OSM: hiphil-imperfect-3fs
# 				Nahum 3:8 w301986"תֵֽיטְבִי֙"
# 					BHS: qal-imperfect-2fs
# 					OSM: hiphil-imperfect-2fs
# 				Habakkuk 2:3 w302499"יָפֵ֥חַ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Zephaniah 1:2 w303103"אָסֵ֜ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303112"אָסֵ֨ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Zephaniah 1:3 w303116"אָסֵ֤ף"
# 					BHS: qal-part act-?ms
# 					OSM: hiphil-imperfect-1cs
# 				Psalms 10:5 w311821"יָפִ֥יחַ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Psalms 12:6 w312121"יָפִ֥יחַֽ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Psalms 56:7 w319689"יצפינו"
# 					BHS: qal-imperfect-3mp
# 					OSM: hiphil-imperfect-3mp
# 				Psalms 66:7 w321035"ירימו"
# 					BHS: qal-imperfect-3mp
# 					OSM: hiphil-jussive-3mp
# 				Psalms 73:10 w322614"ישׁיב"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Psalms 77:12 w323365"אזכיר"
# 					BHS: qal-imperfect-1?s
# 					OSM: hiphil-imperfect-1cs
# 				Psalms 89:18 w325905"תרים"
# 					BHS: qal-imperfect-3fs
# 					OSM: hiphil-imperfect-2ms
# 				Job 19:3 w340658"תַּהְכְּרוּ"
# 					BHS: qal-imperfect-2mp
# 					OSM: hiphil-imperfect-2mp
# 				Job 24:6 w341977"יקצירו"
# 					BHS: qal-imperfect-3mp
# 					OSM: hiphil-imperfect-3mp
# 				Proverbs 6:19 w348420"יָפִ֣יחַ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Proverbs 12:17 w350065"יָפִ֣יחַ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Proverbs 14:5 w350439"יָפִ֥יחַ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Proverbs 14:25 w350621"יָפִ֖חַ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Proverbs 17:13 w351468"תמישׁ"
# 					BHS: qal-imperfect-3fs
# 					OSM: hiphil-imperfect-3fs
# 				Proverbs 19:5 w351890"יָפִ֥יחַ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Proverbs 19:9 w351932"יָפִ֖יחַ"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Proverbs 21:29 w352691"יכין"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				Proverbs 29:8 w354937"יָפִ֣יחוּ"
# 					BHS: qal-imperfect-3mp
# 					OSM: hiphil-imperfect-3mp
# 				Lamentations 3:20 w364603"תשׁיח"
# 					BHS: qal-imperfect-3fs
# 					OSM: hiphil-imperfect-3fs
# 				Daniel 11:18 w377314"ישׁב"
# 					BHS: qal-imperfect-3ms
# 					OSM: hiphil-imperfect-3ms
# 				2_Chronicles 28:23 w420878"יַעְזְר֑וּנִי"
# 					BHS: qal-imperfect-3mp
# 					OSM: hiphil-imperfect-3mp
# 				2_Chronicles 33:16 w424261"יכן"
# 					BHS: qal-wayyiqtol-3ms
# 					OSM: hiphil-wayyiqtol-3ms
# 	niphal          (    3x)
# 				Exodus 16:2 w37382"ילינו"
# 					BHS: niphal-wayyiqtol-3mp
# 					OSM: hiphil-wayyiqtol-3mp
# 				Psalms 72:17 w322495"ינין"
# 					BHS: niphal-imperfect-3ms
# 					OSM: hiphil-jussive-3ms
# 				Psalms 140:11 w334673"ימיטו"
# 					BHS: niphal-imperfect-3mp
# 					OSM: hiphil-jussive-3mp
# 	piel            (    3x)
# 				Isaiah 45:2 w227909"אושׁר"
# 					BHS: piel-imperfect-1?s
# 					OSM: hiphil-imperfect-1cs
# 				Ezra 8:17 w381788"אוצאה"
# 					BHS: piel-wayyiqtol-1?s
# 					OSM: hiphil-wayyiqtol-1cs
# 				2_Chronicles 34:25 w425104"יקטירו"
# 					BHS: piel-wayyiqtol-3mp
# 					OSM: hiphil-wayyiqtol-3mp
# 	hophal          (    1x)
# 				Daniel 8:11 w375455"הרים"
# 					BHS: hophal-perfect-3ms
# 					OSM: hiphil-perfect-3ms
# hishtaphel
# 	hishtaphel      (   95x)
# hithpaal
# 	hithpaal        (   28x)
# 	etpaal          (    3x)
# 				Daniel 2:9 w370715"יִשְׁתַּנֵּ֑א"
# 					BHS: etpaal-imperfect-3ms
# 					OSM: hithpaal-imperfect-3ms
# 				Daniel 5:10 w373387"יִשְׁתַּנֹּֽו"
# 					BHS: etpaal-imperfect-3mp
# 					OSM: hithpaal-imperfect-3mp
# 				Daniel 7:28 w375163"יִשְׁתַּנֹּ֣ון"
# 					BHS: etpaal-imperfect-3mp
# 					OSM: hithpaal-imperfect-3mp
# 	hithpeel        (    1x)
# 				Daniel 2:13 w370814"הִתְקְטָלָֽה"
# 					BHS: hithpeel-inf cons-???
# 					OSM: hithpaal-inf cons-_??
# hithpael
# 	hithpael        (  830x)
# 	hishtaphel      (   77x)
# 				Genesis 18:2 w7840"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 19:1 w8447"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 23:7 w10836"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 23:12 w10939"יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 24:26 w11611"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 24:52 w12151"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 33:3 w18135"יִּשְׁתַּ֤חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 33:7 w18201"יִּֽשְׁתַּחֲו֑וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 33:7 w18209"יִּֽשְׁתַּחֲוֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 37:10 w20376"הִשְׁתַּחֲוֹ֥ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Genesis 42:6 w23531"יִּשְׁתַּֽחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 43:26 w24672"יִּשְׁתַּחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 47:31 w27292"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 48:12 w27526"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Exodus 12:27 w35322"יִּֽשְׁתַּחֲוּֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Exodus 18:7 w38590"יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Exodus 32:8 w46673"יִּשְׁתַּֽחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Exodus 34:8 w47947"יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Leviticus 26:1 w68167"הִֽשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Numbers 22:31 w84474"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Deuteronomy 17:3 w102991"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Joshua 5:14 w115320"יִּשְׁתָּ֔חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Judges 2:12 w128463"יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Judges 2:17 w128557"יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Judges 7:15 w131830"יִּשְׁתָּ֑חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 1:3 w141597"הִֽשְׁתַּחֲוֹ֧ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				1_Samuel 1:19 w141909"יִּֽשְׁתַּחֲווּ֙"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				1_Samuel 1:28 w142112"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 2:36 w142850"הִשְׁתַּחֲוֹ֣ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				1_Samuel 15:31 w150183"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 20:41 w154312"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 24:9 w156189"יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 28:14 w158837"יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 1:2 w160523"יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 9:6 w165082"יִּשְׁתָּ֑חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 9:8 w165122"יִּשְׁתַּ֕חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 12:20 w166861"יִּשְׁתָּ֑חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 14:22 w168581"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 14:33 w168865"יִּשְׁתַּ֨חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 15:5 w168988"הִשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				2_Samuel 18:21 w171622"יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 18:28 w171799"יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 24:20 w175932"יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 1:23 w176556"יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 1:47 w177139"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 1:53 w177267"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 2:19 w177689"יִּשְׁתַּ֣חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 11:33 w185700"יִּֽשְׁתַּחֲווּ֮"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				1_Kings 16:31 w189749"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Kings 2:15 w195624"יִּשְׁתַּחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Kings 5:18 w197911"הִשְׁתַּחֲוֹ֨ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				2_Kings 17:16 w205932"יִּֽשְׁתַּחֲווּ֙"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Kings 21:3 w208743"יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Kings 21:21 w209152"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Isaiah 2:20 w212871"הִֽשְׁתַּחֲוֹ֔ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Isaiah 44:15 w227628"יִּשְׁתָּ֔חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Isaiah 66:23 w234974"הִשְׁתַּחֲוֹ֥ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Jeremiah 1:16 w235290"יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Jeremiah 7:2 w238236"הִֽשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Jeremiah 16:11 w242886"יִּשְׁתַּחֲו֣וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Jeremiah 22:9 w245500"יִּֽשְׁתַּחֲו֛וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Jeremiah 26:2 w247887"הִשְׁתַּחֲוֹ֣ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Ezekiel 46:9 w289272"הִֽשְׁתַּחֲוֹ֗ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Zechariah 14:16 w309317"הִֽשְׁתַּחֲוֹת֙"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Zechariah 14:17 w309342"הִֽשְׁתַּחֲוֹ֔ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Psalms 106:19 w329153"יִּשְׁתַּחֲו֗וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Job 1:20 w336496"יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Nehemiah 8:6 w387353"יִּשְׁתַּחֲוֻּ֛"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				1_Chronicles 21:21 w402295"יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Chronicles 29:20 w406599"יִּֽשְׁתַּחֲו֛וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 7:3 w410083"יִּֽשְׁתַּֽחֲו֔וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 7:22 w410599"יִּשְׁתַּחֲו֥וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 20:18 w416391"הִֽשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				2_Chronicles 24:17 w418632"יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 29:29 w421654"יִּֽשְׁתַּחֲוֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 29:30 w421685"יִּֽשְׁתַּחֲוֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 33:3 w423941"יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 	piel            (    2x)
# 				Ezekiel 37:23 w283685"יִֽטַמְּא֣וּ"
# 					BHS: piel-imperfect-3mp
# 					OSM: hithpael-imperfect-3mp
# 				Nehemiah 12:30 w390106"יִּֽטַּהֲר֔וּ"
# 					BHS: piel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 	etpaal          (    1x)
# 				2_Chronicles 20:35 w416767"אֶתְחַבַּר֙"
# 					BHS: etpaal-perfect-3ms
# 					OSM: hithpael-perfect-3ms
# 	niphal          (    1x)
# 				2_Chronicles 32:23 w423646"יִּנַּשֵּׂ֛א"
# 					BHS: niphal-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 	tiphal          (    1x)
# 				Proverbs 12:9 w349994"מְּתַכַּבֵּ֗ד"
# 					BHS: tiphal-part act-?ms
# 					OSM: hithpael-part act-_ms
# hithpalpel
# 	hithpael        (   20x)
# hithpeel
# 	hithpeel        (   50x)
# hithpoel
# 	hithpael        (    2x)
# hithpolel
# 	hithpael        (  104x)
# 	hithpoel        (    3x)
# 				Isaiah 52:5 w230389"מִנֹּאָֽץ"
# 					BHS: hithpoel-part act-?ms
# 					OSM: hithpolel-part pass-_ms
# 				Jeremiah 25:16 w247375"הִֽתְגֹּֽעֲשׁ֖וּ"
# 					BHS: hithpoel-perfect-3?p
# 					OSM: hithpolel-weqatal-3cp
# 				Jeremiah 46:8 w259825"יִתְגֹּ֣עֲשׁוּ"
# 					BHS: hithpoel-imperfect-3mp
# 					OSM: hithpolel-imperfect-3mp
# 	etpaal          (    1x)
# 				Psalms 76:6 w323181"אֶשְׁתֹּולְל֨וּ"
# 					BHS: etpaal-perfect-3?p
# 					OSM: hithpolel-perfect-3cp
# 	hithpaal        (    1x)
# 				Daniel 5:23 w373712"הִתְרֹומַ֡מְתָּ"
# 					BHS: hithpaal-perfect-2ms
# 					OSM: hithpolel-perfect-2ms
# hophal
# 	hophal          (  411x)
# 	hiphil          (    1x)
# 				Proverbs 11:25 w349860"יֹורֶֽא"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: hophal-imperfect-3ms
# 	qal             (    1x)
# 				Proverbs 19:16 w352001"יומת"
# 					BHS: qal-imperfect-3ms
# 					OSM: hophal-imperfect-3ms
# hothpaal
# 	hothpaal        (    8x)
# ishtaphel
# 	shaphel         (    1x)
# ithpaal
# 	etpaal          (    2x)
# ithpeel
# 	etpeel          (    3x)
# ithpoel
# 	etpaal          (    1x)
# niphal
# 	niphal          ( 4127x)
# 	hiphil          (    4x)
# 				Exodus 16:7 w37525"תלונו"
# 					BHS: hiphil-imperfect-2mp
# 					OSM: niphal-imperfect-2mp
# 				Leviticus 21:9 w65106"תֵחֵ֖ל"
# 					BHS: hiphil-imperfect-3fs
# 					OSM: niphal-imperfect-3fs
# 				Numbers 14:36 w79137"ילונו"
# 					BHS: hiphil-wayyiqtol-3mp
# 					OSM: niphal-wayyiqtol-3mp
# 				1_Samuel 13:8 w147978"ייחל"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: niphal-wayyiqtol-3ms
# 	qal             (    4x)
# 				Genesis 29:27 w15428"נִתְּנָ֨ה"
# 					BHS: qal-imperfect-1?p
# 					OSM: niphal-weqatal-3fs
# 				2_Samuel 23:6 w174905"יִקָּֽחוּ"
# 					BHS: qal-imperfect-3mp
# 					OSM: niphal-imperfect-3mp
# 				Psalms 68:3 w321245"הִנְדֹּ֥ף"
# 					BHS: qal-inf cons-???
# 					OSM: niphal-inf cons-_??
# 				Job 31:31 w343716"נִשְׂבָּֽע"
# 					BHS: qal-imperfect-1?p
# 					OSM: niphal-part pass-_ms
# 	piel            (    3x)
# 				Psalms 93:5 w326759"נַאֲוָה"
# 					BHS: piel-perfect-3ms
# 					OSM: niphal-perfect-3ms
# 				Job 4:2 w337106"נִסָּ֬ה"
# 					BHS: piel-perfect-3ms
# 					OSM: niphal-perfect-3ms
# 				Song_of_songs 1:6 w357664"נִֽחֲרוּ"
# 					BHS: piel-perfect-3?p
# 					OSM: niphal-perfect-3cp
# 	hophal          (    1x)
# 				2_Samuel 21:6 w173854"ינתן"
# 					BHS: hophal-imperfect-3ms
# 					OSM: niphal-jussive-3ms
# nithpael
# 	nithpael        (    3x)
# pael
# 	pael            (   83x)
# palel
# 	piel            (    7x)
# peal
# 	peal            (  630x)
# 	haphel          (    1x)
# 				Daniel 5:19 w373622"מַחֵ֔א"
# 					BHS: haphel-part act-?ms
# 					OSM: peal-part act-_ms
# 	pael            (    1x)
# 				Daniel 2:40 w371367"מְרָעַ֥ע"
# 					BHS: pael-part act-?ms
# 					OSM: peal-part act-_ms
# 	peil            (    1x)
# 				Daniel 6:27 w374483"שִׂ֣ים"
# 					BHS: peil-perfect-3ms
# 					OSM: peal-perfect-3ms
# pealal
# 	piel            (    5x)
# peil
# 	peil            (   39x)
# 	peal            (   22x)
# 				Daniel 2:9 w370707"שְׁחִיתָה֙"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 2:31 w371190"דְּחִֽיל"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Daniel 2:41 w371387"פְלִיגָה֙"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 2:42 w371422"תְבִירָֽה"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 3:25 w372171"שְׁרַ֨יִן֙"
# 					BHS: peal-part pass-?mp
# 					OSM: peil-part pass-_mp
# 				Daniel 3:28 w372260"בְּרִ֤יךְ"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Daniel 4:32 w373089"חֲשִׁיבִ֔ין"
# 					BHS: peal-part pass-?mp
# 					OSM: peil-part pass-_mp
# 				Daniel 6:4 w373909"עֲשִׁ֔ית"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Daniel 6:5 w373933"שְׁחִיתָ֜ה"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 6:5 w373948"שְׁחִיתָ֔ה"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 6:11 w374067"פְּתִיחָ֥ן"
# 					BHS: peal-part pass-?fp
# 					OSM: peil-part pass-_fp
# 				Daniel 6:13 w374112"קְרִ֨יבוּ"
# 					BHS: peal-perfect-3mp
# 					OSM: peil-perfect-3mp
# 				Daniel 7:7 w374694"דְּחִילָה֩"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Daniel 7:19 w374963"דְּחִילָ֣ה"
# 					BHS: peal-part pass-?fs
# 					OSM: peil-part pass-_fs
# 				Ezra 4:12 w379740"יְדִ֨יעַ֙"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Ezra 4:13 w379766"יְדִ֨יעַ֙"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Ezra 5:7 w380161"כְּתִ֣יב"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-perfect-3ms
# 				Ezra 5:8 w380169"יְדִ֣יעַ"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Ezra 5:16 w380394"שְׁלִֽם"
# 					BHS: peal-perfect-3ms
# 					OSM: peil-part pass-_ms
# 				Ezra 6:2 w380464"כְּתִ֥יב"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-perfect-3ms
# 				Ezra 6:11 w380685"זְקִ֖יף"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 				Ezra 7:12 w381158"גְּמִ֖יר"
# 					BHS: peal-part pass-?ms
# 					OSM: peil-part pass-_ms
# 	pael            (    1x)
# 				Daniel 5:21 w373662"שׁוי"
# 					BHS: pael-perfect-3mp
# 					OSM: peil-perfect-3mp
# piel
# 	piel            ( 6471x)
# 	hiphil          (    3x)
# 				Deuteronomy 26:12 w107418"עְשֵׂר"
# 					BHS: hiphil-inf cons-???
# 					OSM: piel-inf cons-_??
# 				Psalms 18:51 w313162"מגדל"
# 					BHS: hiphil-part act-?ms
# 					OSM: piel-part act-_ms
# 				Nehemiah 10:39 w389163"עְשֵׂ֣ר"
# 					BHS: hiphil-inf cons-???
# 					OSM: piel-inf cons-_??
# 	qal             (    3x)
# 				Genesis 8:10 w3740"יָּ֣חֶל"
# 					BHS: qal-wayyiqtol-3ms
# 					OSM: piel-wayyiqtol-3ms
# 				Psalms 23:6 w313954"יִ֭רְדְּפוּנִי"
# 					BHS: qal-imperfect-3mp
# 					OSM: piel-imperfect-3mp
# 				Psalms 67:2 w321170"יְחָנֵּ֥נוּ"
# 					BHS: qal-imperfect-3ms
# 					OSM: piel-imperfect-3ms
# 	niphal          (    2x)
# 				Genesis 30:27 w16018"נִחַ֕שְׁתִּי"
# 					BHS: niphal-perfect-1?s
# 					OSM: piel-perfect-1cs
# 				Ezekiel 16:39 w271716"נִתְּצ֣וּ"
# 					BHS: niphal-perfect-3?p
# 					OSM: piel-weqatal-3cp
# pilpel
# 	piel            (   51x)
# poal
# 	pual            (    4x)
# 	piel            (    3x)
# 				Nahum 3:17 w302145"נֹודַ֔ד"
# 					BHS: piel-perfect-3ms
# 					OSM: poal-perfect-3ms
# 				Psalms 102:9 w327809"מְ֝הֹולָלַ֗י"
# 					BHS: piel-part act-?mp
# 					OSM: poal-part pass-_mp
# 				Job 26:11 w342337"יְרֹופָ֑פוּ"
# 					BHS: piel-imperfect-3mp
# 					OSM: poal-imperfect-3mp
# 	poal            (    1x)
# 				Jeremiah 12:2 w240858"שֹׁרָ֔שׁוּ"
# 					BHS: poal-perfect-3?p
# 					OSM: poal-perfect-3cp
# poel
# 	piel            (   68x)
# 	poel            (    5x)
# 				Isaiah 10:13 w215743"שֹׁושֵׂ֔תִי"
# 					BHS: poel-perfect-1?s
# 					OSM: poel-perfect-1cs
# 				Isaiah 40:24 w225941"שֹׁרֵ֥שׁ"
# 					BHS: poel-perfect-3ms
# 					OSM: poel-perfect-3ms
# 				Hosea 13:3 w293752"יְסֹעֵ֣ר"
# 					BHS: poel-imperfect-3ms
# 					OSM: poel-imperfect-3ms
# 				Psalms 77:18 w323420"זֹ֤רְמוּ"
# 					BHS: poel-perfect-3?p
# 					OSM: poel-perfect-3cp
# 				Job 9:15 w338411"מְשֹׁפְטִ֗י"
# 					BHS: poel-part act-?ms
# 					OSM: poel-part act-_ms
# 	hophal          (    1x)
# 				Isaiah 59:13 w232453"הֹגֹ֛ו"
# 					BHS: hophal-inf abs-???
# 					OSM: poel-inf abs-_??
# 	poal            (    1x)
# 				1_Samuel 21:3 w154423"יֹודַ֔עְתִּי"
# 					BHS: poal-perfect-1?s
# 					OSM: poel-perfect-1cs
# 	qal             (    1x)
# 				Amos 5:11 w296677"בֹּושַׁסְכֶ֞ם"
# 					BHS: qal-inf cons-???
# 					OSM: poel-inf cons-_??
# polal
# 	pual            (   11x)
# polel
# 	piel            (  179x)
# 	pael            (    1x)
# 				Daniel 4:34 w373146"מְרֹומֵ֤ם"
# 					BHS: pael-part act-?ms
# 					OSM: polel-part act-_ms
# polpal
# 	pual            (    2x)
# pual
# 	pual            (  443x)
# 	hophal          (    3x)
# 				Isaiah 12:5 w216481"מידעת"
# 					BHS: hophal-part pass-?fs
# 					OSM: pual-part pass-_fs
# 				Isaiah 49:24 w229570"יֻקַּ֥ח"
# 					BHS: hophal-imperfect-3ms
# 					OSM: pual-imperfect-3ms
# 				Isaiah 49:25 w229586"יֻקָּ֔ח"
# 					BHS: hophal-imperfect-3ms
# 					OSM: pual-imperfect-3ms
# 	qal             (    2x)
# 				Psalms 72:20 w322528"כָּלּ֥וּ"
# 					BHS: qal-perfect-3?p
# 					OSM: pual-perfect-3cp
# 				Ecclesiastes 9:12 w362650"יֽוּקָשִׁים֙"
# 					BHS: qal-part pass-?mp
# 					OSM: pual-part pass-_mp
# 	qalpassive      (    2x)
# 				Isaiah 18:2 w217999"מֹורָ֔ט"
# 					BHS: qalpassive-part pass-?ms
# 					OSM: pual-part pass-_ms
# 				Isaiah 18:7 w218113"מֹורָ֔ט"
# 					BHS: qalpassive-part pass-?ms
# 					OSM: pual-part pass-_ms
# 	poal            (    1x)
# 				Job 31:8 w343483"יְשֹׁרָֽשׁוּ"
# 					BHS: poal-imperfect-3mp
# 					OSM: pual-imperfect-3mp
# pulal
# 	pual            (   15x)
# qal
# 	qal             (49958x)
# 	hiphil          (   34x)
# 				Numbers 21:32 w83725"יירשׁ"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# 				Numbers 32:7 w90015"תנואון"
# 					BHS: hiphil-imperfect-2mp
# 					OSM: qal-imperfect-2mp
# 				2_Samuel 12:20 w166852"יָּ֗סֶךְ"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# 				2_Samuel 15:20 w169328"אנועך"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				2_Samuel 18:22 w171660"מֹצֵֽאת"
# 					BHS: hiphil-part act-?fs
# 					OSM: qal-part act-_fs
# 				2_Samuel 20:5 w173209"ייחר"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# 				1_Kings 18:36 w191138"עֲלֹ֣ות"
# 					BHS: hiphil-inf cons-???
# 					OSM: qal-inf cons-_??
# 				2_Kings 3:20 w196263"עֲלֹ֣ות"
# 					BHS: hiphil-inf cons-???
# 					OSM: qal-inf cons-_??
# 				2_Kings 3:24 w196364"יבו"
# 					BHS: hiphil-wayyiqtol-3mp
# 					OSM: qal-wayyiqtol-3mp
# 				2_Kings 9:30 w200970"תָּ֨שֶׂם"
# 					BHS: hiphil-wayyiqtol-3fs
# 					OSM: qal-wayyiqtol-3fs
# 				2_Kings 23:9 w210086"יַֽעֲלוּ֙"
# 					BHS: hiphil-imperfect-3mp
# 					OSM: qal-imperfect-3mp
# 				Isaiah 64:5 w233863"נָּ֤בֶל"
# 					BHS: hiphil-wayyiqtol-1?p
# 					OSM: qal-wayyiqtol-1cp
# 				Isaiah 65:9 w234110"הֹוצֵאתִ֤י"
# 					BHS: hiphil-perfect-1?s
# 					OSM: qal-perfect-1cs
# 				Jeremiah 2:36 w235976"תֵּזְלִ֥י"
# 					BHS: hiphil-imperfect-2fs
# 					OSM: qal-imperfect-2fs
# 				Jeremiah 4:19 w236889"אחולה"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-cohortative-1cs
# 				Jeremiah 5:28 w237620"יַצְלִ֑יחוּ"
# 					BHS: hiphil-imperfect-3mp
# 					OSM: qal-wayyiqtol-3mp
# 				Jeremiah 33:26 w253138"אשׁוב"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Jeremiah 49:39 w261867"אשׁוב"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Jeremiah 50:44 w262688"ארוצם"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Ezekiel 48:14 w290467"יעבור"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 				Joel 4:1 w295018"אשׁוב"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Jonah 4:6 w299397"יַּ֣עַל"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# 				Micah 5:11 w300804"הִכְרַתִּ֥י"
# 					BHS: hiphil-perfect-1?s
# 					OSM: qal-cohortative-1cs
# 				Psalms 54:7 w319335"ישׁוב"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 				Psalms 55:20 w319558"יַעֲנֵם֮"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 				Psalms 59:16 w320205"ינועון"
# 					BHS: hiphil-imperfect-3mp
# 					OSM: qal-imperfect-3mp
# 				Job 13:27 w339494"תָ֘שֵׂ֤ם"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: qal-imperfect-2ms
# 				Job 31:5 w343449"תַּ֖חַשׁ"
# 					BHS: hiphil-wayyiqtol-3fs
# 					OSM: qal-wayyiqtol-3fs
# 				Job 32:17 w343999"אַעֲנֶ֣ה"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Job 39:12 w345938"ישׁוב"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 				Proverbs 4:16 w347933"יכשׁולו"
# 					BHS: hiphil-imperfect-3mp
# 					OSM: qal-imperfect-3mp
# 				Proverbs 12:14 w350043"ישׁוב"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 				Proverbs 23:5 w353035"תעוף"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: qal-imperfect-2ms
# 				Daniel 9:24 w376322"חתם"
# 					BHS: hiphil-inf cons-???
# 					OSM: qal-inf cons-_??
# 	piel            (   10x)
# 				Judges 5:13 w130132"יְרַ֣ד"
# 					BHS: piel-imperfect-3ms
# 					OSM: qal-perfect-3ms
# 				Judges 5:13 w130138"יְרַד"
# 					BHS: piel-imperfect-3ms
# 					OSM: qal-perfect-3ms
# 				Judges 14:15 w136594"יָרְשֵׁ֕נוּ"
# 					BHS: piel-inf cons-???
# 					OSM: qal-inf cons-_??
# 				Isaiah 10:30 w216030"צַהֲלִ֥י"
# 					BHS: piel-imperative-2fs
# 					OSM: qal-imperative-2fs
# 				Isaiah 52:7 w230407"נָּאו֨וּ"
# 					BHS: piel-perfect-3?p
# 					OSM: qal-perfect-3cp
# 				Jeremiah 15:11 w242412"שׁרותך"
# 					BHS: piel-perfect-1?s
# 					OSM: qal-perfect-1cs
# 				Ezekiel 9:1 w268086"קָרְב֖וּ"
# 					BHS: piel-imperative-2mp
# 					OSM: qal-imperative-2mp
# 				Psalms 77:11 w323360"חַלֹּ֣ותִי"
# 					BHS: piel-inf cons-???
# 					OSM: qal-inf cons-_??
# 				Psalms 87:7 w325533"חֹלְלִ֑ים"
# 					BHS: piel-part act-?mp
# 					OSM: qal-part act-_mp
# 				Song_of_songs 1:10 w357726"נָאו֤וּ"
# 					BHS: piel-perfect-3?p
# 					OSM: qal-perfect-3cp
# 	niphal          (    9x)
# 				Judges 5:5 w130018"נָזְל֖וּ"
# 					BHS: niphal-perfect-3?p
# 					OSM: qal-perfect-3cp
# 				2_Samuel 3:2 w161713"ילדו"
# 					BHS: niphal-wayyiqtol-3mp
# 					OSM: qal-wayyiqtol-3mp
# 				Isaiah 59:5 w232300"תִּבָּקַ֥ע"
# 					BHS: niphal-imperfect-3fs
# 					OSM: qal-imperfect-3fs
# 				Jeremiah 6:29 w238174"נָחַ֣ר"
# 					BHS: niphal-perfect-3ms
# 					OSM: qal-perfect-3ms
# 				Jeremiah 10:2 w239932"יֵחַ֥תּוּ"
# 					BHS: niphal-imperfect-3mp
# 					OSM: qal-imperfect-3mp
# 				Job 14:2 w339528"יִּמָּ֑ל"
# 					BHS: niphal-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# 				Job 21:13 w341291"יֵחָֽתּוּ"
# 					BHS: niphal-imperfect-3mp
# 					OSM: qal-imperfect-3mp
# 				Job 24:24 w342182"יִמָּֽלוּ"
# 					BHS: niphal-imperfect-3mp
# 					OSM: qal-imperfect-3mp
# 				Ecclesiastes 12:6 w363368"ירחק"
# 					BHS: niphal-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 	hithpael        (    3x)
# 				2_Samuel 22:8 w174382"תגעשׁ"
# 					BHS: hithpael-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3fs
# 				Isaiah 41:10 w226209"תִּשְׁתָּ֖ע"
# 					BHS: hithpael-imperfect-2ms
# 					OSM: qal-jussive-2ms
# 				Isaiah 41:23 w226437"נִשְׁתָּ֖עָה"
# 					BHS: hithpael-imperfect-1?p
# 					OSM: qal-cohortative-1cp
# 	hophal          (    2x)
# 				2_Kings 12:12 w202835"פקדים"
# 					BHS: hophal-part pass-?mp
# 					OSM: qal-part pass-_mp
# 				2_Kings 14:6 w203756"ימות"
# 					BHS: hophal-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 	pual            (    1x)
# 				Psalms 58:4 w319935"זֹ֣רוּ"
# 					BHS: pual-perfect-3?p
# 					OSM: qal-perfect-3cp
# qalpassive
# 	pual            (   14x)
# 	hophal          (    8x)
# 				Genesis 12:15 w5773"תֻּקַּ֥ח"
# 					BHS: hophal-wayyiqtol-3fs
# 					OSM: qalpassive-wayyiqtol-3fs
# 				Genesis 18:4 w7857"יֻקַּֽח"
# 					BHS: hophal-imperfect-3ms
# 					OSM: qalpassive-jussive-3ms
# 				Genesis 24:33 w11763"יישׂם"
# 					BHS: hophal-wayyiqtol-3ms
# 					OSM: qalpassive-wayyiqtol-3ms
# 				1_Kings 2:21 w177733"יֻתַּ֖ן"
# 					BHS: hophal-imperfect-3ms
# 					OSM: qalpassive-jussive-3ms
# 				Isaiah 33:1 w222956"תּוּשַּׁ֔ד"
# 					BHS: hophal-imperfect-2ms
# 					OSM: qalpassive-imperfect-2ms
# 				Ezekiel 15:3 w270911"יֻקַּ֤ח"
# 					BHS: hophal-imperfect-3ms
# 					OSM: qalpassive-imperfect-3ms
# 				Hosea 10:14 w293288"יוּשַּׁ֔ד"
# 					BHS: hophal-imperfect-3ms
# 					OSM: qalpassive-imperfect-3ms
# 				Job 28:2 w342604"יֻקָּ֑ח"
# 					BHS: hophal-imperfect-3ms
# 					OSM: qalpassive-imperfect-3ms
# 	qalpassive      (    4x)
# 				Exodus 3:2 w29676"אֻכָּֽל"
# 					BHS: qalpassive-part pass-?ms
# 					OSM: qalpassive-part pass-_ms
# 				Judges 13:8 w135895"יּוּלָּֽד"
# 					BHS: qalpassive-part pass-?ms
# 					OSM: qalpassive-part pass-_ms
# 				2_Kings 2:10 w195488"לֻקָּ֤ח"
# 					BHS: qalpassive-part pass-?ms
# 					OSM: qalpassive-part pass-_ms
# 				Proverbs 25:19 w353909"מוּעָ֑דֶת"
# 					BHS: qalpassive-part pass-?fs
# 					OSM: qalpassive-part pass-_fs
# 	qal             (    3x)
# 				Jeremiah 49:19 w261483"בָח֖וּר"
# 					BHS: qal-part pass-?ms
# 					OSM: qalpassive-part pass-_ms
# 				Job 33:25 w344274"רֻֽטֲפַ֣שׁ"
# 					BHS: qal-perfect-3ms
# 					OSM: qalpassive-perfect-3ms
# 				Song_of_songs 7:3 w358903"סוּגָ֖ה"
# 					BHS: qal-part pass-?fs
# 					OSM: qalpassive-part pass-_fs
# saphel
# 	pael            (    1x)
# shaphel
# 	shaphel         (   14x)
# tiphil
# 	tiphal          (    3x)
#
# stem (OSM ===> BHS): 286 cases
#
# ---------------------------------------------------------------------------------
# --- stem BHS ===> OSM
# ---------------------------------------------------------------------------------
#
# aphel
# 	aphel           (    3x)
# 	haphel          (    1x)
# 				Daniel 5:12 w373436"אַֽחֲוָיַ֨ת"
# 					BHS: aphel-inf cons-???
# 					OSM: haphel-inf cons-_??
# etpaal
# 	hithpaal        (    3x)
# 	ithpaal         (    2x)
# 				Daniel 3:19 w372031"אשׁתנו"
# 					BHS: etpaal-perfect-3ms
# 					OSM: ithpaal-perfect-3ms
# 				Daniel 6:8 w373987"אִתְיָעַ֜טוּ"
# 					BHS: etpaal-perfect-3mp
# 					OSM: ithpaal-perfect-3mp
# 	hithpael        (    1x)
# 				2_Chronicles 20:35 w416767"אֶתְחַבַּר֙"
# 					BHS: etpaal-perfect-3ms
# 					OSM: hithpael-perfect-3ms
# 	hithpolel       (    1x)
# 				Psalms 76:6 w323181"אֶשְׁתֹּולְל֨וּ"
# 					BHS: etpaal-perfect-3?p
# 					OSM: hithpolel-perfect-3cp
# 	ithpoel         (    1x)
# 				Daniel 4:16 w372698"אֶשְׁתֹּומַם֙"
# 					BHS: etpaal-perfect-3ms
# 					OSM: ithpoel-perfect-3ms
# etpeel
# 	ithpeel         (    3x)
# haphel
# 	haphel          (  141x)
# 	aphel           (   20x)
# 				Daniel 2:44 w371457"יְקִים֩"
# 					BHS: haphel-imperfect-3ms
# 					OSM: aphel-imperfect-3ms
# 				Daniel 3:22 w372100"מַחְצְפָ֔ה"
# 					BHS: haphel-part act-?fs
# 					OSM: aphel-part act-_fs
# 				Daniel 3:25 w372172"מַהְלְכִ֣ין"
# 					BHS: haphel-part act-?mp
# 					OSM: aphel-part act-_mp
# 				Daniel 4:9 w372536"תַּטְלֵ֣ל"
# 					BHS: haphel-imperfect-3fs
# 					OSM: aphel-imperfect-3fs
# 				Daniel 4:14 w372660"יְקִ֥ים"
# 					BHS: haphel-imperfect-3ms
# 					OSM: aphel-imperfect-3ms
# 				Daniel 4:34 w373161"מַהְלְכִ֣ין"
# 					BHS: haphel-part act-?mp
# 					OSM: aphel-part act-_mp
# 				Daniel 5:19 w373628"מָרִ֔ים"
# 					BHS: haphel-part act-?ms
# 					OSM: aphel-part act-_ms
# 				Daniel 5:19 w373634"מַשְׁפִּֽיל"
# 					BHS: haphel-part act-?ms
# 					OSM: aphel-part act-_ms
# 				Daniel 6:9 w374027"תְּקִ֥ים"
# 					BHS: haphel-imperfect-2ms
# 					OSM: aphel-imperfect-2ms
# 				Daniel 6:11 w374085"מֹודֵא֙"
# 					BHS: haphel-part act-?ms
# 					OSM: aphel-part act-_ms
# 				Daniel 6:28 w374518"מַצִּ֗ל"
# 					BHS: haphel-part act-?ms
# 					OSM: aphel-part act-_ms
# 				Daniel 7:2 w374585"מְגִיחָ֖ן"
# 					BHS: haphel-part act-?fp
# 					OSM: aphel-part act-_fp
# 				Daniel 7:7 w374708"מַדֱּקָ֔ה"
# 					BHS: haphel-part act-?fs
# 					OSM: aphel-part act-_fs
# 				Daniel 7:18 w374943"יַחְסְנ֤וּן"
# 					BHS: haphel-imperfect-3mp
# 					OSM: aphel-imperfect-3mp
# 				Daniel 7:19 w374973"מַדֲּקָ֔ה"
# 					BHS: haphel-part act-?fs
# 					OSM: aphel-part act-_fs
# 				Daniel 7:23 w375061"תַדְּקִנַּֽהּ"
# 					BHS: haphel-imperfect-3fs
# 					OSM: aphel-imperfect-3fs
# 				Ezra 5:5 w380131"יְתִיב֥וּן"
# 					BHS: haphel-imperfect-3mp
# 					OSM: aphel-imperfect-3mp
# 				Ezra 5:8 w380198"מַצְלַ֥ח"
# 					BHS: haphel-part act-?ms
# 					OSM: aphel-part act-_ms
# 				Ezra 6:5 w380545"תַחֵ֖ת"
# 					BHS: haphel-imperfect-2ms
# 					OSM: aphel-imperfect-2ms
# 				Ezra 6:14 w380746"מַצְלְחִ֔ין"
# 					BHS: haphel-part act-?mp
# 					OSM: aphel-part act-_mp
# 	peal            (    1x)
# 				Daniel 5:19 w373622"מַחֵ֔א"
# 					BHS: haphel-part act-?ms
# 					OSM: peal-part act-_ms
# hiphil
# 	hiphil          ( 9351x)
# 	qal             (   34x)
# 				Numbers 21:32 w83725"יירשׁ"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# 				Numbers 32:7 w90015"תנואון"
# 					BHS: hiphil-imperfect-2mp
# 					OSM: qal-imperfect-2mp
# 				2_Samuel 12:20 w166852"יָּ֗סֶךְ"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# 				2_Samuel 15:20 w169328"אנועך"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				2_Samuel 18:22 w171660"מֹצֵֽאת"
# 					BHS: hiphil-part act-?fs
# 					OSM: qal-part act-_fs
# 				2_Samuel 20:5 w173209"ייחר"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# 				1_Kings 18:36 w191138"עֲלֹ֣ות"
# 					BHS: hiphil-inf cons-???
# 					OSM: qal-inf cons-_??
# 				2_Kings 3:20 w196263"עֲלֹ֣ות"
# 					BHS: hiphil-inf cons-???
# 					OSM: qal-inf cons-_??
# 				2_Kings 3:24 w196364"יבו"
# 					BHS: hiphil-wayyiqtol-3mp
# 					OSM: qal-wayyiqtol-3mp
# 				2_Kings 9:30 w200970"תָּ֨שֶׂם"
# 					BHS: hiphil-wayyiqtol-3fs
# 					OSM: qal-wayyiqtol-3fs
# 				2_Kings 23:9 w210086"יַֽעֲלוּ֙"
# 					BHS: hiphil-imperfect-3mp
# 					OSM: qal-imperfect-3mp
# 				Isaiah 64:5 w233863"נָּ֤בֶל"
# 					BHS: hiphil-wayyiqtol-1?p
# 					OSM: qal-wayyiqtol-1cp
# 				Isaiah 65:9 w234110"הֹוצֵאתִ֤י"
# 					BHS: hiphil-perfect-1?s
# 					OSM: qal-perfect-1cs
# 				Jeremiah 2:36 w235976"תֵּזְלִ֥י"
# 					BHS: hiphil-imperfect-2fs
# 					OSM: qal-imperfect-2fs
# 				Jeremiah 4:19 w236889"אחולה"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-cohortative-1cs
# 				Jeremiah 5:28 w237620"יַצְלִ֑יחוּ"
# 					BHS: hiphil-imperfect-3mp
# 					OSM: qal-wayyiqtol-3mp
# 				Jeremiah 33:26 w253138"אשׁוב"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Jeremiah 49:39 w261867"אשׁוב"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Jeremiah 50:44 w262688"ארוצם"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Ezekiel 48:14 w290467"יעבור"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 				Joel 4:1 w295018"אשׁוב"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Jonah 4:6 w299397"יַּ֣עַל"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3ms
# 				Micah 5:11 w300804"הִכְרַתִּ֥י"
# 					BHS: hiphil-perfect-1?s
# 					OSM: qal-cohortative-1cs
# 				Psalms 54:7 w319335"ישׁוב"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 				Psalms 55:20 w319558"יַעֲנֵם֮"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 				Psalms 59:16 w320205"ינועון"
# 					BHS: hiphil-imperfect-3mp
# 					OSM: qal-imperfect-3mp
# 				Job 13:27 w339494"תָ֘שֵׂ֤ם"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: qal-imperfect-2ms
# 				Job 31:5 w343449"תַּ֖חַשׁ"
# 					BHS: hiphil-wayyiqtol-3fs
# 					OSM: qal-wayyiqtol-3fs
# 				Job 32:17 w343999"אַעֲנֶ֣ה"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: qal-imperfect-1cs
# 				Job 39:12 w345938"ישׁוב"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 				Proverbs 4:16 w347933"יכשׁולו"
# 					BHS: hiphil-imperfect-3mp
# 					OSM: qal-imperfect-3mp
# 				Proverbs 12:14 w350043"ישׁוב"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: qal-imperfect-3ms
# 				Proverbs 23:5 w353035"תעוף"
# 					BHS: hiphil-imperfect-2ms
# 					OSM: qal-imperfect-2ms
# 				Daniel 9:24 w376322"חתם"
# 					BHS: hiphil-inf cons-???
# 					OSM: qal-inf cons-_??
# 	niphal          (    4x)
# 				Exodus 16:7 w37525"תלונו"
# 					BHS: hiphil-imperfect-2mp
# 					OSM: niphal-imperfect-2mp
# 				Leviticus 21:9 w65106"תֵחֵ֖ל"
# 					BHS: hiphil-imperfect-3fs
# 					OSM: niphal-imperfect-3fs
# 				Numbers 14:36 w79137"ילונו"
# 					BHS: hiphil-wayyiqtol-3mp
# 					OSM: niphal-wayyiqtol-3mp
# 				1_Samuel 13:8 w147978"ייחל"
# 					BHS: hiphil-wayyiqtol-3ms
# 					OSM: niphal-wayyiqtol-3ms
# 	piel            (    3x)
# 				Deuteronomy 26:12 w107418"עְשֵׂר"
# 					BHS: hiphil-inf cons-???
# 					OSM: piel-inf cons-_??
# 				Psalms 18:51 w313162"מגדל"
# 					BHS: hiphil-part act-?ms
# 					OSM: piel-part act-_ms
# 				Nehemiah 10:39 w389163"עְשֵׂ֣ר"
# 					BHS: hiphil-inf cons-???
# 					OSM: piel-inf cons-_??
# 	hophal          (    1x)
# 				Proverbs 11:25 w349860"יֹורֶֽא"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: hophal-imperfect-3ms
# hishtaphel
# 	hishtaphel      (   95x)
# 	hithpael        (   77x)
# 				Genesis 18:2 w7840"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 19:1 w8447"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 23:7 w10836"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 23:12 w10939"יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 24:26 w11611"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 24:52 w12151"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 33:3 w18135"יִּשְׁתַּ֤חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 33:7 w18201"יִּֽשְׁתַּחֲו֑וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 33:7 w18209"יִּֽשְׁתַּחֲוֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 37:10 w20376"הִשְׁתַּחֲוֹ֥ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Genesis 42:6 w23531"יִּשְׁתַּֽחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 43:26 w24672"יִּשְׁתַּחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Genesis 47:31 w27292"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Genesis 48:12 w27526"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Exodus 12:27 w35322"יִּֽשְׁתַּחֲוּֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Exodus 18:7 w38590"יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Exodus 32:8 w46673"יִּשְׁתַּֽחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Exodus 34:8 w47947"יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Leviticus 26:1 w68167"הִֽשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Numbers 22:31 w84474"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Deuteronomy 17:3 w102991"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Joshua 5:14 w115320"יִּשְׁתָּ֔חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Judges 2:12 w128463"יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Judges 2:17 w128557"יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Judges 7:15 w131830"יִּשְׁתָּ֑חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 1:3 w141597"הִֽשְׁתַּחֲוֹ֧ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				1_Samuel 1:19 w141909"יִּֽשְׁתַּחֲווּ֙"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				1_Samuel 1:28 w142112"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 2:36 w142850"הִשְׁתַּחֲוֹ֣ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				1_Samuel 15:31 w150183"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 20:41 w154312"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 24:9 w156189"יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Samuel 28:14 w158837"יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 1:2 w160523"יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 9:6 w165082"יִּשְׁתָּ֑חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 9:8 w165122"יִּשְׁתַּ֕חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 12:20 w166861"יִּשְׁתָּ֑חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 14:22 w168581"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 14:33 w168865"יִּשְׁתַּ֨חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 15:5 w168988"הִשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				2_Samuel 18:21 w171622"יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 18:28 w171799"יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Samuel 24:20 w175932"יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 1:23 w176556"יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 1:47 w177139"יִּשְׁתַּ֥חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 1:53 w177267"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 2:19 w177689"יִּשְׁתַּ֣חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Kings 11:33 w185700"יִּֽשְׁתַּחֲווּ֮"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				1_Kings 16:31 w189749"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Kings 2:15 w195624"יִּשְׁתַּחֲווּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Kings 5:18 w197911"הִשְׁתַּחֲוֹ֨ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				2_Kings 17:16 w205932"יִּֽשְׁתַּחֲווּ֙"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Kings 21:3 w208743"יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				2_Kings 21:21 w209152"יִּשְׁתַּ֖חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Isaiah 2:20 w212871"הִֽשְׁתַּחֲוֹ֔ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Isaiah 44:15 w227628"יִּשְׁתָּ֔חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Isaiah 66:23 w234974"הִשְׁתַּחֲוֹ֥ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Jeremiah 1:16 w235290"יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Jeremiah 7:2 w238236"הִֽשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Jeremiah 16:11 w242886"יִּשְׁתַּחֲו֣וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Jeremiah 22:9 w245500"יִּֽשְׁתַּחֲו֛וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Jeremiah 26:2 w247887"הִשְׁתַּחֲוֹ֣ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Ezekiel 46:9 w289272"הִֽשְׁתַּחֲוֹ֗ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Zechariah 14:16 w309317"הִֽשְׁתַּחֲוֹת֙"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Zechariah 14:17 w309342"הִֽשְׁתַּחֲוֹ֔ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				Psalms 106:19 w329153"יִּשְׁתַּחֲו֗וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				Job 1:20 w336496"יִּשְׁתָּֽחוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				Nehemiah 8:6 w387353"יִּשְׁתַּחֲוֻּ֛"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				1_Chronicles 21:21 w402295"יִּשְׁתַּ֧חוּ"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# 				1_Chronicles 29:20 w406599"יִּֽשְׁתַּחֲו֛וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 7:3 w410083"יִּֽשְׁתַּֽחֲו֔וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 7:22 w410599"יִּשְׁתַּחֲו֥וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 20:18 w416391"הִֽשְׁתַּחֲוֹ֖ת"
# 					BHS: hishtaphel-inf cons-???
# 					OSM: hithpael-inf cons-_??
# 				2_Chronicles 24:17 w418632"יִּֽשְׁתַּחֲו֖וּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 29:29 w421654"יִּֽשְׁתַּחֲוֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 29:30 w421685"יִּֽשְׁתַּחֲוֽוּ"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hithpael-wayyiqtol-3mp
# 				2_Chronicles 33:3 w423941"יִּשְׁתַּ֨חוּ֙"
# 					BHS: hishtaphel-wayyiqtol-3ms
# 					OSM: hithpael-wayyiqtol-3ms
# hithpaal
# 	hithpaal        (   28x)
# 	hithpolel       (    1x)
# 				Daniel 5:23 w373712"הִתְרֹומַ֡מְתָּ"
# 					BHS: hithpaal-perfect-2ms
# 					OSM: hithpolel-perfect-2ms
# hithpael
# 	hithpael        (  830x)
# 	hithpolel       (  104x)
# 	hithpalpel      (   20x)
# 				Genesis 19:16 w8774"יִּתְמַהְמָ֓הּ"
# 					BHS: hithpael-wayyiqtol-3ms
# 					OSM: hithpalpel-wayyiqtol-3ms
# 				Genesis 43:10 w24315"הִתְמַהְמָ֑הְנוּ"
# 					BHS: hithpael-perfect-1?p
# 					OSM: hithpalpel-perfect-1cp
# 				Exodus 12:39 w35556"הִתְמַהְמֵ֔הַּ"
# 					BHS: hithpael-inf cons-???
# 					OSM: hithpalpel-inf cons-_??
# 				Judges 3:26 w129260"הִֽתְמַהְמְהָ֑ם"
# 					BHS: hithpael-inf cons-???
# 					OSM: hithpalpel-inf cons-_??
# 				2_Samuel 15:28 w169539"מִתְמַהְמֵ֔הַּ"
# 					BHS: hithpael-part act-?ms
# 					OSM: hithpalpel-part act-_ms
# 				Isaiah 29:9 w221496"הִתְמַהְמְה֣וּ"
# 					BHS: hithpael-imperative-2mp
# 					OSM: hithpalpel-imperative-2mp
# 				Isaiah 29:9 w221499"הִשְׁתַּֽעַשְׁע֖וּ"
# 					BHS: hithpael-imperative-2mp
# 					OSM: hithpalpel-imperative-2mp
# 				Jeremiah 4:24 w236973"הִתְקַלְקָֽלוּ"
# 					BHS: hithpael-perfect-3?p
# 					OSM: hithpalpel-perfect-3cp
# 				Jeremiah 51:58 w263751"תִּתְעַרְעָ֔ר"
# 					BHS: hithpael-imperfect-3fs
# ...
# 					OSM: piel-perfect-3ms
# 				Daniel 4:18 w372762"יִשְׁכְּנָ֖ן"
# 					BHS: peal-imperfect-3fp
# 					OSM: peal-imperfect-3ms
# 				Daniel 6:13 w374114"אָמְרִ֥ין"
# 					BHS: peal-part act-?mp
# 					OSM: peal-part act-_ms
# 				Ezra 3:3 w379173"יעל"
# 					BHS: hiphil-wayyiqtol-3mp
# 					OSM: hiphil-wayyiqtol-3ms
# 				Ezra 4:15 w379837"עָבְדִ֣ין"
# 					BHS: peal-part act-?mp
# 					OSM: peal-part act-_ms
# 				2_Chronicles 2:5 w407372"יְכַלְכְּלֻ֑הוּ"
# 					BHS: piel-imperfect-3mp
# 					OSM: pilpel-imperfect-3ms
# 	?               (   22x)
# 				Leviticus 14:43 w61203"חִלֵּ֣ץ"
# 					BHS: piel-inf cons-???
# 					OSM: piel-perfect-3ms
# 				Joshua 6:13 w115662"הולך"
# 					BHS: qal-inf abs-???
# 					OSM: qal-part act-_ms
# 				Judges 16:25 w137799"טוב"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				Judges 19:11 w139359"רַ֣ד"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				2_Samuel 15:8 w169063"ישׁיב"
# 					BHS: qal-inf abs-???
# 					OSM: hiphil-imperfect-3ms
# 				Isaiah 42:20 w226836"ראית"
# 					BHS: qal-inf abs-???
# 					OSM: qal-perfect-2ms
# 				Isaiah 43:8 w227058"הֹוצִ֥יא"
# 					BHS: hiphil-inf cons-???
# 					OSM: hiphil-imperative-2ms
# 				Jeremiah 6:11 w237842"שְׁפֹ֤ךְ"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Jeremiah 17:23 w243527"שׁומע"
# 					BHS: qal-inf cons-???
# 					OSM: qal-part act-_ms
# 				Ezekiel 11:7 w268985"הֹוצִ֥יא"
# 					BHS: hiphil-inf cons-???
# 					OSM: hiphil-perfect-3ms
# 				Ezekiel 24:4 w276640"מַלֵּֽא"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Hosea 11:3 w293346"קָחָ֖ם"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				Amos 9:1 w297816"בְצַ֨עַם֙"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Nahum 2:2 w301674"צַפֵּה"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301676"חַזֵּ֣ק"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301678"אַמֵּ֥ץ"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Psalms 56:8 w319699"פַּלֶּט"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Psalms 56:8 w319704"הֹורֵ֬ד"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# 				Job 11:5 w338854"דַּבֵּ֑ר"
# 					BHS: piel-inf cons-???
# 					OSM: piel-imperative-2ms
# 				Job 17:3 w340324"עָרְבֵ֣נִי"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Proverbs 17:14 w351479"הִ֝תְגַּלַּ֗ע"
# 					BHS: hithpael-inf cons-???
# 					OSM: hithpael-perfect-3ms
# 				Proverbs 25:2 w353725"הַסְתֵּ֣ר"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
#
# number (OSM ===> BHS): 143 cases
#
# ---------------------------------------------------------------------------------
# --- number BHS ===> OSM
# ---------------------------------------------------------------------------------
#
# ?
# 	?               ( 7432x)
# 	s               (   22x)
# 				Leviticus 14:43 w61203"חִלֵּ֣ץ"
# 					BHS: piel-inf cons-???
# 					OSM: piel-perfect-3ms
# 				Joshua 6:13 w115662"הולך"
# 					BHS: qal-inf abs-???
# 					OSM: qal-part act-_ms
# 				Judges 16:25 w137799"טוב"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				Judges 19:11 w139359"רַ֣ד"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				2_Samuel 15:8 w169063"ישׁיב"
# 					BHS: qal-inf abs-???
# 					OSM: hiphil-imperfect-3ms
# 				Isaiah 42:20 w226836"ראית"
# 					BHS: qal-inf abs-???
# 					OSM: qal-perfect-2ms
# 				Isaiah 43:8 w227058"הֹוצִ֥יא"
# 					BHS: hiphil-inf cons-???
# 					OSM: hiphil-imperative-2ms
# 				Jeremiah 6:11 w237842"שְׁפֹ֤ךְ"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Jeremiah 17:23 w243527"שׁומע"
# 					BHS: qal-inf cons-???
# 					OSM: qal-part act-_ms
# 				Ezekiel 11:7 w268985"הֹוצִ֥יא"
# 					BHS: hiphil-inf cons-???
# 					OSM: hiphil-perfect-3ms
# 				Ezekiel 24:4 w276640"מַלֵּֽא"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Hosea 11:3 w293346"קָחָ֖ם"
# 					BHS: qal-inf cons-???
# 					OSM: qal-perfect-3ms
# 				Amos 9:1 w297816"בְצַ֨עַם֙"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Nahum 2:2 w301674"צַפֵּה"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301676"חַזֵּ֣ק"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Nahum 2:2 w301678"אַמֵּ֥ץ"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Psalms 56:8 w319699"פַּלֶּט"
# 					BHS: piel-inf abs-???
# 					OSM: piel-imperative-2ms
# 				Psalms 56:8 w319704"הֹורֵ֬ד"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# 				Job 11:5 w338854"דַּבֵּ֑ר"
# 					BHS: piel-inf cons-???
# 					OSM: piel-imperative-2ms
# 				Job 17:3 w340324"עָרְבֵ֣נִי"
# 					BHS: qal-inf cons-???
# 					OSM: qal-imperative-2ms
# 				Proverbs 17:14 w351479"הִ֝תְגַּלַּ֗ע"
# 					BHS: hithpael-inf cons-???
# 					OSM: hithpael-perfect-3ms
# 				Proverbs 25:2 w353725"הַסְתֵּ֣ר"
# 					BHS: hiphil-inf abs-???
# 					OSM: hiphil-imperative-2ms
# 	p               (    2x)
# 				Jeremiah 25:7 w247159"הכעסוני"
# 					BHS: hiphil-inf cons-???
# 					OSM: hiphil-perfect-3cp
# 				Psalms 30:4 w314845"יורדי"
# 					BHS: qal-inf cons-???
# 					OSM: qal-part act-_mp
# p
# 	p               (19084x)
# 	s               (   61x)
# 				Genesis 27:29 w14112"ישׁתחו"
# 					BHS: hishtaphel-imperfect-3mp
# 					OSM: hishtaphel-jussive-3ms
# 				Genesis 29:27 w15428"נִתְּנָ֨ה"
# 					BHS: qal-imperfect-1?p
# 					OSM: niphal-weqatal-3fs
# 				Genesis 43:28 w24704"ישׁתחו"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hishtaphel-wayyiqtol-3ms
# 				Leviticus 21:5 w65032"יקרחה"
# 					BHS: qal-imperfect-3mp
# 					OSM: qal-imperfect-3fs
# 				Numbers 34:4 w91467"היה"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-weqatal-3ms
# 				Deuteronomy 2:1 w93765"נָּ֥סָב"
# 					BHS: qal-wayyiqtol-1?p
# 					OSM: qal-wayyiqtol-1cs
# 				Deuteronomy 21:7 w104935"שׁפכה"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-perfect-3fs
# 				Joshua 15:4 w121459"היה"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-perfect-3ms
# 				Joshua 18:12 w123142"היה"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-weqatal-3ms
# 				Joshua 18:14 w123192"היה"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-weqatal-3ms
# 				Joshua 18:19 w123292"היה"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-weqatal-3ms
# 				Judges 1:27 w128006"ישׁב"
# 					BHS: qal-part act-?mp
# 					OSM: qal-part act-_ms
# 				1_Samuel 2:10 w142246"מריבו"
# 					BHS: hiphil-part act-?mp
# 					OSM: hiphil-part act-_ms
# 				1_Samuel 12:10 w147438"יאמר"
# 					BHS: qal-wayyiqtol-3mp
# 					OSM: qal-wayyiqtol-3ms
# 				1_Samuel 13:19 w148221"אמר"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-perfect-3ms
# 				2_Samuel 14:30 w168767"הוצתיה"
# 					BHS: hiphil-imperative-2mp
# 					OSM: hiphil-weqatal-1cs
# 				1_Kings 9:9 w183907"ישׁתחו"
# 					BHS: hishtaphel-wayyiqtol-3mp
# 					OSM: hishtaphel-wayyiqtol-3ms
# 				1_Kings 10:5 w184433"משׁרתו"
# 					BHS: piel-part act-?mp
# 					OSM: piel-part act-_ms
# 				1_Kings 12:7 w186068"ידבר"
# 					BHS: piel-wayyiqtol-3mp
# 					OSM: piel-wayyiqtol-3ms
# 				1_Kings 22:49 w194661"נשׁברה"
# 					BHS: niphal-perfect-3?p
# 					OSM: niphal-perfect-3fs
# 				2_Kings 20:18 w208604"יקח"
# 					BHS: qal-imperfect-3mp
# 					OSM: qal-imperfect-3ms
# 				2_Kings 22:5 w209324"יתנה"
# 					BHS: qal-imperfect-3mp
# 					OSM: qal-jussive-3ms
# 				2_Kings 24:10 w211080"עלה"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-perfect-3ms
# 				Isaiah 52:5 w230379"משׁלו"
# 					BHS: qal-part act-?mp
# 					OSM: qal-part act-_ms
# 				Jeremiah 2:15 w235626"נצתה"
# 					BHS: niphal-perfect-3?p
# 					OSM: niphal-perfect-3fs
# 				Jeremiah 6:25 w238115"תצאי"
# 					BHS: qal-imperfect-2mp
# 					OSM: qal-jussive-2fs
# 				Jeremiah 6:25 w238123"תלכי"
# 					BHS: qal-imperfect-2mp
# 					OSM: qal-jussive-2fs
# 				Jeremiah 13:20 w241574"שׂאי"
# 					BHS: qal-imperative-2mp
# 					OSM: qal-imperative-2fs
# 				Jeremiah 13:20 w241577"ראי"
# 					BHS: qal-imperative-2mp
# 					OSM: qal-imperative-2fs
# 				Jeremiah 22:6 w245447"נושׁבה"
# 					BHS: niphal-perfect-3?p
# 					OSM: niphal-part pass-_fs
# 				Jeremiah 23:36 w246638"תִזְכְּרוּ"
# 					BHS: qal-imperfect-2mp
# 					OSM: qal-imperfect-2ms
# 				Jeremiah 42:20 w258271"התעתים"
# 					BHS: hiphil-perfect-2mp
# 					OSM: hiphil-perfect-1cs
# 				Jeremiah 48:20 w260672"הילילי"
# 					BHS: hiphil-imperative-2mp
# 					OSM: hiphil-imperative-2fs
# 				Jeremiah 48:20 w260674"זעקי"
# 					BHS: qal-imperative-2mp
# 					OSM: qal-imperative-2fs
# 				Jeremiah 50:6 w261981"היה"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-perfect-3ms
# 				Jeremiah 50:11 w262067"תשׂמחי"
# 					BHS: qal-imperfect-2mp
# 					OSM: qal-imperfect-2fs
# 				Jeremiah 50:11 w262069"תעלזי"
# 					BHS: qal-imperfect-2mp
# 					OSM: qal-imperfect-2fs
# 				Jeremiah 50:11 w262073"תפושׁי"
# 					BHS: qal-imperfect-2mp
# 					OSM: qal-imperfect-2fs
# 				Jeremiah 50:11 w262078"תצהלי"
# 					BHS: qal-imperfect-2mp
# 					OSM: qal-imperfect-2fs
# 				Ezekiel 4:12 w266321"תְּעֻגֶ֖נָה"
# 					BHS: qal-imperfect-3fp
# 					OSM: qal-imperfect-2ms
# 				Ezekiel 7:21 w267523"חללה"
# 					BHS: piel-perfect-3?p
# 					OSM: piel-weqatal-3ms
# 				Ezekiel 23:43 w276451"יזנה"
# 					BHS: qal-imperfect-3mp
# 					OSM: qal-imperfect-3ms
# 				Ezekiel 35:12 w282361"שׁממה"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-perfect-3fs
# 				Ezekiel 37:22 w283670"יהיה"
# 					BHS: qal-imperfect-3mp
# 					OSM: qal-imperfect-3ms
# 				Psalms 24:6 w314028"דרשׁו"
# 					BHS: qal-part act-?mp
# 					OSM: qal-part act-_ms
# 				Psalms 73:2 w322548"נטוי"
# 					BHS: qal-perfect-3?p
# 					OSM: qal-part pass-_ms
# 				Psalms 73:2 w322552"שׁפכה"
# 					BHS: pual-perfect-3?p
# 					OSM: qalpassive-perfect-3fs
# 				Psalms 119:171 w332615"תַּבַּ֣עְנָה"
# 					BHS: hiphil-imperfect-3fp
# 					OSM: hiphil-imperfect-3fs
# 				Job 6:29 w337840"שׁבי"
# 					BHS: qal-imperative-2mp
# 					OSM: qal-imperative-2fs
# 				Job 24:1 w341931"ידעו"
# 					BHS: qal-part act-?mp
# 					OSM: qal-part act-_ms
# 				Job 31:31 w343716"נִשְׂבָּֽע"
# 					BHS: qal-imperfect-1?p
# 					OSM: niphal-part pass-_ms
# 				Proverbs 1:20 w347111"תָּרֹ֑נָּה"
# 					BHS: qal-imperfect-3fp
# 					OSM: qal-imperfect-3fs
# 				Proverbs 5:13 w348147"מְלַמְּדַ֗י"
# 					BHS: piel-part act-?mp
# 					OSM: piel-part act-_ms
# 				Proverbs 8:3 w348873"תָּרֹֽנָּה"
# 					BHS: qal-imperfect-3fp
# 					OSM: qal-imperfect-3fs
# 				Ruth 2:20 w356708"גֹּאֲלֵ֖נוּ"
# 					BHS: qal-part act-?mp
# 					OSM: qal-part act-_ms
# 				Esther 9:27 w369840"קבל"
# 					BHS: piel-perfect-3?p
# 					OSM: piel-perfect-3ms
# 				Daniel 4:18 w372762"יִשְׁכְּנָ֖ן"
# 					BHS: peal-imperfect-3fp
# 					OSM: peal-imperfect-3ms
# 				Daniel 6:13 w374114"אָמְרִ֥ין"
# 					BHS: peal-part act-?mp
# 					OSM: peal-part act-_ms
# 				Ezra 3:3 w379173"יעל"
# 					BHS: hiphil-wayyiqtol-3mp
# 					OSM: hiphil-wayyiqtol-3ms
# 				Ezra 4:15 w379837"עָבְדִ֣ין"
# 					BHS: peal-part act-?mp
# 					OSM: peal-part act-_ms
# 				2_Chronicles 2:5 w407372"יְכַלְכְּלֻ֑הוּ"
# 					BHS: piel-imperfect-3mp
# 					OSM: pilpel-imperfect-3ms
# 	?               (    3x)
# 				2_Samuel 6:20 w163891"נִגְלֹ֖ות"
# 					BHS: niphal-part act-?fp
# 					OSM: niphal-inf cons-_??
# 				Isaiah 37:30 w224859"אכול"
# 					BHS: qal-imperative-2mp
# 					OSM: qal-inf abs-_??
# 				Hosea 6:9 w292339"חַכֵּ֨י"
# 					BHS: piel-part act-?mp
# 					OSM: piel-inf cons-_??
# s
# 	s               (46822x)
# 	p               (   33x)
# 				Joshua 6:7 w115495"יאמרו"
# 					BHS: qal-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3mp
# 				Joshua 9:7 w117882"יאמרו"
# 					BHS: qal-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3mp
# 				1_Samuel 15:16 w149896"יאמרו"
# 					BHS: qal-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3mp
# 				1_Samuel 24:5 w156063"איביך"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# 				2_Samuel 18:8 w171255"נפצית"
# 					BHS: niphal-part act-?fs
# 					OSM: niphal-part pass-_fp
# 				2_Samuel 23:37 w175405"נשׂאי"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# 				1_Kings 12:3 w185987"יבאו"
# 					BHS: qal-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3mp
# 				1_Kings 12:21 w186447"יבאו"
# 					BHS: qal-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3mp
# 				2_Kings 14:13 w203921"יבאו"
# 					BHS: qal-wayyiqtol-3ms
# 					OSM: qal-wayyiqtol-3mp
# 				2_Kings 21:12 w208950"שׁמעיו"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# 				Isaiah 8:17 w215019"קִוֵּ֖יתִֽי"
# 					BHS: piel-perfect-1?s
# 					OSM: piel-weqatal-1cp
# 				Isaiah 16:3 w217496"הביאו"
# 					BHS: hiphil-imperative-2fs
# 					OSM: hiphil-imperative-2mp
# 				Isaiah 32:11 w222807"רְגָ֖זָה"
# 					BHS: qal-imperative-2ms
# 					OSM: qal-imperative-2fp
# 				Isaiah 32:11 w222809"פְּשֹׁ֣טָֽה"
# 					BHS: qal-imperative-2ms
# 					OSM: qal-imperative-2fp
# 				Isaiah 32:11 w222811"עֹ֔רָה"
# 					BHS: qal-imperative-2ms
# 					OSM: qal-imperative-2fp
# 				Isaiah 32:11 w222813"חֲגֹ֖ורָה"
# 					BHS: qal-imperative-2ms
# 					OSM: qal-imperative-2fp
# 				Isaiah 52:2 w230332"התפתחו"
# 					BHS: hithpael-imperative-2fs
# 					OSM: hithpael-imperative-2mp
# 				Jeremiah 3:19 w236442"תקראו"
# 					BHS: qal-imperfect-2fs
# 					OSM: qal-imperfect-2mp
# 				Jeremiah 3:19 w236448"תשׁובו"
# 					BHS: qal-imperfect-2fs
# 					OSM: qal-imperfect-2mp
# 				Ezekiel 46:9 w289297"יצאו"
# 					BHS: qal-imperfect-3ms
# 					OSM: qal-imperfect-3mp
# 				Ezekiel 47:12 w289958"היו"
# 					BHS: qal-perfect-3ms
# 					OSM: qal-weqatal-3cp
# 				Nahum 3:7 w301970"רֹאַ֨יִךְ֙"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# 				Zechariah 11:5 w308089"רֹ֣עֵיהֶ֔ם"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# 				Psalms 11:1 w311986"נודו"
# 					BHS: qal-imperative-2fs
# 					OSM: qal-imperative-2mp
# 				Psalms 58:6 w319963"מְחֻכָּֽם"
# 					BHS: pual-part pass-?ms
# 					OSM: pual-part pass-_mp
# 				Psalms 139:20 w334536"נָשֻׂ֖א"
# 					BHS: qal-part pass-?ms
# 					OSM: qal-perfect-3cp
# 				Psalms 140:10 w334672"יכסומו"
# 					BHS: piel-imperfect-3ms
# 					OSM: piel-jussive-3mp
# 				Proverbs 8:35 w349166"מצאי"
# 					BHS: qal-perfect-3ms
# 					OSM: qal-part act-_mp
# 				Proverbs 24:17 w353529"אויביך"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# 				Proverbs 28:16 w354741"שׂנאי"
# 					BHS: qal-part act-?ms
# 					OSM: qal-part act-_mp
# 				Daniel 5:12 w373439"מְשָׁרֵ֣א"
# 					BHS: pael-part act-?ms
# 					OSM: pael-part act-_mp
# 				Daniel 11:10 w377147"יתגרו"
# 					BHS: hithpael-imperfect-3ms
# 					OSM: hithpael-imperfect-3mp
# 				Nehemiah 3:15 w384557"יעמידו"
# 					BHS: hiphil-imperfect-3ms
# 					OSM: hiphil-imperfect-3mp
# 	?               (   22x)
# 				Numbers 11:15 w77104"אֶרְאֶ֖ה"
# 					BHS: qal-imperfect-1?s
# 					OSM: qal-inf cons-_??
# 				2_Samuel 19:43 w173041"נִשֵּׂ֥את"
# 					BHS: niphal-part act-?fs
# 					OSM: niphal-inf abs-_??
# 				1_Kings 6:19 w180469"תִתֵּ֣ן"
# 					BHS: qal-imperfect-2ms
# 					OSM: qal-inf cons-_??
# 				1_Kings 22:30 w194277"הִתְחַפֵּשׂ֙"
# 					BHS: hithpael-imperative-2ms
# 					OSM: hithpael-inf abs-_??
# 				1_Kings 22:30 w194279"בֹ֣א"
# 					BHS: qal-imperative-2ms
# 					OSM: qal-inf abs-_??
# 				Isaiah 24:19 w219967"רֹ֥עָה"
# 					BHS: qal-part act-?fs
# 					OSM: qal-inf abs-_??
# 				Jeremiah 25:3 w247070"אַשְׁכֵּ֥ים"
# 					BHS: hiphil-imperfect-1?s
# 					OSM: hiphil-inf abs-_??
# 				Jeremiah 50:34 w262501"הִרְגִּ֣יעַ"
# 					BHS: hiphil-perfect-3ms
# 					OSM: hiphil-inf cons-_??
# 				Jeremiah 50:34 w262506"הִרְגִּ֖יז"
# 					BHS: hiphil-perfect-3ms
# 					OSM: hiphil-inf cons-_??
# 				Ezekiel 21:24 w274934"בָּרֵ֔א"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
# 				Ezekiel 21:24 w274939"בָּרֵֽא"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
# 				Ezekiel 24:2 w276583"כתוב"
# 					BHS: qal-imperative-2ms
# 					OSM: qal-inf abs-_??
# 				Ezekiel 24:10 w276738"הָתֵ֖ם"
# 					BHS: hiphil-imperative-2ms
# 					OSM: hiphil-inf abs-_??
# 				Amos 4:5 w296309"קַטֵּ֤ר"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
# 				Psalms 51:4 w318895"הרבה"
# 					BHS: hiphil-imperative-2ms
# 					OSM: hiphil-inf abs-_??
# 				Psalms 65:11 w320927"רַ֭וֵּה"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
# 				Psalms 65:11 w320928"נַחֵ֣ת"
# 					BHS: piel-imperative-2ms
# 					OSM: piel-inf abs-_??
# 				Proverbs 13:20 w350342"הלוך"
# 					BHS: qal-part act-?ms
# 					OSM: qal-inf abs-_??
# 				Ezra 3:12 w379465"יָסְדֹ֔ו"
# 					BHS: qal-part act-?ms
# 					OSM: qal-inf cons-_??
# 				2_Chronicles 18:29 w415549"הִתְחַפֵּשׂ֙"
# 					BHS: hithpael-imperative-2ms
# 					OSM: hithpael-inf abs-_??
# 				2_Chronicles 18:29 w415551"בֹ֣וא"
# 					BHS: qal-imperative-2ms
# 					OSM: qal-inf abs-_??
# 				2_Chronicles 34:7 w424602"הֵדַ֔ק"
# 					BHS: hiphil-perfect-3ms
# 					OSM: hiphil-inf cons-_??
#
# number (BHS ===> OSM): 143 cases
#
# number: 143 cases
#
# All features: 832 cases

# %%
closerLook |= cases
print("{} cases for a closer look".format(len(closerLook)))
# Out:
# 1180 cases for a closer look

# %% [markdown]
# # Result
#
# We are going to list all cases in [verbs.tsv](verbs.tsv) .

# %%
fields = """
    passage
    node
    occurrence
    OSMmorph
    stemOSM
    stemBHS
    conjOSM
    conjBHS
    personOSM
    personBHS
    genderOSM
    genderBHS
    numberOSM
    numberBHS
""".strip().split()
lineFormat = ("{}\t" * (len(fields) - 1)) + "{}\n"

with open("verbs.tsv", "w") as fh:
    fh.write(lineFormat.format(*fields))
    for w in sorted(closerLook):
        fh.write(
            lineFormat.format(
                "{} {}:{}".format(*T.sectionFromNode(w)),
                w,
                F.g_word_utf8.v(w),
                F.osm.v(w),
                getStemOSMX(w),
                getStemBHSX(w),
                getConjOSMX(w),
                getConjBHSX(w),
                getPersonOSM(w),
                getPersonBHS(w),
                getGenderOSM(w),
                getGenderBHS(w),
                getNumberOSM(w),
                getNumberBHS(w),
            )
        )
